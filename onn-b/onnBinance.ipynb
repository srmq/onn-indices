# %% [markdown]
# # Computing daily ONN index on Binance

# %% [markdown]
# ## Getting all available symbols on Binance

# %% [markdown]
# In this section, we just get all available assets on Binance, generating at the end a file named `all-binance-tokens.csv`. Each line in this file contains the asset symbol two times, separated by comma (e.g. `ETH,ETH`). This is because we will use it afterwards in the __[`bnbFetchCoinData.py`](https://github.com/srmq/bnbfetch-coin-data)__ script, which expects the CSV file of lines in the format `asset_description,asset_symbol`, and we don't care about descriptions here.

# %%
import httpx
import pandas as pd

# %%
binanceBaseURL = 'https://api.binance.com'

# %%
async def getExchangeInfo():
    spotExchangeInfoURL = binanceBaseURL + "/api/v3/exchangeInfo"

    async with httpx.AsyncClient() as client:
        r = await client.get(spotExchangeInfoURL)
    return r.json()

# %%
exchangeInfo = await getExchangeInfo()

# %%
#blacklist = None
#with open('blacklist.txt', 'r') as f:
#    blacklist = f.read().split(',')
# blacklist should be disabled for now, we need coin data for every coin

# %%
baseAssets = set()
#for coinSymbol in exchangeInfo['symbols']:
#    if not (coinSymbol['baseAsset'].lower() in blacklist):
#        baseAssets.add(coinSymbol['baseAsset'])

# %%
for coinSymbol in exchangeInfo['symbols']:
    baseAssets.add(coinSymbol['baseAsset'])

# %%
def notLeveraged(asset):
    return not (asset.endswith('UP') or asset.endswith('DOWN') or asset.endswith('BEAR') or asset.endswith('BULL'))

# %%
baseAssets = set(filter(notLeveraged, baseAssets))

# %%
baseAssets
# Out:
# {'1INCH',
#  'AAVE',
#  'ACA',
#  'ACH',
#  'ACM',
#  'ADA',
#  'ADX',
#  'AE',
#  'AERGO',
#  'AGI',
#  'AGIX',
#  'AGLD',
#  'AION',
#  'AKRO',
#  'ALCX',
#  'ALGO',
#  'ALICE',
#  'ALPACA',
#  'ALPHA',
#  'ALPINE',
#  'AMB',
#  'AMP',
#  'ANC',
#  'ANKR',
#  'ANT',
#  'ANY',
#  'APE',
#  'API3',
#  'APPC',
#  'AR',
#  'ARDR',
#  'ARK',
#  'ARN',
#  'ARPA',
#  'ASR',
#  'AST',
#  'ASTR',
#  'ATA',
#  'ATM',
#  'ATOM',
#  'AUCTION',
#  'AUD',
#  'AUDIO',
#  'AUTO',
#  'AVA',
#  'AVAX',
#  'AXS',
#  'BADGER',
#  'BAKE',
#  'BAL',
#  'BAND',
#  'BAR',
#  'BAT',
#  'BCC',
#  'BCD',
#  'BCH',
#  'BCHA',
#  'BCHABC',
#  'BCHSV',
#  'BCN',
#  'BCPT',
#  'BDOT',
#  'BEAM',
#  'BEL',
#  'BETA',
#  'BETH',
#  'BGBP',
#  'BICO',
#  'BIFI',
#  'BKRW',
#  'BLZ',
#  'BNB',
#  'BNT',
#  'BNX',
#  'BOND',
#  'BOT',
#  'BQX',
#  'BRD',
#  'BSW',
#  'BTC',
#  'BTCB',
#  'BTCST',
#  'BTG',
#  'BTS',
#  'BTT',
#  'BTTC',
#  'BURGER',
#  'BUSD',
#  'BZRX',
#  'C98',
#  'CAKE',
#  'CDT',
#  'CELO',
#  'CELR',
#  'CFX',
#  'CHAT',
#  'CHESS',
#  'CHR',
#  'CHZ',
#  'CITY',
#  'CKB',
#  'CLOAK',
#  'CLV',
#  'CMT',
#  'CND',
#  'COCOS',
#  'COMP',
#  'COS',
#  'COTI',
#  'COVER',
#  'CREAM',
#  'CRV',
#  'CTK',
#  'CTSI',
#  'CTXC',
#  'CVC',
#  'CVP',
#  'CVX',
#  'DAI',
#  'DAR',
#  'DASH',
#  'DATA',
#  'DCR',
#  'DEGO',
#  'DENT',
#  'DEXE',
#  'DF',
#  'DGB',
#  'DGD',
#  'DIA',
#  'DLT',
#  'DNT',
#  'DOCK',
#  'DODO',
#  'DOGE',
#  'DOT',
#  'DREP',
#  'DUSK',
#  'DYDX',
#  'EASY',
#  'EDO',
#  'EGLD',
#  'ELF',
#  'ENG',
#  'ENJ',
#  'ENS',
#  'EOS',
#  'EPS',
#  'EPX',
#  'ERD',
#  'ERN',
#  'ETC',
#  'ETH',
#  'EUR',
#  'EVX',
#  'EZ',
#  'FARM',
#  'FET',
#  'FIDA',
#  'FIL',
#  'FIO',
#  'FIRO',
#  'FIS',
#  'FLM',
#  'FLOW',
#  'FLUX',
#  'FOR',
#  'FORTH',
#  'FRONT',
#  'FTM',
#  'FTT',
#  'FUEL',
#  'FUN',
#  'FXS',
#  'GAL',
#  'GALA',
#  'GAS',
#  'GBP',
#  'GHST',
#  'GLM',
#  'GLMR',
#  'GMT',
#  'GNO',
#  'GNT',
#  'GO',
#  'GRS',
#  'GRT',
#  'GTC',
#  'GTO',
#  'GVT',
#  'GXS',
#  'HARD',
#  'HBAR',
#  'HC',
#  'HEGIC',
#  'HIGH',
#  'HIVE',
#  'HNT',
#  'HOT',
#  'HSR',
#  'ICN',
#  'ICP',
#  'ICX',
#  'IDEX',
#  'ILV',
#  'IMX',
#  'INJ',
#  'INS',
#  'IOST',
#  'IOTA',
#  'IOTX',
#  'IQ',
#  'IRIS',
#  'JASMY',
#  'JOE',
#  'JST',
#  'JUV',
#  'KAVA',
#  'KDA',
#  'KEEP',
#  'KEY',
#  'KLAY',
#  'KMD',
#  'KNC',
#  'KP3R',
#  'KSM',
#  'LAZIO',
#  'LDO',
#  'LEND',
#  'LEVER',
#  'LINA',
#  'LINK',
#  'LIT',
#  'LOKA',
#  'LOOM',
#  'LPT',
#  'LRC',
#  'LSK',
#  'LTC',
#  'LTO',
#  'LUN',
#  'LUNA',
#  'LUNC',
#  'MANA',
#  'MASK',
#  'MATIC',
#  'MBL',
#  'MBOX',
#  'MC',
#  'MCO',
#  'MDA',
#  'MDT',
#  'MDX',
#  'MFT',
#  'MINA',
#  'MIR',
#  'MITH',
#  'MKR',
#  'MLN',
#  'MOB',
#  'MOD',
#  'MOVR',
#  'MTH',
#  'MTL',
#  'MULTI',
#  'NANO',
#  'NAS',
#  'NAV',
#  'NBS',
#  'NBT',
#  'NCASH',
#  'NEAR',
#  'NEBL',
#  'NEO',
#  'NEXO',
#  'NKN',
#  'NMR',
#  'NPXS',
#  'NU',
#  'NULS',
#  'NXS',
#  'OAX',
#  'OCEAN',
#  'OG',
#  'OGN',
#  'OM',
#  'OMG',
#  'ONE',
#  'ONG',
#  'ONT',
#  'OOKI',
#  'OP',
#  'ORN',
#  'OST',
#  'OXT',
#  'PAX',
#  'PAXG',
#  'PEOPLE',
#  'PERL',
#  'PERP',
#  'PHA',
#  'PHB',
#  'PHX',
#  'PIVX',
#  'PLA',
#  'PNT',
#  'POA',
#  'POE',
#  'POLS',
#  'POLY',
#  'POND',
#  'PORTO',
#  'POWR',
#  'PPT',
#  'PROM',
#  'PROS',
#  'PSG',
#  'PUNDIX',
#  'PYR',
#  'QI',
#  'QKC',
#  'QLC',
#  'QNT',
#  'QSP',
#  'QTUM',
#  'QUICK',
#  'RAD',
#  'RAMP',
#  'RARE',
#  'RAY',
#  'RCN',
#  'RDN',
#  'REEF',
#  'REI',
#  'REN',
#  'RENBTC',
#  'REP',
#  'REQ',
#  'RGT',
#  'RIF',
#  'RLC',
#  'RNDR',
#  'ROSE',
#  'RPX',
#  'RSR',
#  'RUNE',
#  'RVN',
#  'SALT',
#  'SAND',
#  'SANTOS',
#  'SC',
#  'SCRT',
#  'SFP',
#  'SHIB',
#  'SKL',
#  'SKY',
#  'SLP',
#  'SNGLS',
#  'SNM',
#  'SNT',
#  'SNX',
#  'SOL',
#  'SPARTA',
#  'SPELL',
#  'SRM',
#  'SSV',
#  'STEEM',
#  'STMX',
#  'STORJ',
#  'STORM',
#  'STPT',
#  'STRAT',
#  'STRAX',
#  'STX',
#  'SUB',
#  'SUN',
#  'SUPER',
#  'SUSD',
#  'SUSHI',
#  'SWRV',
#  'SXP',
#  'SYS',
#  'T',
#  'TCT',
#  'TFUEL',
#  'THETA',
#  'TKO',
#  'TLM',
#  'TNB',
#  'TNT',
#  'TOMO',
#  'TORN',
#  'TRB',
#  'TRIBE',
#  'TRIG',
#  'TROY',
#  'TRU',
#  'TRX',
#  'TUSD',
#  'TUSDB',
#  'TVK',
#  'TWT',
#  'UFT',
#  'UMA',
#  'UNFI',
#  'UNI',
#  'USDC',
#  'USDP',
#  'USDS',
#  'USDSB',
#  'USDT',
#  'UST',
#  'USTC',
#  'UTK',
#  'VEN',
#  'VET',
#  'VGX',
#  'VIA',
#  'VIB',
#  'VIBE',
#  'VIDT',
#  'VITE',
#  'VOXEL',
#  'VTHO',
#  'WABI',
#  'WAN',
#  'WAVES',
#  'WAXP',
#  'WBTC',
#  'WIN',
#  'WING',
#  'WINGS',
#  'WNXM',
#  'WOO',
#  'WPR',
#  'WRX',
#  'WTC',
#  'XEC',
#  'XEM',
#  'XLM',
#  'XMR',
#  'XNO',
#  'XRP',
#  'XTZ',
#  'XVG',
#  'XVS',
#  'XZC',
#  'YFI',
#  'YFII',
#  'YGG',
#  'YOYO',
#  'ZEC',
#  'ZEN',
#  'ZIL',
#  'ZRX'}

# %%
with open('all-binance-tokens.csv', 'w') as f:
    for asset in baseAssets:
        f.write(f"{asset},{asset}\n")

# %% [markdown]
# Now that we have our `all-binance-tokens.csv` file, we can download, for instance, the complete historical data for all assets on Binance, using something like:

# %% [raw]
# `python <path_to_script>/bnbFetchCoinData.py --coins all-binance-tokens.csv --interval 1d`

# %% [markdown]
# This will create a `coindata` directory under the current one with everything we need.

# %% [markdown]
# ## Importing Data to QuestDB

# %% [markdown]
# We will use __[QuestDB](https://questdb.io/)__ in order to facilitate data manipulation and keep memory requirements low (we won't need to load everything on RAM). First we will create a table for holding the data. Here is what we did:

# %% [markdown]
# `CREATE TABLE binance_daily(symb SYMBOL capacity 2048, open_time TIMESTAMP, high DOUBLE, low DOUBLE, close DOUBLE, volume DOUBLE, close_time TIMESTAMP, quote_asset_vol DOUBLE, num_trades LONG, takerbuy_baseasset_vol DOUBLE, takerbuy_quoteasset_vol DOUBLE), index(symb) timestamp(open_time) PARTITION BY YEAR;`

# %% [markdown]
# Now we will import the data (that went to the `coindata` subdirectory)...

# %%
import glob

allCSVFiles = glob.glob('./coindata/*.csv')

# %%
import httpx
import csv

host = 'http://localhost:9000'

async def executeInsertQuery(valStrings):
    sql_query = "INSERT INTO binance_daily VALUES"
    sql_query += valStrings[0]
    for i in range(1, len(valStrings)):
        sql_query += f",{valStrings[i]}"
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
        await client.get(host + '/exec', params=query_params)


async def questInsert(symbol: str, filename: str, lotSize=300):
    with open(filename, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        valStrings = []
        for row in reader:
            if len(valStrings) == lotSize:
                await executeInsertQuery(valStrings)
                valStrings = []
            val = f"(\'{symbol}\', {int(row['Open time'])*1000}, {float(row['High'])}, {float(row['Low'])}, {float(row['Close'])}, {float(row['Volume'])}, {int(row['Close time'] + '999')}, {float(row['Quote asset volume'])}, {int(row['Number of trades'])}, {float(row['Taker buy base asset volume'])}, {float(row['Taker buy quote asset volume'])})"
            valStrings.append(val)
        if len(valStrings) > 0:
            await executeInsertQuery(valStrings)

# %%
from pathlib import Path
i = 0
for csvFile in allCSVFiles:
    symb = Path(csvFile).name.split('.')[0]
    await questInsert(symb, csvFile)
    i += 1
    if i % 100 == 0:
        print(f"Inserted {i} symbols out of {len(allCSVFiles)}")

# %% [markdown]
# If we want, we can update already existing data...

# %%
import pytz
import datetime as dt
async def lastOpenTimeFor(symbol: str) -> str:
    sql_query = f"SELECT open_time FROM binance_daily WHERE symb='{symbol}' ORDER BY open_time DESC LIMIT 1"
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
        r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    result = None
    if 'dataset' in jsonR:
        dataset = jsonR['dataset']
        if dataset is not None and len(dataset) > 0:
            if dataset[0] is not None and len(dataset[0]) > 0:
                result = jsonR['dataset'][0][0]
    return result

async def questUpdate(symbol: str, filename: str, lotSize=300):
    lastPointOpenTime = await lastOpenTimeFor(symbol)
    cutp = 19
    if lastPointOpenTime is None:
        lastPointOpenTime = "0"
    else:
        lastPointOpenTime = lastPointOpenTime[:cutp]
    with open(filename, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        valStrings = []
        for row in reader:
            if len(valStrings) == lotSize:
                await executeInsertQuery(valStrings)
                valStrings = []
            openTime = dt.datetime.fromtimestamp(int(row['Open time'])/1000, tz=pytz.utc)
            openTime = openTime.isoformat()
            openTime = openTime[:cutp]
            if openTime > lastPointOpenTime:
                val = f"(\'{symbol}\', {int(row['Open time'])*1000}, {float(row['High'])}, {float(row['Low'])}, {float(row['Close'])}, {float(row['Volume'])}, {int(row['Close time'] + '999')}, {float(row['Quote asset volume'])}, {int(row['Number of trades'])}, {float(row['Taker buy base asset volume'])}, {float(row['Taker buy quote asset volume'])})"
                valStrings.append(val)
        if len(valStrings) > 0:
            await executeInsertQuery(valStrings)
            
from pathlib import Path
i = 0
for csvFile in allCSVFiles:
    symb = Path(csvFile).name.split('.')[0]
    await questUpdate(symb, csvFile)
    i += 1
    if i % 100 == 0:
        print(f"Inserted {i} symbols out of {len(allCSVFiles)}")
# Out:
# Inserted 100 symbols out of 1836
# Inserted 200 symbols out of 1836
# Inserted 300 symbols out of 1836
# Inserted 400 symbols out of 1836
# Inserted 500 symbols out of 1836
# Inserted 600 symbols out of 1836
# Inserted 700 symbols out of 1836
# Inserted 800 symbols out of 1836
# Inserted 900 symbols out of 1836
# Inserted 1000 symbols out of 1836
# Inserted 1100 symbols out of 1836
# Inserted 1200 symbols out of 1836
# Inserted 1300 symbols out of 1836
# Inserted 1400 symbols out of 1836
# Inserted 1500 symbols out of 1836
# Inserted 1600 symbols out of 1836
# Inserted 1700 symbols out of 1836
# Inserted 1800 symbols out of 1836

# %% [markdown]
# Now QuestDB has ingested all data. Let's play!

# %% [markdown]
# ## Playing with the data

# %%
import pandas as pd
import httpx

# %%
host = 'http://localhost:9000'

# %%
async def daysTradedInMonthBySymbol(year: int, month: int) -> pd.DataFrame:
    assert(month >= 1 and month <= 12)
    assert(year >= 2000 and year <= 9999)
    if month == 12:
        nextMonth = 1
        nextMonthYear = year + 1
    else:
        nextMonth = month + 1
        nextMonthYear = year
    sql_query = "select symb, count(*) as daystraded from 'binance_daily' where open_time >= '%d-%02d-01T00:00:00.000000Z' and open_time < '%d-%02d-01T00:00:00.000000Z' and num_trades >= 1 group by symb"%(year, month, nextMonthYear, nextMonth)
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
            r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    return pd.DataFrame(columns=['symb', 'daysTraded'], data=jsonR['dataset'])

# %%
import json
with open('coindata/coin-metadata.json', 'r') as f:
    coinMetadata = json.loads(f.read())
symbols = coinMetadata['exchange-info']['symbols']
symbolDict = {}
symbolsByBaseDict = {}
for symbol in symbols:
    symbolDict[symbol['symbol']] = symbol
    baseSymbols = symbolsByBaseDict.get(symbol['baseAsset'], [])
    baseSymbols.append(symbol)
    symbolsByBaseDict[symbol['baseAsset']] = baseSymbols
del symbols

# %%
from typing import Set
# It starts as all assets with TRADING status
async def initialAssetCandidateSet() -> Set[str]:
    candidateAssets = set()
    for symbol in symbolDict:
        baseAsset = symbolDict[symbol]['baseAsset']
        if symbolDict[symbol]['status'] == 'TRADING':
            if not baseAsset.endswith('UP') and not baseAsset.endswith('DOWN') and not baseAsset.endswith('BEAR') and not baseAsset.endswith('BULL'):
                candidateAssets.add(baseAsset)
    
    return candidateAssets

# %%
def getTradeSymbols(baseAssetSet):
    symbols = []
    for base in baseAssetSet:
        baseInfo = symbolsByBaseDict[base]
        for el in baseInfo:
            symbols.append(el['symbol'])
    return symbols

# %%
# We will use USDT to compare apples to apples
def shortestPathToUSDT(fromBaseAsset, coinGraph):
        
    if fromBaseAsset == 'USDT':
        return [fromBaseAsset]
    parent = {}
    explored = set()
    frontier = [fromBaseAsset]
    def solution(baseAsset):
        if parent.get(baseAsset) is None:
            return [baseAsset]
        else:
            result = solution(parent[baseAsset])
            result.append(baseAsset)
            return result

    while len(frontier) > 0:
        node = frontier.pop(0)
        explored.add(node)
        for coin in coinGraph[node]:
            if coin not in explored and coin not in frontier:
                parent[coin] = node
                if coin == 'USDT':
                    return solution(coin)
                else:
                    frontier.append(coin)
    assert False, "Should never get here"

# %%
import psutil
import numpy as np
import concurrent.futures
def splitAddUSDTInfo(df, splittedDf, coinGraph):
    volInUSDT = []
    closePricesInUSDT = []

    for (_, row) in splittedDf.iterrows():
        # print("(Base asset: %s, Quote asset: %s)"%(row['baseAsset'],row['quoteAsset']))
        if row['quoteAsset'] == 'USDT':
            val = row['volume'] * row['close']
            closePriceUSDT = row['close']
        else:
            path = shortestPathToUSDT(row['quoteAsset'], coinGraph)
            multiplier = 1.0
            assert len(path) > 1
            i = 0
            while i + 1 < len(path):
                dfFiltered = df[(df['baseAsset'] == path[i])
                                     & (df['quoteAsset'] == path[i + 1])
                                     & (df['open_time'] == row['open_time'])]
                if dfFiltered.shape[0] > 0:
                    # print(dfFiltered)
                    pathRow = dfFiltered.iloc[0]
                    multiplier *= pathRow['close']
                else:
                    dfFiltered = df[(df['baseAsset'] == path[i + 1]) 
                            & (df['quoteAsset'] == path[i])
                            & (df['open_time'] == row['open_time'])]
                    # print(dfFiltered)
                    pathRow = dfFiltered.iloc[0]
                    multiplier *= 1.0 / pathRow['close']
                i += 1
            assert path[i] == 'USDT'
            val = row['volume'] * row['close'] * multiplier
            closePriceUSDT = row['close'] * multiplier
        volInUSDT.append(val)
        closePricesInUSDT.append(closePriceUSDT)
    splittedDf.insert(splittedDf.shape[1], 'volInUSDT', volInUSDT)
    splittedDf.insert(splittedDf.shape[1], 'closePriceUSDT', closePricesInUSDT)
    del volInUSDT
    del closePricesInUSDT
    return splittedDf
    
def addUSDTInfo(df: pd.DataFrame, coinGraph) -> pd.DataFrame:
    numprocs = psutil.cpu_count(logical=False)
    splittedDfs = np.array_split(df, numprocs)
    dfResults = []
    with concurrent.futures.ProcessPoolExecutor(max_workers=numprocs) as executor:
        results = [ executor.submit(splitAddUSDTInfo, df=df, splittedDf=splittedDf, coinGraph=coinGraph) for splittedDf in splittedDfs ]
        for result in concurrent.futures.as_completed(results):
            try:
                dfResults.append(result.result())
            except Exception as ex:
                print("BOOOO! Exception!")
                print(ex)
                pass
    
    df = pd.concat(dfResults)
    return df

# %%
async def getMedianUSDTTradeVol(baseAssetSet: Set[str], isoInstantFrom: str, isoInstantTo: str) -> pd.DataFrame:
    def listToStr(l):
        result = l[0]
        for i in range(1, len(l)):
            result += f", {l[i]}"
        return result
    
    def genCoinGraph():
        from collections import defaultdict
        coinGraph = defaultdict(set)
        for key in symbolDict:
            symbol = symbolDict[key]
            coinGraph[symbol['baseAsset']].add(symbol['quoteAsset'])
            coinGraph[symbol['quoteAsset']].add(symbol['baseAsset'])
        return coinGraph
    
    coinGraph = genCoinGraph()
     
    columns = ['symb', 'open_time', 'close', 'volume', 'close_time', 'quote_asset_vol']
    sql_query = "SELECT %s FROM 'binance_daily' WHERE open_time >= '%s' and open_time < '%s'"%(listToStr(columns), isoInstantFrom, isoInstantTo)    
    #print(sql_query)
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
            r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    df = pd.DataFrame(columns=columns, data=jsonR['dataset'])
    del r
    del jsonR
    df['baseAsset'] = df.apply(lambda row: symbolDict[row['symb']]['baseAsset'], axis = 1)
    df['quoteAsset'] = df.apply(lambda row: symbolDict[row['symb']]['quoteAsset'], axis = 1)
      
    df = addUSDTInfo(df, coinGraph)
    df.sort_values(['close_time'], ascending=[True], ignore_index=True, inplace=True)
    dfSymbLastPrices = df[['symb', 'baseAsset', 'quoteAsset', 'volInUSDT', 'closePriceUSDT']].groupby(['symb', 'baseAsset', 'quoteAsset'], as_index=False).last()
    dfBaseAssetLastPrices = pd.DataFrame(columns= ['baseAsset', 'lastAvgPriceUSDT'])
    for _, group in dfSymbLastPrices.groupby('baseAsset'):
        num = 0.0
        den = 0.0
        for (_, row) in group.iterrows():
            num += row['closePriceUSDT']*row['volInUSDT']
            den += row['volInUSDT']
        avgPrice = num / den
        dfBaseAssetLastPrices.loc[len(dfBaseAssetLastPrices)] = [row['baseAsset'], avgPrice]
    dfBaseAssetLastPrices = dfBaseAssetLastPrices.set_index('baseAsset')

    df = df[['open_time', 'baseAsset', 'volInUSDT']].groupby(['baseAsset', 'open_time'], as_index=False).sum()    
    df = df[['baseAsset', 'volInUSDT']].groupby(['baseAsset'], as_index=True).median()
    df = pd.concat([df, dfBaseAssetLastPrices], axis=1, join='inner')
    df.reset_index(inplace=True)
    df.sort_values(['volInUSDT'], ascending=[False], ignore_index=True, inplace=True)
    return df

# %%
def getBlacklistSet(blackListFile) -> Set[str]:
    blacklist = None
    with open(blackListFile, 'r') as f:
        blacklist = f.read().split(',')
    return set(blacklist)

# %%
async def daysTradedBetweenBySymbol(isoInstantFrom: str, isoInstantTo: str) -> pd.DataFrame:
    sql_query = "select symb, count(*) as daystraded from 'binance_daily' where open_time >= '%s' and open_time < '%s' and num_trades >= 1 group by symb"%(isoInstantFrom, isoInstantTo)
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
            r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    return pd.DataFrame(columns=['symb', 'daysTraded'], data=jsonR['dataset'])

# %%
from datetime import date
from typing import List

# we will consider that an eligible asset should have at least one trade
# pair that was negotiated every day of the month
async def symbolsTradedEveryDay(isoInstantFrom: str, isoInstantTo: str) -> List[str]:
    fromDate = date.fromisoformat(isoInstantFrom[:10])
    toDate = date.fromisoformat(isoInstantTo[:10])
    daysBetween = abs(toDate - fromDate).days    
    df = await daysTradedBetweenBySymbol(isoInstantFrom, isoInstantTo)
    return df[df['daysTraded']==daysBetween]['symb'].tolist()

# %%
async def assetsTradedEveryDay(isoInstantFrom: str, isoInstantTo: str) -> Set[str]:
    result = set()
    symbols = await symbolsTradedEveryDay(isoInstantFrom, isoInstantTo)
    for symbol in symbols:
        symbolInfo = symbolDict[symbol]
        result.add(symbolInfo['baseAsset'])
        result.add(symbolInfo['quoteAsset'])
    return result

# %%
async def eligibleAssetsAndMedianVolumes(isoInstantFrom: str, isoInstantTo: str, getBlacklistFunc, whitelistFunc=None) -> pd.DataFrame:
    initialAssets = await initialAssetCandidateSet()
    df = await getMedianUSDTTradeVol(initialAssets, isoInstantFrom, isoInstantTo)
    blackListSet = getBlacklistFunc()
    print('blackListSet')
    print(blackListSet)
    df = df[~df['baseAsset'].str.lower().isin(blackListSet)]
    if df.shape[0] > 0:
        if whitelistFunc is not None:
            print('whitelist is present')
            whitelistSet = whitelistFunc()
            df = df[df['baseAsset'].str.lower().isin(whitelistSet)]
        else:
            print('no whitelist being used')
        everydayAssets = await assetsTradedEveryDay(isoInstantFrom, isoInstantTo)
        df = df[df['baseAsset'].isin(everydayAssets)]
        df.reset_index(drop=True, inplace=True)
        if df.shape[0] > 0:
            maxVolume = df['volInUSDT'][0]
            df = df[df['volInUSDT'] >= (0.005 * maxVolume)]
        df.reset_index(inplace=True, drop=True)
    return df

# %% [markdown]
# Now we have everything to compute our eligibleAssets, and we will proceed to select among then the ones that will be part of the index constituents... For this we will need market cap data, which is not available from Binance API, so we will get them from Coin Gecko.

# %%
geckoBaseURL = "https://api.coingecko.com:443/api/v3"

# %%
from typing import Dict
import asyncio
async def baseAsset2GeckoId(exchangeId = 'binance') -> Dict[str, str]:
    result = {}
    done = False
    page = 1
    while not done:
        query_params = {'page': page, 'order': 'trust_score_desc'}
        print(f"Page {page}. Pausing...")
        await asyncio.sleep(4)
        async with httpx.AsyncClient() as client:
            r = await client.get(geckoBaseURL + f"/exchanges/{exchangeId}/tickers", params=query_params, timeout=30)
        tickerInfo = r.json()
        if len(tickerInfo['tickers']) == 0:
            done = True
        else:
            page += 1
            for ticker in tickerInfo['tickers']:
                baseAsset = ticker['base']
                quoteAsset = ticker['target']
                if "coin_id" in ticker:
                    if not baseAsset in result:
                        result[baseAsset] = ticker['coin_id']
                if "target_coin_id" in ticker:
                    if not quoteAsset in result:
                        result[quoteAsset] = ticker['target_coin_id']
    return result

# %%
baseAssets2GeckoDict = await baseAsset2GeckoId()
# Out:
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Page 4. Pausing...
# Page 5. Pausing...
# Page 6. Pausing...
# Page 7. Pausing...
# Page 8. Pausing...
# Page 9. Pausing...
# Page 10. Pausing...
# Page 11. Pausing...
# Page 12. Pausing...
# Page 13. Pausing...
# Page 14. Pausing...
# Page 15. Pausing...
# Page 16. Pausing...

# %%
baseAssets2GeckoDict
# Out:
# {'BUSD': 'binance-usd',
#  'USDT': 'tether',
#  'BTC': 'bitcoin',
#  'USDC': 'usd-coin',
#  'ETH': 'ethereum',
#  'BETH': 'binance-eth',
#  'WBTC': 'wrapped-bitcoin',
#  'SOL': 'solana',
#  'BNB': 'binancecoin',
#  'XRP': 'ripple',
#  'ETC': 'ethereum-classic',
#  'MATIC': 'matic-network',
#  'ADA': 'cardano',
#  'TUSD': 'true-usd',
#  'USDP': 'paxos-standard',
#  'AVAX': 'avalanche-2',
#  'DOGE': 'dogecoin',
#  'SHIB': 'shiba-inu',
#  'LUNC': 'terra-luna',
#  'TRX': 'tron',
#  'GMT': 'stepn',
#  'ATOM': 'cosmos',
#  'NEAR': 'near',
#  'LINK': 'chainlink',
#  'CHZ': 'chiliz',
#  'SAND': 'the-sandbox',
#  'OP': 'optimism',
#  'EOS': 'eos',
#  'APE': 'apecoin',
#  'DOT': 'polkadot',
#  'DAI': 'dai',
#  'LTC': 'litecoin',
#  'BIDR': 'binanceidr',
#  'FTM': 'fantom',
#  'PAXG': 'pax-gold',
#  'FIL': 'filecoin',
#  'COMP': 'compound-governance-token',
#  'FTT': 'ftx-token',
#  'AAVE': 'aave',
#  'GALA': 'gala',
#  'MANA': 'decentraland',
#  'BCH': 'bitcoin-cash',
#  'XMR': 'monero',
#  'UNI': 'uniswap',
#  'WAVES': 'waves',
#  'FLOW': 'flow',
#  'ALGO': 'algorand',
#  'AXS': 'axie-infinity',
#  'ZEC': 'zcash',
#  'DYDX': 'dydx',
#  'RUNE': 'thorchain',
#  'VET': 'vechain',
#  'XLM': 'stellar',
#  'LRC': 'loopring',
#  'SNX': 'havven',
#  'SUSHI': 'sushi',
#  'STG': 'stargate-finance',
#  'TRB': 'tellor',
#  'KNC': 'kyber-network-crystal',
#  'DASH': 'dash',
#  'ZRX': '0x',
#  'LDO': 'lido-dao',
#  'CRV': 'curve-dao-token',
#  'KAVA': 'kava',
#  'UNFI': 'unifi-protocol-dao',
#  'VGX': 'ethos',
#  'YFI': 'yearn-finance',
#  'GRT': 'the-graph',
#  'ROSE': 'oasis-network',
#  'XTZ': 'tezos',
#  'ICP': 'internet-computer',
#  'BAT': 'basic-attention-token',
#  'NEO': 'neo',
#  'ZIL': 'zilliqa',
#  'JASMY': 'jasmycoin',
#  'ENS': 'ethereum-name-service',
#  'ANKR': 'ankr',
#  'ONE': 'harmony',
#  'USTC': 'terrausd',
#  'OMG': 'omisego',
#  'EGLD': 'elrond-erd-2',
#  'YFII': 'yfii-finance',
#  'XEC': 'ecash',
#  'PEOPLE': 'constitutiondao',
#  'BURGER': 'burger-swap',
#  'CAKE': 'pancakeswap-token',
#  'BLZ': 'bluzelle',
#  'HBAR': 'hedera-hashgraph',
#  'LAZIO': 'lazio-fan-token',
#  'ENJ': 'enjincoin',
#  'GAL': 'project-galaxy',
#  'AR': 'arweave',
#  'SANTOS': 'santos-fc-fan-token',
#  'KLAY': 'klay-token',
#  'QNT': 'quant-network',
#  'SRM': 'serum',
#  'IMX': 'immutable-x',
#  'CHR': 'chromaway',
#  'THETA': 'theta-token',
#  'IOST': 'iostoken',
#  'C98': 'coin98',
#  'ALICE': 'my-neighbor-alice',
#  'MKR': 'maker',
#  'STORJ': 'storj',
#  'HNT': 'helium',
#  'KSM': 'kusama',
#  '1INCH': '1inch',
#  'BTCST': 'btc-standard-hashrate-token',
#  'CTK': 'certik',
#  'PUNDIX': 'pundi-x-2',
#  'FIRO': 'zcoin',
#  'LOKA': 'league-of-kingdoms',
#  'BOND': 'barnbridge',
#  'SYS': 'syscoin',
#  'JST': 'just',
#  'RVN': 'ravencoin',
#  'QTUM': 'qtum',
#  'CELO': 'celo',
#  'WING': 'wing-finance',
#  'PORTO': 'fc-porto',
#  'DAR': 'mines-of-dalarnia',
#  'RLC': 'iexec-rlc',
#  'IOTX': 'iotex',
#  'RSR': 'reserve-rights-token',
#  'WOO': 'woo-network',
#  'RAY': 'raydium',
#  'OGN': 'origin-protocol',
#  'HOT': 'holotoken',
#  'SXP': 'swipe',
#  'CELR': 'celer-network',
#  'AUDIO': 'audius',
#  'BEL': 'bella-protocol',
#  'NEXO': 'nexo',
#  'IOTA': 'iota',
#  'LIT': 'litentry',
#  'MASK': 'mask-network',
#  'ANC': 'anchor-protocol',
#  'OG': 'og-fan-token',
#  'ATA': 'automata',
#  'OOKI': 'ooki',
#  'FLUX': 'zelcash',
#  'SPELL': 'spell-token',
#  'MIR': 'mirror-protocol',
#  'SLP': 'smooth-love-potion',
#  'RIF': 'rif-token',
#  'MINA': 'mina-protocol',
#  'BAND': 'band-protocol',
#  'ZEN': 'zencash',
#  'OCEAN': 'ocean-protocol',
#  'SFP': 'safepal',
#  'DGB': 'digibyte',
#  'TWT': 'trust-wallet-token',
#  'MITH': 'mithril',
#  'NKN': 'nkn',
#  'PYR': 'vulcan-forged',
#  'ICX': 'icon',
#  'STMX': 'storm',
#  'ETHDOWN': 'ethdown',
#  'DUSK': 'dusk-network',
#  'AUCTION': 'auction',
#  'KP3R': 'keep3rv1',
#  'JUV': 'juventus-fan-token',
#  'BAL': 'balancer',
#  'ANT': 'aragon',
#  'ALPHA': 'alpha-finance',
#  'KDA': 'kadena',
#  'DEXE': 'dexe',
#  'ACM': 'ac-milan-fan-token',
#  'SNM': 'sonm',
#  'FXS': 'frax-share',
#  'ADX': 'adex',
#  'LPT': 'livepeer',
#  'GTC': 'gitcoin',
#  'LINA': 'linear',
#  'HIGH': 'highstreet',
#  'BAR': 'fc-barcelona-fan-token',
#  'COTI': 'coti',
#  'COCOS': 'cocos-bcx',
#  'GLMR': 'moonbeam',
#  'KEY': 'selfkey',
#  'SKL': 'skale',
#  'CVC': 'civic',
#  'YGG': 'yield-guild-games',
#  'BNX': 'binaryx',
#  'VIDT': 'v-id-blockchain',
#  'RAD': 'radicle',
#  'FLM': 'flamingo-finance',
#  'ONT': 'ontology',
#  'AVA': 'concierge-io',
#  'WNXM': 'wrapped-nxm',
#  'TORN': 'tornado-cash',
#  'REEF': 'reef',
#  'INJ': 'injective-protocol',
#  'ASR': 'as-roma-fan-token',
#  'DODO': 'dodo',
#  'ARPA': 'arpa-chain',
#  'FET': 'fetch-ai',
#  'FIDA': 'bonfida',
#  'TLM': 'alien-worlds',
#  'TOMO': 'tomochain',
#  'ACH': 'alchemy-pay',
#  'ALPINE': 'alpine-f1-team-fan-token',
#  'API3': 'api3',
#  'LEVER': 'lever',
#  'FORTH': 'ampleforth-governance-token',
#  'TFUEL': 'theta-fuel',
#  'TCT': 'tokenclub',
#  'MBOX': 'mobox',
#  'MDT': 'measurable-data-token',
#  'FRONT': 'frontier-token',
#  'CITY': 'manchester-city-fan-token',
#  'STX': 'blockstack',
#  'REN': 'republic-protocol',
#  'NMR': 'numeraire',
#  'BAKE': 'bakerytoken',
#  'XEM': 'nem',
#  'BEAM': 'beam',
#  'GTO': 'gifto',
#  'FIS': 'stafi',
#  'ERN': 'ethernity-chain',
#  'MOVR': 'moonriver',
#  'ATM': 'atletico-madrid',
#  'IDEX': 'aurora-dao',
#  'WIN': 'wink',
#  'UMA': 'uma',
#  'MOB': 'mobilecoin',
#  'CTSI': 'cartesi',
#  'POND': 'marlin',
#  'BADGER': 'badger-dao',
#  'BICO': 'biconomy',
#  'PERL': 'perlin',
#  'CFX': 'conflux-token',
#  'DEGO': 'dego-finance',
#  'PSG': 'paris-saint-germain-fan-token',
#  'WTC': 'waltonchain',
#  'BSW': 'biswap',
#  'CVP': 'concentrated-voting-power',
#  'COS': 'contentos',
#  'VOXEL': 'voxies',
#  'CLV': 'clover-finance',
#  'DENT': 'dent',
#  'DATA': 'streamr',
#  'SUN': 'sun-token',
#  'TROY': 'troy',
#  'WAXP': 'wax',
#  'FOR': 'force-protocol',
#  'HARD': 'kava-lend',
#  'CVX': 'convex-finance',
#  'ALPACA': 'alpaca-finance',
#  'SCRT': 'secret',
#  'IDRT': 'rupiah-token',
#  'SSV': 'ssv-network',
#  'AGLD': 'adventure-gold',
#  'PHA': 'pha',
#  'PERP': 'perpetual-protocol',
#  'RNDR': 'render-token',
#  'WAN': 'wanchain',
#  'AION': 'aion',
#  'ETHUP': 'ethup',
#  'MTL': 'metal',
#  'NBS': 'new-bitshares',
#  'QI': 'benqi',
#  'DOCK': 'dock',
#  'DNT': 'district0x',
#  'CTXC': 'cortex',
#  'MFT': 'mainframe',
#  'QUICK': 'quick',
#  'IRIS': 'iris-network',
#  'FARM': 'harvest-finance',
#  'MULTI': 'multichain',
#  'WRX': 'wazirx',
#  'AKRO': 'akropolis',
#  'MC': 'merit-circle',
#  'ELF': 'aelf',
#  'KMD': 'komodo',
#  'PLA': 'playdapp',
#  'T': 'threshold-network-token',
#  'OM': 'mantra-dao',
#  'SC': 'siacoin',
#  'TRIBE': 'tribe-2',
#  'VITE': 'vite',
#  'SUPER': 'superfarm',
#  'RARE': 'superrare',
#  'AUTO': 'auto',
#  'STRAX': 'stratis',
#  'FIO': 'fio-protocol',
#  'BETA': 'beta-finance',
#  'ACA': 'acala',
#  'CKB': 'nervos-network',
#  'NULS': 'nuls',
#  'ILV': 'illuvium',
#  'AMP': 'amp-token',
#  'CHESS': 'tranchess',
#  'DIA': 'dia-data',
#  'ALCX': 'alchemix',
#  'MBL': 'moviebloc',
#  'PNT': 'pnetwork',
#  'BNT': 'bancor',
#  'POWR': 'power-ledger',
#  'EPX': 'ellipsis-x',
#  'REQ': 'request-network',
#  'VTHO': 'vethor-token',
#  'STPT': 'stp-network',
#  'XNO': 'nano',
#  'GAS': 'gas',
#  'DF': 'dforce-token',
#  'HIVE': 'hive',
#  'TKO': 'tokocrypto',
#  'BTG': 'bitcoin-gold',
#  'XVS': 'venus',
#  'WABI': 'wabi',
#  'GHST': 'aavegotchi',
#  'TVK': 'the-virtua-kolect',
#  'BDOT': 'binance-wrapped-dot',
#  'REP': 'augur',
#  'ASTR': 'astar',
#  'LOOM': 'loom-network-new',
#  'PHB': 'phoenix-global',
#  'TRU': 'truefi',
#  'LTO': 'lto-network',
#  'MDX': 'mdex',
#  'MLN': 'melon',
#  'POLS': 'polkastarter',
#  'NEBL': 'neblio',
#  'BTS': 'bitshares',
#  'BIFI': 'beefy-finance',
#  'LSK': 'lisk',
#  'ORN': 'orion-protocol',
#  'UTK': 'utrust',
#  'OXT': 'orchid-protocol',
#  'POLY': 'polymath',
#  'ONG': 'ong',
#  'REI': 'rei-network',
#  'DREP': 'drep-new',
#  'XVG': 'verge',
#  'DCR': 'decred',
#  'CREAM': 'cream-2',
#  'QLC': 'qlink',
#  'PROM': 'prometeus',
#  'STEEM': 'steem',
#  'GNO': 'gnosis',
#  'FUN': 'funfair',
#  'JOE': 'joe',
#  'PROS': 'prosper',
#  'VIB': 'viberate',
#  'OAX': 'openanx',
#  'AERGO': 'aergo',
#  'AGIX': 'singularitynet',
#  'QKC': 'quark-chain',
#  'GLM': 'golem',
#  'ARK': 'ark',
#  'PIVX': 'pivx',
#  'ARDR': 'ardor',
#  'SNT': 'status',
#  'AST': 'airswap',
#  'AMB': 'amber',
#  'UFT': 'unlend-finance',
#  'IQ': 'everipedia',
#  'BTTC': 'bittorrent',
#  'VAI': 'vai'}

# %%
import dateutil
from dateutil.parser import parse
import datetime as dt
import pytz

async def computeMedianDailyMarketCapAndLastCirSupply(geckoCoinId: str, isoInstantFrom: str, isoInstantTo: str, maxDelaySeconds=7200) -> (float, float):
    dtFrom = parse(isoInstantFrom)
    dtTo = parse(isoInstantTo)
    epochSecondsFrom = dtFrom.timestamp()
    epochSecondsTo = dtTo.timestamp()
    query_params = {'vs_currency': 'usd', 'from': epochSecondsFrom, 'to': epochSecondsTo}
    async with httpx.AsyncClient() as client:
        r = await client.get(geckoBaseURL + f"/coins/{geckoCoinId}/market_chart/range", params=query_params, timeout=30)
    jsonR = r.json()
    if jsonR is None or not 'market_caps' in jsonR:
        print("WARNING: Could not find market_caps for %s, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)
    df = pd.DataFrame(columns=['epoch', 'market_cap'], data=jsonR['market_caps'])
    if (df.shape[0] < 1 or df.shape[1] != 2):
        print("WARNING: Unexpected shape for %s, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)
    if df['epoch'].isnull().values.any():
        print("WARNING: coingecko data for %s, contains empty epochs, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)

    df['isodate'] = df.apply(lambda row: dt.datetime.fromtimestamp(int(row['epoch'])/1000, tz=pytz.utc).isoformat()[:10] if (len(str(row['epoch'])) >= 13) else dt.datetime.fromtimestamp(int(row['epoch']), tz=pytz.utc).isoformat()[:10], axis = 1)
    df.sort_values(['epoch'], ascending=[True], ignore_index=True, inplace=True)
    lastMarketCap = df.iloc[-1]
    lastMarketCapDT = dt.datetime.fromtimestamp(int(lastMarketCap['epoch']/1000), tz=pytz.utc) if (len(str(lastMarketCap['epoch'])) >= 13) else dt.datetime.fromtimestamp(int(lastMarketCap['epoch']), tz=pytz.utc)
    if (abs(dtTo - lastMarketCapDT).total_seconds() > maxDelaySeconds):
        print("computeMedianDailyMarketCapAndLastCirSupply: WARNING last market cap data for %s is too old, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)    
    dfPrices = pd.DataFrame(columns=['epoch', 'price'], data=jsonR['prices'])
    dfPrices.sort_values(['epoch'], ascending=[True], ignore_index=True, inplace=True)
    lastPrice = dfPrices.iloc[-1]
    lastPriceDT = dt.datetime.fromtimestamp(int(lastPrice['epoch']/1000), tz=pytz.utc) if (len(str(lastPrice['epoch'])) >= 13) else dt.datetime.fromtimestamp(int(lastPrice['epoch']), tz=pytz.utc)
    if (abs(dtTo - lastPriceDT).total_seconds() >= maxDelaySeconds):
        print("computeMedianDailyMarketCapAndLastCirSupply: WARNING last price data for %s is too old, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)                                                                                                                                         
    df = df[['isodate', 'market_cap']].groupby(['isodate'], as_index=False).last()
    return (df['market_cap'].median(), float(lastMarketCap['market_cap'])/float(lastPrice['price']))

# %%
def addWeights(indexConstituents: pd.DataFrame):
    indexConstituents['lastMarketcap'] = indexConstituents['lastCircSupply']*indexConstituents['lastAvgPriceUSDT']
    totalLastMarketcap = indexConstituents['lastMarketcap'].sum()
    indexConstituents['weight'] = indexConstituents['lastMarketcap']/totalLastMarketcap
    print(indexConstituents)
    assert(abs(indexConstituents['weight'].sum() - 1.0) < 0.0000001)

# %%
# as we are severely rate limited by coingecko (poor free user) we will build a cache
# of median daily market cap and last circulating supply data that will benefit
# us over repeated runs
import sqlite3
from sqlite3 import Error
def createCacheDBConnection(dbFile):
    conn = None
    try:
        conn = sqlite3.connect(dbFile)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        return conn
    
def createTable(conn, sqlStmt):
    try:
        c = conn.cursor()
        c.execute(sqlStmt)
    except Error as e:
        print(e)
        
def createGeckoCacheDataBase(conn=None):
    sqlStmt = """CREATE TABLE IF NOT EXISTS MedianDailyMarketCapAndLastCirSupply (
                    id text PRIMARY KEY,
                    medDailyMarketCap real NOT NULL,
                    lastCirSupply real NOT NULL
                 );"""
    if conn is None:
        conn = createCacheDBConnection("geckoCache.db")
    if conn is not None:
        createTable(conn, sqlStmt)
        return conn
    else:
        print("Error, could not create cache database")
        
def insertCacheData(geckoId: str, isoInstantFrom: str, isoInstantTo: str, marketCap: float, cirSupply: float, conn):
    sql = 'INSERT INTO MedianDailyMarketCapAndLastCirSupply(id, medDailyMarketCap, lastCirSupply) VALUES(?, ?, ?)'
    key = geckoId + "_" + isoInstantFrom + "_" + isoInstantTo
    value = (key, marketCap, cirSupply)
    cur = conn.cursor()
    cur.execute(sql, value)
    conn.commit()
    
def getCachedData(geckoId: str, isoInstantFrom: str, isoInstantTo: str, conn):
    key = geckoId + "_" + isoInstantFrom + "_" + isoInstantTo
    cur = conn.cursor()
    cur.execute("SELECT medDailyMarketCap, lastCirSupply FROM MedianDailyMarketCapAndLastCirSupply WHERE id=?", (key,))
    rows = cur.fetchall()
    if (len(rows) > 0):
        for row in rows:
            return (row[0], row[1])
    else:
        return (None, None)

# %%
import asyncio
import pandas as pd
async def selectIndexConstituents(isoInstantFrom: str, isoInstantTo: str, eligibleAssets: pd.DataFrame, cacheConn=None) -> pd.DataFrame:
    def getGeckoId(baseAsset: str):
        if (baseAsset == 'LUNA'):
            if isoInstantTo < '2022-05-31':
                return 'terra-luna'
            else:
                return 'terra-luna-2'
        elif (baseAsset == 'ANY'):
            return 'anyswap'
        elif (baseAsset == 'EPS'):
            return 'ellipsis'
        elif (baseAsset == 'NPXS'):
            return 'pundi-x'
        elif (baseAsset == 'BTT'):
            if isoInstantTo < '2022-01-17':
                return 'bittorrent-old'
            else:
                return 'bittorrent'
        elif (baseAsset == 'NANO'):
            return 'nano'
        elif (baseAsset == 'NU'):
            return 'nucypher'
        elif (baseAsset == 'KEEP'):
            return 'keep-network'
        elif (baseAsset == 'GXS'):
            return 'gxchain'
        elif (baseAsset in baseAssets2GeckoDict):
            return baseAssets2GeckoDict[baseAsset]
        else:
            return None
        
    indexConstituents = eligibleAssets.copy()
    eligibleAssets = None
    indexConstituents['geckoId'] = indexConstituents.apply(lambda row: getGeckoId(row['baseAsset']), axis = 1)
    geckoUnsupported = indexConstituents[indexConstituents['geckoId'].isna()]
    if geckoUnsupported.shape[0] > 0:
        print("WARNING: coingecko seems to not support the following eligible assets. Ignoring them")
        print(geckoUnsupported['baseAsset'])
        indexConstituents = indexConstituents[~indexConstituents['geckoId'].isna()]
    medians = []
    lastCircSupplies = []
    for geckoId in indexConstituents['geckoId']:
        print(geckoId)
        (medianDailyMarketCap, lastCircSupply) = (None, None)
        if cacheConn is not None:
            (medianDailyMarketCap, lastCircSupply) = getCachedData(geckoId, isoInstantFrom, isoInstantTo, cacheConn)
        if medianDailyMarketCap is None or lastCircSupply is None:
            await asyncio.sleep(4)
            (medianDailyMarketCap, lastCircSupply) = await computeMedianDailyMarketCapAndLastCirSupply(geckoId, isoInstantFrom, isoInstantTo)
            if (cacheConn is not None):
                insertCacheData(geckoId, isoInstantFrom, isoInstantTo, medianDailyMarketCap, lastCircSupply, cacheConn)
                
        medians.append(medianDailyMarketCap)
        lastCircSupplies.append(lastCircSupply)
    indexConstituents['medianMarketcap'] = medians
    indexConstituents['lastCircSupply'] = lastCircSupplies
    del medians
    del lastCircSupplies
    totalMarketCap = indexConstituents['medianMarketcap'].sum()
    if not totalMarketCap > 0:
        return None
    indexConstituents.sort_values(['medianMarketcap'], ascending=[False], ignore_index=True, inplace=True)
    indexConstituents['fracTotalMarketCap'] = indexConstituents.apply(lambda row: row['medianMarketcap']/totalMarketCap, axis = 1)
    accumulatedPerc = []
    cumul = 0.0
    for _, row in indexConstituents.iterrows():
        cumul += row['fracTotalMarketCap']
        accumulatedPerc.append(cumul)
    indexConstituents.insert(indexConstituents.shape[1], 'accumulatedPerc', accumulatedPerc)
    del accumulatedPerc
    lastIndex = 0
    cutFrame = False
    for lastIndex, row in indexConstituents.iterrows():
        if row['fracTotalMarketCap'] < 0.005 and row['accumulatedPerc'] > 0.75:
            cutFrame = True
            break
    if cutFrame:
        indexConstituents = indexConstituents[:lastIndex]
    addWeights(indexConstituents)
    return indexConstituents

# %%
import json
import pandas as pd
class IndexData:
    indexId: str
    _indexValue: float
    isoInstant: str
    isRebalanceDay: bool
    _divisor: float
    lastRebalanceISOInstant: str
    indexConstituents: pd.DataFrame
    
    class IndexDataEncoder(json.JSONEncoder):
        def default(self, obj):
            if isinstance(obj, IndexData):
                return {"indexId": obj.indexId, "isoInstant": obj.isoInstant, "indexValue": obj.indexValue, "isRebalanceDay": obj.isRebalanceDay, "divisor": obj.divisor, "lastRebalanceISOInstant": obj.lastRebalanceISOInstant, "indexConstituents": json.loads(obj.indexConstituents.to_json(orient='split', index=False))}
            return json.JSONEncoder.default(self, obj)
    
    def set_indexValue(self, value):
        self._indexValue = round(value, 2)
    
    def get_indexValue(self):
        return self._indexValue
    
    def del_indexValue(self):
        del self._indexValue
        
    indexValue = property(get_indexValue, set_indexValue, del_indexValue)
    
    def set_divisor(self, value):
        self._divisor = round(value, 4)
    
    def get_divisor(self):
        return self._divisor
    
    def del_divisor(self):
        del self._divisor
       
    divisor = property(get_divisor, set_divisor, del_divisor)
    
    def toJSON(self):
        return json.dumps(self, cls=IndexData.IndexDataEncoder)
    
    def __repr__(self):
        return self.toJSON()
    
    def __jsonDecode(dct):
        attrs = ["indexId", "isoInstant", "indexValue", "isRebalanceDay", "divisor", "lastRebalanceISOInstant", "indexConstituents"]
        for attr in attrs:
            if attr not in dct:
                return dct
        result = IndexData()
        result.indexId = dct['indexId']
        result.isoInstant = dct['isoInstant']
        result.indexValue = dct['indexValue']
        result.isRebalanceDay = dct['isRebalanceDay']
        result.divisor = dct['divisor']
        result.lastRebalanceISOInstant = dct['lastRebalanceISOInstant']
        result.indexConstituents = pd.read_json(json.dumps(dct['indexConstituents']), orient='split')
        return result
    
    def fromJSON(jsStr):
        return json.loads(jsStr, object_hook=IndexData.__jsonDecode)

# %%
from functools import partial
async def startIndex(isoInstantFrom: str, isoInstantTo: str, startValue: int, name: str, cacheConn=None, whitelistFunc=None, getBlacklistFunc=partial(getBlacklistSet, 'blacklist.txt')) -> IndexData:
    assert(startValue >= 1)
    eligibleAssets = await eligibleAssetsAndMedianVolumes(isoInstantFrom, isoInstantTo, getBlacklistFunc, whitelistFunc)
    if eligibleAssets.shape[0] > 0:
        indexConstituents = await selectIndexConstituents(isoInstantFrom, isoInstantTo, eligibleAssets, cacheConn)
        if indexConstituents is None:
            return None
        indexData = IndexData()
        indexData.indexId = name
        indexData.isoInstant = isoInstantTo
        indexData.isRebalanceDay = True
        indexData.lastRebalanceISOInstant = isoInstantTo
        indexData.indexValue = startValue
        dInitial = indexConstituents['lastMarketcap'].sum() / float(startValue)
        indexData.indexConstituents = indexConstituents
        indexData.divisor = dInitial
        return indexData
    else:
        return None

# %%
cacheConn = createGeckoCacheDataBase()
# Out:
# 2.6.0

# %%
firstIndexData = await startIndex('2020-11-01T00:00:00.000000Z', '2020-12-01T00:00:00.000000Z', 1000, 'ONN-B-30dW-30dR', cacheConn, None, partial(getBlacklistSet, 'blacklist.txt'))
# Out:
# blackListSet
# {'tusd', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# bitcoin
# ethereum
# chainlink
# yearn-finance
# litecoin
# ripple
# binancecoin
# bitcoin-cash
# uniswap
# cardano
# eos
# polkadot
# yfii-finance
# aave
# tron
# swipe
# sushi
# vechain
# curve-dao-token
# monero
# zcash
# filecoin
# tezos
# ethereum-classic
# neo
# cosmos
# stellar
# reserve-rights-token
# waves
# dash
# omisego
# band-protocol
# near
# alpha-finance
# havven
# republic-protocol
# civic
# tellor
#    baseAsset     volInUSDT  lastAvgPriceUSDT       geckoId  medianMarketcap  \
# 0        BTC  1.799611e+09      19695.427291       bitcoin     3.061478e+11
# 1        ETH  8.656754e+08        616.664287      ethereum     5.305535e+10
# 2        XRP  1.256029e+08          0.664212        ripple     1.258803e+10
# 3       LINK  1.757122e+08         14.265454     chainlink     5.041331e+09
# 4        BCH  7.264516e+07        317.484899  bitcoin-cash     4.805316e+09
# 5        LTC  1.489384e+08         87.654205      litecoin     4.428630e+09
# 6        DOT  3.833155e+07          5.376746      polkadot     4.275687e+09
# 7        BNB  1.004437e+08         31.488570   binancecoin     4.163545e+09
# 8        ADA  5.294544e+07          0.172060       cardano     3.307420e+09
# 9        EOS  4.550082e+07          3.261507           eos     2.455377e+09
# 10       XMR  2.349528e+07        130.677915        monero     2.119402e+09
#
#     lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap
    baseAssetSet = set(indexData.indexConstituents['baseAsset'])
    dfNewPrices = await getMedianUSDTTradeVol(baseAssetSet, beginIsoInstant, endIsoInstant)
    dfNewPrices = dfNewPrices[dfNewPrices['baseAsset'].isin(baseAssetSet)]
    dfNewPrices.set_index('baseAsset', inplace=True)
    dfNewPrices.drop(columns=['volInUSDT'], inplace=True)
    dfNewPrices.rename(columns={'lastAvgPriceUSDT':'endAvgPriceUSDT'}, inplace=True)
    return dfNewPrices

# %%
import copy
async def lastIndexDataNoRebalance(beginIsoInstant: str, endIsoInstant: str, lastPoint: IndexData) -> IndexData:
    baseAssetSet = set(lastPoint.indexConstituents['baseAsset'])
    dfNewPrices = await computeUpdatedPrices(lastPoint, beginIsoInstant, endIsoInstant)
    dfLastCircSupplies = lastPoint.indexConstituents.copy()
    dfLastCircSupplies.set_index('baseAsset', inplace=True)
    if('endAvgPriceUSDT' in dfLastCircSupplies.columns):
        dfLastCircSupplies.drop(columns=['endAvgPriceUSDT'], inplace=True)
    #dfNew = pd.join([dfLastCircSupplies, dfNewPrices], axis=1, join='inner')
    dfNew = pd.merge(dfLastCircSupplies, dfNewPrices, how='right', on='baseAsset')
    dfNew.fillna(value=0, inplace=True)
    #assert(dfNew.shape[0] == dfLastCircSupplies.shape[0])
    assert(dfNew.shape[0] == dfNewPrices.shape[0])
    del dfNewPrices
    del dfLastCircSupplies
    dfNew.reset_index(inplace=True)
    dfNew.sort_values(['volInUSDT'], ascending=[False], ignore_index=True, inplace=True)
    dfNew['instantDummyMarketCap'] = dfNew['lastCircSupply']*dfNew['endAvgPriceUSDT']
    indexAtEnd = dfNew['instantDummyMarketCap'].sum() / lastPoint.divisor
    endIndex = copy.copy(lastPoint)
    endIndex.indexValue = indexAtEnd
    endIndex.isoInstant = endIsoInstant
    endIndex.isRebalanceDay = False
    dfNew.drop(columns=['instantDummyMarketCap'], inplace=True)
    endIndex.indexConstituents = dfNew
    return endIndex

# %%
async def lastIndexDataRebalance(beginIsoInstant: str, endIsoInstant:str, lastPoint: IndexData, cacheConn=None, whitelistFunc=None, getBlacklistFunc=partial(getBlacklistSet, 'blacklist.txt')) -> IndexData:
    updatedPricesOldConstituents = await computeUpdatedPrices(lastPoint, beginIsoInstant, endIsoInstant)
    dfLastCircSupplies = lastPoint.indexConstituents.copy()
    dfLastCircSupplies.set_index('baseAsset', inplace=True)
    if('endAvgPriceUSDT' in dfLastCircSupplies.columns):
        dfLastCircSupplies.drop(columns=['endAvgPriceUSDT'], inplace=True)
    dfNew = pd.concat([dfLastCircSupplies, updatedPricesOldConstituents], axis=1, join='inner')
    assert(dfNew.shape[0] == dfLastCircSupplies.shape[0])
    assert(dfNew.shape[0] == updatedPricesOldConstituents.shape[0])
    del updatedPricesOldConstituents
    del dfLastCircSupplies
    dfNew.reset_index(inplace=True)
    dfNew['instantDummyMarketCap'] = dfNew['lastCircSupply']*dfNew['endAvgPriceUSDT']
    oldConstituentsNewMarketcap = dfNew['instantDummyMarketCap'].sum()
    
    eligibleAssets = await eligibleAssetsAndMedianVolumes(lastPoint.lastRebalanceISOInstant, endIsoInstant, getBlacklistFunc, whitelistFunc)
    indexConstituents = await selectIndexConstituents(lastPoint.lastRebalanceISOInstant, endIsoInstant, eligibleAssets, cacheConn)
    newConstituentsMarketcap = indexConstituents['lastMarketcap'].sum()
    
    newDivisor = (newConstituentsMarketcap/oldConstituentsNewMarketcap)*lastPoint.divisor
    newValue = newConstituentsMarketcap/newDivisor

    endIndex = copy.copy(lastPoint)
    endIndex.indexValue = newValue
    endIndex.isoInstant = endIsoInstant
    endIndex.isRebalanceDay = True
    endIndex.indexConstituents = indexConstituents
    endIndex.divisor = newDivisor
    endIndex.lastRebalanceISOInstant = endIsoInstant
    return endIndex

# %%
import datetime
computeDay = parse(firstIndexData.isoInstant) + datetime.timedelta(days = 1)
endDate = parse("2022-08-29T00:00:00.000000Z") + datetime.timedelta(days = 1)
lastIndex = firstIndexData
fileName = f"{firstIndexData.indexId}_{firstIndexData.isoInstant[:10]}_{str(endDate)[:10]}.json"
with open(fileName, 'w') as f:
    print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
    f.write('[\n')
    f.write(lastIndex.toJSON())
    while computeDay <= endDate:
        if(computeDay.day == 1):
            lastIndex = await lastIndexDataRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex, cacheConn, None, partial(getBlacklistSet, 'blacklist.txt'))
        else:
            lastIndex = await lastIndexDataNoRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex)
        print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
        f.write(',\n')
        f.write(lastIndex.toJSON())
        computeDay = computeDay + datetime.timedelta(days = 1)
    f.write('\n]\n')
# Out:
# 2020-12-01T00:00:00.000000Z: 1000.000000
# 2020-12-02T00:00:00.000000Z: 949.040000
# 2020-12-03T00:00:00.000000Z: 971.890000
# 2020-12-04T00:00:00.000000Z: 984.790000
# 2020-12-05T00:00:00.000000Z: 932.790000
# 2020-12-06T00:00:00.000000Z: 963.710000
# 2020-12-07T00:00:00.000000Z: 975.780000
# 2020-12-08T00:00:00.000000Z: 964.340000
# 2020-12-09T00:00:00.000000Z: 916.170000
# 2020-12-10T00:00:00.000000Z: 931.640000
# 2020-12-11T00:00:00.000000Z: 915.200000
# 2020-12-12T00:00:00.000000Z: 900.560000
# 2020-12-13T00:00:00.000000Z: 932.960000
# 2020-12-14T00:00:00.000000Z: 955.370000
# 2020-12-15T00:00:00.000000Z: 957.050000
# 2020-12-16T00:00:00.000000Z: 960.870000
# 2020-12-17T00:00:00.000000Z: 1056.540000
# 2020-12-18T00:00:00.000000Z: 1112.800000
# 2020-12-19T00:00:00.000000Z: 1128.720000
# 2020-12-20T00:00:00.000000Z: 1157.470000
# 2020-12-21T00:00:00.000000Z: 1137.750000
# 2020-12-22T00:00:00.000000Z: 1094.240000
# 2020-12-23T00:00:00.000000Z: 1138.330000
# 2020-12-24T00:00:00.000000Z: 1079.940000
# 2020-12-25T00:00:00.000000Z: 1116.780000
# 2020-12-26T00:00:00.000000Z: 1158.090000
# 2020-12-27T00:00:00.000000Z: 1224.320000
# 2020-12-28T00:00:00.000000Z: 1227.090000
# 2020-12-29T00:00:00.000000Z: 1270.140000
# 2020-12-30T00:00:00.000000Z: 1281.360000
# 2020-12-31T00:00:00.000000Z: 1338.490000
# blackListSet
# {'tusd', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# bitcoin
# ethereum
# ripple
# litecoin
# bitcoin-cash
# binancecoin
# chainlink
# cardano
# yearn-finance
# eos
# stellar
# sushi
# polkadot
# tron
# aave
# vechain
# zilliqa
# uniswap
# monero
# filecoin
# elrond-erd-2
# theta-token
# nem
# ethereum-classic
# zcash
# unifi-protocol-dao
# waves
# neo
# dash
# swipe
# algorand
# injective-protocol
# havven
# cosmos
# tezos
# oasis-network
# curve-dao-token
# omisego
#   baseAsset     volInUSDT  lastAvgPriceUSDT       geckoId  medianMarketcap  \
# 0       BTC  2.217092e+09      28924.484956       bitcoin     3.949897e+11
# 1       ETH  9.785287e+08        736.383567      ethereum     6.983237e+10
# 2       XRP  5.461872e+08          0.219566        ripple     2.437093e+10
# 3       LTC  2.798965e+08        124.216852      litecoin     6.085811e+09
# 4       BCH  1.124867e+08        342.109816  bitcoin-cash     5.429744e+09
# 5      LINK  9.958130e+07         11.236749     chainlink     5.028525e+09
# 6       ADA  9.072983e+07          0.181340       cardano     4.881394e+09
# 7       DOT  3.764692e+07          9.261683      polkadot     4.858717e+09
# 8       BNB  1.020633e+08         37.358518   binancecoin     4.509991e+09
# 9       XLM  5.741504e+07          0.127630       stellar     3.622805e+09
#
#    lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap  \
# 0    1.858691e+07            0.719360         0.719360   5.376169e+11
# 1    1.138949e+08            0.127180         0.846540   8.387032e+10
# 2    4.552273e+10            0.044385         0.890924   9.995247e+09
# 3    6.614610e+07            0.011084         0.902008   8.216460e+09
# 4    1.857987e+07            0.009889         0.911897   6.356356e+09
# 5    3.993847e+08            0.009158         0.921055   4.487786e+09
# 6    3.111678e+10            0.008890         0.929945   5.642705e+09
# 7    9.435092e+08            0.008849         0.938794   8.738483e+09
# 8    1.480740e+08            0.008214         0.947007   5.531824e+09
# 9    2.191461e+10            0.006598         0.953605   2.796957e+09
#
#      weight
# 0  0.798536
# 1  0.124575
# 2  0.014846
# 3  0.012204
# 4  0.009441
# 5  0.006666
# 6  0.008381
# 7  0.012979
# 8  0.008217
# 9  0.004154
# 2021-01-01T00:00:00.000000Z: 1339.310000
# 2021-01-02T00:00:00.000000Z: 1353.080000
# 2021-01-03T00:00:00.000000Z: 1471.180000
# 2021-01-04T00:00:00.000000Z: 1559.830000
# 2021-01-05T00:00:00.000000Z: 1537.420000
# 2021-01-06T00:00:00.000000Z: 1627.610000
# 2021-01-07T00:00:00.000000Z: 1775.200000
# 2021-01-08T00:00:00.000000Z: 1879.410000
# 2021-01-09T00:00:00.000000Z: 1917.860000
# 2021-01-10T00:00:00.000000Z: 1924.490000
# 2021-01-11T00:00:00.000000Z: 1841.770000
# 2021-01-12T00:00:00.000000Z: 1684.700000
# 2021-01-13T00:00:00.000000Z: 1625.790000
# 2021-01-14T00:00:00.000000Z: 1780.850000
# 2021-01-15T00:00:00.000000Z: 1879.330000
# 2021-01-16T00:00:00.000000Z: 1769.990000
# 2021-01-17T00:00:00.000000Z: 1768.220000
# 2021-01-18T00:00:00.000000Z: 1766.630000
# 2021-01-19T00:00:00.000000Z: 1802.430000
# 2021-01-20T00:00:00.000000Z: 1797.190000
# 2021-01-21T00:00:00.000000Z: 1788.020000
# 2021-01-22T00:00:00.000000Z: 1535.400000
# 2021-01-23T00:00:00.000000Z: 1651.150000
# 2021-01-24T00:00:00.000000Z: 1624.350000
# 2021-01-25T00:00:00.000000Z: 1667.300000
# 2021-01-26T00:00:00.000000Z: 1645.220000
# 2021-01-27T00:00:00.000000Z: 1663.300000
# 2021-01-28T00:00:00.000000Z: 1543.500000
# 2021-01-29T00:00:00.000000Z: 1687.810000
# 2021-01-30T00:00:00.000000Z: 1733.870000
# 2021-01-31T00:00:00.000000Z: 1752.080000
# blackListSet
# {'tusd', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# bitcoin
# ethereum
# polkadot
# litecoin
# chainlink
# ripple
# cardano
# bitcoin-cash
# binancecoin
# stellar
# eos
# uniswap
# sushi
# yearn-finance
# vechain
# aave
# tron
# curve-dao-token
# the-graph
# swipe
# cosmos
# neo
# theta-token
# iostoken
# ethereum-classic
# zcash
# zilliqa
# tezos
# havven
# monero
# elrond-erd-2
# algorand
# dogecoin
# omisego
# 1inch
# dash
# band-protocol
# reserve-rights-token
# filecoin
# alpha-finance
# solana
#   baseAsset     volInUSDT  lastAvgPriceUSDT       geckoId  medianMarketcap  \
# 0       BTC  5.194311e+09      33092.019526       bitcoin     6.392124e+11
# 1       ETH  3.843625e+09       1312.570203      ethereum     1.411019e+11
# 2       DOT  4.387007e+08         16.113764      polkadot     1.485573e+10
# 3       XRP  3.496491e+08          0.495185        ripple     1.264934e+10
# 4       ADA  3.448142e+08          0.344692       cardano     1.035520e+10
# 5       LTC  4.084202e+08        129.362628      litecoin     9.415226e+09
# 6      LINK  3.598829e+08         22.560279     chainlink     8.213089e+09
# 7       BCH  2.269958e+08        399.328865  bitcoin-cash     8.155137e+09
# 8       XLM  1.855409e+08          0.306977       stellar     6.325116e+09
# 9       BNB  2.123090e+08         44.333967   binancecoin     6.116758e+09
#
#    lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap  \
# 0    1.867742e+07            0.717742         0.717742   6.180736e+11
# 1    1.150718e+08            0.158437         0.876179   1.510399e+11
# 2    9.596844e+08            0.016681         0.892860   1.546413e+10
# 3    4.548177e+10            0.014203         0.907063   2.252188e+10
# 4    3.197379e+10            0.011627         0.918690   1.102112e+10
# 5    6.653929e+07            0.010572         0.929262   8.607698e+09
# 6    4.040096e+08            0.009222         0.938484   9.114568e+09
# 7    1.864242e+07            0.009157         0.947641   7.444458e+09
# 8    2.223387e+10            0.007102         0.954744   6.825289e+09
# 9    1.478839e+08            0.006868         0.961612   6.556282e+09
#
#      weight
# 0  0.721485
# 1  0.176311
# 2  0.018051
# 3  0.026290
# 4  0.012865
# 5  0.010048
# 6  0.010640
# 7  0.008690
# 8  0.007967
# 9  0.007653
# 2021-02-01T00:00:00.000000Z: 1693.550000
# 2021-02-02T00:00:00.000000Z: 1721.020000
# 2021-02-03T00:00:00.000000Z: 1829.800000
# 2021-02-04T00:00:00.000000Z: 1958.370000
# 2021-02-05T00:00:00.000000Z: 1916.820000
# 2021-02-06T00:00:00.000000Z: 2012.250000
# 2021-02-07T00:00:00.000000Z: 2042.030000
# 2021-02-08T00:00:00.000000Z: 2008.900000
# 2021-02-09T00:00:00.000000Z: 2338.310000
# 2021-02-10T00:00:00.000000Z: 2361.600000
# 2021-02-11T00:00:00.000000Z: 2319.490000
# 2021-02-12T00:00:00.000000Z: 2453.280000
# 2021-02-13T00:00:00.000000Z: 2467.040000
# 2021-02-14T00:00:00.000000Z: 2467.040000
# 2021-02-15T00:00:00.000000Z: 2504.270000
# 2021-02-16T00:00:00.000000Z: 2469.910000
# 2021-02-17T00:00:00.000000Z: 2517.010000
# 2021-02-18T00:00:00.000000Z: 2663.900000
# 2021-02-19T00:00:00.000000Z: 2670.070000
# 2021-02-20T00:00:00.000000Z: 2889.620000
# 2021-02-21T00:00:00.000000Z: 2864.710000
# 2021-02-22T00:00:00.000000Z: 2944.430000
# 2021-02-23T00:00:00.000000Z: 2767.420000
# 2021-02-24T00:00:00.000000Z: 2481.020000
# 2021-02-25T00:00:00.000000Z: 2533.710000
# 2021-02-26T00:00:00.000000Z: 2388.820000
# 2021-02-27T00:00:00.000000Z: 2356.970000
# 2021-02-28T00:00:00.000000Z: 2366.360000
# blackListSet
# {'tusd', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# bitcoin
# ethereum
# binancecoin
# cardano
# ripple
# polkadot
# dogecoin
# litecoin
# chainlink
# eos
# bitcoin-cash
# stellar
# swipe
# tron
# uniswap
# sushi
# aave
# the-graph
# vechain
# cosmos
# terra-luna
# elrond-erd-2
# reef
# matic-network
# avalanche-2
# filecoin
# 1inch
# algorand
# ontology
# neo
# iostoken
# yearn-finance
# tezos
# iota
# alpha-finance
# venus
# zcash
# dash
# monero
# curve-dao-token
# omisego
# ethereum-classic
# fantom
# pancakeswap-token
# band-protocol
# zilliqa
# theta-token
# havven
# nem
# icon
# solana
# republic-protocol
# qtum
# 0x
# compound-governance-token
# 2021-03-20T00:00:00.000000Z: 2913.590000
# 2021-03-21T00:00:00.000000Z: 2914.620000
# 2021-03-22T00:00:00.000000Z: 2876.930000
# 2021-03-23T00:00:00.000000Z: 2720.890000
# 2021-03-24T00:00:00.000000Z: 2726.730000
# 2021-03-25T00:00:00.000000Z: 2607.470000
# 2021-03-26T00:00:00.000000Z: 2570.390000
# 2021-03-27T00:00:00.000000Z: 2763.680000
# 2021-03-28T00:00:00.000000Z: 2794.620000
# 2021-03-29T00:00:00.000000Z: 2787.330000
# 2021-03-30T00:00:00.000000Z: 2896.810000
# 2021-03-31T00:00:00.000000Z: 2953.730000
# blackListSet
# {'tusd', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# bitcoin
# ethereum
# binancecoin
# cardano
# chiliz
# ripple
# polkadot
# enjincoin
# litecoin
# theta-token
# swipe
# chainlink
# terra-luna
# vechain
# harmony
# filecoin
# uniswap
# nem
# pancakeswap-token
# eos
# holotoken
# tron
# dogecoin
# matic-network
# bitcoin-cash
# avalanche-2
# stellar
# theta-fuel
# reef
# coti
# decentraland
# sushi
# bittorrent-old
# algorand
# ankr
# ontology
# the-graph
# fantom
# hedera-hashgraph
# aave
# the-sandbox
# chromaway
# cosmos
# pundi-x
# iostoken
# sun-token
# celer-network
# zilliqa
# solana
# curve-dao-token
# neo
# elrond-erd-2
# ravencoin
# 1inch
# dent
# fetch-ai
# venus
# safepal
# storm
# basic-attention-token
# iota
# tezos
# kusama
# monero
# alpha-finance
# qtum
# reserve-rights-token
# audius
# dash
# siacoin
# icon
# zcash
# omisego
# ethereum-classic
# ocean-protocol
# kava
# origin-protocol
# skale
# bluzelle
# selfkey
# serum
# axie-infinity
# near
# yearn-finance
# litentry
# oasis-network
# republic-protocol
# band-protocol
# thorchain
# dodo
#    baseAsset     volInUSDT  lastAvgPriceUSDT       geckoId  medianMarketcap  \
# 0        BTC  5.028688e+09      58743.958981       bitcoin     1.049077e+12
# 1        ETH  2.529378e+09       1919.253375      ethereum     2.052500e+11
# 2        BNB  1.285202e+09        302.395268   binancecoin     4.073682e+10
# 3        ADA  6.950713e+08          1.191785       cardano     3.806077e+10
# 4        DOT  3.642487e+08         37.079380      polkadot     3.427047e+10
# 5        XRP  3.907408e+08          0.569842        ripple     2.162961e+10
# 6        UNI  1.462661e+08         28.033776       uniswap     1.557822e+10
# 7        LTC  2.553194e+08        196.705412      litecoin     1.298726e+10
# 8       LINK  1.936521e+08         29.420389     chainlink     1.163647e+10
# 9        BCH  1.023227e+08        541.022425  bitcoin-cash     9.796704e+09
# 10       XLM  9.976552e+07          0.405647       stellar     9.143084e+09
#
#     lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap  \
# 0     1.869230e+07            0.664113         0.664113   1.098060e+12
# 1     1.154773e+08            0.129933         0.794046   2.216302e+11
# 2     1.545755e+08            0.025788         0.819834   4.674289e+10
# 3     3.201254e+10            0.024094         0.843928   3.815206e+10
# 4     9.796208e+08            0.021695         0.865623   3.632373e+10
# 5     4.588505e+10            0.013693         0.879315   2.614725e+10
# 6     5.195840e+08            0.009862         0.889177   1.456590e+10
# 7     6.678569e+07            0.008222         0.897399   1.313711e+10
# 8     4.157090e+08            0.007366         0.904765   1.223032e+10
# 9     1.874389e+07            0.006202         0.910967   1.014087e+10
# 10    2.264655e+10            0.005788         0.916755   9.186517e+09
#
#       weight
# 0   0.719418
# 1   0.145206
# 2   0.030625
# 3   0.024996
# 4   0.023798
# 5   0.017131
# 6   0.009543
# 7   0.008607
# 8   0.008013
# 9   0.006644
# 10  0.006019
# 2021-04-01T00:00:00.000000Z: 2975.990000
# 2021-04-02T00:00:00.000000Z: 2999.560000
# 2021-04-03T00:00:00.000000Z: 3062.990000
# 2021-04-04T00:00:00.000000Z: 2948.280000
# 2021-04-05T00:00:00.000000Z: 3031.020000
# 2021-04-06T00:00:00.000000Z: 3119.180000
# 2021-04-07T00:00:00.000000Z: 3108.430000
# 2021-04-08T00:00:00.000000Z: 2951.200000
# 2021-04-09T00:00:00.000000Z: 3093.300000
# 2021-04-10T00:00:00.000000Z: 3093.970000
# 2021-04-11T00:00:00.000000Z: 3217.770000
# 2021-04-12T00:00:00.000000Z: 3250.010000
# 2021-04-13T00:00:00.000000Z: 3280.040000
# 2021-04-14T00:00:00.000000Z: 3487.540000
# 2021-04-15T00:00:00.000000Z: 3508.160000
# 2021-04-16T00:00:00.000000Z: 3533.500000
# 2021-04-17T00:00:00.000000Z: 3417.680000
# 2021-04-18T00:00:00.000000Z: 3336.440000
# 2021-04-19T00:00:00.000000Z: 3130.860000
# 2021-04-20T00:00:00.000000Z: 3073.440000
# 2021-04-21T00:00:00.000000Z: 3184.180000
# 2021-04-22T00:00:00.000000Z: 3061.630000
# 2021-04-23T00:00:00.000000Z: 2960.650000
# 2021-04-24T00:00:00.000000Z: 2937.340000
# 2021-04-25T00:00:00.000000Z: 2822.120000
# 2021-04-26T00:00:00.000000Z: 2816.290000
# 2021-04-27T00:00:00.000000Z: 3114.560000
# 2021-04-28T00:00:00.000000Z: 3208.980000
# 2021-04-29T00:00:00.000000Z: 3218.810000
# 2021-04-30T00:00:00.000000Z: 3186.990000
# blackListSet
# {'tusd', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# bitcoin
# ethereum
# binancecoin
# ripple
# dogecoin
# cardano
# wink
# vechain
# tron
# litecoin
# polkadot
# bittorrent-old
# chiliz
# eos
# pancakeswap-token
# holotoken
# swipe
# filecoin
# chainlink
# bitcoin-cash
# dent
# stellar
# theta-token
# solana
# uniswap
# neo
# enjincoin
# ontology
# terra-luna
# ethereum-classic
# harmony
# iostoken
# cosmos
# aave
# avalanche-2
# elrond-erd-2
# matic-network
# siacoin
# qtum
# zcash
# iota
# wazirx
# monero
# sushi
# dash
# algorand
# tezos
# thorchain
# the-graph
# nkn
# zilliqa
# curve-dao-token
# nem
# omisego
# reef
# ankr
# 1inch
# hedera-hashgraph
# decentraland
# serum
# mithril
# ftx-token
# sun-token
# venus
# yearn-finance
# origin-protocol
# basic-attention-token
# fantom
# storm
# kusama
# reserve-rights-token
# band-protocol
# ravencoin
# coti
# theta-fuel
# verge
# alpha-finance
# chromaway
# icon
# compound-governance-token
# waves
# paris-saint-germain-fan-token
# storj
# fetch-ai
# celer-network
# btc-standard-hashrate-token
# dodo
# zencash
# safepal
# the-sandbox
# digibyte
# wrapped-bitcoin
# near
# vethor-token
# linear
# 0x
# audius
# republic-protocol
# axie-infinity
# litentry
# my-neighbor-alice
# kava
# cartesi
# maker
# metal
# flamingo-finance
# havven
# gifto
# vite
# kyber-network-crystal
# just
# ocean-protocol
# dia-data
# tellor
# nano
# tomochain
# akropolis
# loopring
#    baseAsset     volInUSDT  lastAvgPriceUSDT       geckoId  medianMarketcap  \
# 0        BTC  4.437773e+09      57695.415182       bitcoin     1.080574e+12
# 1        ETH  3.425702e+09       2772.501102      ethereum     2.633113e+11
# 2        BNB  3.164454e+09        622.657051   binancecoin     7.934024e+10
# 3        XRP  2.843658e+09          1.598790        ripple     6.035981e+10
# 4        DOT  5.616670e+08         36.518976      polkadot     3.925090e+10
# 5        ADA  7.528277e+08          1.352986       cardano     3.920727e+10
# 6       DOGE  1.729545e+09          0.337467      dogecoin     2.698492e+10
# 7        UNI  1.844569e+08         40.633980       uniswap     1.677420e+10
# 8        LTC  5.703262e+08        271.137259      litecoin     1.656292e+10
# 9        BCH  2.726696e+08        995.567176  bitcoin-cash     1.508643e+10
# 10      LINK  2.922281e+08         38.107836     chainlink     1.446268e+10
# 11     THETA  1.983325e+08         11.182244   theta-token     1.172215e+10
# 12       XLM  2.032690e+08          0.529557       stellar     1.158297e+10
# 13       VET  6.140941e+08          0.201035       vechain     1.150671e+10
# 14       FIL  2.969211e+08        163.916774      filecoin     1.095250e+10
#
#     lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap  \
# 0     1.869555e+07            0.573417         0.573417   1.078648e+12
# 1     1.159948e+08            0.139729         0.713146   3.215958e+11
# 2     1.547934e+08            0.042103         0.755248   9.638320e+10
# 3     4.646839e+10            0.032030         0.787279   7.429319e+10
# 4     9.868402e+08            0.020829         0.808108   3.603840e+10
# 5     3.212233e+10            0.020806         0.828913   4.346106e+10
# 6     1.294034e+11            0.014320         0.843233   4.366932e+10
# 7     5.208356e+08            0.008901         0.852134   2.116363e+10
# 8     6.680406e+07            0.008789         0.860924   1.811307e+10
# 9     1.881932e+07            0.008006         0.868929   1.873590e+10
# 10    4.248117e+08            0.007675         0.876604   1.618865e+10
# 11    1.003311e+09            0.006220         0.882825   1.121927e+10
# 12    2.302870e+10            0.006147         0.888971   1.219502e+10
# 13    6.517541e+10            0.006106         0.895077   1.310252e+10
# 14    6.921307e+07            0.005812         0.900889   1.134518e+10
#
#       weight
# 0   0.593919
# 1   0.177075
# 2   0.053070
# 3   0.040907
# 4   0.019843
# 5   0.023930
# 6   0.024045
# 7   0.011653
# 8   0.009973
# 9   0.010316
# 10  0.008914
# 11  0.006177
# 12  0.006715
# 13  0.007214
# 14  0.006247
# 2021-05-01T00:00:00.000000Z: 3379.040000
# 2021-05-02T00:00:00.000000Z: 3441.710000
# 2021-05-03T00:00:00.000000Z: 3386.250000
# 2021-05-04T00:00:00.000000Z: 3551.750000
# 2021-05-05T00:00:00.000000Z: 3344.840000
# 2021-05-06T00:00:00.000000Z: 3672.150000
# 2021-05-07T00:00:00.000000Z: 3617.930000
# 2021-05-08T00:00:00.000000Z: 3661.920000
# 2021-05-09T00:00:00.000000Z: 3800.900000
# 2021-05-10T00:00:00.000000Z: 3787.090000
# 2021-05-11T00:00:00.000000Z: 3621.130000
# 2021-05-12T00:00:00.000000Z: 3761.290000
# 2021-05-13T00:00:00.000000Z: 3314.030000
# 2021-05-14T00:00:00.000000Z: 3356.610000
# 2021-05-15T00:00:00.000000Z: 3498.030000
# 2021-05-16T00:00:00.000000Z: 3265.580000
# 2021-05-17T00:00:00.000000Z: 3243.570000
# 2021-05-18T00:00:00.000000Z: 3020.840000
# 2021-05-19T00:00:00.000000Z: 3031.940000
# 2021-05-20T00:00:00.000000Z: 2344.930000
# 2021-05-21T00:00:00.000000Z: 2645.200000
# 2021-05-22T00:00:00.000000Z: 2365.650000
# 2021-05-23T00:00:00.000000Z: 2304.860000
# 2021-05-24T00:00:00.000000Z: 2100.890000
# 2021-05-25T00:00:00.000000Z: 2478.690000
# 2021-05-26T00:00:00.000000Z: 2464.990000
# 2021-05-27T00:00:00.000000Z: 2588.140000
# 2021-05-28T00:00:00.000000Z: 2506.150000
# 2021-05-29T00:00:00.000000Z: 2282.330000
# 2021-05-30T00:00:00.000000Z: 2182.470000
# 2021-05-31T00:00:00.000000Z: 2271.650000
# blackListSet
# {'tusd', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# ethereum
# bitcoin
# dogecoin
# binancecoin
# ripple
# cardano
# matic-network
# polkadot
# ethereum-classic
# eos
# litecoin
# chainlink
# vechain
# bitcoin-cash
# tron
# pancakeswap-token
# solana
# stellar
# swipe
# uniswap
# theta-token
# chiliz
# bakerytoken
# terra-luna
# sushi
# filecoin
# aave
# neo
# bittorrent-old
# venus
# zcash
# thorchain
# ontology
# fantom
# avalanche-2
# yearn-finance
# cosmos
# qtum
# reef
# omisego
# monero
# holotoken
# dash
# wink
# kusama
# iexec-rlc
# enjincoin
# tezos
# dent
# curve-dao-token
# waves
# alien-worlds
# zilliqa
# harmony
# iota
# algorand
# hedera-hashgraph
# 1inch
# my-neighbor-alice
# compound-governance-token
# iostoken
# the-graph
# elrond-erd-2
# serum
# cartesi
# wrapped-bitcoin
# nano
# maker
# zencash
# havven
# decentraland
# wazirx
# nem
# coti
# smooth-love-potion
# siacoin
# near
# kava
# chromaway
# theta-fuel
# tokocrypto
# alpha-finance
#    baseAsset     volInUSDT  lastAvgPriceUSDT           geckoId  \
# 0        BTC  5.828304e+09      37253.444003           bitcoin
# 2021-06-13T00:00:00.000000Z: 2249.890000
# 2021-06-14T00:00:00.000000Z: 2430.420000
# 2021-06-15T00:00:00.000000Z: 2513.660000
# 2021-06-16T00:00:00.000000Z: 2479.790000
# 2021-06-17T00:00:00.000000Z: 2356.780000
# 2021-06-18T00:00:00.000000Z: 2351.520000
# 2021-06-19T00:00:00.000000Z: 2215.630000
# 2021-06-20T00:00:00.000000Z: 2174.540000
# 2021-06-21T00:00:00.000000Z: 2203.060000
# 2021-06-22T00:00:00.000000Z: 1875.250000
# 2021-06-23T00:00:00.000000Z: 1895.660000
# 2021-06-24T00:00:00.000000Z: 2000.360000
# 2021-06-25T00:00:00.000000Z: 2064.010000
# 2021-06-26T00:00:00.000000Z: 1878.300000
# 2021-06-27T00:00:00.000000Z: 1911.250000
# 2021-06-28T00:00:00.000000Z: 2049.950000
# 2021-06-29T00:00:00.000000Z: 2066.600000
# 2021-06-30T00:00:00.000000Z: 2155.440000
# blackListSet
# {'tusd', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# bitcoin
# ethereum
# binancecoin
# cardano
# matic-network
# dogecoin
# ripple
# polkadot
# solana
# vechain
# chainlink
# shiba-inu
# litecoin
# theta-fuel
# theta-token
# filecoin
# ethereum-classic
# eos
# tron
# pancakeswap-token
# kusama
# chiliz
# internet-computer
# swipe
# thorchain
# terra-luna
# bakerytoken
# bitcoin-cash
# aave
# uniswap
# stellar
# sushi
# monero
# fantom
# neo
# bittorrent-old
# waves
# enjincoin
# curve-dao-token
# cosmos
# zcash
# kava
# zilliqa
# 1inch
# wink
# holotoken
# avalanche-2
# omisego
# streamr
# dash
# ontology
# hedera-hashgraph
# yearn-finance
# algorand
# the-graph
# venus
# wazirx
# iota
# dexe
# dent
# elrond-erd-2
#    baseAsset     volInUSDT  lastAvgPriceUSDT            geckoId  \
# 0        BTC  4.468768e+09      35044.992509            bitcoin
# 1        ETH  3.004539e+09       2275.500129           ethereum
# 2        BNB  1.155192e+09        303.670584        binancecoin
# 3        ADA  7.028866e+08          1.385187            cardano
# 4       DOGE  6.534231e+08          0.253927           dogecoin
# 5        XRP  5.842686e+08          0.706280             ripple
# 6        DOT  3.969980e+08         16.403023           polkadot
# 7        UNI  6.975843e+07         19.280763            uniswap
# 8        BCH  7.728181e+07        526.804327       bitcoin-cash
# 9        LTC  1.744721e+08        144.260527           litecoin
# 10       SOL  2.627700e+08         35.514434             solana
# 11      LINK  2.420619e+08         19.515239          chainlink
# 12     MATIC  6.672556e+08          1.168752      matic-network
# 13     THETA  1.545397e+08          6.916927        theta-token
# 14       ICP  1.067710e+08         49.935647  internet-computer
# 15       XLM  6.461087e+07          0.283948            stellar
# 16       ETC  1.300738e+08         57.549783   ethereum-classic
# 17       VET  2.490543e+08          0.091301            vechain
#
#     medianMarketcap  lastCircSupply  fracTotalMarketCap  accumulatedPerc  \
# 0      6.705638e+11    1.883056e+07            0.504457         0.504457
# 2021-07-27T00:00:00.000000Z: 2164.130000
# 2021-07-28T00:00:00.000000Z: 2266.800000
# 2021-07-29T00:00:00.000000Z: 2294.600000
# 2021-07-30T00:00:00.000000Z: 2319.410000
# 2021-07-31T00:00:00.000000Z: 2422.400000
# blackListSet
# {'tusd', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# bitcoin
# ethereum
# binancecoin
# axie-infinity
# dogecoin
# cardano
# ripple
# polkadot
# matic-network
# alien-worlds
# solana
# chainlink
# ethereum-classic
# theta-token
# litecoin
# my-neighbor-alice
# vechain
# terra-luna
# eos
# internet-computer
# the-sandbox
# shiba-inu
# filecoin
# aave
# pancakeswap-token
# smooth-love-potion
# tron
# uniswap
# thorchain
# chromaway
# chiliz
# bitcoin-cash
# enjincoin
# bakerytoken
# sushi
# compound-governance-token
# swipe
# cosmos
# stellar
# theta-fuel
# kusama
# havven
# monero
# decentraland
# neo
# dexe
# zcash
# the-graph
# alpha-finance
# linear
# bittorrent-old
# omisego
# kava
# fetch-ai
# ontology
# elrond-erd-2
# waves
# fantom
# mdex
# iostoken
# dash
# curve-dao-token
# holotoken
# dodo
# yearn-finance
# origin-protocol
# ellipsis
# hedera-hashgraph
# tezos
# ftx-token
# superfarm
# 1inch
# harmony
# audius
# algorand
# zilliqa
# the-virtua-kolect
# near
# wink
# unifi-protocol-dao
# avalanche-2
# iota
# sun-token
# litentry
# blockstack
# dent
# nem
# dego-finance
# wrapped-bitcoin
# tomochain
#    baseAsset     volInUSDT  lastAvgPriceUSDT           geckoId  \
# 0        BTC  2.255761e+09      41460.325536           bitcoin
# 1        ETH  2.251244e+09       2531.011843          ethereum
# 2        BNB  6.507345e+08        332.404502       binancecoin
# 3        ADA  2.877678e+08          1.319126           cardano
# 4        XRP  2.864988e+08          0.746018            ripple
# 5       DOGE  3.251619e+08          0.207619          dogecoin
# 6        DOT  2.036858e+08         16.781822          polkadot
# 7        UNI  6.392715e+07         21.765224           uniswap
# 8        BCH  5.598043e+07        545.954410      bitcoin-cash
# 9        LTC  9.840062e+07        144.360838          litecoin
# 10       SOL  1.332385e+08         36.749924            solana
# 11      LINK  1.278123e+08         22.711185         chainlink
# 12      WBTC  1.180148e+07      41498.953032   wrapped-bitcoin
# 13     MATIC  2.018989e+08          1.082417     matic-network
# 14       ETC  1.219578e+08         51.320838  ethereum-classic
#
#     medianMarketcap  lastCircSupply  fracTotalMarketCap  accumulatedPerc  \
# 0      6.333120e+11    1.877261e+07            0.521364         0.521364
# 1      2.489468e+11    1.168590e+08            0.204942         0.726306
# 2      4.741774e+10    1.545642e+08            0.039036         0.765342
# 3      4.116223e+10    3.208337e+10            0.033886         0.799228
# 4      2.901619e+10    4.631244e+10            0.023887         0.823115
# 5      2.687095e+10    1.306667e+11            0.022121         0.845236
# 6      1.479782e+10    1.015970e+09            0.012182         0.857418
# my-neighbor-alice
# litecoin
# ethereum-classic
# eos
# alien-worlds
# coin98
# theta-token
# thorchain
# pancakeswap-token
# tron
# chiliz
# shiba-inu
# uniswap
# avalanche-2
# bitcoin-cash
# bakerytoken
# sushi
# smooth-love-potion
# kava
# fantom
# dent
# aave
# the-graph
# swipe
# cosmos
# stellar
# bittorrent-old
# neo
# ftx-token
# the-sandbox
# qtum
# enjincoin
# kusama
# chromaway
# holotoken
# iotex
# audius
# algorand
# monero
# wink
# elrond-erd-2
# near
# coti
# curve-dao-token
# omisego
# ellipsis
# dash
# tezos
# serum
# 1inch
# decentraland
# zcash
# linear
# compound-governance-token
# ravencoin
# alpha-finance
# ontology
# superfarm
# zilliqa
# reef
# havven
# truefi
# dodo
# venus
# iostoken
# paris-saint-germain-fan-token
# dego-finance
# origin-protocol
# iota
# the-virtua-kolect
# harmony
# fetch-ai
# hedera-hashgraph
# reserve-rights-token
# waves
# yearn-finance
# helium
# siacoin
# trust-wallet-token
# litentry
# unifi-protocol-dao
# theta-fuel
# tokocrypto
# perpetual-protocol
# cartesi
# automata
# funfair
# certik
# clover-finance
# wazirx
# ankr
# arweave
# verge
# ocean-protocol
# wrapped-bitcoin
# skale
# mask-network
# stafi
# celer-network
# iexec-rlc
#    baseAsset     volInUSDT  lastAvgPriceUSDT            geckoId  \
# 0        BTC  3.175149e+09      47101.584059            bitcoin
# 1        ETH  3.167046e+09       3429.395755           ethereum
# 2        ADA  1.124814e+09          2.767376            cardano
# 3        BNB  8.935195e+08        463.892771        binancecoin
# 4        XRP  7.991914e+08          1.185603             ripple
# 5       DOGE  7.483170e+08          0.278153           dogecoin
# 6        DOT  4.389602e+08         31.348386           polkadot
# 7        SOL  4.155243e+08        108.277750             solana
# 8        UNI  9.390389e+07         29.387614            uniswap
# 9        BCH  8.997182e+07        636.682126       bitcoin-cash
# 10      LINK  2.121070e+08         26.701552          chainlink
# 11       LTC  1.593921e+08        171.504737           litecoin
# 12       ICP  1.976044e+08         62.783980  internet-computer
# 13      LUNA  3.038716e+08         31.565682         terra-luna
# 14      WBTC  1.735202e+07      47093.942861    wrapped-bitcoin
# 15     MATIC  3.100542e+08          1.336309      matic-network
#
#     medianMarketcap  lastCircSupply  fracTotalMarketCap  accumulatedPerc  \
# 0      8.679601e+11    1.880887e+07            0.494732         0.494732
# 1      3.715448e+11    1.173371e+08            0.211778         0.706510
# 2      6.817714e+10    3.192625e+10            0.038861         0.745370
# 3      6.302429e+10    1.539733e+08            0.035923         0.781294
# 4      5.254277e+10    4.656257e+10            0.029949         0.811243
# 5      3.686342e+10    1.311149e+11            0.021012         0.832255
# 6      2.435092e+10    1.018321e+09            0.013880         0.846134
# 7      1.853144e+10    2.856687e+08            0.010563         0.856697
# 8      1.420302e+10    5.152216e+08            0.008096         0.864793
# 9      1.195693e+10    1.877831e+07            0.006815         0.871608
# 10     1.159478e+10    4.467364e+08            0.006609         0.878217
# 11     1.142696e+10    6.675261e+07            0.006513         0.884731
# 12     9.069793e+09    1.567189e+08            0.005170         0.889900
# uniswap
# ecash
# my-neighbor-alice
# coti
# bitcoin-cash
# smooth-love-potion
# shiba-inu
# curve-dao-token
# chiliz
# aave
# swipe
# mina-protocol
# iota
# thorchain
# alien-worlds
# fetch-ai
# kusama
# celo
# stellar
# kava
# the-graph
# arweave
# automata
# oasis-network
# mobox
# bittorrent-old
# monero
# quant-network
# neo
# audius
# raydium
# trust-wallet-token
# the-sandbox
# dent
# 1inch
# waves
# marlin
# zilliqa
# chromaway
# qtum
# holotoken
# dash
# zcash
# ellipsis
# reef
# havven
# bakerytoken
# ontology
# mask-network
# compound-governance-token
# icon
# republic-protocol
# origin-protocol
# funfair
# perpetual-protocol
# iotex
# enjincoin
# venus
# arpa-chain
# dodo
# yearn-finance
# v-id-blockchain
# decentraland
# reserve-rights-token
# force-protocol
# wink
# ravencoin
# alpha-finance
# dexe
# skale
# injective-protocol
# tokocrypto
# wrapped-bitcoin
# theta-fuel
# siacoin
# linear
# aelf
# zencash
# superfarm
# cartesi
# civic
# loopring
# litentry
#    baseAsset     volInUSDT  lastAvgPriceUSDT          geckoId  \
# 0        BTC  2.931305e+09      43824.381266          bitcoin
# 1        ETH  2.632188e+09       3000.749428         ethereum
# 2        ADA  9.627739e+08          2.115094          cardano
# 3        BNB  8.040318e+08        387.473246      binancecoin
# 4        XRP  5.697459e+08          0.953361           ripple
# 5        SOL  1.437793e+09        141.357055           solana
# 6        DOT  6.369789e+08         28.617051         polkadot
# 7       DOGE  3.224236e+08          0.204209         dogecoin
# 8       LUNA  4.396790e+08         38.829202       terra-luna
# 9       AVAX  5.632712e+08         66.628749      avalanche-2
# 10      LINK  3.109482e+08         24.000776        chainlink
# 11       UNI  8.987060e+07         23.530172          uniswap
# 12       LTC  1.925210e+08        153.305940         litecoin
# 13       BCH  7.719274e+07        502.686285     bitcoin-cash
# 14      ALGO  1.987185e+08          1.627423         algorand
# 15      ATOM  3.062246e+08         36.229122           cosmos
# 16      WBTC  1.679450e+07      43833.400179  wrapped-bitcoin
#
#     medianMarketcap  lastCircSupply  fracTotalMarketCap  accumulatedPerc  \
# 0      8.683409e+11    1.882311e+07            0.466379         0.466379
# 1      3.921499e+11    1.177705e+08            0.210620         0.676999
# 2      7.614054e+10    3.213480e+10            0.040894         0.717894
# 3      6.279002e+10    1.549002e+08            0.033724         0.751618
# 4      4.988502e+10    4.678327e+10            0.026793         0.778410
# 5      4.362811e+10    2.969935e+08            0.023432         0.801843
# 6      3.283187e+10    1.033471e+09            0.017634         0.819476
# 7      3.151940e+10    1.315015e+11            0.016929         0.836405
# 8      1.383338e+10    3.978749e+08            0.007430         0.843835
# 9      1.300323e+10    2.200230e+08            0.006984         0.850819
# 10     1.243280e+10    4.553364e+08            0.006678         0.857497
# 11     1.228360e+10    5.171085e+08            0.006597         0.864094
# 12     1.198546e+10    6.675261e+07            0.006437         0.870531
# 13     1.174822e+10    1.886790e+07            0.006310         0.876841
# 14     1.020456e+10    6.017020e+09            0.005481         0.882322
# 15     9.534417e+09    2.796064e+08            0.005121         0.887443
# 4   0.022219
# 5   0.021075
# 6   0.018755
# 7   0.011948
# 8   0.012501
# 9   0.013083
# 10  0.008624
# 11  0.005467
# 12  0.005550
# 2022-05-01T00:00:00.000000Z: 2252.350000
# 2022-05-02T00:00:00.000000Z: 2321.610000
# 2022-05-03T00:00:00.000000Z: 2328.570000
# 2022-05-04T00:00:00.000000Z: 2280.020000
# 2022-05-05T00:00:00.000000Z: 2413.100000
# 2022-05-06T00:00:00.000000Z: 2229.760000
# 2022-05-07T00:00:00.000000Z: 2193.270000
# 2022-05-08T00:00:00.000000Z: 2145.390000
# 2022-05-09T00:00:00.000000Z: 2059.970000
# 2022-05-10T00:00:00.000000Z: 1783.130000
# 2022-05-11T00:00:00.000000Z: 1851.340000
# 2022-05-12T00:00:00.000000Z: 1660.040000
# 2022-05-13T00:00:00.000000Z: 1616.790000
# 2022-05-14T00:00:00.000000Z: 1659.380000
# 2022-05-15T00:00:00.000000Z: 1703.450000
# 2022-05-16T00:00:00.000000Z: 1782.010000
# 2022-05-17T00:00:00.000000Z: 1687.980000
# 2022-05-18T00:00:00.000000Z: 1731.620000
# 2022-05-19T00:00:00.000000Z: 1610.740000
# 2022-05-20T00:00:00.000000Z: 1698.970000
# 2022-05-21T00:00:00.000000Z: 1641.220000
# 2022-05-22T00:00:00.000000Z: 1659.290000
# 2022-05-23T00:00:00.000000Z: 1708.540000
# 2022-05-24T00:00:00.000000Z: 1645.400000
# 2022-05-25T00:00:00.000000Z: 1670.400000
# 2022-05-26T00:00:00.000000Z: 1654.340000
# 2022-05-27T00:00:00.000000Z: 1592.130000
# 2022-05-28T00:00:00.000000Z: 1555.170000
# 2022-05-29T00:00:00.000000Z: 1589.280000
# 2022-05-30T00:00:00.000000Z: 1611.960000
# 2022-05-31T00:00:00.000000Z: 1744.630000
# blackListSet
# {'tusd', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# bitcoin
# ethereum
# stepn
# binancecoin
# solana
# apecoin
# ripple
# avalanche-2
# tron
# cardano
# fantom
# near
# polkadot
# shiba-inu
# dogecoin
# matic-network
# gala
# the-sandbox
# axie-infinity
# anchor-protocol
# litecoin
# cosmos
# jasmycoin
# zilliqa
# decentraland
# chainlink
# thorchain
# ethereum-name-service
# vechain
# mines-of-dalarnia
# waves
# monero
# filecoin
# oasis-network
# ethereum-classic
# smooth-love-potion
# kyber-network-crystal
# constitutiondao
# aave
# internet-computer
# algorand
# elrond-erd-2
# curve-dao-token
# loopring
# eos
# uniswap
# my-neighbor-alice
# harmony
# theta-token
# bitcoin-cash
# zcash
# the-graph
# sushi
# kava
# league-of-kingdoms
# dydx
# celo
# kusama
# chiliz
# pancakeswap-token
# alien-worlds
# immutable-x
# binaryx
# moonbeam
# enjincoin
# tezos
# wink
#    baseAsset     volInUSDT  lastAvgPriceUSDT      geckoId  medianMarketcap  \
# 0        BTC  2.852479e+09      31798.810261      bitcoin     5.761524e+11
# 2022-06-28T00:00:00.000000Z: 1151.790000
# 2022-06-29T00:00:00.000000Z: 1116.090000
# 2022-06-30T00:00:00.000000Z: 1097.990000
# blackListSet
# {'tusd', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# bitcoin
# ethereum
# solana
# binancecoin
# cardano
# ripple
# stepn
# avalanche-2
# tron
# dogecoin
# terra-luna-2
# chainlink
# apecoin
# matic-network
# shiba-inu
# polkadot
# near
# waves
# fantom
# gala
# the-sandbox
# optimism
# litecoin
# terra-luna
# thorchain
# decentraland
# cosmos
# anchor-protocol
# constitutiondao
# unifi-protocol-dao
# bella-protocol
# elrond-erd-2
# jasmycoin
# vechain
# internet-computer
# filecoin
# axie-infinity
# zilliqa
# project-galaxy
# bitcoin-cash
# theta-token
# monero
# litentry
# aave
# uniswap
# oasis-network
# my-neighbor-alice
# ethereum-classic
# ethereum-name-service
# moviebloc
# origin-protocol
# reserve-rights-token
# ftx-token
# algorand
# eos
# harmony
#    baseAsset     volInUSDT  lastAvgPriceUSDT        geckoId  medianMarketcap  \
# 0        BTC  2.897920e+09      19942.769382        bitcoin     4.105209e+11
# 1        ETH  2.585964e+09       1071.069121       ethereum     1.477098e+11
# 2        BNB  2.975129e+08        219.583176    binancecoin     3.836206e+10
# 3        XRP  1.797717e+08          0.332104         ripple     1.705814e+10
# 4        ADA  2.114560e+08          0.459914        cardano     1.678390e+10
# 5        SOL  3.151529e+08         33.756384         solana     1.267813e+10
# 6       DOGE  9.167177e+07          0.066448       dogecoin     9.013921e+09
# 7        DOT  7.366359e+07          7.062628       polkadot     8.869741e+09
# 8        TRX  1.033111e+08          0.064808           tron     6.092243e+09
# 9       SHIB  7.677916e+07          0.000010      shiba-inu     5.971914e+09
# 10      AVAX  1.261121e+08         16.989276    avalanche-2     5.355145e+09
# 11     MATIC  8.091558e+07          0.480808  matic-network     4.081237e+09
# 12       LTC  5.509812e+07         53.830205       litecoin     3.899598e+09
#
#     lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap  \
# 0     1.908174e+07            0.562623         0.562623   3.805427e+11
# 1     1.213593e+08            0.202438         0.765061   1.299842e+11
# 2     1.632352e+08            0.052576         0.817636   3.584371e+10
# 3     4.834310e+10            0.023378         0.841015   1.605493e+10
# 4     3.379341e+10            0.023002         0.864017   1.554205e+10
# 5     3.431148e+08            0.017376         0.881393   1.158232e+10
# 6     1.326708e+11            0.012354         0.893746   8.815702e+09
# 7     1.128769e+09            0.012156         0.905902   7.972079e+09
# 8     9.249564e+10            0.008349         0.914252   5.994436e+09
# 9     5.893889e+14            0.008185         0.922436   6.101161e+09
# 10    2.822280e+08            0.007339         0.929776   4.794849e+09
# 11    8.006804e+09            0.005593         0.935369   3.849737e+09
# 12    7.061876e+07            0.005344         0.940713   3.801422e+09
#
#       weight
# 0   0.603194
# 1   0.206037
# 2   0.056815
# 3   0.025448
# 4   0.024636
# 5   0.018359
# 6   0.013974
# 7   0.012636
# 8   0.009502
firstAltIndexData = await startIndex('2020-11-01T00:00:00.000000Z', '2020-12-01T00:00:00.000000Z', 1000, 'ONN-Alt-B-30dW-30dR', cacheConn, None, partial(getBlacklistSet, 'blacklist-alt.txt'))
computeDay = parse(firstAltIndexData.isoInstant) + datetime.timedelta(days = 1)
endDate = parse("2022-08-29T00:00:00.000000Z") + datetime.timedelta(days = 1)
lastIndex = firstAltIndexData
fileName = f"{firstAltIndexData.indexId}_{firstAltIndexData.isoInstant[:10]}_{str(endDate)[:10]}.json"
with open(fileName, 'w') as f:
    print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
    f.write('[\n')
    f.write(lastIndex.toJSON())
    while computeDay <= endDate:
        if(computeDay.day == 1):
            lastIndex = await lastIndexDataRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex, cacheConn, None, partial(getBlacklistSet, 'blacklist-alt.txt'))
        else:
            lastIndex = await lastIndexDataNoRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex)
        print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
        f.write(',\n')
        f.write(lastIndex.toJSON())
        computeDay = computeDay + datetime.timedelta(days = 1)
    f.write('\n]\n')
# Out:
# blackListSet
# {'tusd', 'wbtc', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'btc', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# ethereum
# chainlink
# yearn-finance
# litecoin
# ripple
# binancecoin
# bitcoin-cash
# uniswap
# cardano
# eos
# polkadot
# yfii-finance
# aave
# tron
# swipe
# sushi
# vechain
# curve-dao-token
# monero
# zcash
# filecoin
# tezos
# ethereum-classic
# neo
# cosmos
# stellar
# reserve-rights-token
# waves
# dash
# omisego
# band-protocol
# near
# alpha-finance
# havven
# republic-protocol
# civic
# tellor
# ocean-protocol
# kava
# theta-token
# ontology
# qtum
# thorchain
# algorand
# solana
# zilliqa
# compound-governance-token
# matic-network
# dia-data
# ankr
# basic-attention-token
# iostoken
# bittorrent-old
# iota
# serum
#    baseAsset     volInUSDT  lastAvgPriceUSDT           geckoId  \
# 0        ETH  8.656754e+08        616.664287          ethereum
# 1        XRP  1.256029e+08          0.664212            ripple
# 2       LINK  1.757122e+08         14.265454         chainlink
# 3        BCH  7.264516e+07        317.484899      bitcoin-cash
# 4        LTC  1.489384e+08         87.654205          litecoin
# 5        DOT  3.833155e+07          5.376746          polkadot
# 6        BNB  1.004437e+08         31.488570       binancecoin
# 7        ADA  5.294544e+07          0.172060           cardano
# 8        EOS  4.550082e+07          3.261507               eos
# 9        XMR  2.349528e+07        130.677915            monero
# 10       TRX  3.500758e+07          0.032354              tron
# 11       XLM  1.469151e+07          0.202894           stellar
# 12       XTZ  1.653046e+07          2.491238             tezos
# 2020-12-04T00:00:00.000000Z: 981.630000
# 2020-12-05T00:00:00.000000Z: 896.070000
# 2020-12-06T00:00:00.000000Z: 942.470000
# 2020-12-07T00:00:00.000000Z: 955.830000
# 2020-12-08T00:00:00.000000Z: 940.690000
# 2020-12-09T00:00:00.000000Z: 878.010000
# 2020-12-10T00:00:00.000000Z: 906.050000
# 2020-12-11T00:00:00.000000Z: 882.580000
# 2020-12-12T00:00:00.000000Z: 858.560000
# 2020-12-13T00:00:00.000000Z: 875.310000
# 2020-12-14T00:00:00.000000Z: 908.990000
# 2020-12-15T00:00:00.000000Z: 902.200000
# 2020-12-16T00:00:00.000000Z: 895.850000
# 2020-12-17T00:00:00.000000Z: 985.300000
# 2020-12-18T00:00:00.000000Z: 990.770000
# 2020-12-19T00:00:00.000000Z: 1006.580000
# 2020-12-20T00:00:00.000000Z: 1014.200000
# 2020-12-21T00:00:00.000000Z: 991.720000
# 2020-12-22T00:00:00.000000Z: 933.070000
# 2020-12-23T00:00:00.000000Z: 946.590000
# 2020-12-24T00:00:00.000000Z: 811.430000
# 2020-12-25T00:00:00.000000Z: 883.290000
# 2020-12-26T00:00:00.000000Z: 900.010000
# 2020-12-27T00:00:00.000000Z: 903.430000
# 2020-12-28T00:00:00.000000Z: 935.630000
# 2020-12-29T00:00:00.000000Z: 984.660000
# 2020-12-30T00:00:00.000000Z: 980.770000
# 2020-12-31T00:00:00.000000Z: 987.330000
# blackListSet
# {'tusd', 'wbtc', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'btc', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# ethereum
# ripple
# litecoin
# bitcoin-cash
# binancecoin
# chainlink
# cardano
# yearn-finance
# eos
# stellar
# sushi
# polkadot
# tron
# aave
# vechain
# zilliqa
# uniswap
# monero
# filecoin
# elrond-erd-2
# theta-token
# nem
# ethereum-classic
# zcash
# unifi-protocol-dao
# waves
# neo
# dash
# swipe
# algorand
# injective-protocol
# havven
# cosmos
# tezos
# oasis-network
# curve-dao-token
# omisego
# band-protocol
# yfii-finance
# skale
# compound-governance-token
# theta-fuel
# kava-lend
# ontology
# ocean-protocol
# reserve-rights-token
# thorchain
# near
# kusama
# iostoken
# basic-attention-token
# coti
# iota
# terra-luna
# dogecoin
# qtum
# chiliz
# republic-protocol
# alpha-finance
# keep3rv1
#    baseAsset     volInUSDT  lastAvgPriceUSDT       geckoId  medianMarketcap  \
# 0        ETH  9.785287e+08        736.383567      ethereum     6.983237e+10
# 1        XRP  5.461872e+08          0.219566        ripple     2.437093e+10
# 2        LTC  2.798965e+08        124.216852      litecoin     6.085811e+09
# 3        BCH  1.124867e+08        342.109816  bitcoin-cash     5.429744e+09
# 4       LINK  9.958130e+07         11.236749     chainlink     5.028525e+09
# 5        ADA  9.072983e+07          0.181340       cardano     4.881394e+09
# 6        DOT  3.764692e+07          9.261683      polkadot     4.858717e+09
# 7        BNB  1.020633e+08         37.358518   binancecoin     4.509991e+09
# 2021-01-08T00:00:00.000000Z: 1491.550000
# 2021-01-09T00:00:00.000000Z: 1474.190000
# 2021-01-10T00:00:00.000000Z: 1565.250000
# 2021-01-11T00:00:00.000000Z: 1534.290000
# 2021-01-12T00:00:00.000000Z: 1338.670000
# 2021-01-13T00:00:00.000000Z: 1309.910000
# 2021-01-14T00:00:00.000000Z: 1425.330000
# 2021-01-15T00:00:00.000000Z: 1530.210000
# 2021-01-16T00:00:00.000000Z: 1466.280000
# 2021-01-17T00:00:00.000000Z: 1553.500000
# 2021-01-18T00:00:00.000000Z: 1569.440000
# 2021-01-19T00:00:00.000000Z: 1597.800000
# 2021-01-20T00:00:00.000000Z: 1663.400000
# 2021-01-21T00:00:00.000000Z: 1685.660000
# 2021-01-22T00:00:00.000000Z: 1401.100000
# 2021-01-23T00:00:00.000000Z: 1534.920000
# 2021-01-24T00:00:00.000000Z: 1556.890000
# 2021-01-25T00:00:00.000000Z: 1676.460000
# 2021-01-26T00:00:00.000000Z: 1603.050000
# 2021-01-27T00:00:00.000000Z: 1640.000000
# 2021-01-28T00:00:00.000000Z: 1496.020000
# 2021-01-29T00:00:00.000000Z: 1610.820000
# 2021-01-30T00:00:00.000000Z: 1655.480000
# 2021-01-31T00:00:00.000000Z: 1714.320000
# blackListSet
# {'tusd', 'wbtc', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'btc', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# ethereum
# polkadot
# litecoin
# chainlink
# ripple
# cardano
# bitcoin-cash
# binancecoin
# stellar
# eos
# uniswap
# sushi
# yearn-finance
# vechain
# aave
# tron
# curve-dao-token
# the-graph
# swipe
# cosmos
# neo
# theta-token
# iostoken
# ethereum-classic
# zcash
# zilliqa
# tezos
# havven
# monero
# elrond-erd-2
# algorand
# dogecoin
# omisego
# 1inch
# dash
# band-protocol
# reserve-rights-token
# filecoin
# alpha-finance
# solana
# nem
# qtum
# enjincoin
# ontology
# waves
# republic-protocol
# loopring
# avalanche-2
# near
# hedera-hashgraph
#    baseAsset     volInUSDT  lastAvgPriceUSDT       geckoId  medianMarketcap  \
# 0        ETH  3.843625e+09       1312.570203      ethereum     1.411019e+11
# 1        DOT  4.387007e+08         16.113764      polkadot     1.485573e+10
# 2        XRP  3.496491e+08          0.495185        ripple     1.264934e+10
# 3        ADA  3.448142e+08          0.344692       cardano     1.035520e+10
# 4        LTC  4.084202e+08        129.362628      litecoin     9.415226e+09
# 5       LINK  3.598829e+08         22.560279     chainlink     8.213089e+09
# 6        BCH  2.269958e+08        399.328865  bitcoin-cash     8.155137e+09
# 7        XLM  1.855409e+08          0.306977       stellar     6.325116e+09
# 8        BNB  2.123090e+08         44.333967   binancecoin     6.116758e+09
# 9        EOS  1.239635e+08          2.929642           eos     2.630887e+09
# 10       XMR  4.262329e+07        137.744298        monero     2.506885e+09
# 11       TRX  8.054858e+07          0.031521          tron     2.145965e+09
# 12       SNX  4.319550e+07         17.194832        havven     2.117865e+09
# 2021-02-17T00:00:00.000000Z: 2502.600000
# 2021-02-18T00:00:00.000000Z: 2629.600000
# 2021-02-19T00:00:00.000000Z: 2715.680000
# 2021-02-20T00:00:00.000000Z: 2910.660000
# 2021-02-21T00:00:00.000000Z: 2844.990000
# 2021-02-22T00:00:00.000000Z: 2921.810000
# 2021-02-23T00:00:00.000000Z: 2736.310000
# 2021-02-24T00:00:00.000000Z: 2398.200000
# 2021-02-25T00:00:00.000000Z: 2475.380000
# 2021-02-26T00:00:00.000000Z: 2303.770000
# 2021-02-27T00:00:00.000000Z: 2296.800000
# 2021-02-28T00:00:00.000000Z: 2356.100000
# blackListSet
# {'tusd', 'wbtc', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'btc', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 82    BQX
# Name: baseAsset, dtype: object
# ethereum
# binancecoin
# cardano
# ripple
# polkadot
# dogecoin
# litecoin
# chainlink
# eos
# bitcoin-cash
# stellar
# swipe
# tron
# uniswap
# sushi
# aave
# the-graph
# vechain
# cosmos
# terra-luna
# elrond-erd-2
# reef
# matic-network
# avalanche-2
# filecoin
# 1inch
# algorand
# ontology
# neo
# iostoken
# yearn-finance
# tezos
# iota
# alpha-finance
# venus
# zcash
# dash
# monero
# curve-dao-token
# omisego
# ethereum-classic
# fantom
# pancakeswap-token
# band-protocol
# zilliqa
# theta-token
# havven
# nem
# icon
# solana
# republic-protocol
# qtum
# 0x
# compound-governance-token
# thorchain
# reserve-rights-token
# basic-attention-token
# serum
# chiliz
# ravencoin
# kava
# ocean-protocol
# near
# waves
# enjincoin
# unifi-protocol-dao
# hedera-hashgraph
# bittorrent-old
# yfii-finance
# kusama
# coti
# the-sandbox
# tomochain
# ankr
# fetch-ai
# nano
# loopring
# harmony
# kyber-network-crystal
# mainframe
# holotoken
# decentraland
# injective-protocol
# dia-data
# maker
# flamingo-finance
# ftx-token
# storm
# pundi-x
# btc-standard-hashrate-token
# tellor
#    baseAsset     volInUSDT  lastAvgPriceUSDT       geckoId  medianMarketcap  \
# 0        ETH  3.424310e+09       1419.117549      ethereum     1.979582e+11
# 1        ADA  1.127870e+09          1.312295       cardano     2.854398e+10
# 2        DOT  7.441913e+08         33.798321      polkadot     2.766387e+10
# 3        XRP  8.201686e+08          0.415578        ripple     2.135350e+10
# 4        BNB  1.402499e+09        210.213126   binancecoin     1.976983e+10
# 5        LTC  4.946607e+08        165.208760      litecoin     1.190989e+10
# 6       LINK  3.283065e+08         24.696829     chainlink     1.108731e+10
# 7        BCH  2.853714e+08        460.121781  bitcoin-cash     9.536239e+09
# 8        XLM  2.404296e+08          0.405615       stellar     9.192463e+09
# 9       DOGE  6.094459e+08          0.048111      dogecoin     7.032573e+09
# 10       UNI  1.691043e+08         22.208407       uniswap     6.334566e+09
# 11      AAVE  1.635151e+08        354.196891          aave     5.397868e+09
# 16  0.008323
# 17  0.007811
# 18  0.006980
# 19  0.007923
# 20  0.006624
# 21  0.006561
# 22  0.006324
# 23  0.005568
# 24  0.005749
# 25  0.004723
# 26  0.008772
# 27  0.004678
# 2021-03-01T00:00:00.000000Z: 2292.890000
# 2021-03-02T00:00:00.000000Z: 2503.120000
# 2021-03-03T00:00:00.000000Z: 2428.490000
# 2021-03-04T00:00:00.000000Z: 2513.520000
# 2021-03-05T00:00:00.000000Z: 2448.800000
# 2021-03-06T00:00:00.000000Z: 2424.850000
# 2021-03-07T00:00:00.000000Z: 2510.200000
# 2021-03-08T00:00:00.000000Z: 2613.900000
# 2021-03-09T00:00:00.000000Z: 2715.740000
# 2021-03-10T00:00:00.000000Z: 2849.010000
# 2021-03-11T00:00:00.000000Z: 2734.160000
# 2021-03-12T00:00:00.000000Z: 2765.160000
# 2021-03-13T00:00:00.000000Z: 2656.570000
# 2021-03-14T00:00:00.000000Z: 2835.080000
# 2021-03-15T00:00:00.000000Z: 2723.420000
# 2021-03-16T00:00:00.000000Z: 2649.670000
# 2021-03-17T00:00:00.000000Z: 2738.150000
# 2021-03-18T00:00:00.000000Z: 2815.510000
# 2021-03-19T00:00:00.000000Z: 2732.160000
# 2021-03-20T00:00:00.000000Z: 2799.780000
# 2021-03-21T00:00:00.000000Z: 2799.240000
# 2021-03-22T00:00:00.000000Z: 2780.280000
# 2021-03-23T00:00:00.000000Z: 2655.450000
# 2021-03-24T00:00:00.000000Z: 2650.150000
# 2021-03-25T00:00:00.000000Z: 2482.080000
# 2021-03-26T00:00:00.000000Z: 2487.710000
# 2021-03-27T00:00:00.000000Z: 2690.190000
# 2021-03-28T00:00:00.000000Z: 2690.230000
# 2021-03-29T00:00:00.000000Z: 2685.280000
# 2021-03-30T00:00:00.000000Z: 2824.670000
# 2021-03-31T00:00:00.000000Z: 2871.250000
# blackListSet
# {'tusd', 'wbtc', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'btc', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# ethereum
# binancecoin
# cardano
# chiliz
# ripple
# polkadot
# enjincoin
# litecoin
# theta-token
# swipe
# chainlink
# terra-luna
# vechain
# harmony
# filecoin
# uniswap
# nem
# pancakeswap-token
# eos
# holotoken
# tron
# dogecoin
# matic-network
# bitcoin-cash
# avalanche-2
# stellar
# theta-fuel
# reef
# coti
# decentraland
# sushi
# bittorrent-old
# algorand
# ankr
# ontology
# the-graph
# fantom
# hedera-hashgraph
# aave
# the-sandbox
# chromaway
# cosmos
# pundi-x
# iostoken
# sun-token
# celer-network
# zilliqa
# solana
# curve-dao-token
# neo
# elrond-erd-2
# ravencoin
# 1inch
# dent
# fetch-ai
# venus
# safepal
# storm
# basic-attention-token
# iota
# tezos
# kusama
# monero
# alpha-finance
# qtum
# reserve-rights-token
# audius
# dash
# siacoin
# icon
# zcash
# omisego
# ethereum-classic
# ocean-protocol
# kava
# origin-protocol
# skale
# bluzelle
# selfkey
# serum
# axie-infinity
# near
# yearn-finance
# litentry
# oasis-network
# republic-protocol
# band-protocol
# thorchain
# dodo
# 0x
# tomochain
# arpa-chain
# vethor-token
# kyber-network-crystal
# perlin
# vite
# kava-lend
# akropolis
# nervos-network
# the-virtua-kolect
# havven
# unifi-protocol-dao
# dia-data
# ftx-token
# contentos
# bancor
# iotex
# wink
# loopring
# troy
# compound-governance-token
# verge
# storj
# lto-network
# bakerytoken
# orion-protocol
# just
# pnetwork
# dock
# cartesi
# waltonchain
# orchid-protocol
# bella-protocol
# digibyte
# waves
# civic
# aion
# helium
# mithril
# flamingo-finance
#    baseAsset     volInUSDT  lastAvgPriceUSDT       geckoId  medianMarketcap  \
# 0        ETH  2.529378e+09       1919.253375      ethereum     2.052500e+11
# 1        BNB  1.285202e+09        302.395268   binancecoin     4.073682e+10
# 2        ADA  6.950713e+08          1.191785       cardano     3.806077e+10
# 3        DOT  3.642487e+08         37.079380      polkadot     3.427047e+10
# 4        XRP  3.907408e+08          0.569842        ripple     2.162961e+10
# 5        UNI  1.462661e+08         28.033776       uniswap     1.557822e+10
# 6        LTC  2.553194e+08        196.705412      litecoin     1.298726e+10
# 7       LINK  1.936521e+08         29.420389     chainlink     1.163647e+10
# 8        BCH  1.023227e+08        541.022425  bitcoin-cash     9.796704e+09
# 9        XLM  9.976552e+07          0.405647       stellar     9.143084e+09
# 10     THETA  2.235183e+08         12.327599   theta-token     7.534605e+09
# 11      DOGE  1.199142e+08          0.053720      dogecoin     7.082243e+09
# 12      LUNA  1.934247e+08         18.667373    terra-luna     6.619085e+09
# 13       VET  1.933903e+08          0.087693       vechain     4.976009e+09
# 14      AAVE  7.280816e+07        382.523667          aave     4.647390e+09
# 15      ATOM  6.661970e+07         19.081514        cosmos     4.590561e+09
# 16       XMR  4.449008e+07        245.934567        monero     3.976229e+09
# 17       EOS  1.328536e+08          4.801694           eos     3.869745e+09
# 18       SOL  5.729359e+07         19.387486        solana     3.823885e+09
# 19       TRX  1.303145e+08          0.092933          tron     3.819723e+09
# 20      IOTA  4.593710e+07          1.538123          iota     3.735077e+09
# 21      AVAX  1.002046e+08         28.721980   avalanche-2     3.687056e+09
# 22       FIL  1.671899e+08        190.852726      filecoin     3.590450e+09
# 23       XEM  1.352822e+08          0.368673           nem     3.468855e+09
# 24       FTT  1.787679e+07         39.890172     ftx-token     3.296609e+09
# 25       XTZ  4.590995e+07          4.827443         tezos     3.154527e+09
# 26       KSM  4.552935e+07        495.570372        kusama     2.936099e+09
# 27       SNX  1.894822e+07         17.651293        havven     2.918470e+09
# 28       NEO  5.454796e+07         50.774645           neo     2.913328e+09
# 29      ALGO  8.298833e+07          1.366740      algorand     2.886625e+09
# 30       CHZ  4.799586e+08          0.500379        chiliz     2.762532e+09
#
#     lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap
# 2021-04-17T00:00:00.000000Z: 4340.270000
# 2021-04-18T00:00:00.000000Z: 4169.330000
# 2021-04-19T00:00:00.000000Z: 3988.020000
# 2021-04-20T00:00:00.000000Z: 3890.890000
# 2021-04-21T00:00:00.000000Z: 4084.730000
# 2021-04-22T00:00:00.000000Z: 3962.690000
# 2021-04-23T00:00:00.000000Z: 3825.030000
# 2021-04-24T00:00:00.000000Z: 3807.170000
# 2021-04-25T00:00:00.000000Z: 3576.340000
# 2021-04-26T00:00:00.000000Z: 3661.350000
# 2021-04-27T00:00:00.000000Z: 4079.140000
# 2021-04-28T00:00:00.000000Z: 4271.080000
# 2021-04-29T00:00:00.000000Z: 4344.860000
# 2021-04-30T00:00:00.000000Z: 4361.400000
# blackListSet
# {'tusd', 'wbtc', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'btc', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 116    BZRX
# 133    RAMP
# Name: baseAsset, dtype: object
# ethereum
# binancecoin
# ripple
# dogecoin
# cardano
# wink
# vechain
# tron
# litecoin
# polkadot
# bittorrent-old
# chiliz
# eos
# pancakeswap-token
# holotoken
# swipe
# filecoin
# chainlink
# bitcoin-cash
# dent
# stellar
# theta-token
# solana
# uniswap
# neo
# enjincoin
# ontology
# terra-luna
# ethereum-classic
# harmony
# iostoken
# cosmos
# aave
# avalanche-2
# elrond-erd-2
# matic-network
# siacoin
# qtum
# zcash
# iota
# wazirx
# monero
# sushi
# dash
# algorand
# tezos
# thorchain
# the-graph
# nkn
# zilliqa
# curve-dao-token
# nem
# omisego
# reef
# ankr
# 1inch
# hedera-hashgraph
# decentraland
# serum
# mithril
# ftx-token
# sun-token
# venus
# yearn-finance
# origin-protocol
# basic-attention-token
# fantom
# storm
# kusama
# reserve-rights-token
# band-protocol
# ravencoin
# coti
# theta-fuel
# verge
# alpha-finance
# chromaway
# icon
# compound-governance-token
# waves
# paris-saint-germain-fan-token
# storj
# fetch-ai
# celer-network
# btc-standard-hashrate-token
# dodo
# zencash
# safepal
# the-sandbox
# digibyte
# near
# vethor-token
# linear
# 0x
# audius
# republic-protocol
# axie-infinity
# litentry
# my-neighbor-alice
# kava
# cartesi
# maker
# metal
# flamingo-finance
# havven
# gifto
# vite
# kyber-network-crystal
# just
# ocean-protocol
# dia-data
# tellor
# nano
# tomochain
# akropolis
# loopring
# bluzelle
# blockstack
# skale
# nervos-network
# civic
# helium
# oasis-network
# dego-finance
# force-protocol
# moviebloc
# bakerytoken
# bitshares
# iotex
# funfair
# arpa-chain
# bella-protocol
# bitcoin-gold
# yfii-finance
# injective-protocol
# marlin
#    baseAsset     volInUSDT  lastAvgPriceUSDT         geckoId  medianMarketcap  \
# 0        ETH  3.425702e+09       2772.501102        ethereum     2.633113e+11
# 1        BNB  3.164454e+09        622.657051     binancecoin     7.934024e+10
# 2        XRP  2.843658e+09          1.598790          ripple     6.035981e+10
# harmony
# iota
# algorand
# hedera-hashgraph
# 1inch
# my-neighbor-alice
# compound-governance-token
# iostoken
# the-graph
# elrond-erd-2
# serum
# cartesi
# nano
# maker
# zencash
# havven
# decentraland
# wazirx
# nem
# coti
# smooth-love-potion
# siacoin
# near
# kava
# chromaway
# theta-fuel
# tokocrypto
# alpha-finance
#    baseAsset     volInUSDT  lastAvgPriceUSDT            geckoId  \
# 0        ETH  7.778202e+09       2706.359562           ethereum
# 1        BNB  2.627767e+09        353.361224        binancecoin
# 2        XRP  2.040923e+09          1.040980             ripple
# 3       DOGE  3.359639e+09          0.325585           dogecoin
# 4        ADA  1.816824e+09          1.737280            cardano
# 5        DOT  9.127012e+08         23.265474           polkadot
# 6        UNI  2.311308e+08         28.242457            uniswap
# 7        BCH  4.323814e+08        702.483475       bitcoin-cash
# 8        LTC  6.907917e+08        187.982395           litecoin
# 9       LINK  5.824540e+08         32.096388          chainlink
# 10       XLM  2.552351e+08          0.402446            stellar
# 11       SOL  2.638076e+08         32.765180             solana
# 12       VET  5.448721e+08          0.125901            vechain
# 13       ETC  8.976715e+08         70.031163   ethereum-classic
# 14     THETA  2.154610e+08          7.107242        theta-token
# 15     MATIC  1.374094e+09          1.871324      matic-network
# 16       TRX  3.458827e+08          0.076791               tron
# 17       FIL  1.978755e+08         72.521171           filecoin
# 18       XMR  1.006982e+08        272.330768             monero
# 19       EOS  7.175741e+08          6.629327                eos
# 20       NEO  1.813328e+08         55.867443                neo
# 21      LUNA  2.060011e+08          6.546479         terra-luna
# 22      AAVE  1.939097e+08        382.448607               aave
# 23      ATOM  1.132069e+08         13.962529             cosmos
# 24      IOTA  7.185221e+07          1.114865               iota
# 25      CAKE  2.880916e+08         17.927817  pancakeswap-token
#
#     medianMarketcap  lastCircSupply  fracTotalMarketCap  accumulatedPerc  \
# 0      3.757197e+11    1.163331e+08            0.391597         0.391597
# 1      8.502493e+10    1.540556e+08            0.088618         0.480214
# 2      6.357056e+10    4.619152e+10            0.066257         0.546471
# 3      5.668051e+10    1.298269e+11            0.059076         0.605547
# 4      5.199892e+10    3.206822e+10            0.054196         0.659743
# 5      3.631123e+10    9.981136e+08            0.037846         0.697589
# 6      1.876618e+10    5.196004e+08            0.019559         0.717148
# 7      1.874422e+10    1.874535e+07            0.019536         0.736684
# 8      1.848421e+10    6.674607e+07            0.019265         0.755950
# 9      1.706745e+10    4.246738e+08            0.017789         0.773738
# 10     1.247928e+10    2.301922e+10            0.013007         0.786745
# 11     1.181223e+10    2.711142e+08            0.012311         0.799056
# 12     1.126811e+10    6.506110e+10            0.011744         0.810800
# 13     9.944752e+09    1.278573e+08            0.010365         0.821165
# 14     9.576652e+09    9.971874e+08            0.009981         0.831147
# 15     8.923660e+09    6.262090e+09            0.009301         0.840448
# 16     8.475494e+09    7.152142e+10            0.008834         0.849281
# 17     7.644366e+09    7.494830e+07            0.007967         0.857249
# 18     6.886218e+09    1.784222e+07            0.007177         0.864426
# 19     6.488135e+09    9.581758e+08            0.006762         0.871188
# 2022-06-02T00:00:00.000000Z: 1905.220000
# 2022-06-03T00:00:00.000000Z: 1940.270000
# 2022-06-04T00:00:00.000000Z: 1871.190000
# 2022-06-05T00:00:00.000000Z: 1898.510000
# 2022-06-06T00:00:00.000000Z: 1895.910000
# 2022-06-07T00:00:00.000000Z: 1949.030000
# 2022-06-08T00:00:00.000000Z: 1907.360000
# 2022-06-09T00:00:00.000000Z: 1890.500000
# 2022-06-10T00:00:00.000000Z: 1893.310000
# 2022-06-11T00:00:00.000000Z: 1776.210000
# 2022-06-12T00:00:00.000000Z: 1650.100000
# 2022-06-13T00:00:00.000000Z: 1539.230000
# 2022-06-14T00:00:00.000000Z: 1338.580000
# 2022-06-15T00:00:00.000000Z: 1345.840000
# 2022-06-16T00:00:00.000000Z: 1421.520000
# 2022-06-17T00:00:00.000000Z: 1245.150000
# 2022-06-18T00:00:00.000000Z: 1273.030000
# 2022-06-19T00:00:00.000000Z: 1185.090000
# 2022-06-20T00:00:00.000000Z: 1311.750000
# 2022-06-21T00:00:00.000000Z: 1320.120000
# 2022-06-22T00:00:00.000000Z: 1337.710000
# 2022-06-23T00:00:00.000000Z: 1268.360000
# 2022-06-24T00:00:00.000000Z: 1367.950000
# 2022-06-25T00:00:00.000000Z: 1453.520000
# 2022-06-26T00:00:00.000000Z: 1470.750000
# 2022-06-27T00:00:00.000000Z: 1422.530000
# 2022-06-28T00:00:00.000000Z: 1412.190000
# 2022-06-29T00:00:00.000000Z: 1348.220000
# 2022-06-30T00:00:00.000000Z: 1312.460000
# blackListSet
# {'tusd', 'wbtc', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'btc', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# ethereum
# solana
# binancecoin
# cardano
# ripple
# stepn
# avalanche-2
# tron
# dogecoin
# terra-luna-2
# chainlink
# apecoin
# matic-network
# shiba-inu
# polkadot
# near
# waves
# fantom
# gala
# the-sandbox
# optimism
# litecoin
# terra-luna
# thorchain
# decentraland
# cosmos
# anchor-protocol
# constitutiondao
# unifi-protocol-dao
# bella-protocol
# elrond-erd-2
# jasmycoin
# vechain
# internet-computer
# filecoin
# axie-infinity
# zilliqa
# project-galaxy
# bitcoin-cash
# theta-token
# monero
# litentry
# aave
# uniswap
# oasis-network
# my-neighbor-alice
# ethereum-classic
# ethereum-name-service
# moviebloc
# origin-protocol
# reserve-rights-token
# ftx-token
# algorand
# eos
# harmony
# stellar
# chiliz
#    baseAsset     volInUSDT  lastAvgPriceUSDT           geckoId  \
# 0        ETH  2.585964e+09       1071.069121          ethereum
# 1        BNB  2.975129e+08        219.583176       binancecoin
# 2        XRP  1.797717e+08          0.332104            ripple
# 3        ADA  2.114560e+08          0.459914           cardano
# 4        SOL  3.151529e+08         33.756384            solana
# 5       DOGE  9.167177e+07          0.066448          dogecoin
# 6        DOT  7.366359e+07          7.062628          polkadot
# 7        TRX  1.033111e+08          0.064808              tron
# 8       SHIB  7.677916e+07          0.000010         shiba-inu
# 2022-07-02T00:00:00.000000Z: 1269.540000
# 2022-07-03T00:00:00.000000Z: 1279.570000
# 2022-07-04T00:00:00.000000Z: 1286.280000
# 2022-07-05T00:00:00.000000Z: 1362.250000
# 2022-07-06T00:00:00.000000Z: 1340.570000
# 2022-07-07T00:00:00.000000Z: 1388.090000
# 2022-07-08T00:00:00.000000Z: 1441.260000
# 2022-07-09T00:00:00.000000Z: 1420.270000
# 2022-07-10T00:00:00.000000Z: 1433.300000
# 2022-07-11T00:00:00.000000Z: 1377.330000
# 2022-07-12T00:00:00.000000Z: 1297.670000
# 2022-07-13T00:00:00.000000Z: 1247.450000
# 2022-07-14T00:00:00.000000Z: 1326.090000
# 2022-07-15T00:00:00.000000Z: 1395.950000
# 2022-07-16T00:00:00.000000Z: 1419.910000
# 2022-07-17T00:00:00.000000Z: 1523.970000
# 2022-07-18T00:00:00.000000Z: 1502.260000
# 2022-07-19T00:00:00.000000Z: 1709.850000
# 2022-07-20T00:00:00.000000Z: 1705.870000
# 2022-07-21T00:00:00.000000Z: 1660.370000
# 2022-07-22T00:00:00.000000Z: 1712.200000
# 2022-07-23T00:00:00.000000Z: 1665.740000
# 2022-07-24T00:00:00.000000Z: 1675.950000
# 2022-07-25T00:00:00.000000Z: 1710.420000
# 2022-07-26T00:00:00.000000Z: 1558.570000
# 2022-07-27T00:00:00.000000Z: 1568.330000
# 2022-07-28T00:00:00.000000Z: 1746.680000
# 2022-07-29T00:00:00.000000Z: 1830.780000
# 2022-07-30T00:00:00.000000Z: 1842.320000
# 2022-07-31T00:00:00.000000Z: 1830.030000
# blackListSet
# {'tusd', 'wbtc', 'dai', 'usdp', 'aud', 'usdd', 'frax', 'usdn', 'ust', 'mimatic', 'eur', 'pax', 'btc', 'busd', 'usdt', 'usdc', 'gbp', 'mim'}
# no whitelist being used
# ethereum
# solana
# binancecoin
# matic-network
# ripple
# cardano
# avalanche-2
# stepn
# apecoin
# shiba-inu
# thorchain
# polkadot
# the-sandbox
# chainlink
# dogecoin
# near
# cosmos
# tron
# fantom
# gala
# uniswap
# litecoin
# terrausd
# waves
# terra-luna
# burger-swap
# ethereum-classic
# decentraland
# aave
# dydx
# filecoin
# terra-luna-2
# curve-dao-token
# jasmycoin
# internet-computer
# unifi-protocol-dao
# barnbridge
# monero
# vechain
# optimism
# harmony
# axie-infinity
# zilliqa
# ethereum-name-service
# elrond-erd-2
# havven
# lido-dao
# ftx-token
# chiliz
# algorand
# constitutiondao
# bitcoin-cash
# oasis-network
# sushi
# origin-protocol
# eos
#    baseAsset     volInUSDT  lastAvgPriceUSDT           geckoId  \
# 0        ETH  2.586683e+09       1678.221954          ethereum
# 1        BNB  2.311008e+08        283.396385       binancecoin
# 2        XRP  1.396177e+08          0.379186            ripple
# 3        ADA  1.332197e+08          0.516147           cardano
# 4        SOL  2.691987e+08         42.352222            solana
# 5       DOGE  5.665694e+07          0.068070          dogecoin
# 6        DOT  7.041981e+07          8.621758          polkadot
# 7       SHIB  8.187313e+07          0.000012         shiba-inu
# 2022-08-04T00:00:00.000000Z: 1762.380000
# 2022-08-05T00:00:00.000000Z: 1771.040000
# 2022-08-06T00:00:00.000000Z: 1875.780000
# 2022-08-07T00:00:00.000000Z: 1840.910000
# 2022-08-08T00:00:00.000000Z: 1862.230000
# 2022-08-09T00:00:00.000000Z: 1923.760000
# 2022-08-10T00:00:00.000000Z: 1858.260000
# 2022-08-11T00:00:00.000000Z: 1980.140000
# 2022-08-12T00:00:00.000000Z: 1985.780000
# 2022-08-13T00:00:00.000000Z: 2049.550000
# 2022-08-14T00:00:00.000000Z: 2067.000000
# 2022-08-15T00:00:00.000000Z: 2041.000000
# 2022-08-16T00:00:00.000000Z: 2001.550000
# 2022-08-17T00:00:00.000000Z: 1991.380000
# 2022-08-18T00:00:00.000000Z: 1935.650000
# 2022-08-19T00:00:00.000000Z: 1910.840000
# 2022-08-20T00:00:00.000000Z: 1700.970000
# 2022-08-21T00:00:00.000000Z: 1686.330000
# 2022-08-22T00:00:00.000000Z: 1739.950000
# 2022-08-23T00:00:00.000000Z: 1737.770000
# 2022-08-24T00:00:00.000000Z: 1770.810000
# 2022-08-25T00:00:00.000000Z: 1757.010000
# 2022-08-26T00:00:00.000000Z: 1790.790000
# 2022-08-27T00:00:00.000000Z: 1621.660000
# 2022-08-28T00:00:00.000000Z: 1612.210000
# 2022-08-29T00:00:00.000000Z: 1555.460000
# 2022-08-30T00:00:00.000000Z: 1661.840000

# %% [markdown]
# ## And now the ONN-Vapour Index

# %%
import datetime
firstVapIndexData = await startIndex('2020-11-01T00:00:00.000000Z', '2020-12-01T00:00:00.000000Z', 1000, 'ONN-Vap-B-30dW-30dR', cacheConn, None, partial(getBlacklistSet, 'blacklist-vapour.txt'))
computeDay = parse(firstVapIndexData.isoInstant) + datetime.timedelta(days = 1)
endDate = parse("2022-08-29T00:00:00.000000Z") + datetime.timedelta(days = 1)
lastIndex = firstVapIndexData
fileName = f"{firstVapIndexData.indexId}_{firstVapIndexData.isoInstant[:10]}_{str(endDate)[:10]}.json"
with open(fileName, 'w') as f:
    print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
    f.write('[\n')
    f.write(lastIndex.toJSON())
    while computeDay <= endDate:
        if(computeDay.day == 1):
            lastIndex = await lastIndexDataRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex, cacheConn, None, partial(getBlacklistSet, 'blacklist-vapour.txt'))
        else:
            lastIndex = await lastIndexDataNoRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex)
        print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
        f.write(',\n')
        f.write(lastIndex.toJSON())
        computeDay = computeDay + datetime.timedelta(days = 1)
    f.write('\n]\n')
# Out:
# blackListSet
# {'dai', 'eth', 'tusd', 'usdp', 'aud', 'frax', 'usdn', 'ust', 'eur', 'btc', 'mimatic', 'wbtc', 'usdc', 'pax', 'gbp', 'mim', 'weth', 'usdd', 'busd', 'usdt'}
# no whitelist being used
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 55    BZRX
# 94    EASY
# Name: baseAsset, dtype: object
# chainlink
# yearn-finance
# litecoin
# ripple
# binancecoin
# bitcoin-cash
# uniswap
# cardano
# eos
# polkadot
# yfii-finance
# aave
# tron
# swipe
# sushi
# vechain
# curve-dao-token
# monero
# zcash
# filecoin
# tezos
# ethereum-classic
# neo
# cosmos
# stellar
# reserve-rights-token
# waves
# dash
# omisego
# band-protocol
# near
# alpha-finance
# havven
# republic-protocol
# civic
# tellor
# ocean-protocol
# kava
# theta-token
# ontology
# qtum
# thorchain
# algorand
# solana
# zilliqa
# compound-governance-token
# matic-network
# dia-data
# ankr
# basic-attention-token
# iostoken
# bittorrent-old
# iota
# serum
# venus
# district0x
# certik
# kyber-network-crystal
# fantom
# nem
# elrond-erd-2
# kusama
# coti
# loopring
# 0x
# balancer
# flamingo-finance
# injective-protocol
# bella-protocol
# icon
# fetch-ai
# dogecoin
# lto-network
# tomochain
# arpa-chain
# decentraland
# avalanche-2
# enjincoin
# iexec-rlc
# maker
# harmony
# the-sandbox
# origin-protocol
# aragon
# wing-finance
# blockstack
# wrapped-nxm
# storj
# ravencoin
# audius
# terra-luna
# digibyte
# bluzelle
# bancor
# utrust
# orchid-protocol
# hedera-hashgraph
# just
# celer-network
# wink
# decred
# ftx-token
# wanchain
# cartesi
# nano
# concierge-io
# theta-fuel
# chromaway
#    baseAsset     volInUSDT  lastAvgPriceUSDT                    geckoId  \
# 0        XRP  1.256029e+08          0.664212                     ripple
# 1       LINK  1.757122e+08         14.265454                  chainlink
# 2        BCH  7.264516e+07        317.484899               bitcoin-cash
# 3        LTC  1.489384e+08         87.654205                   litecoin
# 4        DOT  3.833155e+07          5.376746                   polkadot
# 5        BNB  1.004437e+08         31.488570                binancecoin
# 6        ADA  5.294544e+07          0.172060                    cardano
# 7        EOS  4.550082e+07          3.261507                        eos
# 8        XMR  2.349528e+07        130.677915                     monero
# 9        TRX  3.500758e+07          0.032354                       tron
# 10       XLM  1.469151e+07          0.202894                    stellar
# 11       XTZ  1.653046e+07          2.491238                      tezos
# 12      ATOM  1.492854e+07          5.570883                     cosmos
# 13       XEM  3.872414e+06          0.189706                        nem
# 14       NEO  1.498634e+07         18.576523                        neo
# 15       FIL  2.137828e+07         30.381550                   filecoin
# 16      DASH  1.341181e+07        112.842500                       dash
# 17      AAVE  3.525279e+07         76.037068                       aave
# 18       VET  2.411100e+07          0.015970                    vechain
# 19       UNI  6.673704e+07          3.781631                    uniswap
# 20      IOTA  4.454703e+06          0.352314                       iota
# 21       ZEC  2.275736e+07         78.917087                      zcash
# 22       ETC  1.498859e+07          6.745544           ethereum-classic
# 23     THETA  8.080231e+06          0.642897                theta-token
# 18   1.035653e+09  0.011038
# 19   8.132697e+08  0.008668
# 20   9.747621e+08  0.010389
# 21   8.358795e+08  0.008909
# 22   7.846403e+08  0.008363
# 23   6.399757e+08  0.006821
# 24   6.363903e+08  0.006782
# 25   7.941175e+08  0.008464
# 26   5.138887e+08  0.005477
# 27   5.550672e+08  0.005916
# 28   7.083928e+08  0.007550
# 29   4.448955e+08  0.004742
# 30   4.874379e+08  0.005195
# 31   4.575296e+08  0.004876
# 2020-12-01T00:00:00.000000Z: 1000.000000
# 2020-12-02T00:00:00.000000Z: 932.460000
# 2020-12-03T00:00:00.000000Z: 966.390000
# 2020-12-04T00:00:00.000000Z: 975.480000
# 2020-12-05T00:00:00.000000Z: 889.290000
# 2020-12-06T00:00:00.000000Z: 937.010000
# 2020-12-07T00:00:00.000000Z: 952.160000
# 2020-12-08T00:00:00.000000Z: 938.560000
# 2020-12-09T00:00:00.000000Z: 872.030000
# 2020-12-10T00:00:00.000000Z: 898.220000
# 2020-12-11T00:00:00.000000Z: 873.830000
# 2020-12-12T00:00:00.000000Z: 848.430000
# 2020-12-13T00:00:00.000000Z: 855.530000
# 2020-12-14T00:00:00.000000Z: 885.360000
# 2020-12-15T00:00:00.000000Z: 879.420000
# 2020-12-16T00:00:00.000000Z: 864.760000
# 2020-12-17T00:00:00.000000Z: 959.040000
# 2020-12-18T00:00:00.000000Z: 964.450000
# 2020-12-19T00:00:00.000000Z: 981.270000
# 2020-12-20T00:00:00.000000Z: 987.950000
# 2020-12-21T00:00:00.000000Z: 972.770000
# 2020-12-22T00:00:00.000000Z: 907.760000
# 2020-12-23T00:00:00.000000Z: 898.120000
# 2020-12-24T00:00:00.000000Z: 721.660000
# 2020-12-25T00:00:00.000000Z: 816.900000
# 2020-12-26T00:00:00.000000Z: 826.220000
# 2020-12-27T00:00:00.000000Z: 818.420000
# 2020-12-28T00:00:00.000000Z: 815.360000
# 2020-12-29T00:00:00.000000Z: 843.230000
# 2020-12-30T00:00:00.000000Z: 833.260000
# 2020-12-31T00:00:00.000000Z: 816.910000
# blackListSet
# {'dai', 'eth', 'tusd', 'usdp', 'aud', 'frax', 'usdn', 'ust', 'eur', 'btc', 'mimatic', 'wbtc', 'usdc', 'pax', 'gbp', 'mim', 'weth', 'usdd', 'busd', 'usdt'}
# no whitelist being used
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 76    BZRX
# Name: baseAsset, dtype: object
# ripple
# litecoin
# bitcoin-cash
# binancecoin
# chainlink
# cardano
# yearn-finance
# eos
# stellar
# sushi
# polkadot
# tron
# aave
# vechain
# zilliqa
# uniswap
# monero
# filecoin
# elrond-erd-2
# theta-token
# nem
# ethereum-classic
# zcash
# unifi-protocol-dao
# waves
# neo
# dash
# swipe
# algorand
# injective-protocol
# havven
# cosmos
# tezos
# oasis-network
# curve-dao-token
# omisego
# band-protocol
# yfii-finance
# skale
# compound-governance-token
# theta-fuel
# kava-lend
# ontology
# ocean-protocol
# reserve-rights-token
# thorchain
# near
# kusama
# iostoken
# basic-attention-token
# 2021-01-26T00:00:00.000000Z: 1207.190000
# 2021-01-27T00:00:00.000000Z: 1220.830000
# 2021-01-28T00:00:00.000000Z: 1126.610000
# 2021-01-29T00:00:00.000000Z: 1217.590000
# 2021-01-30T00:00:00.000000Z: 1237.160000
# 2021-01-31T00:00:00.000000Z: 1350.830000
# blackListSet
# {'dai', 'eth', 'tusd', 'usdp', 'aud', 'frax', 'usdn', 'ust', 'eur', 'btc', 'mimatic', 'wbtc', 'usdc', 'pax', 'gbp', 'mim', 'weth', 'usdd', 'busd', 'usdt'}
# no whitelist being used
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 68     BQX
# 84    BZRX
# Name: baseAsset, dtype: object
# polkadot
# litecoin
# chainlink
# ripple
# cardano
# bitcoin-cash
# binancecoin
# stellar
# eos
# uniswap
# sushi
# yearn-finance
# vechain
# aave
# tron
# curve-dao-token
# the-graph
# swipe
# cosmos
# neo
# theta-token
# iostoken
# ethereum-classic
# zcash
# zilliqa
# tezos
# havven
# monero
# elrond-erd-2
# algorand
# dogecoin
# omisego
# 1inch
# dash
# band-protocol
# reserve-rights-token
# filecoin
# alpha-finance
# solana
# nem
# qtum
# enjincoin
# ontology
# waves
# republic-protocol
# loopring
# avalanche-2
# near
# hedera-hashgraph
# basic-attention-token
# thorchain
# nano
# iota
# matic-network
# icon
# serum
# reef
# compound-governance-token
# ocean-protocol
# yfii-finance
# kusama
# terra-luna
# kava
# zencash
# maker
# 0x
# kyber-network-crystal
# injective-protocol
# chiliz
# tomochain
# civic
# tellor
# dia-data
# decentraland
# oasis-network
# blockstack
# kava-lend
# skale
# coti
# theta-fuel
# unifi-protocol-dao
# verge
# lto-network
# balancer
# fantom
# venus
# flamingo-finance
# certik
# fetch-ai
# ankr
# the-sandbox
# axie-infinity
# storj
# bittorrent-old
# iexec-rlc
# bella-protocol
# harmony
# bluzelle
# digibyte
# siacoin
# origin-protocol
# district0x
# ftx-token
# arpa-chain
# ravencoin
# funfair
# decred
# holotoken
# keep3rv1
# aragon
# bancor
# just
# pax-gold
# utrust
# orchid-protocol
# celer-network
# akropolis
# wink
# uma
# wanchain
# wing-finance
# perlin
# dock
# aion
#    baseAsset     volInUSDT  lastAvgPriceUSDT                    geckoId  \
# 0        DOT  4.387007e+08         16.113764                   polkadot
# 1        XRP  3.496491e+08          0.495185                     ripple
# 2        ADA  3.448142e+08          0.344692                    cardano
# 3        LTC  4.084202e+08        129.362628                   litecoin
# 4       LINK  3.598829e+08         22.560279                  chainlink
# 5        BCH  2.269958e+08        399.328865               bitcoin-cash
# 6        XLM  1.855409e+08          0.306977                    stellar
# 7        BNB  2.123090e+08         44.333967                binancecoin
# 8        EOS  1.239635e+08          2.929642                        eos
# 9        XMR  4.262329e+07        137.744298                     monero
# 10       TRX  8.054858e+07          0.031521                       tron
# 11       SNX  4.319550e+07         17.194832                     havven
# 12       XTZ  4.394871e+07          2.844062                      tezos
# 13       XEM  2.525850e+07          0.235873                        nem
# 14     THETA  4.794865e+07          1.910284                theta-token
# 15      AAVE  8.441687e+07        299.723341                       aave
# {'dai', 'eth', 'tusd', 'usdp', 'aud', 'frax', 'usdn', 'ust', 'eur', 'btc', 'mimatic', 'wbtc', 'usdc', 'pax', 'gbp', 'mim', 'weth', 'usdd', 'busd', 'usdt'}
# no whitelist being used
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 81      BQX
# 102    BZRX
# Name: baseAsset, dtype: object
# binancecoin
# cardano
# ripple
# polkadot
# dogecoin
# litecoin
# chainlink
# eos
# bitcoin-cash
# stellar
# swipe
# tron
# uniswap
# sushi
# aave
# the-graph
# vechain
# cosmos
# terra-luna
# elrond-erd-2
# reef
# matic-network
# avalanche-2
# filecoin
# 1inch
# algorand
# ontology
# neo
# iostoken
# yearn-finance
# tezos
# iota
# alpha-finance
# venus
# zcash
# dash
# monero
# curve-dao-token
# omisego
# ethereum-classic
# fantom
# pancakeswap-token
# band-protocol
# zilliqa
# theta-token
# havven
# nem
# icon
# solana
# republic-protocol
# qtum
# 0x
# compound-governance-token
# thorchain
# reserve-rights-token
# basic-attention-token
# serum
# chiliz
# ravencoin
# kava
# ocean-protocol
# near
# waves
# enjincoin
# unifi-protocol-dao
# hedera-hashgraph
# bittorrent-old
# yfii-finance
# kusama
# coti
# the-sandbox
# tomochain
# ankr
# fetch-ai
# nano
# loopring
# harmony
# kyber-network-crystal
# mainframe
# holotoken
# decentraland
# injective-protocol
# dia-data
# maker
# flamingo-finance
# ftx-token
# storm
# pundi-x
# btc-standard-hashrate-token
# tellor
# zencash
# trust-wallet-token
# bella-protocol
# balancer
# pnetwork
# kava-lend
# akropolis
# sun-token
# bancor
# civic
# certik
# digibyte
# oasis-network
# bakerytoken
# verge
# celer-network
# lisk
# siacoin
# theta-fuel
# blockstack
# skale
# iexec-rlc
# bluzelle
# cartesi
# dent
# just
# uma
# orchid-protocol
# origin-protocol
# storj
# axie-infinity
# lto-network
# decred
# aion
# iotex
# wink
# aragon
# wanchain
# vethor-token
# district0x
# wazirx
#    baseAsset     volInUSDT  lastAvgPriceUSDT                    geckoId  \
# 0        ADA  1.127870e+09          1.312295                    cardano
# 1        DOT  7.441913e+08         33.798321                   polkadot
# 2        XRP  8.201686e+08          0.415578                     ripple
# 3        BNB  1.402499e+09        210.213126                binancecoin
# 4        LTC  4.946607e+08        165.208760                   litecoin
# 5       LINK  3.283065e+08         24.696829                  chainlink
# 6        BCH  2.853714e+08        460.121781               bitcoin-cash
# 7        XLM  2.404296e+08          0.405615                    stellar
# 8       DOGE  6.094459e+08          0.048111                   dogecoin
# 9        UNI  1.691043e+08         22.208407                    uniswap
# 10      AAVE  1.635151e+08        354.196891                       aave
# 11      ATOM  1.484089e+08         17.641519                     cosmos
# 12       EOS  2.966106e+08          3.476051                        eos
# 13       XMR  7.407676e+07        219.133474                     monero
# 14       XEM  5.597965e+07          0.610236                        nem
# 15       TRX  1.705265e+08          0.045614                       tron
# 16      IOTA  8.745645e+07          1.124520                       iota
# 17       SNX  5.820161e+07         18.725723                     havven
# 18     THETA  5.947389e+07          3.135184                theta-token
# 2021-03-25T00:00:00.000000Z: 2523.800000
# 2021-03-26T00:00:00.000000Z: 2527.160000
# 2021-03-27T00:00:00.000000Z: 2766.390000
# 2021-03-28T00:00:00.000000Z: 2756.000000
# 2021-03-29T00:00:00.000000Z: 2780.500000
# 2021-03-30T00:00:00.000000Z: 2876.770000
# 2021-03-31T00:00:00.000000Z: 2939.930000
# blackListSet
# {'dai', 'eth', 'tusd', 'usdp', 'aud', 'frax', 'usdn', 'ust', 'eur', 'btc', 'mimatic', 'wbtc', 'usdc', 'pax', 'gbp', 'mim', 'weth', 'usdd', 'busd', 'usdt'}
# no whitelist being used
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 129     BQX
# 146    BZRX
# 155    EASY
# Name: baseAsset, dtype: object
# binancecoin
# cardano
# chiliz
# ripple
# polkadot
# enjincoin
# litecoin
# theta-token
# swipe
# chainlink
# terra-luna
# vechain
# harmony
# filecoin
# uniswap
# nem
# pancakeswap-token
# eos
# holotoken
# tron
# dogecoin
# matic-network
# bitcoin-cash
# avalanche-2
# stellar
# theta-fuel
# reef
# coti
# decentraland
# sushi
# bittorrent-old
# algorand
# ankr
# ontology
# the-graph
# fantom
# hedera-hashgraph
# aave
# the-sandbox
# chromaway
# cosmos
# pundi-x
# iostoken
# sun-token
# celer-network
# zilliqa
# solana
# curve-dao-token
# neo
# elrond-erd-2
# ravencoin
# 1inch
# dent
# fetch-ai
# venus
# safepal
# storm
# basic-attention-token
# iota
# tezos
# kusama
# monero
# alpha-finance
# qtum
# reserve-rights-token
# audius
# dash
# siacoin
# icon
# zcash
# omisego
# ethereum-classic
# ocean-protocol
# kava
# origin-protocol
# skale
# bluzelle
# selfkey
# serum
# axie-infinity
# near
# yearn-finance
# litentry
# oasis-network
# republic-protocol
# band-protocol
# thorchain
# dodo
# 0x
# tomochain
# arpa-chain
# vethor-token
# kyber-network-crystal
# perlin
# vite
# kava-lend
# akropolis
# nervos-network
# the-virtua-kolect
# havven
# unifi-protocol-dao
# dia-data
# ftx-token
# contentos
# bancor
# iotex
# wink
# loopring
# troy
# compound-governance-token
# verge
# storj
# lto-network
# bakerytoken
# orion-protocol
# just
# pnetwork
# dock
# cartesi
# waltonchain
# orchid-protocol
# bella-protocol
# digibyte
# waves
# civic
# aion
# helium
# mithril
# flamingo-finance
# dusk-network
# aragon
# zencash
# tellor
# yfii-finance
# blockstack
# pha
# nkn
# streamr
# certik
# moviebloc
# measurable-data-token
# mainframe
# bitshares
# iexec-rlc
# lisk
# balancer
# cocos-bcx
# nano
# injective-protocol
# wazirx
# utrust
# iris-network
# trust-wallet-token
# fio-protocol
# funfair
# dexe
# wanchain
# frontier-token
# ong
# tokenclub
# maker
# metal
# beam
# gifto
# hive
# nuls
# uma
#    baseAsset     volInUSDT  lastAvgPriceUSDT                    geckoId  \
# 0        BNB  1.285202e+09        302.395268                binancecoin
# 1        ADA  6.950713e+08          1.191785                    cardano
# 2        DOT  3.642487e+08         37.079380                   polkadot
# 3        XRP  3.907408e+08          0.569842                     ripple
# 2021-04-07T00:00:00.000000Z: 3647.080000
# 2021-04-08T00:00:00.000000Z: 3345.350000
# 2021-04-09T00:00:00.000000Z: 3595.130000
# 2021-04-10T00:00:00.000000Z: 3617.630000
# 2021-04-11T00:00:00.000000Z: 3868.580000
# 2021-04-12T00:00:00.000000Z: 3993.820000
# 2021-04-13T00:00:00.000000Z: 4155.970000
# 2021-04-14T00:00:00.000000Z: 4396.470000
# 2021-04-15T00:00:00.000000Z: 4508.180000
# 2021-04-16T00:00:00.000000Z: 4655.620000
# 2021-04-17T00:00:00.000000Z: 4789.140000
# 2021-04-18T00:00:00.000000Z: 4613.020000
# 2021-04-19T00:00:00.000000Z: 4380.730000
# 2021-04-20T00:00:00.000000Z: 4285.220000
# 2021-04-21T00:00:00.000000Z: 4435.020000
# 2021-04-22T00:00:00.000000Z: 4208.110000
# 2021-04-23T00:00:00.000000Z: 3933.170000
# 2021-04-24T00:00:00.000000Z: 3937.960000
# 2021-04-25T00:00:00.000000Z: 3706.710000
# 2021-04-26T00:00:00.000000Z: 3734.260000
# 2021-04-27T00:00:00.000000Z: 4217.580000
# 2021-04-28T00:00:00.000000Z: 4410.940000
# 2021-04-29T00:00:00.000000Z: 4441.370000
# 2021-04-30T00:00:00.000000Z: 4455.920000
# blackListSet
# {'dai', 'eth', 'tusd', 'usdp', 'aud', 'frax', 'usdn', 'ust', 'eur', 'btc', 'mimatic', 'wbtc', 'usdc', 'pax', 'gbp', 'mim', 'weth', 'usdd', 'busd', 'usdt'}
# no whitelist being used
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 115    BZRX
# 132    RAMP
# Name: baseAsset, dtype: object
# binancecoin
# ripple
# dogecoin
# cardano
# wink
# vechain
# tron
# litecoin
# polkadot
# bittorrent-old
# chiliz
# eos
# pancakeswap-token
# holotoken
# swipe
# filecoin
# chainlink
# bitcoin-cash
# dent
# stellar
# theta-token
# solana
# uniswap
# neo
# enjincoin
# ontology
# terra-luna
# ethereum-classic
# harmony
# iostoken
# cosmos
# aave
# avalanche-2
# elrond-erd-2
# matic-network
# siacoin
# qtum
# zcash
# iota
# wazirx
# monero
# sushi
# dash
# algorand
# tezos
# thorchain
# the-graph
# nkn
# zilliqa
# curve-dao-token
# nem
# omisego
# reef
# ankr
# 1inch
# hedera-hashgraph
# decentraland
# serum
# mithril
# ftx-token
# sun-token
# venus
# yearn-finance
# origin-protocol
# basic-attention-token
# fantom
# storm
# kusama
# reserve-rights-token
# band-protocol
# ravencoin
# coti
# theta-fuel
# verge
# alpha-finance
# chromaway
# icon
# compound-governance-token
# waves
# paris-saint-germain-fan-token
# storj
# fetch-ai
# celer-network
# btc-standard-hashrate-token
# dodo
# zencash
# safepal
# the-sandbox
# digibyte
# near
# vethor-token
# linear
# 0x
# audius
# republic-protocol
# axie-infinity
# litentry
# my-neighbor-alice
# kava
# cartesi
# maker
# metal
# flamingo-finance
# havven
# gifto
# vite
# kyber-network-crystal
# just
# ocean-protocol
# dia-data
# tellor
# nano
# tomochain
# akropolis
# lido-dao
# ftx-token
# chiliz
# algorand
# constitutiondao
# bitcoin-cash
# oasis-network
# sushi
# origin-protocol
# eos
# project-galaxy
# quant-network
# theta-token
# anchor-protocol
# arweave
# compound-governance-token
# loopring
# stellar
# bakerytoken
# flamingo-finance
# the-graph
# alien-worlds
# tezos
# smooth-love-potion
# litentry
# just
# pancakeswap-token
# zcash
# yfii-finance
# pax-gold
# mines-of-dalarnia
# my-neighbor-alice
# enjincoin
# serum
# numeraire
# alchemy-pay
# v-id-blockchain
# bella-protocol
# immutable-x
# basic-attention-token
# bittorrent
# wink
# yearn-finance
# mina-protocol
# reserve-rights-token
# mithril
# zcoin
# kava
# kadena
# btc-standard-hashrate-token
# woo-network
# dodo
# neo
# iotex
# vulcan-forged
# tellor
# hedera-hashgraph
# trust-wallet-token
# storj
# moonbeam
# holotoken
# celo
# aurora-dao
# celer-network
# 1inch
# ethos
# convex-finance
# marlin
# keep3rv1
# bonfida
# league-of-kingdoms
# dash
# flow
# yield-guild-games
# spell-token
# kyber-network-crystal
# iostoken
# perpetual-protocol
# dusk-network
# benqi
# bluzelle
# audius
# moviebloc
# chromaway
# klay-token
# beta-finance
# selfkey
# iota
# mobox
# coin98
# helium
# render-token
# dent
# concentrated-voting-power
# gifto
# automata
# mask-network
# swipe
# sun-token
# fetch-ai
# qtum
# kusama
# wing-finance
# aragon
# cortex
# ocean-protocol
# ravencoin
# adex
# the-virtua-kolect
# arpa-chain
# coti
# maker
# skale
# injective-protocol
# quick
# republic-protocol
# prometeus
# perlin
# superfarm
# aelf
# moonriver
# api3
# tranchess
# acala
# syscoin
# radicle
# highstreet
# troy
# reef
# voxies
# astar
# metal
# mirror-protocol
# og-fan-token
# stp-network
# cartesi
# ampleforth-governance-token
# ooki
# stratis
# frax-share
# biswap
# pnetwork
# binaryx
# gitcoin
# linear
# secret
# ellipsis-x
# badger-dao
# measurable-data-token
# theta-fuel
# ontology
# band-protocol
# ankr
# uma
# 0x
# ecash
# cocos-bcx
# zencash
# tokenclub
# illuvium
# kava-lend
# omisego
# request-network
# rei-network
# komodo
# frontier-token
# ethernity-chain
# nem
# new-bitshares
# as-roma-fan-token
# safepal
# adventure-gold
# lto-network
# iexec-rlc
# blockstack
# wax
# hive
# certik
# mantra-dao
# auto
# contentos
# icon
# akropolis
# force-protocol
# wrapped-nxm
# dego-finance
# biconomy
# wazirx
# clover-finance
# ac-milan-fan-token
# digibyte
# tornado-cash
# superrare
# polkastarter
# joe
# stafi
# fc-porto
# santos-fc-fan-token
# truefi
# streamr
# alpine-f1-team-fan-token
# harvest-finance
# orion-protocol
# vite
# conflux-token
# paris-saint-germain-fan-token
# auction
# wanchain
# waltonchain
# orchid-protocol
# unlend-finance
# vethor-token
# venus
# bancor
# beam
# alpha-finance
#    baseAsset     volInUSDT  lastAvgPriceUSDT            geckoId  \
# 0        BNB  2.311008e+08        283.396385        binancecoin
# 1        XRP  1.396177e+08          0.379186             ripple
# 2        ADA  1.332197e+08          0.516147            cardano
# 3        SOL  2.691987e+08         42.352222             solana
# 2022-08-15T00:00:00.000000Z: 1500.820000
# 2022-08-16T00:00:00.000000Z: 1470.820000
# 2022-08-17T00:00:00.000000Z: 1473.410000
# 2022-08-18T00:00:00.000000Z: 1422.270000
# 2022-08-19T00:00:00.000000Z: 1369.700000
# 2022-08-20T00:00:00.000000Z: 1248.480000
# 2022-08-21T00:00:00.000000Z: 1254.050000
# 2022-08-22T00:00:00.000000Z: 1299.780000
# 2022-08-23T00:00:00.000000Z: 1288.930000
# 2022-08-24T00:00:00.000000Z: 1304.450000
# 2022-08-25T00:00:00.000000Z: 1291.890000
# 2022-08-26T00:00:00.000000Z: 1310.610000
# 2022-08-27T00:00:00.000000Z: 1208.020000
# 2022-08-28T00:00:00.000000Z: 1209.300000
# 2022-08-29T00:00:00.000000Z: 1176.510000
# 2022-08-30T00:00:00.000000Z: 1235.290000

# %% [markdown]
# ### Testing categories

# %%
categories = ['ethereum-ecosystem', 
              'binance-smart-chain', 
              'polygon-ecosystem', 
              'avalanche-ecosystem', 
              'moonriver-ecosystem', 
              'centralized-exchange-token-cex',
              'decentralized-finance-defi',
              'non-fungible-tokens-nft',
              'meme-token',
              'gaming',
              'Other'
             ]

# %%
categories = ['smart-contract-platform',
              'centralized-exchange-token-cex',
              'decentralized-finance-defi',
              'non-fungible-tokens-nft',
              'meme-token',
              'gaming',
              'Other']

# %%
categories = ['sports',
              'smart-contract-platform',
              'centralized-exchange-token-cex',
              'decentralized-finance-defi',
              'non-fungible-tokens-nft',
              'meme-token',
              'gaming',
              'Other']

# %%
import asyncio
import httpx
async def getCategoryInfo(categories):
    result = {}
    for cat in categories:
        page = 1
        done = False
        perPage = 250
        result[cat] = {}
        result[cat]['totalMarketCap'] = 0
        result[cat]['tickers'] = {}
        print(f"Getting info for {cat}")
        while not done:
            query_params = {'vs_currency': 'usd', 'category': cat, 'order': 'market_cap_desc', 'per_page': 250, 'page': page, 'sparkline': 'false'}
            print(f"Page {page}. Pausing...")
            await asyncio.sleep(4)
            async with httpx.AsyncClient() as client:
                r = await client.get(geckoBaseURL + f"/coins/markets", params=query_params, timeout=30)
            catInfo = r.json()
            if len(catInfo) == 0:
                done = True
            else:
                for pt in catInfo:
                    marketCap = None
                    try:
                        if 'market_cap' in pt and pt['market_cap'] is not None:
                            marketCap = float(pt['market_cap'])
                    except ValueError:
                        marketCap = None
                    if not marketCap or marketCap < 1000000:
                        done = True
                    else:
                        result[cat]['tickers'][pt['id']] = pt
                        result[cat]['totalMarketCap'] += pt['market_cap']
                page += 1
    return result

# %%
catInfo = await getCategoryInfo(categories)
# Out:
# Getting info for sports
# Page 1. Pausing...
# Getting info for smart-contract-platform
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Getting info for centralized-exchange-token-cex
# Page 1. Pausing...
# Getting info for decentralized-finance-defi
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Page 4. Pausing...
# Page 5. Pausing...
# Page 6. Pausing...
# Getting info for non-fungible-tokens-nft
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Page 4. Pausing...
# Getting info for meme-token
# Page 1. Pausing...
# Getting info for gaming
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Getting info for Other
# Page 1. Pausing...

# %%
def getDominantCategoryFor(geckoId):
    maxParticipation = 0.0
    result = 'Other'
    for catName in catInfo:
        blacklist = None
        with open(f"blacklist-{catName}.txt", 'r') as f:
            blacklist = f.read().split(',')
        #print(f"blacklist is: {blacklist}")
        cat = catInfo[catName]
        if geckoId in cat['tickers']:
            assetSymbol = cat['tickers'][geckoId]['symbol'].lower()
            #print(f"assetSymbol is {assetSymbol}")
            if not assetSymbol in blacklist:
                thisParticipation = cat['tickers'][geckoId]['market_cap']/cat['totalMarketCap']
                if thisParticipation > maxParticipation:
                    maxParticipation = thisParticipation
                    result = catName
    return result

# %%
getDominantCategoryFor('santos-fc-fan-token')
# Out:
# 'sports'

# %%
categWhiteLists = {}
for baseAsset in baseAssets2GeckoDict:
    geckoId = baseAssets2GeckoDict[baseAsset]
    dominantCateg = getDominantCategoryFor(geckoId)
    if dominantCateg in categWhiteLists:
        categWhiteLists[dominantCateg].append(baseAsset.lower())
    else:
        categWhiteLists[dominantCateg] = [baseAsset.lower()]
categWhiteLists['Other'] += ['luna','any','eps','npxs','btt','nano','nu','keep','gxs']
categWhiteLists
# Out:
# {'Other': ['busd',
#   'usdt',
#   'btc',
#   'usdc',
#   'beth',
#   'wbtc',
#   'xrp',
#   'dai',
#   'usdp',
#   'atom',
#   'lunc',
#   'tusd',
#   'op',
#   'ltc',
#   'bidr',
#   'fil',
#   'xmr',
#   'bch',
#   'paxg',
#   'idrt',
#   'bat',
#   'zec',
#   'dash',
#   'jasmy',
#   'porto',
#   'ankr',
#   'people',
#   'mith',
#   'ustc',
#   'btcst',
#   'xec',
#   'klay',
#   'iost',
#   'nexo',
#   'vgx',
#   'ar',
#   'pundix',
#   'storj',
#   'ctk',
#   'hnt',
#   'sys',
#   'dar',
#   'ksm',
#   'burger',
#   'alpine',
#   'qnt',
#   'celo',
#   'ocean',
#   'iotx',
#   'nkn',
#   'rvn',
#   'mask',
#   'rlc',
#   'og',
#   'flux',
#   'sxp',
#   'ethdown',
#   'gtc',
#   'bnx',
#   'lit',
#   'ava',
#   'twt',
#   'firo',
#   'key',
#   'zen',
#   'glmr',
#   'dexe',
#   'stmx',
#   'mina',
#   'mob',
#   'tfuel',
#   'celr',
#   'skl',
#   'sfp',
#   'ant',
#   'rif',
#   'dent',
#   'adx',
#   'arpa',
#   'lpt',
#   'snm',
#   'ata',
#   'perl',
#   'high',
#   'cvc',
#   'xem',
#   'forth',
#   'ooki',
#   'gto',
#   'tct',
#   'agld',
#   'win',
#   'xno',
#   'wtc',
#   'reef',
#   'lever',
#   'bico',
#   'bsw',
#   'sun',
#   'ach',
#   'powr',
#   'nbs',
#   'cfx',
#   'pond',
#   'multi',
#   'ctxc',
#   'pha',
#   'mtl',
#   'dock',
#   't',
#   'aca',
#   'phb',
#   'dnt',
#   'mdt',
#   'voxel',
#   'om',
#   'ethup',
#   'beta',
#   'clv',
#   'ckb',
#   'mbl',
#   'epx',
#   'data',
#   'elf',
#   'akro',
#   'mft',
#   'fio',
#   'hive',
#   'utk',
#   'sc',
#   'tko',
#   'drep',
#   'mdx',
#   'btg',
#   'bdot',
#   'iris',
#   'troy',
#   'aion',
#   'poly',
#   'ssv',
#   'vtho',
#   'loom',
#   'req',
#   'ong',
#   'bts',
#   'gas',
#   'oxt',
#   'wrx',
#   'prom',
#   'fun',
#   'steem',
#   'snt',
#   'lto',
#   'pivx',
#   'qlc',
#   'glm',
#   'dcr',
#   'rei',
#   'xvg',
#   'amb',
#   'wabi',
#   'qkc',
#   'agix',
#   'oax',
#   'vib',
#   'ark',
#   'iq',
#   'bttc',
#   'luna',
#   'any',
#   'eps',
#   'npxs',
#   'btt',
#   'nano',
#   'nu',
#   'keep',
#   'gxs'],
#  'smart-contract-platform': ['eth',
#   'sol',
#   'etc',
#   'ada',
#   'avax',
#   'matic',
#   'near',
#   'eos',
#   'trx',
#   'dot',
#   'ftm',
#   'waves',
#   'vet',
#   'xlm',
#   'neo',
#   'omg',
#   'icp',
#   'algo',
#   'rose',
#   'xtz',
#   'zil',
#   'egld',
#   'one',
#   'hbar',
#   'chr',
#   'icx',
#   'qtum',
#   'dusk',
#   'hot',
#   'iota',
#   'kda',
#   'ont',
#   'strax',
#   'stx',
#   'coti',
#   'beam',
#   'movr',
#   'ctsi',
#   'dgb',
#   'tomo',
#   'kmd',
#   'nuls',
#   'nebl',
#   'scrt',
#   'astr',
#   'vite',
#   'lsk',
#   'ardr',
#   'aergo'],
#  'centralized-exchange-token-cex': ['bnb', 'ftt', 'woo'],
#  'meme-token': ['doge', 'shib'],
#  'sports': ['chz',
#   'flow',
#   'lazio',
#   'santos',
#   'acm',
#   'asr',
#   'psg',
#   'juv',
#   'city',
#   'bar',
#   'atm'],
#  'gaming': ['gmt',
#   'sand',
#   'gala',
#   'axs',
#   'enj',
#   'blz',
#   'alice',
#   'imx',
#   'ghst',
#   'slp',
#   'pyr',
#   'loka',
#   'tlm',
#   'vidt',
#   'ygg',
#   'mbox',
#   'waxp',
#   'mc',
#   'ilv',
#   'cocos'],
#  'non-fungible-tokens-nft': ['ape',
#   'mana',
#   'theta',
#   'ens',
#   'gal',
#   'audio',
#   'ogn',
#   'bake',
#   'rad',
#   'ern',
#   'dego',
#   'fet',
#   'cos',
#   'rndr',
#   'rare',
#   'tvk',
#   'pla',
#   'super'],
#  'decentralized-finance-defi': ['link',
#   'aave',
#   'uni',
#   'rune',
#   'knc',
#   'trb',
#   'ldo',
#   'yfi',
#   'comp',
#   'lrc',
#   'crv',
#   'dydx',
#   'kava',
#   'zrx',
#   'snx',
#   'stg',
#   'grt',
#   'unfi',
#   'yfii',
#   'sushi',
#   'cake',
#   '1inch',
#   'srm',
#   'rsr',
#   'mkr',
#   'bel',
#   'bal',
#   'wing',
#   'bond',
#   'c98',
#   'fxs',
#   'jst',
#   'spell',
#   'auction',
#   'ren',
#   'api3',
#   'anc',
#   'flm',
#   'ray',
#   'lina',
#   'kp3r',
#   'band',
#   'farm',
#   'cvx',
#   'dodo',
#   'fida',
#   'inj',
#   'mir',
#   'uma',
#   'for',
#   'alpha',
#   'front',
#   'torn',
#   'fis',
#   'wnxm',
#   'hard',
#   'perp',
#   'quick',
#   'auto',
#   'qi',
#   'idex',
#   'alpaca',
#   'pnt',
#   'badger',
#   'nmr',
#   'chess',
#   'cvp',
#   'wan',
#   'stpt',
#   'amp',
#   'orn',
#   'df',
#   'bnt',
#   'xvs',
#   'tru',
#   'tribe',
#   'pols',
#   'cream',
#   'dia',
#   'bifi',
#   'rep',
#   'uft',
#   'mln',
#   'joe',
#   'gno',
#   'alcx',
#   'pros',
#   'ast',
#   'vai']}

# %%
def categWhiteList(categ):
    return set(categWhiteLists[categ])

# %%
categWhiteList('sports')
# Out:
# {'acm',
#  'asr',
#  'atm',
#  'bar',
#  'chz',
#  'city',
#  'flow',
#  'juv',
#  'lazio',
#  'psg',
#  'santos'}

# %%
import datetime
import calendar
for categ in categories:
    whiteListFunc = partial(categWhiteList, categ)
    print(f"Doing index for category {categ}")
    startDay = '2020-11-01T00:00:00.000000Z'
    firstCategIndexData = await startIndex(startDay, '2020-12-01T00:00:00.000000Z', 1000, f"ONN-({categ})-B-30dW-30dR", cacheConn, whiteListFunc, partial(getBlacklistSet, f"blacklist-{categ}.txt"))
    while firstCategIndexData is None:
        print(f"WARNING: could not start index for {categ} on {startDay}, shifting one month")
        startDateTime = parse(startDay)
        daysInMonth = calendar.monthrange(startDateTime.year, startDateTime.month)[1]
        startDateTime = startDateTime + datetime.timedelta(days=daysInMonth)
        daysInMonth = calendar.monthrange(startDateTime.year, startDateTime.month)[1]
        endDateTime = startDateTime + datetime.timedelta(days=daysInMonth)
        startDay = str(startDateTime)
        firstCategIndexData = await startIndex(startDay, str(endDateTime), 1000, f"ONN-({categ})-B-30dW-30dR", cacheConn, whiteListFunc, partial(getBlacklistSet, f"blacklist-{categ}.txt"))
        
    computeDay = parse(firstCategIndexData.isoInstant) + datetime.timedelta(days = 1)
    endDate = parse("2022-08-29T00:00:00.000000Z") + datetime.timedelta(days = 1)
    lastIndex = firstCategIndexData
    fileName = f"{firstCategIndexData.indexId}_{firstCategIndexData.isoInstant[:10]}_{str(endDate)[:10]}.json"
    with open(fileName, 'w') as f:
        print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
        f.write('[\n')
        f.write(lastIndex.toJSON())
        while computeDay <= endDate:
            if(computeDay.day == 1):
                lastIndex = await lastIndexDataRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex, cacheConn, whiteListFunc, partial(getBlacklistSet, f"blacklist-{categ}.txt"))
            else:
                lastIndex = await lastIndexDataNoRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex)
            print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
            f.write(',\n')
            f.write(lastIndex.toJSON())
            computeDay = computeDay + datetime.timedelta(days = 1)
        f.write('\n]\n')
# Out:
# Doing index for category sports
# blackListSet
# {'ust', 'usdp', 'pax', 'usdd', 'frax', 'aud', 'usdt', 'eur', 'steth', 'usdc', 'tusd', 'matic', 'dai', 'ftt', 'bnb', 'wbtc', 'busd', 'mim', 'gbp', 'usdn', 'hbtc', 'mimatic'}
# whitelist is present
# chiliz
#   baseAsset      volInUSDT  lastAvgPriceUSDT geckoId  medianMarketcap  \
# 0       CHZ  783651.052643           0.01212  chiliz     5.777376e+07
#
#    lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap  weight
# 0    5.344065e+09                 1.0              1.0   6.477063e+07     1.0
# 2020-12-01T00:00:00.000000Z: 1000.000000
# 2020-12-02T00:00:00.000000Z: 1000.230000
# 2020-12-03T00:00:00.000000Z: 1069.310000
# 2020-12-04T00:00:00.000000Z: 1075.690000
# 2020-12-05T00:00:00.000000Z: 1010.670000
# 2020-12-06T00:00:00.000000Z: 1052.010000
# 2020-12-07T00:00:00.000000Z: 1049.780000
# 2020-12-08T00:00:00.000000Z: 1055.560000
# 2020-12-09T00:00:00.000000Z: 1011.940000
# 2020-12-10T00:00:00.000000Z: 1004.810000
# 2020-12-11T00:00:00.000000Z: 991.540000
# 2020-12-12T00:00:00.000000Z: 1023.960000
# 2020-12-13T00:00:00.000000Z: 1017.820000
# 2020-12-14T00:00:00.000000Z: 1037.050000
# 2020-12-15T00:00:00.000000Z: 1211.730000
# 2020-12-16T00:00:00.000000Z: 1236.420000
# 2020-12-17T00:00:00.000000Z: 1188.400000
# 2020-12-18T00:00:00.000000Z: 1199.910000
# 2020-12-19T00:00:00.000000Z: 1217.250000
# 2020-12-20T00:00:00.000000Z: 1326.880000
# 2020-12-21T00:00:00.000000Z: 1308.100000
# 2020-12-22T00:00:00.000000Z: 1555.810000
# 2020-12-23T00:00:00.000000Z: 1434.410000
# 2020-12-24T00:00:00.000000Z: 1493.660000
# 2020-12-25T00:00:00.000000Z: 1550.600000
# 2020-12-26T00:00:00.000000Z: 1580.080000
# 2020-12-27T00:00:00.000000Z: 1745.820000
# 2020-12-28T00:00:00.000000Z: 1984.500000
# 2020-12-29T00:00:00.000000Z: 2276.790000
# 2020-12-30T00:00:00.000000Z: 2338.840000
# 2020-12-31T00:00:00.000000Z: 1896.530000
# blackListSet
# {'ust', 'usdp', 'pax', 'usdd', 'frax', 'aud', 'usdt', 'eur', 'steth', 'usdc', 'tusd', 'matic', 'dai', 'ftt', 'bnb', 'wbtc', 'busd', 'mim', 'gbp', 'usdn', 'hbtc', 'mimatic'}
# whitelist is present
# chiliz
#   baseAsset     volInUSDT  lastAvgPriceUSDT geckoId  medianMarketcap  \
# 0       CHZ  5.443993e+06          0.021287  chiliz     7.775875e+07
#
#    lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap
# 5   1.842720e+07  0.006808
# 6   1.461849e+07  0.005401
# 2022-05-01T00:00:00.000000Z: 9314.430000
# 2022-05-02T00:00:00.000000Z: 9879.460000
# 2022-05-03T00:00:00.000000Z: 9664.730000
# 2022-05-04T00:00:00.000000Z: 9561.190000
# 2022-05-05T00:00:00.000000Z: 10584.710000
# 2022-05-06T00:00:00.000000Z: 9457.850000
# 2022-05-07T00:00:00.000000Z: 9330.450000
# 2022-05-08T00:00:00.000000Z: 9108.540000
# 2022-05-09T00:00:00.000000Z: 8837.280000
# 2022-05-10T00:00:00.000000Z: 7131.720000
# 2022-05-11T00:00:00.000000Z: 7853.800000
# 2022-05-12T00:00:00.000000Z: 6063.170000
# 2022-05-13T00:00:00.000000Z: 5429.150000
# 2022-05-14T00:00:00.000000Z: 5959.120000
# 2022-05-15T00:00:00.000000Z: 6213.900000
# 2022-05-16T00:00:00.000000Z: 6503.620000
# 2022-05-17T00:00:00.000000Z: 5937.230000
# 2022-05-18T00:00:00.000000Z: 6275.500000
# 2022-05-19T00:00:00.000000Z: 6193.030000
# 2022-05-20T00:00:00.000000Z: 6349.390000
# 2022-05-21T00:00:00.000000Z: 6061.370000
# 2022-05-22T00:00:00.000000Z: 6165.920000
# 2022-05-23T00:00:00.000000Z: 6277.780000
# 2022-05-24T00:00:00.000000Z: 5977.270000
# 2022-05-25T00:00:00.000000Z: 6032.380000
# 2022-05-26T00:00:00.000000Z: 5999.380000
# 2022-05-27T00:00:00.000000Z: 5543.560000
# 2022-05-28T00:00:00.000000Z: 5313.810000
# 2022-05-29T00:00:00.000000Z: 5470.650000
# 2022-05-30T00:00:00.000000Z: 5517.300000
# 2022-05-31T00:00:00.000000Z: 5992.970000
# blackListSet
# {'ust', 'usdp', 'pax', 'usdd', 'frax', 'aud', 'usdt', 'eur', 'steth', 'usdc', 'tusd', 'matic', 'dai', 'ftt', 'bnb', 'wbtc', 'busd', 'mim', 'gbp', 'usdn', 'hbtc', 'mimatic'}
# whitelist is present
# chiliz
# flow
# santos-fc-fan-token
# manchester-city-fan-token
# lazio-fan-token
# ac-milan-fan-token
# paris-saint-germain-fan-token
# juventus-fan-token
# fc-barcelona-fan-token
# atletico-madrid
# as-roma-fan-token
# ...
# 2022-06-29T00:00:00.000000Z: 494.940000
# 2022-06-30T00:00:00.000000Z: 487.370000
# blackListSet
# {'gbp', 'usdt', 'usdn', 'ust', 'usdp', 'wbtc', 'eur', 'busd', 'pax', 'btc', 'usdc', 'mimatic', 'mim', 'tusd', 'dai', 'usdd', 'frax', 'aud'}
# whitelist is present
# ripple
# terra-luna-2
# optimism
# litecoin
# terra-luna
# cosmos
# constitutiondao
# jasmycoin
# filecoin
# bitcoin-cash
# monero
# litentry
# moviebloc
# helium
# mines-of-dalarnia
# zcash
# moonbeam
# selfkey
# basic-attention-token
# pax-gold
# wink
# automata
# celo
# binaryx
# mina-protocol
# arweave
# swipe
# terrausd
# kusama
# mask-network
# iotex
# bittorrent
# trust-wallet-token
# metal
# iostoken
# dash
# ocean-protocol
# sun-token
# burger-swap
# beta-finance
# storj
# celer-network
# og-fan-token
# dent
# gitcoin
# ankr
# klay-token
# ellipsis-x
# ravencoin
# marlin
# binance-eth
# quant-network
# power-ledger
# voxies
# safepal
# aragon
# reef
# skale
# syscoin
# biconomy
# biswap
# arpa-chain
# ecash
# troy
# alchemy-pay
# theta-fuel
# alpine-f1-team-fan-token
# adex
# threshold-network-token
# siacoin
# aelf
# certik
# akropolis
# zencash
# fc-porto
# livepeer
# ooki
# acala
# highstreet
# hive
# ethos
# adventure-gold
# polymath
# request-network
# civic
# gifto
# zelcash
# storm
# nkn
# cortex
# rei-network
# utrust
# nexo
# tokenclub
# wazirx
# clover-finance
# drep-new
# conflux-token
# iexec-rlc
# steem
# verge
# mithril
# district0x
# btc-standard-hashrate-token
# dexe
# streamr
# orchid-protocol
# ong
# nervos-network
# nem
# tokocrypto
# lto-network
# measurable-data-token
# nano
# mainframe
# mobilecoin
# ampleforth-governance-token
# mantra-dao
# pundi-x-2
#    baseAsset     volInUSDT  lastAvgPriceUSDT                geckoId  \
# 0        XRP  1.797717e+08      3.321038e-01                 ripple
# 1        LTC  5.509812e+07      5.383020e+01               litecoin
# 2        BCH  2.296405e+07      1.031928e+02           bitcoin-cash
# 3        XMR  2.272206e+07      1.130988e+02                 monero
# 4       ATOM  3.787446e+07      7.569850e+00                 cosmos
# 5      TFUEL  3.058868e+06      4.761566e-02             theta-fuel
# 6        FIL  2.550040e+07      5.399735e+00               filecoin
# 7        HNT  1.284010e+07      9.417483e+00                 helium
# 8        ZEC  9.996291e+06      5.451390e+01                  zcash
# 9       BTTC  6.024727e+06      8.101027e-07             bittorrent
# 10       XEC  3.164442e+06      3.829223e-05                  ecash
# 11       QNT  3.818136e+06      5.349257e+01          quant-network
# 12      KLAY  4.266959e+06      2.418318e-01             klay-token
# 13      PAXG  8.514936e+06      1.816401e+03               pax-gold
# 14       BAT  8.879243e+06      3.926078e-01  basic-attention-token
# 15      DASH  5.737870e+06      4.230612e+01                   dash
# 16        AR  7.097947e+06      9.740332e+00                arweave
# 17       KSM  6.453076e+06      4.829553e+01                 kusama
# 18      CELO  8.277074e+06      8.613263e-01                   celo
# 19      NEXO  1.433970e+06      5.822637e-01                   nexo
# 20       XEM  1.039923e+06      3.852919e-02                    nem
# 21      MINA  7.147719e+06      6.140909e-01          mina-protocol
# 22      IOST  5.756522e+06      1.339616e-02               iostoken
# 23      IOTX  6.211201e+06      2.493729e-02                  iotex
# 24       RVN  3.973477e+06      2.306640e-02              ravencoin
# 25      GLMR  9.605315e+06      6.204573e-01               moonbeam
# 26      ANKR  4.290028e+06      2.762897e-02                   ankr
# 27       LPT  1.862804e+06      9.328533e+00               livepeer
# 28      LUNA  9.008405e+07      2.129140e+00           terra-luna-2
#
#     medianMarketcap  lastCircSupply  fracTotalMarketCap  accumulatedPerc  \
# 0      1.705814e+10    4.834310e+10            0.356518         0.356518
# 1      3.899598e+09    7.061876e+07            0.081502         0.438021
# 2      2.322980e+09    1.911310e+07            0.048551         0.486572
# 2022-07-11T00:00:00.000000Z: 501.140000
# 2022-07-12T00:00:00.000000Z: 477.640000
# 2022-07-13T00:00:00.000000Z: 467.090000
# 2022-07-14T00:00:00.000000Z: 486.660000
# 2022-07-15T00:00:00.000000Z: 504.800000
# 2022-07-16T00:00:00.000000Z: 509.650000
# 2022-07-17T00:00:00.000000Z: 528.940000
# 2022-07-18T00:00:00.000000Z: 526.850000
# 2022-07-19T00:00:00.000000Z: 562.460000
# 2022-07-20T00:00:00.000000Z: 575.210000
# 2022-07-21T00:00:00.000000Z: 552.750000
# 2022-07-22T00:00:00.000000Z: 563.950000
# 2022-07-23T00:00:00.000000Z: 551.350000
# 2022-07-24T00:00:00.000000Z: 551.180000
# 2022-07-25T00:00:00.000000Z: 554.810000
# 2022-07-26T00:00:00.000000Z: 514.810000
# 2022-07-27T00:00:00.000000Z: 519.030000
# 2022-07-28T00:00:00.000000Z: 557.610000
# 2022-07-29T00:00:00.000000Z: 588.040000
# 2022-07-30T00:00:00.000000Z: 584.060000
# 2022-07-31T00:00:00.000000Z: 599.410000
# blackListSet
# {'gbp', 'usdt', 'usdn', 'ust', 'usdp', 'wbtc', 'eur', 'busd', 'pax', 'btc', 'usdc', 'mimatic', 'mim', 'tusd', 'dai', 'usdd', 'frax', 'aud'}
# whitelist is present
# ripple
# cosmos
# litecoin
# terrausd
# terra-luna
# burger-swap
# filecoin
# terra-luna-2
# jasmycoin
# monero
# optimism
# constitutiondao
# bitcoin-cash
# quant-network
# arweave
# litentry
# zcash
# pax-gold
# mines-of-dalarnia
# alchemy-pay
# basic-attention-token
# bittorrent
# wink
# mina-protocol
# mithril
# zcoin
# btc-standard-hashrate-token
# iotex
# trust-wallet-token
# storj
# moonbeam
# celo
# celer-network
# ethos
# marlin
# dash
# iostoken
# moviebloc
# klay-token
# beta-finance
# selfkey
# helium
# dent
# gifto
# automata
# mask-network
# swipe
# sun-token
# kusama
# aragon
# cortex
# ocean-protocol
# ravencoin
# adex
# arpa-chain
# skale
# prometeus
# perlin
# aelf
# acala
# syscoin
# highstreet
# troy
# reef
# voxies
# metal
# og-fan-token
# ampleforth-governance-token
# ooki
# biswap
# binaryx
# gitcoin
# ellipsis-x
# measurable-data-token
# theta-fuel
# ankr
# ecash
# zencash
# tokenclub
# request-network
# rei-network
# nem
# new-bitshares
# safepal
# adventure-gold
# lto-network
# iexec-rlc
# hive
# certik
# mantra-dao
# akropolis
# biconomy
# wazirx
# clover-finance
# fc-porto
# streamr
# alpine-f1-team-fan-token
# conflux-token
# waltonchain
# orchid-protocol
# vethor-token
# power-ledger
# storm
# fio-protocol
# dexe
# mdex
# district0x
# nexo
# livepeer
# iris-network
# aion
# drep-new
# binance-eth
# nkn
# tokocrypto
# steem
# mainframe
# utrust
# polymath
# pha
# zelcash
# siacoin
# concierge-io
# civic
# dock
# nano
# threshold-network-token
# verge
# mobilecoin
# nervos-network
# multichain
# bitcoin-gold
# bitshares
#    baseAsset     volInUSDT  lastAvgPriceUSDT                geckoId  \
