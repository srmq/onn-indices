# %% [markdown]
# # Computing daily ONN index on Binance

# %% [markdown]
# ## Getting all available symbols on Binance

# %% [markdown]
# In this section, we just get all available assets on Binance, generating at the end a file named `all-binance-tokens.csv`. Each line in this file contains the asset symbol two times, separated by comma (e.g. `ETH,ETH`). This is because we will use it afterwards in the __[`bnbFetchCoinData.py`](https://github.com/srmq/bnbfetch-coin-data)__ script, which expects the CSV file of lines in the format `asset_description,asset_symbol`, and we don't care about descriptions here.

# %%
import httpx
import pandas as pd

# %%
binanceBaseURL = 'https://api.binance.com'

# %%
async def getExchangeInfo():
    spotExchangeInfoURL = binanceBaseURL + "/api/v3/exchangeInfo"

    async with httpx.AsyncClient() as client:
        r = await client.get(spotExchangeInfoURL)
    return r.json()

# %%
exchangeInfo = await getExchangeInfo()

# %%
#blacklist = None
#with open('blacklist.txt', 'r') as f:
#    blacklist = f.read().split(',')
# blacklist should be disabled for now, we need coin data for every coin

# %%
baseAssets = set()
#for coinSymbol in exchangeInfo['symbols']:
#    if not (coinSymbol['baseAsset'].lower() in blacklist):
#        baseAssets.add(coinSymbol['baseAsset'])

# %%
for coinSymbol in exchangeInfo['symbols']:
    baseAssets.add(coinSymbol['baseAsset'])

# %%
def notLeveraged(asset):
    return not (asset.endswith('UP') or asset.endswith('DOWN') or asset.endswith('BEAR') or asset.endswith('BULL'))

# %%
baseAssets = set(filter(notLeveraged, baseAssets))

# %%
baseAssets
# Out:
# {'1INCH',
#  'AAVE',
#  'ACA',
#  'ACH',
#  'ACM',
#  'ADA',
#  'ADX',
#  'AE',
#  'AERGO',
#  'AGI',
#  'AGIX',
#  'AGLD',
#  'AION',
#  'AKRO',
#  'ALCX',
#  'ALGO',
#  'ALICE',
#  'ALPACA',
#  'ALPHA',
#  'ALPINE',
#  'AMB',
#  'AMP',
#  'ANC',
#  'ANKR',
#  'ANT',
#  'ANY',
#  'APE',
#  'API3',
#  'APPC',
#  'AR',
#  'ARDR',
#  'ARK',
#  'ARN',
#  'ARPA',
#  'ASR',
#  'AST',
#  'ASTR',
#  'ATA',
#  'ATM',
#  'ATOM',
#  'AUCTION',
#  'AUD',
#  'AUDIO',
#  'AUTO',
#  'AVA',
#  'AVAX',
#  'AXS',
#  'BADGER',
#  'BAKE',
#  'BAL',
#  'BAND',
#  'BAR',
#  'BAT',
#  'BCC',
#  'BCD',
#  'BCH',
#  'BCHA',
#  'BCHABC',
#  'BCHSV',
#  'BCN',
#  'BCPT',
#  'BDOT',
#  'BEAM',
#  'BEL',
#  'BETA',
#  'BETH',
#  'BGBP',
#  'BICO',
#  'BIFI',
#  'BKRW',
#  'BLZ',
#  'BNB',
#  'BNT',
#  'BNX',
#  'BOND',
#  'BOT',
#  'BQX',
#  'BRD',
#  'BSW',
#  'BTC',
#  'BTCB',
#  'BTCST',
#  'BTG',
#  'BTS',
#  'BTT',
#  'BTTC',
#  'BURGER',
#  'BUSD',
#  'BZRX',
#  'C98',
#  'CAKE',
#  'CDT',
#  'CELO',
#  'CELR',
#  'CFX',
#  'CHAT',
#  'CHESS',
#  'CHR',
#  'CHZ',
#  'CITY',
#  'CKB',
#  'CLOAK',
#  'CLV',
#  'CMT',
#  'CND',
#  'COCOS',
#  'COMP',
#  'COS',
#  'COTI',
#  'COVER',
#  'CREAM',
#  'CRV',
#  'CTK',
#  'CTSI',
#  'CTXC',
#  'CVC',
#  'CVP',
#  'CVX',
#  'DAI',
#  'DAR',
#  'DASH',
#  'DATA',
#  'DCR',
#  'DEGO',
#  'DENT',
#  'DEXE',
#  'DF',
#  'DGB',
#  'DGD',
#  'DIA',
#  'DLT',
#  'DNT',
#  'DOCK',
#  'DODO',
#  'DOGE',
#  'DOT',
#  'DREP',
#  'DUSK',
#  'DYDX',
#  'EASY',
#  'EDO',
#  'EGLD',
#  'ELF',
#  'ENG',
#  'ENJ',
#  'ENS',
#  'EOS',
#  'EPS',
#  'EPX',
#  'ERD',
#  'ERN',
#  'ETC',
#  'ETH',
#  'EUR',
#  'EVX',
#  'EZ',
#  'FARM',
#  'FET',
#  'FIDA',
#  'FIL',
#  'FIO',
#  'FIRO',
#  'FIS',
#  'FLM',
#  'FLOW',
#  'FLUX',
#  'FOR',
#  'FORTH',
#  'FRONT',
#  'FTM',
#  'FTT',
#  'FUEL',
#  'FUN',
#  'FXS',
#  'GAL',
#  'GALA',
#  'GAS',
#  'GBP',
#  'GHST',
#  'GLM',
#  'GLMR',
#  'GMT',
#  'GNO',
#  'GNT',
#  'GO',
#  'GRS',
#  'GRT',
#  'GTC',
#  'GTO',
#  'GVT',
#  'GXS',
#  'HARD',
#  'HBAR',
#  'HC',
#  'HEGIC',
#  'HIGH',
#  'HIVE',
#  'HNT',
#  'HOT',
#  'HSR',
#  'ICN',
#  'ICP',
#  'ICX',
#  'IDEX',
#  'ILV',
#  'IMX',
#  'INJ',
#  'INS',
#  'IOST',
#  'IOTA',
#  'IOTX',
#  'IQ',
#  'IRIS',
#  'JASMY',
#  'JOE',
#  'JST',
#  'JUV',
#  'KAVA',
#  'KDA',
#  'KEEP',
#  'KEY',
#  'KLAY',
#  'KMD',
#  'KNC',
#  'KP3R',
#  'KSM',
#  'LAZIO',
#  'LDO',
#  'LEND',
#  'LINA',
#  'LINK',
#  'LIT',
#  'LOKA',
#  'LOOM',
#  'LPT',
#  'LRC',
#  'LSK',
#  'LTC',
#  'LTO',
#  'LUN',
#  'LUNA',
#  'LUNC',
#  'MANA',
#  'MASK',
#  'MATIC',
#  'MBL',
#  'MBOX',
#  'MC',
#  'MCO',
#  'MDA',
#  'MDT',
#  'MDX',
#  'MFT',
#  'MINA',
#  'MIR',
#  'MITH',
#  'MKR',
#  'MLN',
#  'MOB',
#  'MOD',
#  'MOVR',
#  'MTH',
#  'MTL',
#  'MULTI',
#  'NANO',
#  'NAS',
#  'NAV',
#  'NBS',
#  'NBT',
#  'NCASH',
#  'NEAR',
#  'NEBL',
#  'NEO',
#  'NEXO',
#  'NKN',
#  'NMR',
#  'NPXS',
#  'NU',
#  'NULS',
#  'NXS',
#  'OAX',
#  'OCEAN',
#  'OG',
#  'OGN',
#  'OM',
#  'OMG',
#  'ONE',
#  'ONG',
#  'ONT',
#  'OOKI',
#  'OP',
#  'ORN',
#  'OST',
#  'OXT',
#  'PAX',
#  'PAXG',
#  'PEOPLE',
#  'PERL',
#  'PERP',
#  'PHA',
#  'PHB',
#  'PHX',
#  'PIVX',
#  'PLA',
#  'PNT',
#  'POA',
#  'POE',
#  'POLS',
#  'POLY',
#  'POND',
#  'PORTO',
#  'POWR',
#  'PPT',
#  'PROM',
#  'PROS',
#  'PSG',
#  'PUNDIX',
#  'PYR',
#  'QI',
#  'QKC',
#  'QLC',
#  'QNT',
#  'QSP',
#  'QTUM',
#  'QUICK',
#  'RAD',
#  'RAMP',
#  'RARE',
#  'RAY',
#  'RCN',
#  'RDN',
#  'REEF',
#  'REI',
#  'REN',
#  'RENBTC',
#  'REP',
#  'REQ',
#  'RGT',
#  'RIF',
#  'RLC',
#  'RNDR',
#  'ROSE',
#  'RPX',
#  'RSR',
#  'RUNE',
#  'RVN',
#  'SALT',
#  'SAND',
#  'SANTOS',
#  'SC',
#  'SCRT',
#  'SFP',
#  'SHIB',
#  'SKL',
#  'SKY',
#  'SLP',
#  'SNGLS',
#  'SNM',
#  'SNT',
#  'SNX',
#  'SOL',
#  'SPARTA',
#  'SPELL',
#  'SRM',
#  'SSV',
#  'STEEM',
#  'STMX',
#  'STORJ',
#  'STORM',
#  'STPT',
#  'STRAT',
#  'STRAX',
#  'STX',
#  'SUB',
#  'SUN',
#  'SUPER',
#  'SUSD',
#  'SUSHI',
#  'SWRV',
#  'SXP',
#  'SYS',
#  'T',
#  'TCT',
#  'TFUEL',
#  'THETA',
#  'TKO',
#  'TLM',
#  'TNB',
#  'TNT',
#  'TOMO',
#  'TORN',
#  'TRB',
#  'TRIBE',
#  'TRIG',
#  'TROY',
#  'TRU',
#  'TRX',
#  'TUSD',
#  'TUSDB',
#  'TVK',
#  'TWT',
#  'UFT',
#  'UMA',
#  'UNFI',
#  'UNI',
#  'USDC',
#  'USDP',
#  'USDS',
#  'USDSB',
#  'USDT',
#  'UST',
#  'USTC',
#  'UTK',
#  'VEN',
#  'VET',
#  'VGX',
#  'VIA',
#  'VIB',
#  'VIBE',
#  'VIDT',
#  'VITE',
#  'VOXEL',
#  'VTHO',
#  'WABI',
#  'WAN',
#  'WAVES',
#  'WAXP',
#  'WBTC',
#  'WIN',
#  'WING',
#  'WINGS',
#  'WNXM',
#  'WOO',
#  'WPR',
#  'WRX',
#  'WTC',
#  'XEC',
#  'XEM',
#  'XLM',
#  'XMR',
#  'XNO',
#  'XRP',
#  'XTZ',
#  'XVG',
#  'XVS',
#  'XZC',
#  'YFI',
#  'YFII',
#  'YGG',
#  'YOYO',
#  'ZEC',
#  'ZEN',
#  'ZIL',
#  'ZRX'}

# %%
with open('all-binance-tokens.csv', 'w') as f:
    for asset in baseAssets:
        f.write(f"{asset},{asset}\n")

# %% [markdown]
# Now that we have our `all-binance-tokens.csv` file, we can download, for instance, the complete historical data for all assets on Binance, using something like:

# %% [raw]
# `python <path_to_script>/bnbFetchCoinData.py --coins all-binance-tokens.csv --interval 1d`

# %% [markdown]
# This will create a `coindata` directory under the current one with everything we need.

# %% [markdown]
# ## Importing Data to QuestDB

# %% [markdown]
# We will use __[QuestDB](https://questdb.io/)__ in order to facilitate data manipulation and keep memory requirements low (we won't need to load everything on RAM). First we will create a table for holding the data. Here is what we did:

# %% [markdown]
# `CREATE TABLE binance_daily(symb SYMBOL capacity 2048, open_time TIMESTAMP, high DOUBLE, low DOUBLE, close DOUBLE, volume DOUBLE, close_time TIMESTAMP, quote_asset_vol DOUBLE, num_trades LONG, takerbuy_baseasset_vol DOUBLE, takerbuy_quoteasset_vol DOUBLE), index(symb) timestamp(open_time) PARTITION BY YEAR;`

# %% [markdown]
# Now we will import the data (that went to the `coindata` subdirectory)...

# %%
import glob

allCSVFiles = glob.glob('./coindata/*.csv')

# %%
import httpx
import csv

host = 'http://localhost:9000'

async def questInsert(symbol: str, filename: str, lotSize=300):
    async def executeQuery(valStrings):
        sql_query = "INSERT INTO binance_daily VALUES"
        sql_query += valStrings[0]
        for i in range(1, len(valStrings)):
            sql_query += f",{valStrings[i]}"
        query_params = {'query': sql_query, 'fmt': 'json'}
        async with httpx.AsyncClient() as client:
            await client.get(host + '/exec', params=query_params)
        
    with open(filename, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        valStrings = []
        for row in reader:
            if len(valStrings) == lotSize:
                await executeQuery(valStrings)
                valStrings = []
            val = f"(\'{symbol}\', {int(row['Open time'])*1000}, {float(row['High'])}, {float(row['Low'])}, {float(row['Close'])}, {float(row['Volume'])}, {int(row['Close time'] + '999')}, {float(row['Quote asset volume'])}, {int(row['Number of trades'])}, {float(row['Taker buy base asset volume'])}, {float(row['Taker buy quote asset volume'])})"
            valStrings.append(val)
        if len(valStrings) > 0:
            await executeQuery(valStrings)

# %%
from pathlib import Path
i = 0
for csvFile in allCSVFiles:
    symb = Path(csvFile).name.split('.')[0]
    await questInsert(symb, csvFile)
    i += 1
    if i % 100 == 0:
        print(f"Inserted {i} symbols out of {len(allCSVFiles)}")
# Out:
# Inserted 100 symbols out of 1821
# Inserted 200 symbols out of 1821
# Inserted 300 symbols out of 1821
# Inserted 400 symbols out of 1821
# Inserted 500 symbols out of 1821
# Inserted 600 symbols out of 1821
# Inserted 700 symbols out of 1821
# Inserted 800 symbols out of 1821
# Inserted 900 symbols out of 1821
# Inserted 1000 symbols out of 1821
# Inserted 1100 symbols out of 1821
# Inserted 1200 symbols out of 1821
# Inserted 1300 symbols out of 1821
# Inserted 1400 symbols out of 1821
# Inserted 1500 symbols out of 1821
# Inserted 1600 symbols out of 1821
# Inserted 1700 symbols out of 1821
# Inserted 1800 symbols out of 1821

# %% [markdown]
# Now QuestDB has ingested all data. Let's play!

# %% [markdown]
# ## Playing with the data

# %%
import pandas as pd
import httpx

# %%
host = 'http://localhost:9000'

# %%
async def daysTradedInMonthBySymbol(year: int, month: int) -> pd.DataFrame:
    assert(month >= 1 and month <= 12)
    assert(year >= 2000 and year <= 9999)
    if month == 12:
        nextMonth = 1
        nextMonthYear = year + 1
    else:
        nextMonth = month + 1
        nextMonthYear = year
    sql_query = "select symb, count(*) as daystraded from 'binance_daily' where open_time >= '%d-%02d-01T00:00:00.000000Z' and open_time < '%d-%02d-01T00:00:00.000000Z' and num_trades >= 1 group by symb"%(year, month, nextMonthYear, nextMonth)
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
            r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    return pd.DataFrame(columns=['symb', 'daysTraded'], data=jsonR['dataset'])

# %%
import json
with open('coindata/coin-metadata.json', 'r') as f:
    coinMetadata = json.loads(f.read())
symbols = coinMetadata['exchange-info']['symbols']
symbolDict = {}
symbolsByBaseDict = {}
for symbol in symbols:
    symbolDict[symbol['symbol']] = symbol
    baseSymbols = symbolsByBaseDict.get(symbol['baseAsset'], [])
    baseSymbols.append(symbol)
    symbolsByBaseDict[symbol['baseAsset']] = baseSymbols
del symbols

# %%
from typing import Set
# It starts as all assets with TRADING status
async def initialAssetCandidateSet() -> Set[str]:
    candidateAssets = set()
    for symbol in symbolDict:
        baseAsset = symbolDict[symbol]['baseAsset']
        if symbolDict[symbol]['status'] == 'TRADING':
            if not baseAsset.endswith('UP') and not baseAsset.endswith('DOWN') and not baseAsset.endswith('BEAR') and not baseAsset.endswith('BULL'):
                candidateAssets.add(baseAsset)
    
    return candidateAssets

# %%
def getTradeSymbols(baseAssetSet):
    symbols = []
    for base in baseAssetSet:
        baseInfo = symbolsByBaseDict[base]
        for el in baseInfo:
            symbols.append(el['symbol'])
    return symbols

# %%
# We will use USDT to compare apples to apples
def shortestPathToUSDT(fromBaseAsset, coinGraph):
        
    if fromBaseAsset == 'USDT':
        return [fromBaseAsset]
    parent = {}
    explored = set()
    frontier = [fromBaseAsset]
    def solution(baseAsset):
        if parent.get(baseAsset) is None:
            return [baseAsset]
        else:
            result = solution(parent[baseAsset])
            result.append(baseAsset)
            return result

    while len(frontier) > 0:
        node = frontier.pop(0)
        explored.add(node)
        for coin in coinGraph[node]:
            if coin not in explored and coin not in frontier:
                parent[coin] = node
                if coin == 'USDT':
                    return solution(coin)
                else:
                    frontier.append(coin)
    assert False, "Should never get here"

# %%
import psutil
import numpy as np
import concurrent.futures
def splitAddUSDTInfo(df, splittedDf, coinGraph):
    volInUSDT = []
    closePricesInUSDT = []

    for (_, row) in splittedDf.iterrows():
        # print("(Base asset: %s, Quote asset: %s)"%(row['baseAsset'],row['quoteAsset']))
        if row['quoteAsset'] == 'USDT':
            val = row['volume'] * row['close']
            closePriceUSDT = row['close']
        else:
            path = shortestPathToUSDT(row['quoteAsset'], coinGraph)
            multiplier = 1.0
            assert len(path) > 1
            i = 0
            while i + 1 < len(path):
                dfFiltered = df[(df['baseAsset'] == path[i])
                                     & (df['quoteAsset'] == path[i + 1])
                                     & (df['open_time'] == row['open_time'])]
                if dfFiltered.shape[0] > 0:
                    # print(dfFiltered)
                    pathRow = dfFiltered.iloc[0]
                    multiplier *= pathRow['close']
                else:
                    dfFiltered = df[(df['baseAsset'] == path[i + 1]) 
                            & (df['quoteAsset'] == path[i])
                            & (df['open_time'] == row['open_time'])]
                    # print(dfFiltered)
                    pathRow = dfFiltered.iloc[0]
                    multiplier *= 1.0 / pathRow['close']
                i += 1
            assert path[i] == 'USDT'
            val = row['volume'] * row['close'] * multiplier
            closePriceUSDT = row['close'] * multiplier
        volInUSDT.append(val)
        closePricesInUSDT.append(closePriceUSDT)
    splittedDf.insert(splittedDf.shape[1], 'volInUSDT', volInUSDT)
    splittedDf.insert(splittedDf.shape[1], 'closePriceUSDT', closePricesInUSDT)
    del volInUSDT
    del closePricesInUSDT
    return splittedDf
    
def addUSDTInfo(df: pd.DataFrame, coinGraph) -> pd.DataFrame:
    numprocs = psutil.cpu_count(logical=False)
    splittedDfs = np.array_split(df, numprocs)
    dfResults = []
    with concurrent.futures.ProcessPoolExecutor(max_workers=numprocs) as executor:
        results = [ executor.submit(splitAddUSDTInfo, df=df, splittedDf=splittedDf, coinGraph=coinGraph) for splittedDf in splittedDfs ]
        for result in concurrent.futures.as_completed(results):
            try:
                dfResults.append(result.result())
            except Exception as ex:
                print("BOOOO! Exception!")
                print(ex)
                pass
    
    df = pd.concat(dfResults)
    return df

# %%
async def getMedianUSDTTradeVol(baseAssetSet: Set[str], isoInstantFrom: str, isoInstantTo: str) -> pd.DataFrame:
    def listToStr(l):
        result = l[0]
        for i in range(1, len(l)):
            result += f", {l[i]}"
        return result
    
    def genCoinGraph():
        from collections import defaultdict
        coinGraph = defaultdict(set)
        for key in symbolDict:
            symbol = symbolDict[key]
            coinGraph[symbol['baseAsset']].add(symbol['quoteAsset'])
            coinGraph[symbol['quoteAsset']].add(symbol['baseAsset'])
        return coinGraph
    
    coinGraph = genCoinGraph()
     
    columns = ['symb', 'open_time', 'close', 'volume', 'close_time', 'quote_asset_vol']
    sql_query = "SELECT %s FROM 'binance_daily' WHERE open_time >= '%s' and open_time < '%s'"%(listToStr(columns), isoInstantFrom, isoInstantTo)    
    #print(sql_query)
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
            r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    df = pd.DataFrame(columns=columns, data=jsonR['dataset'])
    del r
    del jsonR
    df['baseAsset'] = df.apply(lambda row: symbolDict[row['symb']]['baseAsset'], axis = 1)
    df['quoteAsset'] = df.apply(lambda row: symbolDict[row['symb']]['quoteAsset'], axis = 1)
      
    df = addUSDTInfo(df, coinGraph)
    df.sort_values(['close_time'], ascending=[True], ignore_index=True, inplace=True)
    dfSymbLastPrices = df[['symb', 'baseAsset', 'quoteAsset', 'volInUSDT', 'closePriceUSDT']].groupby(['symb', 'baseAsset', 'quoteAsset'], as_index=False).last()
    dfBaseAssetLastPrices = pd.DataFrame(columns= ['baseAsset', 'lastAvgPriceUSDT'])
    for _, group in dfSymbLastPrices.groupby('baseAsset'):
        num = 0.0
        den = 0.0
        for (_, row) in group.iterrows():
            num += row['closePriceUSDT']*row['volInUSDT']
            den += row['volInUSDT']
        avgPrice = num / den
        dfBaseAssetLastPrices.loc[len(dfBaseAssetLastPrices)] = [row['baseAsset'], avgPrice]
    dfBaseAssetLastPrices = dfBaseAssetLastPrices.set_index('baseAsset')

    df = df[['open_time', 'baseAsset', 'volInUSDT']].groupby(['baseAsset', 'open_time'], as_index=False).sum()    
    df = df[['baseAsset', 'volInUSDT']].groupby(['baseAsset'], as_index=True).median()
    df = pd.concat([df, dfBaseAssetLastPrices], axis=1, join='inner')
    df.reset_index(inplace=True)
    df.sort_values(['volInUSDT'], ascending=[False], ignore_index=True, inplace=True)
    return df

# %%
def getBlacklistSet() -> Set[str]:
    blacklist = None
    with open('blacklist.txt', 'r') as f:
        blacklist = f.read().split(',')
    return set(blacklist)

# %%
async def daysTradedBetweenBySymbol(isoInstantFrom: str, isoInstantTo: str) -> pd.DataFrame:
    sql_query = "select symb, count(*) as daystraded from 'binance_daily' where open_time >= '%s' and open_time < '%s' and num_trades >= 1 group by symb"%(isoInstantFrom, isoInstantTo)
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
            r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    return pd.DataFrame(columns=['symb', 'daysTraded'], data=jsonR['dataset'])

# %%
from datetime import date
from typing import List

# we will consider that an eligible asset should have at least one trade
# pair that was negotiated every day of the month
async def symbolsTradedEveryDay(isoInstantFrom: str, isoInstantTo: str) -> List[str]:
    fromDate = date.fromisoformat(isoInstantFrom[:10])
    toDate = date.fromisoformat(isoInstantTo[:10])
    daysBetween = abs(toDate - fromDate).days    
    df = await daysTradedBetweenBySymbol(isoInstantFrom, isoInstantTo)
    return df[df['daysTraded']==daysBetween]['symb'].tolist()

# %%
async def assetsTradedEveryDay(isoInstantFrom: str, isoInstantTo: str) -> Set[str]:
    result = set()
    symbols = await symbolsTradedEveryDay(isoInstantFrom, isoInstantTo)
    for symbol in symbols:
        symbolInfo = symbolDict[symbol]
        result.add(symbolInfo['baseAsset'])
        result.add(symbolInfo['quoteAsset'])
    return result

# %%
async def eligibleAssetsAndMedianVolumes(isoInstantFrom: str, isoInstantTo: str) -> pd.DataFrame:
    initialAssets = await initialAssetCandidateSet()
    df = await getMedianUSDTTradeVol(initialAssets, isoInstantFrom, isoInstantTo)
    blackListSet = getBlacklistSet()
    df = df[~df['baseAsset'].str.lower().isin(blackListSet)]
    everydayAssets = await assetsTradedEveryDay(isoInstantFrom, isoInstantTo)
    df = df[df['baseAsset'].isin(everydayAssets)]
    maxVolume = df['volInUSDT'][0]
    df = df[df['volInUSDT'] >= (0.005 * maxVolume)]
    df.reset_index(inplace=True, drop=True)
    return df

# %% [markdown]
# Now we have everything to compute our eligibleAssets, and we will proceed to select among then the ones that will be part of the index constituents... For this we will need market cap data, which is not available from Binance API, so we will get them from Coin Gecko.

# %%
geckoBaseURL = "https://api.coingecko.com:443/api/v3"

# %%
from typing import Dict
import asyncio
async def baseAsset2GeckoId(exchangeId = 'binance') -> Dict[str, str]:
    result = {}
    done = False
    page = 1
    while not done:
        query_params = {'page': page, 'order': 'trust_score_desc'}
        print(f"Page {page}. Pausing...")
        await asyncio.sleep(4)
        async with httpx.AsyncClient() as client:
            r = await client.get(geckoBaseURL + f"/exchanges/{exchangeId}/tickers", params=query_params, timeout=30)
        tickerInfo = r.json()
        if len(tickerInfo['tickers']) == 0:
            done = True
        else:
            page += 1
            for ticker in tickerInfo['tickers']:
                baseAsset = ticker['base']
                quoteAsset = ticker['target']
                if "coin_id" in ticker:
                    if not baseAsset in result:
                        result[baseAsset] = ticker['coin_id']
                if "target_coin_id" in ticker:
                    if not quoteAsset in result:
                        result[quoteAsset] = ticker['target_coin_id']
    return result

# %%
baseAssets2GeckoDict = await baseAsset2GeckoId()
# Out:
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Page 4. Pausing...
# Page 5. Pausing...
# Page 6. Pausing...
# Page 7. Pausing...
# Page 8. Pausing...
# Page 9. Pausing...
# Page 10. Pausing...
# Page 11. Pausing...
# Page 12. Pausing...
# Page 13. Pausing...
# Page 14. Pausing...
# Page 15. Pausing...
# Page 16. Pausing...

# %%
import dateutil
from dateutil.parser import parse
import datetime as dt
import pytz

async def computeMedianDailyMarketCapAndLastCirSupply(geckoCoinId: str, isoInstantFrom: str, isoInstantTo: str, maxDelaySeconds=7200) -> (float, float):
    dtFrom = parse(isoInstantFrom)
    dtTo = parse(isoInstantTo)
    epochSecondsFrom = dtFrom.timestamp()
    epochSecondsTo = dtTo.timestamp()
    query_params = {'vs_currency': 'usd', 'from': epochSecondsFrom, 'to': epochSecondsTo}
    async with httpx.AsyncClient() as client:
        r = await client.get(geckoBaseURL + f"/coins/{geckoCoinId}/market_chart/range", params=query_params, timeout=30)
    jsonR = r.json()
    if jsonR is None or not 'market_caps' in jsonR:
        print("WARNING: Could not find market_caps for %s, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)
    df = pd.DataFrame(columns=['epoch', 'market_cap'], data=jsonR['market_caps'])
    if (df.shape[0] < 1 or df.shape[1] != 2):
        print("WARNING: Unexpected shape for %s, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)
    if df['epoch'].isnull().values.any():
        print("WARNING: coingecko data for %s, contains empty epochs, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)

    df['isodate'] = df.apply(lambda row: dt.datetime.fromtimestamp(int(row['epoch'])/1000, tz=pytz.utc).isoformat()[:10] if (len(str(row['epoch'])) >= 13) else dt.datetime.fromtimestamp(int(row['epoch']), tz=pytz.utc).isoformat()[:10], axis = 1)
    df.sort_values(['epoch'], ascending=[True], ignore_index=True, inplace=True)
    lastMarketCap = df.iloc[-1]
    lastMarketCapDT = dt.datetime.fromtimestamp(int(lastMarketCap['epoch']/1000), tz=pytz.utc) if (len(str(lastMarketCap['epoch'])) >= 13) else dt.datetime.fromtimestamp(int(lastMarketCap['epoch']), tz=pytz.utc)
    if (abs(dtTo - lastMarketCapDT).total_seconds() > maxDelaySeconds):
        print("computeMedianDailyMarketCapAndLastCirSupply: WARNING last market cap data for %s is too old, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)    
    dfPrices = pd.DataFrame(columns=['epoch', 'price'], data=jsonR['prices'])
    dfPrices.sort_values(['epoch'], ascending=[True], ignore_index=True, inplace=True)
    lastPrice = dfPrices.iloc[-1]
    lastPriceDT = dt.datetime.fromtimestamp(int(lastPrice['epoch']/1000), tz=pytz.utc) if (len(str(lastPrice['epoch'])) >= 13) else dt.datetime.fromtimestamp(int(lastPrice['epoch']), tz=pytz.utc)
    if (abs(dtTo - lastPriceDT).total_seconds() >= maxDelaySeconds):
        print("computeMedianDailyMarketCapAndLastCirSupply: WARNING last price data for %s is too old, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)                                                                                                                                         
    df = df[['isodate', 'market_cap']].groupby(['isodate'], as_index=False).last()
    return (df['market_cap'].median(), float(lastMarketCap['market_cap'])/float(lastPrice['price']))

# %%
def addWeights(indexConstituents: pd.DataFrame):
    indexConstituents['lastMarketcap'] = indexConstituents['lastCircSupply']*indexConstituents['lastAvgPriceUSDT']
    totalLastMarketcap = indexConstituents['lastMarketcap'].sum()
    indexConstituents['weight'] = indexConstituents['lastMarketcap']/totalLastMarketcap
    assert(abs(indexConstituents['weight'].sum() - 1.0) < 0.0000001)

# %%
# as we are severely rate limited by coingecko (poor free user) we will build a cache
# of median daily market cap and last circulating supply data that will benefit
# us over repeated runs
import sqlite3
from sqlite3 import Error
def createCacheDBConnection(dbFile):
    conn = None
    try:
        conn = sqlite3.connect(dbFile)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        return conn
    
def createTable(conn, sqlStmt):
    try:
        c = conn.cursor()
        c.execute(sqlStmt)
    except Error as e:
        print(e)
        
def createGeckoCacheDataBase(conn=None):
    sqlStmt = """CREATE TABLE IF NOT EXISTS MedianDailyMarketCapAndLastCirSupply (
                    id text PRIMARY KEY,
                    medDailyMarketCap real NOT NULL,
                    lastCirSupply real NOT NULL
                 );"""
    if conn is None:
        conn = createCacheDBConnection("geckoCache.db")
    if conn is not None:
        createTable(conn, sqlStmt)
        return conn
    else:
        print("Error, could not create cache database")
        
def insertCacheData(geckoId: str, isoInstantFrom: str, isoInstantTo: str, marketCap: float, cirSupply: float, conn):
    sql = 'INSERT INTO MedianDailyMarketCapAndLastCirSupply(id, medDailyMarketCap, lastCirSupply) VALUES(?, ?, ?)'
    key = geckoId + "_" + isoInstantFrom + "_" + isoInstantTo
    value = (key, marketCap, cirSupply)
    cur = conn.cursor()
    cur.execute(sql, value)
    conn.commit()
    
def getCachedData(geckoId: str, isoInstantFrom: str, isoInstantTo: str, conn):
    key = geckoId + "_" + isoInstantFrom + "_" + isoInstantTo
    cur = conn.cursor()
    cur.execute("SELECT medDailyMarketCap, lastCirSupply FROM MedianDailyMarketCapAndLastCirSupply WHERE id=?", (key,))
    rows = cur.fetchall()
    if (len(rows) > 0):
        for row in rows:
            return (row[0], row[1])
    else:
        return (None, None)

# %%
import asyncio
import pandas as pd
async def selectIndexConstituents(isoInstantFrom: str, isoInstantTo: str, eligibleAssets: pd.DataFrame, cacheConn=None) -> pd.DataFrame:
    def getGeckoId(baseAsset: str):
        if (baseAsset in baseAssets2GeckoDict):
            return baseAssets2GeckoDict[baseAsset]
        else:
            return None
        
    indexConstituents = eligibleAssets.copy()
    eligibleAssets = None
    indexConstituents['geckoId'] = indexConstituents.apply(lambda row: getGeckoId(row['baseAsset']), axis = 1)
    geckoUnsupported = indexConstituents[indexConstituents['geckoId'].isna()]
    if geckoUnsupported.shape[0] > 0:
        print("WARNING: coingecko seems to not support the following eligible assets. Ignoring them")
        print(geckoUnsupported['baseAsset'])
        indexConstituents = indexConstituents[~indexConstituents['geckoId'].isna()]
    medians = []
    lastCircSupplies = []
    for geckoId in indexConstituents['geckoId']:
        print(geckoId)
        (medianDailyMarketCap, lastCircSupply) = (None, None)
        if cacheConn is not None:
            (medianDailyMarketCap, lastCircSupply) = getCachedData(geckoId, isoInstantFrom, isoInstantTo, cacheConn)
        if medianDailyMarketCap is None or lastCircSupply is None:
            await asyncio.sleep(4)
            (medianDailyMarketCap, lastCircSupply) = await computeMedianDailyMarketCapAndLastCirSupply(geckoId, isoInstantFrom, isoInstantTo)
            if (cacheConn is not None):
                insertCacheData(geckoId, isoInstantFrom, isoInstantTo, medianDailyMarketCap, lastCircSupply, cacheConn)
                
        medians.append(medianDailyMarketCap)
        lastCircSupplies.append(lastCircSupply)
    indexConstituents['medianMarketcap'] = medians
    indexConstituents['lastCircSupply'] = lastCircSupplies
    del medians
    del lastCircSupplies
    totalMarketCap = indexConstituents['medianMarketcap'].sum()
    indexConstituents.sort_values(['medianMarketcap'], ascending=[False], ignore_index=True, inplace=True)
    indexConstituents['fracTotalMarketCap'] = indexConstituents.apply(lambda row: row['medianMarketcap']/totalMarketCap, axis = 1)
    accumulatedPerc = []
    cumul = 0.0
    for _, row in indexConstituents.iterrows():
        cumul += row['fracTotalMarketCap']
        accumulatedPerc.append(cumul)
    indexConstituents.insert(indexConstituents.shape[1], 'accumulatedPerc', accumulatedPerc)
    del accumulatedPerc
    lastIndex = 0
    for lastIndex, row in indexConstituents.iterrows():
        if row['fracTotalMarketCap'] < 0.005 and row['accumulatedPerc'] > 0.75:
            break
    indexConstituents = indexConstituents[:lastIndex]
    addWeights(indexConstituents)
    return indexConstituents

# %%
class IndexData:
    indexId: str
    _indexValue: float
    isoInstant: str
    isRebalanceDay: bool
    _divisor: float
    lastRebalanceISOInstant: str
    indexConstituents: pd.DataFrame
    
    def set_indexValue(self, value):
        self._indexValue = round(value, 2)
    
    def get_indexValue(self):
        return self._indexValue
    
    def del_indexValue(self):
        del self._indexValue
        
    indexValue = property(get_indexValue, set_indexValue, del_indexValue)
    
    def set_divisor(self, value):
        self._divisor = round(value, 4)
    
    def get_divisor(self):
        return self._divisor
    
    def del_divisor(self):
        del self._divisor
        
    divisor = property(get_divisor, set_divisor, del_divisor)

# %%
async def startIndex(isoInstantFrom: str, isoInstantTo: str, startValue: int, name: str, cacheConn=None) -> IndexData:
    assert(startValue >= 1)
    eligibleAssets = await eligibleAssetsAndMedianVolumes(isoInstantFrom, isoInstantTo)
    indexConstituents = await selectIndexConstituents(isoInstantFrom, isoInstantTo, eligibleAssets, cacheConn)
    indexData = IndexData()
    indexData.indexId = name
    indexData.isoInstant = isoInstantTo
    indexData.isRebalanceDay = True
    indexData.lastRebalanceISOInstant = isoInstantTo
    indexData.indexValue = startValue
    dInitial = indexConstituents['lastMarketcap'].sum() / float(startValue)
    indexData.indexConstituents = indexConstituents
    indexData.divisor = dInitial
    return indexData

# %%
cacheConn = createGeckoCacheDataBase()
firstIndexData = await startIndex('2020-11-01T00:00:00.000000Z', '2020-12-01T00:00:00.000000Z', 1000, 'ONN-B-30dW-30dR', cacheConn)
# Out:
# 2.6.0
# bitcoin
# ethereum
# chainlink
# yearn-finance
# litecoin
# ripple
# binancecoin
# bitcoin-cash
# uniswap
# cardano
# eos
# polkadot
# yfii-finance
# aave
# tron
# swipe
# sushi
# vechain
# curve-dao-token
# monero
# zcash
# filecoin
# tezos
# ethereum-classic
# neo
# cosmos
# stellar
# reserve-rights-token
# waves
# dash
# omisego
# band-protocol
# near
# alpha-finance
# havven
# republic-protocol
# civic
# tellor

# %%
async def computeUpdatedPrices(indexData: IndexData, beginIsoInstant: str, endIsoInstant: str):
    baseAssetSet = set(indexData.indexConstituents['baseAsset'])
    dfNewPrices = await getMedianUSDTTradeVol(baseAssetSet, beginIsoInstant, endIsoInstant)
    dfNewPrices = dfNewPrices[dfNewPrices['baseAsset'].isin(baseAssetSet)]
    dfNewPrices.set_index('baseAsset', inplace=True)
    dfNewPrices.drop(columns=['volInUSDT'], inplace=True)
    dfNewPrices.rename(columns={'lastAvgPriceUSDT':'endAvgPriceUSDT'}, inplace=True)
    return dfNewPrices

# %%
import copy
async def lastIndexDataNoRebalance(beginIsoInstant: str, endIsoInstant: str, lastPoint: IndexData) -> IndexData:
    baseAssetSet = set(lastPoint.indexConstituents['baseAsset'])
    dfNewPrices = await computeUpdatedPrices(lastPoint, beginIsoInstant, endIsoInstant)
    dfLastCircSupplies = lastPoint.indexConstituents.copy()
    dfLastCircSupplies.set_index('baseAsset', inplace=True)
    if('endAvgPriceUSDT' in dfLastCircSupplies.columns):
        dfLastCircSupplies.drop(columns=['endAvgPriceUSDT'], inplace=True)
    dfNew = pd.concat([dfLastCircSupplies, dfNewPrices], axis=1, join='inner')
    assert(dfNew.shape[0] == dfLastCircSupplies.shape[0])
    assert(dfNew.shape[0] == dfNewPrices.shape[0])
    del dfNewPrices
    del dfLastCircSupplies
    dfNew.reset_index(inplace=True)
    dfNew.sort_values(['volInUSDT'], ascending=[False], ignore_index=True, inplace=True)
    dfNew['instantDummyMarketCap'] = dfNew['lastCircSupply']*dfNew['endAvgPriceUSDT']
    indexAtEnd = dfNew['instantDummyMarketCap'].sum() / lastPoint.divisor
    endIndex = copy.copy(lastPoint)
    endIndex.indexValue = indexAtEnd
    endIndex.isoInstant = endIsoInstant
    endIndex.isRebalanceDay = False
    dfNew.drop(columns=['instantDummyMarketCap'], inplace=True)
    endIndex.indexConstituents = dfNew
    return endIndex

# %%
async def lastIndexDataRebalance(beginIsoInstant: str, endIsoInstant:str, lastPoint: IndexData, cacheConn=None) -> IndexData:
    updatedPricesOldConstituents = await computeUpdatedPrices(lastPoint, beginIsoInstant, endIsoInstant)
    dfLastCircSupplies = lastPoint.indexConstituents.copy()
    dfLastCircSupplies.set_index('baseAsset', inplace=True)
    if('endAvgPriceUSDT' in dfLastCircSupplies.columns):
        dfLastCircSupplies.drop(columns=['endAvgPriceUSDT'], inplace=True)
    dfNew = pd.concat([dfLastCircSupplies, updatedPricesOldConstituents], axis=1, join='inner')
    assert(dfNew.shape[0] == dfLastCircSupplies.shape[0])
    assert(dfNew.shape[0] == updatedPricesOldConstituents.shape[0])
    del updatedPricesOldConstituents
    del dfLastCircSupplies
    dfNew.reset_index(inplace=True)
    dfNew['instantDummyMarketCap'] = dfNew['lastCircSupply']*dfNew['endAvgPriceUSDT']
    oldConstituentsNewMarketcap = dfNew['instantDummyMarketCap'].sum()
    
    eligibleAssets = await eligibleAssetsAndMedianVolumes(lastPoint.lastRebalanceISOInstant, endIsoInstant)
    indexConstituents = await selectIndexConstituents(lastPoint.lastRebalanceISOInstant, endIsoInstant, eligibleAssets, cacheConn)
    newConstituentsMarketcap = indexConstituents['lastMarketcap'].sum()
    
    newDivisor = (newConstituentsMarketcap/oldConstituentsNewMarketcap)*lastPoint.divisor
    newValue = newConstituentsMarketcap/newDivisor

    endIndex = copy.copy(lastPoint)
    endIndex.indexValue = newValue
    endIndex.isoInstant = endIsoInstant
    endIndex.isRebalanceDay = True
    endIndex.indexConstituents = indexConstituents
    endIndex.divisor = newDivisor
    endIndex.lastRebalanceISOInstant = endIsoInstant
    return endIndex

# %%
import datetime
computeDay = parse(firstIndexData.isoInstant) + datetime.timedelta(days = 1)
endDate = parse("2022-06-30T00:00:00.000000Z") + datetime.timedelta(days = 1)
lastIndex = firstIndexData
print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
while computeDay <= endDate:
    if(computeDay.day == 1):
        lastIndex = await lastIndexDataRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex, cacheConn)
    else:
        lastIndex = await lastIndexDataNoRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex)
    print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
    computeDay = computeDay + datetime.timedelta(days = 1)
# Out:
# 2020-12-01T00:00:00.000000Z: 1000.000000
# 2020-12-02T00:00:00.000000Z: 949.040000
# 2020-12-03T00:00:00.000000Z: 971.890000
# 2020-12-04T00:00:00.000000Z: 984.790000
# 2020-12-05T00:00:00.000000Z: 932.790000
# 2020-12-06T00:00:00.000000Z: 963.710000
# 2020-12-07T00:00:00.000000Z: 975.780000
# 2020-12-08T00:00:00.000000Z: 964.340000
# 2020-12-09T00:00:00.000000Z: 916.170000
# 2020-12-10T00:00:00.000000Z: 931.640000
# 2020-12-11T00:00:00.000000Z: 915.200000
# 2020-12-12T00:00:00.000000Z: 900.560000
# 2020-12-13T00:00:00.000000Z: 932.960000
# 2020-12-14T00:00:00.000000Z: 955.370000
# 2020-12-15T00:00:00.000000Z: 957.050000
# 2020-12-16T00:00:00.000000Z: 960.870000
# 2020-12-17T00:00:00.000000Z: 1056.540000
# 2020-12-18T00:00:00.000000Z: 1112.800000
# 2020-12-19T00:00:00.000000Z: 1128.720000
# 2020-12-20T00:00:00.000000Z: 1157.470000
# 2020-12-21T00:00:00.000000Z: 1137.750000
# 2020-12-22T00:00:00.000000Z: 1094.240000
# 2020-12-23T00:00:00.000000Z: 1138.330000
# 2020-12-24T00:00:00.000000Z: 1079.940000
# 2020-12-25T00:00:00.000000Z: 1116.780000
# 2020-12-26T00:00:00.000000Z: 1158.090000
# 2020-12-27T00:00:00.000000Z: 1224.320000
# 2020-12-28T00:00:00.000000Z: 1227.090000
# 2020-12-29T00:00:00.000000Z: 1270.140000
# 2020-12-30T00:00:00.000000Z: 1281.360000
# 2020-12-31T00:00:00.000000Z: 1338.490000
# bitcoin
# ethereum
# ripple
# litecoin
# bitcoin-cash
# binancecoin
# chainlink
# cardano
# yearn-finance
# eos
# stellar
# sushi
# polkadot
# tron
# aave
# vechain
# zilliqa
# uniswap
# monero
# filecoin
# elrond-erd-2
# theta-token
# nem
# ethereum-classic
# zcash
# unifi-protocol-dao
# waves
# neo
# dash
# swipe
# algorand
# injective-protocol
# havven
# cosmos
# tezos
# oasis-network
# curve-dao-token
# omisego
# 2021-01-01T00:00:00.000000Z: 1339.310000
# 2021-01-02T00:00:00.000000Z: 1353.080000
# 2021-01-03T00:00:00.000000Z: 1471.180000
# 2021-01-04T00:00:00.000000Z: 1559.830000
# 2021-01-05T00:00:00.000000Z: 1537.420000
# 2021-01-06T00:00:00.000000Z: 1627.610000
# 2021-01-07T00:00:00.000000Z: 1775.200000
# 2021-01-08T00:00:00.000000Z: 1879.410000
# 2021-01-09T00:00:00.000000Z: 1917.860000
# 2021-01-10T00:00:00.000000Z: 1924.490000
# 2021-01-11T00:00:00.000000Z: 1841.770000
# 2021-01-12T00:00:00.000000Z: 1684.700000
# 2021-01-13T00:00:00.000000Z: 1625.790000
# 2021-01-14T00:00:00.000000Z: 1780.850000
# 2021-01-15T00:00:00.000000Z: 1879.330000
# 2021-01-16T00:00:00.000000Z: 1769.990000
# 2021-01-17T00:00:00.000000Z: 1768.220000
# 2021-01-18T00:00:00.000000Z: 1766.630000
# 2021-01-19T00:00:00.000000Z: 1802.430000
# 2021-01-20T00:00:00.000000Z: 1797.190000
# 2021-01-21T00:00:00.000000Z: 1788.020000
# 2021-01-22T00:00:00.000000Z: 1535.400000
# 2021-01-23T00:00:00.000000Z: 1651.150000
# 2021-01-24T00:00:00.000000Z: 1624.350000
# 2021-01-25T00:00:00.000000Z: 1667.300000
# 2021-01-26T00:00:00.000000Z: 1645.220000
# 2021-01-27T00:00:00.000000Z: 1663.300000
# 2021-01-28T00:00:00.000000Z: 1543.500000
# 2021-01-29T00:00:00.000000Z: 1687.810000
# 2021-01-30T00:00:00.000000Z: 1733.870000
# 2021-01-31T00:00:00.000000Z: 1752.080000
# bitcoin
# ethereum
# polkadot
# litecoin
# chainlink
# ripple
# cardano
# bitcoin-cash
# binancecoin
# stellar
# eos
# uniswap
# sushi
# yearn-finance
# vechain
# aave
# tron
# curve-dao-token
# the-graph
# swipe
# cosmos
# neo
# theta-token
# iostoken
# ethereum-classic
# zcash
# zilliqa
# tezos
# havven
# monero
# elrond-erd-2
# algorand
# dogecoin
# omisego
# 1inch
# dash
# band-protocol
# reserve-rights-token
# filecoin
# alpha-finance
# solana
# 2021-02-01T00:00:00.000000Z: 1693.550000
# 2021-02-02T00:00:00.000000Z: 1721.020000
# 2021-02-03T00:00:00.000000Z: 1829.800000
# 2021-02-04T00:00:00.000000Z: 1958.370000
# 2021-02-05T00:00:00.000000Z: 1916.820000
# 2021-02-06T00:00:00.000000Z: 2012.250000
# 2021-02-07T00:00:00.000000Z: 2042.030000
# 2021-02-08T00:00:00.000000Z: 2008.900000
# 2021-02-09T00:00:00.000000Z: 2338.310000
# 2021-02-10T00:00:00.000000Z: 2361.600000
# 2021-02-11T00:00:00.000000Z: 2319.490000
# 2021-02-12T00:00:00.000000Z: 2453.280000
# 2021-02-13T00:00:00.000000Z: 2467.040000
# 2021-02-14T00:00:00.000000Z: 2467.040000
# 2021-02-15T00:00:00.000000Z: 2504.270000
# 2021-02-16T00:00:00.000000Z: 2469.910000
# 2021-02-17T00:00:00.000000Z: 2517.010000
# 2021-02-18T00:00:00.000000Z: 2663.900000
# 2021-02-19T00:00:00.000000Z: 2670.070000
# 2021-02-20T00:00:00.000000Z: 2889.620000
# 2021-02-21T00:00:00.000000Z: 2864.710000
# 2021-02-22T00:00:00.000000Z: 2944.430000
# 2021-02-23T00:00:00.000000Z: 2767.420000
# 2021-02-24T00:00:00.000000Z: 2481.020000
# 2021-02-25T00:00:00.000000Z: 2533.710000
# 2021-02-26T00:00:00.000000Z: 2388.820000
# 2021-02-27T00:00:00.000000Z: 2356.970000
# 2021-02-28T00:00:00.000000Z: 2366.360000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 20    LUNA
# 68     BTT
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# binancecoin
# cardano
# ripple
# polkadot
# dogecoin
# litecoin
# chainlink
# eos
# bitcoin-cash
# stellar
# swipe
# tron
# uniswap
# sushi
# aave
# the-graph
# vechain
# cosmos
# elrond-erd-2
# reef
# matic-network
# avalanche-2
# filecoin
# 1inch
# algorand
# ontology
# neo
# iostoken
# yearn-finance
# tezos
# iota
# alpha-finance
# venus
# zcash
# dash
# monero
# curve-dao-token
# omisego
# ethereum-classic
# fantom
# pancakeswap-token
# band-protocol
# zilliqa
# theta-token
# havven
# nem
# icon
# solana
# republic-protocol
# qtum
# 0x
# compound-governance-token
# thorchain
# reserve-rights-token
# basic-attention-token
# serum
# chiliz
# ravencoin
# kava
# ocean-protocol
# near
# waves
# enjincoin
# unifi-protocol-dao
# hedera-hashgraph
# yfii-finance
# kusama
# wrapped-bitcoin
# coti
# the-sandbox
# tomochain
# ankr
# fetch-ai
# 2021-03-01T00:00:00.000000Z: 2311.590000
# 2021-03-02T00:00:00.000000Z: 2534.560000
# 2021-03-03T00:00:00.000000Z: 2465.830000
# 2021-03-04T00:00:00.000000Z: 2559.000000
# 2021-03-05T00:00:00.000000Z: 2466.040000
# 2021-03-06T00:00:00.000000Z: 2473.050000
# 2021-03-07T00:00:00.000000Z: 2504.710000
# 2021-03-08T00:00:00.000000Z: 2609.050000
# 2021-03-09T00:00:00.000000Z: 2690.690000
# 2021-03-10T00:00:00.000000Z: 2820.390000
# 2021-03-11T00:00:00.000000Z: 2823.950000
# 2021-03-12T00:00:00.000000Z: 2902.560000
# 2021-03-13T00:00:00.000000Z: 2851.780000
# 2021-03-14T00:00:00.000000Z: 3051.090000
# 2021-03-15T00:00:00.000000Z: 2937.200000
# 2021-03-16T00:00:00.000000Z: 2788.800000
# 2021-03-17T00:00:00.000000Z: 2859.770000
# 2021-03-18T00:00:00.000000Z: 2955.130000
# 2021-03-19T00:00:00.000000Z: 2881.550000
# 2021-03-20T00:00:00.000000Z: 2913.590000
# 2021-03-21T00:00:00.000000Z: 2914.620000
# 2021-03-22T00:00:00.000000Z: 2876.930000
# 2021-03-23T00:00:00.000000Z: 2720.890000
# 2021-03-24T00:00:00.000000Z: 2726.730000
# 2021-03-25T00:00:00.000000Z: 2607.470000
# 2021-03-26T00:00:00.000000Z: 2570.390000
# 2021-03-27T00:00:00.000000Z: 2763.680000
# 2021-03-28T00:00:00.000000Z: 2794.620000
# 2021-03-29T00:00:00.000000Z: 2787.330000
# 2021-03-30T00:00:00.000000Z: 2896.810000
# 2021-03-31T00:00:00.000000Z: 2953.730000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 12    LUNA
# 32     BTT
# 43    NPXS
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# binancecoin
# cardano
# chiliz
# ripple
# polkadot
# enjincoin
# litecoin
# theta-token
# swipe
# chainlink
# vechain
# harmony
# filecoin
# uniswap
# nem
# pancakeswap-token
# eos
# holotoken
# tron
# dogecoin
# matic-network
# bitcoin-cash
# avalanche-2
# stellar
# theta-fuel
# reef
# coti
# decentraland
# sushi
# algorand
# ankr
# ontology
# the-graph
# fantom
# hedera-hashgraph
# aave
# the-sandbox
# chromaway
# cosmos
# iostoken
# sun-token
# celer-network
# zilliqa
# solana
# curve-dao-token
# neo
# elrond-erd-2
# ravencoin
# 1inch
# dent
# fetch-ai
# venus
# safepal
# storm
# basic-attention-token
# iota
# tezos
# kusama
# monero
# alpha-finance
# qtum
# reserve-rights-token
# audius
# dash
# siacoin
# icon
# zcash
# omisego
# ethereum-classic
# ocean-protocol
# kava
# origin-protocol
# skale
# bluzelle
# selfkey
# serum
# axie-infinity
# near
# yearn-finance
# litentry
# oasis-network
# republic-protocol
# band-protocol
# thorchain
# dodo
# 2021-04-01T00:00:00.000000Z: 2975.990000
# 2021-04-02T00:00:00.000000Z: 2999.560000
# 2021-04-03T00:00:00.000000Z: 3062.990000
# 2021-04-04T00:00:00.000000Z: 2948.280000
# 2021-04-05T00:00:00.000000Z: 3031.020000
# 2021-04-06T00:00:00.000000Z: 3119.180000
# 2021-04-07T00:00:00.000000Z: 3108.430000
# 2021-04-08T00:00:00.000000Z: 2951.200000
# 2021-04-09T00:00:00.000000Z: 3093.300000
# 2021-04-10T00:00:00.000000Z: 3093.970000
# 2021-04-11T00:00:00.000000Z: 3217.770000
# 2021-04-12T00:00:00.000000Z: 3250.010000
# 2021-04-13T00:00:00.000000Z: 3280.040000
# 2021-04-14T00:00:00.000000Z: 3487.540000
# 2021-04-15T00:00:00.000000Z: 3508.160000
# 2021-04-16T00:00:00.000000Z: 3533.500000
# 2021-04-17T00:00:00.000000Z: 3417.680000
# 2021-04-18T00:00:00.000000Z: 3336.440000
# 2021-04-19T00:00:00.000000Z: 3130.860000
# 2021-04-20T00:00:00.000000Z: 3073.440000
# 2021-04-21T00:00:00.000000Z: 3184.180000
# 2021-04-22T00:00:00.000000Z: 3061.630000
# 2021-04-23T00:00:00.000000Z: 2960.650000
# 2021-04-24T00:00:00.000000Z: 2937.340000
# 2021-04-25T00:00:00.000000Z: 2822.120000
# 2021-04-26T00:00:00.000000Z: 2816.290000
# 2021-04-27T00:00:00.000000Z: 3114.560000
# 2021-04-28T00:00:00.000000Z: 3208.980000
# 2021-04-29T00:00:00.000000Z: 3218.810000
# 2021-04-30T00:00:00.000000Z: 3186.990000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 11      BTT
# 28     LUNA
# 104     AUD
# 115    NANO
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# binancecoin
# ripple
# dogecoin
# cardano
# wink
# vechain
# tron
# litecoin
# polkadot
# chiliz
# eos
# pancakeswap-token
# holotoken
# swipe
# filecoin
# chainlink
# bitcoin-cash
# dent
# stellar
# theta-token
# solana
# uniswap
# neo
# enjincoin
# ontology
# ethereum-classic
# harmony
# iostoken
# cosmos
# aave
# avalanche-2
# elrond-erd-2
# matic-network
# siacoin
# qtum
# zcash
# iota
# wazirx
# monero
# sushi
# dash
# algorand
# tezos
# thorchain
# the-graph
# nkn
# zilliqa
# curve-dao-token
# nem
# omisego
# reef
# ankr
# 1inch
# hedera-hashgraph
# decentraland
# serum
# mithril
# ftx-token
# sun-token
# venus
# yearn-finance
# origin-protocol
# basic-attention-token
# fantom
# storm
# kusama
# reserve-rights-token
# band-protocol
# ravencoin
# coti
# theta-fuel
# verge
# alpha-finance
# chromaway
# icon
# compound-governance-token
# waves
# paris-saint-germain-fan-token
# storj
# fetch-ai
# celer-network
# btc-standard-hashrate-token
# dodo
# zencash
# safepal
# the-sandbox
# digibyte
# wrapped-bitcoin
# near
# vethor-token
# linear
# 0x
# audius
# republic-protocol
# axie-infinity
# litentry
# my-neighbor-alice
# kava
# cartesi
# maker
# metal
# flamingo-finance
# havven
# gifto
# vite
# kyber-network-crystal
# just
# ocean-protocol
# dia-data
# tellor
# tomochain
# akropolis
# loopring
# 2021-05-01T00:00:00.000000Z: 3379.040000
# 2021-05-02T00:00:00.000000Z: 3441.710000
# 2021-05-03T00:00:00.000000Z: 3386.250000
# 2021-05-04T00:00:00.000000Z: 3551.750000
# 2021-05-05T00:00:00.000000Z: 3344.840000
# 2021-05-06T00:00:00.000000Z: 3672.150000
# 2021-05-07T00:00:00.000000Z: 3617.930000
# 2021-05-08T00:00:00.000000Z: 3661.920000
# 2021-05-09T00:00:00.000000Z: 3800.900000
# 2021-05-10T00:00:00.000000Z: 3787.090000
# 2021-05-11T00:00:00.000000Z: 3621.130000
# 2021-05-12T00:00:00.000000Z: 3761.290000
# 2021-05-13T00:00:00.000000Z: 3314.030000
# 2021-05-14T00:00:00.000000Z: 3356.610000
# 2021-05-15T00:00:00.000000Z: 3498.030000
# 2021-05-16T00:00:00.000000Z: 3265.580000
# 2021-05-17T00:00:00.000000Z: 3243.570000
# 2021-05-18T00:00:00.000000Z: 3020.840000
# 2021-05-19T00:00:00.000000Z: 3031.940000
# 2021-05-20T00:00:00.000000Z: 2344.930000
# 2021-05-21T00:00:00.000000Z: 2645.200000
# 2021-05-22T00:00:00.000000Z: 2365.650000
# 2021-05-23T00:00:00.000000Z: 2304.860000
# 2021-05-24T00:00:00.000000Z: 2100.890000
# 2021-05-25T00:00:00.000000Z: 2478.690000
# 2021-05-26T00:00:00.000000Z: 2464.990000
# 2021-05-27T00:00:00.000000Z: 2588.140000
# 2021-05-28T00:00:00.000000Z: 2506.150000
# 2021-05-29T00:00:00.000000Z: 2282.330000
# 2021-05-30T00:00:00.000000Z: 2182.470000
# 2021-05-31T00:00:00.000000Z: 2271.650000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 23    LUNA
# 28     BTT
# 66    NANO
# 71     AUD
# Name: baseAsset, dtype: object
# ethereum
# bitcoin
# dogecoin
# binancecoin
# ripple
# cardano
# matic-network
# polkadot
# ethereum-classic
# eos
# litecoin
# chainlink
# vechain
# bitcoin-cash
# tron
# pancakeswap-token
# solana
# stellar
# swipe
# uniswap
# theta-token
# chiliz
# bakerytoken
# sushi
# filecoin
# aave
# neo
# venus
# zcash
# thorchain
# ontology
# fantom
# avalanche-2
# yearn-finance
# cosmos
# qtum
# reef
# omisego
# monero
# holotoken
# dash
# wink
# kusama
# iexec-rlc
# enjincoin
# tezos
# dent
# curve-dao-token
# waves
# alien-worlds
# zilliqa
# harmony
# iota
# algorand
# hedera-hashgraph
# 1inch
# my-neighbor-alice
# compound-governance-token
# iostoken
# the-graph
# elrond-erd-2
# serum
# cartesi
# wrapped-bitcoin
# maker
# zencash
# havven
# decentraland
# wazirx
# nem
# coti
# smooth-love-potion
# siacoin
# near
# kava
# chromaway
# theta-fuel
# tokocrypto
# alpha-finance
# 2021-06-01T00:00:00.000000Z: 2452.410000
# 2021-06-02T00:00:00.000000Z: 2423.940000
# 2021-06-03T00:00:00.000000Z: 2505.090000
# 2021-06-04T00:00:00.000000Z: 2618.920000
# 2021-06-05T00:00:00.000000Z: 2449.430000
# 2021-06-06T00:00:00.000000Z: 2376.910000
# 2021-06-07T00:00:00.000000Z: 2412.770000
# 2021-06-08T00:00:00.000000Z: 2257.620000
# 2021-06-09T00:00:00.000000Z: 2232.310000
# 2021-06-10T00:00:00.000000Z: 2422.590000
# 2021-06-11T00:00:00.000000Z: 2336.560000
# 2021-06-12T00:00:00.000000Z: 2309.720000
# 2021-06-13T00:00:00.000000Z: 2249.890000
# 2021-06-14T00:00:00.000000Z: 2430.420000
# 2021-06-15T00:00:00.000000Z: 2513.660000
# 2021-06-16T00:00:00.000000Z: 2479.790000
# 2021-06-17T00:00:00.000000Z: 2356.780000
# 2021-06-18T00:00:00.000000Z: 2351.520000
# 2021-06-19T00:00:00.000000Z: 2215.630000
# 2021-06-20T00:00:00.000000Z: 2174.540000
# 2021-06-21T00:00:00.000000Z: 2203.060000
# 2021-06-22T00:00:00.000000Z: 1875.250000
# 2021-06-23T00:00:00.000000Z: 1895.660000
# 2021-06-24T00:00:00.000000Z: 2000.360000
# 2021-06-25T00:00:00.000000Z: 2064.010000
# 2021-06-26T00:00:00.000000Z: 1878.300000
# 2021-06-27T00:00:00.000000Z: 1911.250000
# 2021-06-28T00:00:00.000000Z: 2049.950000
# 2021-06-29T00:00:00.000000Z: 2066.600000
# 2021-06-30T00:00:00.000000Z: 2155.440000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 25    LUNA
# 35     BTT
# 46     AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# binancecoin
# cardano
# matic-network
# dogecoin
# ripple
# polkadot
# solana
# vechain
# chainlink
# shiba-inu
# litecoin
# theta-fuel
# theta-token
# filecoin
# ethereum-classic
# eos
# tron
# pancakeswap-token
# kusama
# chiliz
# internet-computer
# swipe
# thorchain
# bakerytoken
# bitcoin-cash
# aave
# uniswap
# stellar
# sushi
# monero
# fantom
# neo
# waves
# enjincoin
# curve-dao-token
# cosmos
# zcash
# kava
# zilliqa
# 1inch
# wink
# holotoken
# avalanche-2
# omisego
# streamr
# dash
# ontology
# hedera-hashgraph
# yearn-finance
# algorand
# the-graph
# venus
# wazirx
# iota
# dexe
# dent
# elrond-erd-2
# 2021-07-01T00:00:00.000000Z: 2150.110000
# 2021-07-02T00:00:00.000000Z: 2034.350000
# 2021-07-03T00:00:00.000000Z: 2058.660000
# 2021-07-04T00:00:00.000000Z: 2114.670000
# 2021-07-05T00:00:00.000000Z: 2167.750000
# 2021-07-06T00:00:00.000000Z: 2066.310000
# 2021-07-07T00:00:00.000000Z: 2125.940000
# 2021-07-08T00:00:00.000000Z: 2111.910000
# 2021-07-09T00:00:00.000000Z: 2006.370000
# 2021-07-10T00:00:00.000000Z: 2055.330000
# 2021-07-11T00:00:00.000000Z: 2029.070000
# 2021-07-12T00:00:00.000000Z: 2067.130000
# 2021-07-13T00:00:00.000000Z: 1990.590000
# 2021-07-14T00:00:00.000000Z: 1945.800000
# 2021-07-15T00:00:00.000000Z: 1959.200000
# 2021-07-16T00:00:00.000000Z: 1898.580000
# 2021-07-17T00:00:00.000000Z: 1852.740000
# 2021-07-18T00:00:00.000000Z: 1864.990000
# 2021-07-19T00:00:00.000000Z: 1873.120000
# 2021-07-20T00:00:00.000000Z: 1802.620000
# 2021-07-21T00:00:00.000000Z: 1741.140000
# 2021-07-22T00:00:00.000000Z: 1905.910000
# 2021-07-23T00:00:00.000000Z: 1926.480000
# 2021-07-24T00:00:00.000000Z: 2004.070000
# 2021-07-25T00:00:00.000000Z: 2045.590000
# 2021-07-26T00:00:00.000000Z: 2085.530000
# 2021-07-27T00:00:00.000000Z: 2164.130000
# 2021-07-28T00:00:00.000000Z: 2266.800000
# 2021-07-29T00:00:00.000000Z: 2294.600000
# 2021-07-30T00:00:00.000000Z: 2319.410000
# 2021-07-31T00:00:00.000000Z: 2422.400000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 17    LUNA
# 50     BTT
# 59     AUD
# 67     EPS
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# binancecoin
# axie-infinity
# dogecoin
# cardano
# ripple
# polkadot
# matic-network
# alien-worlds
# solana
# chainlink
# ethereum-classic
# theta-token
# litecoin
# my-neighbor-alice
# vechain
# eos
# internet-computer
# the-sandbox
# shiba-inu
# filecoin
# aave
# pancakeswap-token
# smooth-love-potion
# tron
# uniswap
# thorchain
# chromaway
# chiliz
# bitcoin-cash
# enjincoin
# bakerytoken
# sushi
# compound-governance-token
# swipe
# cosmos
# stellar
# theta-fuel
# kusama
# havven
# monero
# decentraland
# neo
# dexe
# zcash
# the-graph
# alpha-finance
# linear
# omisego
# kava
# fetch-ai
# ontology
# elrond-erd-2
# waves
# fantom
# mdex
# iostoken
# dash
# curve-dao-token
# holotoken
# dodo
# yearn-finance
# origin-protocol
# hedera-hashgraph
# tezos
# ftx-token
# superfarm
# 1inch
# harmony
# audius
# algorand
# zilliqa
# the-virtua-kolect
# near
# wink
# unifi-protocol-dao
# avalanche-2
# iota
# sun-token
# litentry
# blockstack
# dent
# nem
# dego-finance
# wrapped-bitcoin
# tomochain
# 2021-08-01T00:00:00.000000Z: 2419.970000
# 2021-08-02T00:00:00.000000Z: 2365.800000
# 2021-08-03T00:00:00.000000Z: 2353.680000
# 2021-08-04T00:00:00.000000Z: 2295.230000
# 2021-08-05T00:00:00.000000Z: 2408.770000
# 2021-08-06T00:00:00.000000Z: 2474.680000
# 2021-08-07T00:00:00.000000Z: 2566.870000
# 2021-08-08T00:00:00.000000Z: 2720.710000
# 2021-08-09T00:00:00.000000Z: 2636.760000
# 2021-08-10T00:00:00.000000Z: 2776.810000
# 2021-08-11T00:00:00.000000Z: 2771.470000
# 2021-08-12T00:00:00.000000Z: 2808.150000
# 2021-08-13T00:00:00.000000Z: 2737.070000
# 2021-08-14T00:00:00.000000Z: 2972.880000
# 2021-08-15T00:00:00.000000Z: 2954.970000
# 2021-08-16T00:00:00.000000Z: 2981.640000
# 2021-08-17T00:00:00.000000Z: 2893.240000
# 2021-08-18T00:00:00.000000Z: 2788.240000
# 2021-08-19T00:00:00.000000Z: 2806.770000
# 2021-08-20T00:00:00.000000Z: 2968.060000
# 2021-08-21T00:00:00.000000Z: 3102.950000
# 2021-08-22T00:00:00.000000Z: 3057.210000
# 2021-08-23T00:00:00.000000Z: 3091.670000
# 2021-08-24T00:00:00.000000Z: 3150.540000
# 2021-08-25T00:00:00.000000Z: 3001.080000
# 2021-08-26T00:00:00.000000Z: 3078.070000
# 2021-08-27T00:00:00.000000Z: 2930.030000
# 2021-08-28T00:00:00.000000Z: 3111.160000
# 2021-08-29T00:00:00.000000Z: 3086.770000
# 2021-08-30T00:00:00.000000Z: 3072.790000
# 2021-08-31T00:00:00.000000Z: 2998.720000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 10    LUNA
# 41     BTT
# 60     EPS
# 89     AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# cardano
# binancecoin
# ripple
# dogecoin
# polkadot
# solana
# axie-infinity
# matic-network
# chainlink
# filecoin
# internet-computer
# vechain
# my-neighbor-alice
# litecoin
# ethereum-classic
# eos
# alien-worlds
# coin98
# theta-token
# thorchain
# pancakeswap-token
# tron
# chiliz
# shiba-inu
# uniswap
# avalanche-2
# bitcoin-cash
# bakerytoken
# sushi
# smooth-love-potion
# kava
# fantom
# dent
# aave
# the-graph
# swipe
# cosmos
# stellar
# neo
# ftx-token
# the-sandbox
# qtum
# enjincoin
# kusama
# chromaway
# holotoken
# iotex
# audius
# algorand
# monero
# wink
# elrond-erd-2
# near
# coti
# curve-dao-token
# omisego
# dash
# tezos
# serum
# 1inch
# decentraland
# zcash
# linear
# compound-governance-token
# ravencoin
# alpha-finance
# ontology
# superfarm
# zilliqa
# reef
# havven
# truefi
# dodo
# venus
# iostoken
# paris-saint-germain-fan-token
# dego-finance
# origin-protocol
# iota
# the-virtua-kolect
# harmony
# fetch-ai
# hedera-hashgraph
# reserve-rights-token
# waves
# yearn-finance
# helium
# siacoin
# trust-wallet-token
# litentry
# unifi-protocol-dao
# theta-fuel
# tokocrypto
# perpetual-protocol
# cartesi
# automata
# funfair
# certik
# clover-finance
# wazirx
# ankr
# arweave
# verge
# ocean-protocol
# wrapped-bitcoin
# skale
# mask-network
# stafi
# celer-network
# iexec-rlc
# 2021-09-01T00:00:00.000000Z: 3071.490000
# 2021-09-02T00:00:00.000000Z: 3250.750000
# 2021-09-03T00:00:00.000000Z: 3267.510000
# 2021-09-04T00:00:00.000000Z: 3349.560000
# 2021-09-05T00:00:00.000000Z: 3327.460000
# 2021-09-06T00:00:00.000000Z: 3433.150000
# 2021-09-07T00:00:00.000000Z: 3469.150000
# 2021-09-08T00:00:00.000000Z: 3052.600000
# 2021-09-09T00:00:00.000000Z: 3038.780000
# 2021-09-10T00:00:00.000000Z: 3040.760000
# 2021-09-11T00:00:00.000000Z: 2909.960000
# 2021-09-12T00:00:00.000000Z: 2958.130000
# 2021-09-13T00:00:00.000000Z: 3032.340000
# 2021-09-14T00:00:00.000000Z: 2934.820000
# 2021-09-15T00:00:00.000000Z: 3057.880000
# 2021-09-16T00:00:00.000000Z: 3149.620000
# 2021-09-17T00:00:00.000000Z: 3106.060000
# 2021-09-18T00:00:00.000000Z: 3031.520000
# 2021-09-19T00:00:00.000000Z: 3093.160000
# 2021-09-20T00:00:00.000000Z: 3009.440000
# 2021-09-21T00:00:00.000000Z: 2710.150000
# 2021-09-22T00:00:00.000000Z: 2552.980000
# 2021-09-23T00:00:00.000000Z: 2793.090000
# 2021-09-24T00:00:00.000000Z: 2865.960000
# 2021-09-25T00:00:00.000000Z: 2707.860000
# 2021-09-26T00:00:00.000000Z: 2698.160000
# 2021-09-27T00:00:00.000000Z: 2738.680000
# 2021-09-28T00:00:00.000000Z: 2658.050000
# 2021-09-29T00:00:00.000000Z: 2577.120000
# 2021-09-30T00:00:00.000000Z: 2625.440000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 8     LUNA
# 63     BTT
# 81     EPS
# 91     AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# solana
# cardano
# binancecoin
# polkadot
# ripple
# avalanche-2
# fantom
# filecoin
# dogecoin
# chainlink
# cosmos
# ftx-token
# matic-network
# algorand
# litecoin
# vechain
# eos
# tron
# omisego
# celer-network
# near
# axie-infinity
# tezos
# theta-token
# internet-computer
# harmony
# elrond-erd-2
# serum
# pancakeswap-token
# hedera-hashgraph
# coin98
# aurora-dao
# iostoken
# ethereum-classic
# sushi
# uniswap
# ecash
# my-neighbor-alice
# coti
# bitcoin-cash
# smooth-love-potion
# shiba-inu
# curve-dao-token
# chiliz
# aave
# swipe
# mina-protocol
# iota
# thorchain
# alien-worlds
# fetch-ai
# kusama
# celo
# stellar
# kava
# the-graph
# arweave
# automata
# oasis-network
# mobox
# monero
# quant-network
# neo
# audius
# raydium
# trust-wallet-token
# the-sandbox
# dent
# 1inch
# waves
# marlin
# zilliqa
# chromaway
# qtum
# holotoken
# dash
# zcash
# reef
# havven
# bakerytoken
# ontology
# mask-network
# compound-governance-token
# icon
# republic-protocol
# origin-protocol
# funfair
# perpetual-protocol
# iotex
# enjincoin
# venus
# arpa-chain
# dodo
# yearn-finance
# v-id-blockchain
# decentraland
# reserve-rights-token
# force-protocol
# wink
# ravencoin
# alpha-finance
# dexe
# skale
# injective-protocol
# tokocrypto
# wrapped-bitcoin
# theta-fuel
# siacoin
# linear
# aelf
# zencash
# superfarm
# cartesi
# civic
# loopring
# litentry
# 2021-10-01T00:00:00.000000Z: 2758.740000
# 2021-10-02T00:00:00.000000Z: 3028.210000
# 2021-10-03T00:00:00.000000Z: 3032.850000
# 2021-10-04T00:00:00.000000Z: 3067.890000
# 2021-10-05T00:00:00.000000Z: 3084.630000
# 2021-10-06T00:00:00.000000Z: 3204.340000
# 2021-10-07T00:00:00.000000Z: 3336.170000
# 2021-10-08T00:00:00.000000Z: 3293.420000
# 2021-10-09T00:00:00.000000Z: 3284.000000
# 2021-10-10T00:00:00.000000Z: 3338.690000
# 2021-10-11T00:00:00.000000Z: 3261.040000
# 2021-10-12T00:00:00.000000Z: 3383.250000
# 2021-10-13T00:00:00.000000Z: 3327.800000
# 2021-10-14T00:00:00.000000Z: 3428.090000
# 2021-10-15T00:00:00.000000Z: 3468.210000
# 2021-10-16T00:00:00.000000Z: 3648.380000
# 2021-10-17T00:00:00.000000Z: 3605.290000
# 2021-10-18T00:00:00.000000Z: 3625.920000
# 2021-10-19T00:00:00.000000Z: 3619.430000
# 2021-10-20T00:00:00.000000Z: 3727.040000
# 2021-10-21T00:00:00.000000Z: 3886.130000
# 2021-10-22T00:00:00.000000Z: 3715.940000
# 2021-10-23T00:00:00.000000Z: 3657.490000
# 2021-10-24T00:00:00.000000Z: 3730.280000
# 2021-10-25T00:00:00.000000Z: 3690.400000
# 2021-10-26T00:00:00.000000Z: 3816.330000
# 2021-10-27T00:00:00.000000Z: 3698.620000
# 2021-10-28T00:00:00.000000Z: 3518.210000
# 2021-10-29T00:00:00.000000Z: 3719.920000
# 2021-10-30T00:00:00.000000Z: 3828.150000
# 2021-10-31T00:00:00.000000Z: 3774.930000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 10    LUNA
# 49     BTT
# 70     AUD
# 89     EPS
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# shiba-inu
# solana
# binancecoin
# polkadot
# ripple
# fantom
# dogecoin
# cardano
# filecoin
# axie-infinity
# avalanche-2
# chainlink
# matic-network
# tron
# litecoin
# cosmos
# omisego
# vechain
# harmony
# smooth-love-potion
# dydx
# eos
# internet-computer
# ftx-token
# theta-token
# near
# algorand
# gala
# stellar
# ethereum-classic
# celer-network
# pancakeswap-token
# uniswap
# tezos
# bitcoin-cash
# elrond-erd-2
# coti
# chiliz
# kava
# coin98
# sushi
# curve-dao-token
# thorchain
# 1inch
# swipe
# hedera-hashgraph
# my-neighbor-alice
# fetch-ai
# the-graph
# serum
# wink
# iota
# btc-standard-hashrate-token
# dent
# holotoken
# monero
# aave
# ecash
# reef
# alien-worlds
# zcash
# celo
# ontology
# iostoken
# arpa-chain
# qtum
# mina-protocol
# kusama
# oasis-network
# zilliqa
# enjincoin
# arweave
# flow
# compound-governance-token
# dash
# bakerytoken
# linear
# mobox
# neo
# aurora-dao
# the-sandbox
# wrapped-bitcoin
# automata
# iotex
# waves
# dodo
# wax
# cartesi
# yearn-finance
# superfarm
# chromaway
# trust-wallet-token
# marlin
# mask-network
# 2021-11-01T00:00:00.000000Z: 3758.830000
# 2021-11-02T00:00:00.000000Z: 3776.700000
# 2021-11-03T00:00:00.000000Z: 3929.750000
# 2021-11-04T00:00:00.000000Z: 3943.260000
# 2021-11-05T00:00:00.000000Z: 3863.330000
# 2021-11-06T00:00:00.000000Z: 3848.100000
# 2021-11-07T00:00:00.000000Z: 3893.570000
# 2021-11-08T00:00:00.000000Z: 3984.120000
# 2021-11-09T00:00:00.000000Z: 4193.590000
# 2021-11-10T00:00:00.000000Z: 4151.270000
# 2021-11-11T00:00:00.000000Z: 4015.710000
# 2021-11-12T00:00:00.000000Z: 4047.830000
# 2021-11-13T00:00:00.000000Z: 3998.060000
# 2021-11-14T00:00:00.000000Z: 4022.730000
# 2021-11-15T00:00:00.000000Z: 4057.070000
# 2021-11-16T00:00:00.000000Z: 3961.840000
# 2021-11-17T00:00:00.000000Z: 3702.900000
# 2021-11-18T00:00:00.000000Z: 3732.690000
# 2021-11-19T00:00:00.000000Z: 3495.490000
# 2021-11-20T00:00:00.000000Z: 3652.130000
# 2021-11-21T00:00:00.000000Z: 3752.210000
# 2021-11-22T00:00:00.000000Z: 3670.910000
# 2021-11-23T00:00:00.000000Z: 3525.310000
# 2021-11-24T00:00:00.000000Z: 3637.380000
# 2021-11-25T00:00:00.000000Z: 3576.590000
# 2021-11-26T00:00:00.000000Z: 3721.480000
# 2021-11-27T00:00:00.000000Z: 3369.290000
# 2021-11-28T00:00:00.000000Z: 3426.030000
# 2021-11-29T00:00:00.000000Z: 3568.420000
# 2021-11-30T00:00:00.000000Z: 3639.790000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 17     LUNA
# 52      BTT
# 76      AUD
# 106    KEEP
# 117      NU
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# shiba-inu
# the-sandbox
# binancecoin
# decentraland
# solana
# polkadot
# avalanche-2
# ripple
# tron
# gala
# cardano
# dogecoin
# loopring
# fantom
# litecoin
# filecoin
# omisego
# chiliz
# chainlink
# matic-network
# vechain
# chromaway
# enjincoin
# alien-worlds
# axie-infinity
# smooth-love-potion
# my-neighbor-alice
# iotex
# elrond-erd-2
# internet-computer
# harmony
# theta-token
# cosmos
# zcash
# wax
# algorand
# dydx
# eos
# curve-dao-token
# holotoken
# pancakeswap-token
# near
# ethereum-classic
# the-graph
# oasis-network
# stellar
# wink
# bitcoin-cash
# ftx-token
# arweave
# swipe
# sushi
# thorchain
# basic-attention-token
# uniswap
# celer-network
# ankr
# mina-protocol
# aave
# just
# dent
# dash
# tezos
# 1inch
# monero
# mobox
# hedera-hashgraph
# cartesi
# fetch-ai
# iota
# coti
# the-virtua-kolect
# arpa-chain
# storj
# qtum
# mask-network
# sun-token
# zencash
# kava
# audius
# superfarm
# reef
# livepeer
# helium
# flow
# kusama
# ontology
# linear
# beta-finance
# automata
# origin-protocol
# coin98
# serum
# keep3rv1
# aurora-dao
# bakerytoken
# ecash
# iostoken
# zilliqa
# icon
# siacoin
# yield-guild-games
# trust-wallet-token
# compound-governance-token
# neo
# ocean-protocol
# skale
# marlin
# ravencoin
# celo
# lto-network
# reserve-rights-token
# syscoin
# nervos-network
# havven
# blockstack
# wrapped-bitcoin
# quant-network
# nkn
# dodo
# 2021-12-01T00:00:00.000000Z: 3655.760000
# 2021-12-02T00:00:00.000000Z: 3659.160000
# 2021-12-03T00:00:00.000000Z: 3618.320000
# 2021-12-04T00:00:00.000000Z: 3414.390000
# 2021-12-05T00:00:00.000000Z: 3184.930000
# 2021-12-06T00:00:00.000000Z: 3190.100000
# 2021-12-07T00:00:00.000000Z: 3274.620000
# 2021-12-08T00:00:00.000000Z: 3266.510000
# 2021-12-09T00:00:00.000000Z: 3309.430000
# 2021-12-10T00:00:00.000000Z: 3097.930000
# 2021-12-11T00:00:00.000000Z: 3011.220000
# 2021-12-12T00:00:00.000000Z: 3155.130000
# 2021-12-13T00:00:00.000000Z: 3194.760000
# 2021-12-14T00:00:00.000000Z: 2949.910000
# 2021-12-15T00:00:00.000000Z: 3046.320000
# 2021-12-16T00:00:00.000000Z: 3121.490000
# 2021-12-17T00:00:00.000000Z: 3047.740000
# 2021-12-18T00:00:00.000000Z: 2975.130000
# 2021-12-19T00:00:00.000000Z: 3033.510000
# 2021-12-20T00:00:00.000000Z: 3012.970000
# 2021-12-21T00:00:00.000000Z: 3024.270000
# 2021-12-22T00:00:00.000000Z: 3128.170000
# 2021-12-23T00:00:00.000000Z: 3119.120000
# 2021-12-24T00:00:00.000000Z: 3261.180000
# 2021-12-25T00:00:00.000000Z: 3225.780000
# 2021-12-26T00:00:00.000000Z: 3233.430000
# 2021-12-27T00:00:00.000000Z: 3247.000000
# 2021-12-28T00:00:00.000000Z: 3246.360000
# 2021-12-29T00:00:00.000000Z: 3035.870000
# 2021-12-30T00:00:00.000000Z: 2941.650000
# 2021-12-31T00:00:00.000000Z: 2988.560000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 2     LUNA
# 37     BTT
# 49     GXS
# 77     AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# binancecoin
# matic-network
# solana
# the-sandbox
# shiba-inu
# avalanche-2
# gala
# polkadot
# ripple
# cardano
# decentraland
# dogecoin
# fantom
# chainlink
# near
# tron
# filecoin
# litecoin
# curve-dao-token
# cosmos
# oasis-network
# vechain
# elrond-erd-2
# sushi
# axie-infinity
# internet-computer
# loopring
# eos
# theta-token
# omisego
# algorand
# harmony
# my-neighbor-alice
# enjincoin
# mobox
# dydx
# chromaway
# stellar
# uniswap
# pancakeswap-token
# alien-worlds
# zcash
# smooth-love-potion
# chiliz
# mines-of-dalarnia
# aave
# ethereum-name-service
# wink
# tezos
# bitcoin-cash
# basic-attention-token
# iotex
# aragon
# the-graph
# just
# dusk-network
# sun-token
# ethereum-classic
# thorchain
# cortex
# contentos
# iota
# monero
# kava
# holotoken
# 1inch
# measurable-data-token
# celer-network
# vulcan-forged
# arweave
# yearn-finance
# ftx-token
# gitcoin
# cocos-bcx
# safepal
# hedera-hashgraph
# wax
# syscoin
# swipe
# coti
# lto-network
# mina-protocol
# jasmycoin
# zilliqa
# celo
# helium
# dash
# dent
# reserve-rights-token
# nuls
# superfarm
# coin98
# mask-network
# flow
# ocean-protocol
# ankr
# waves
# serum
# neo
# icon
# yield-guild-games
# reef
# audius
# request-network
# theta-fuel
# havven
# mithril
# compound-governance-token
# render-token
# iostoken
# quant-network
# marlin
# linear
# zencash
# qtum
# 2022-01-01T00:00:00.000000Z: 2943.770000
# 2022-01-02T00:00:00.000000Z: 3037.180000
# 2022-01-03T00:00:00.000000Z: 3037.530000
# 2022-01-04T00:00:00.000000Z: 2976.210000
# 2022-01-05T00:00:00.000000Z: 2948.600000
# 2022-01-06T00:00:00.000000Z: 2776.740000
# 2022-01-07T00:00:00.000000Z: 2737.320000
# 2022-01-08T00:00:00.000000Z: 2608.950000
# 2022-01-09T00:00:00.000000Z: 2576.230000
# 2022-01-10T00:00:00.000000Z: 2605.210000
# 2022-01-11T00:00:00.000000Z: 2570.200000
# 2022-01-12T00:00:00.000000Z: 2667.560000
# 2022-01-13T00:00:00.000000Z: 2771.630000
# 2022-01-14T00:00:00.000000Z: 2677.300000
# 2022-01-15T00:00:00.000000Z: 2726.210000
# 2022-01-16T00:00:00.000000Z: 2735.440000
# 2022-01-17T00:00:00.000000Z: 2744.730000
# 2022-01-18T00:00:00.000000Z: 2674.490000
# 2022-01-19T00:00:00.000000Z: 2653.670000
# 2022-01-20T00:00:00.000000Z: 2593.390000
# 2022-01-21T00:00:00.000000Z: 2518.910000
# 2022-01-22T00:00:00.000000Z: 2220.130000
# 2022-01-23T00:00:00.000000Z: 2105.430000
# 2022-01-24T00:00:00.000000Z: 2196.690000
# 2022-01-25T00:00:00.000000Z: 2170.570000
# 2022-01-26T00:00:00.000000Z: 2193.550000
# 2022-01-27T00:00:00.000000Z: 2186.360000
# 2022-01-28T00:00:00.000000Z: 2189.400000
# 2022-01-29T00:00:00.000000Z: 2236.770000
# 2022-01-30T00:00:00.000000Z: 2272.780000
# 2022-01-31T00:00:00.000000Z: 2249.650000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 2     LUNA
# 74     GXS
# 75     AUD
# 98     ANY
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# fantom
# binancecoin
# solana
# cosmos
# cardano
# matic-network
# polkadot
# near
# the-sandbox
# shiba-inu
# ripple
# chainlink
# avalanche-2
# dogecoin
# oasis-network
# gala
# harmony
# tron
# curve-dao-token
# decentraland
# internet-computer
# litecoin
# filecoin
# loopring
# axie-infinity
# vechain
# dusk-network
# sushi
# theta-token
# algorand
# chromaway
# ftx-token
# elrond-erd-2
# omisego
# aave
# enjincoin
# aragon
# kava
# eos
# pancakeswap-token
# uniswap
# wink
# dydx
# monero
# my-neighbor-alice
# stellar
# swipe
# yearn-finance
# sun-token
# just
# zcash
# arweave
# thorchain
# ethereum-classic
# keep3rv1
# chiliz
# celer-network
# syscoin
# constitutiondao
# bitcoin-cash
# smooth-love-potion
# the-graph
# tezos
# alien-worlds
# ethereum-name-service
# iota
# celo
# mina-protocol
# hedera-hashgraph
# zelcash
# 1inch
# basic-attention-token
# coti
# secret
# flow
# dash
# helium
# ravencoin
# vulcan-forged
# iotex
# voxies
# spell-token
# zilliqa
# klay-token
# holotoken
# dent
# wax
# mobox
# mines-of-dalarnia
# havven
# biconomy
# gitcoin
# jasmycoin
# ocean-protocol
# wrapped-bitcoin
# yield-guild-games
# linear
# coin98
# neo
# fetch-ai
# quant-network
# render-token
# 2022-02-01T00:00:00.000000Z: 2296.710000
# 2022-02-02T00:00:00.000000Z: 2340.320000
# 2022-02-03T00:00:00.000000Z: 2232.210000
# 2022-02-04T00:00:00.000000Z: 2256.990000
# 2022-02-05T00:00:00.000000Z: 2499.100000
# 2022-02-06T00:00:00.000000Z: 2502.650000
# 2022-02-07T00:00:00.000000Z: 2561.170000
# 2022-02-08T00:00:00.000000Z: 2662.250000
# 2022-02-09T00:00:00.000000Z: 2650.080000
# 2022-02-10T00:00:00.000000Z: 2699.370000
# 2022-02-11T00:00:00.000000Z: 2610.340000
# 2022-02-12T00:00:00.000000Z: 2506.940000
# 2022-02-13T00:00:00.000000Z: 2504.600000
# 2022-02-14T00:00:00.000000Z: 2481.830000
# 2022-02-15T00:00:00.000000Z: 2514.650000
# 2022-02-16T00:00:00.000000Z: 2671.710000
# 2022-02-17T00:00:00.000000Z: 2628.710000
# 2022-02-18T00:00:00.000000Z: 2431.970000
# 2022-02-19T00:00:00.000000Z: 2383.200000
# 2022-02-20T00:00:00.000000Z: 2388.490000
# 2022-02-21T00:00:00.000000Z: 2277.880000
# 2022-02-22T00:00:00.000000Z: 2186.350000
# 2022-02-23T00:00:00.000000Z: 2258.230000
# 2022-02-24T00:00:00.000000Z: 2203.150000
# 2022-02-25T00:00:00.000000Z: 2242.270000
# 2022-02-26T00:00:00.000000Z: 2332.350000
# 2022-02-27T00:00:00.000000Z: 2330.270000
# 2022-02-28T00:00:00.000000Z: 2228.400000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 2     LUNA
# 69     AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# binancecoin
# ripple
# shiba-inu
# solana
# gala
# avalanche-2
# cardano
# fantom
# the-sandbox
# smooth-love-potion
# polkadot
# decentraland
# matic-network
# cosmos
# dogecoin
# tron
# chainlink
# near
# constitutiondao
# litecoin
# oasis-network
# axie-infinity
# filecoin
# internet-computer
# harmony
# theta-token
# vechain
# elrond-erd-2
# ethereum-classic
# curve-dao-token
# my-neighbor-alice
# loopring
# algorand
# eos
# enjincoin
# dydx
# beta-finance
# bitcoin-cash
# zcash
# ftx-token
# monero
# tezos
# alien-worlds
# mines-of-dalarnia
# uniswap
# chromaway
# kava
# jasmycoin
# wink
# pancakeswap-token
# omisego
# chiliz
# sushi
# aave
# stellar
# waves
# aurora-dao
# arweave
# neo
# flow
# vulcan-forged
# the-graph
# hedera-hashgraph
# just
# league-of-kingdoms
# sun-token
# aragon
# immutable-x
# thorchain
# mina-protocol
# render-token
# dusk-network
# moonbeam
# swipe
# mobox
# bittorrent
# ethereum-name-service
# api3
# syscoin
# quant-network
# celer-network
# ooki
# spell-token
# celo
# kyber-network-crystal
# dash
# voxies
# coti
# klay-token
# iotex
# anchor-protocol
# dent
# holotoken
# qtum
# keep3rv1
# helium
# iota
# 2022-03-01T00:00:00.000000Z: 2520.390000
# 2022-03-02T00:00:00.000000Z: 2579.580000
# 2022-03-03T00:00:00.000000Z: 2551.680000
# 2022-03-04T00:00:00.000000Z: 2467.380000
# 2022-03-05T00:00:00.000000Z: 2282.720000
# 2022-03-06T00:00:00.000000Z: 2312.550000
# 2022-03-07T00:00:00.000000Z: 2238.310000
# 2022-03-08T00:00:00.000000Z: 2205.590000
# 2022-03-09T00:00:00.000000Z: 2251.600000
# 2022-03-10T00:00:00.000000Z: 2411.400000
# 2022-03-11T00:00:00.000000Z: 2280.360000
# 2022-03-12T00:00:00.000000Z: 2249.030000
# 2022-03-13T00:00:00.000000Z: 2253.870000
# 2022-03-14T00:00:00.000000Z: 2195.470000
# 2022-03-15T00:00:00.000000Z: 2284.470000
# 2022-03-16T00:00:00.000000Z: 2277.080000
# 2022-03-17T00:00:00.000000Z: 2391.070000
# 2022-03-18T00:00:00.000000Z: 2394.730000
# 2022-03-19T00:00:00.000000Z: 2458.190000
# 2022-03-20T00:00:00.000000Z: 2488.810000
# 2022-03-21T00:00:00.000000Z: 2424.490000
# 2022-03-22T00:00:00.000000Z: 2429.110000
# 2022-03-23T00:00:00.000000Z: 2502.260000
# 2022-03-24T00:00:00.000000Z: 2550.580000
# 2022-03-25T00:00:00.000000Z: 2615.770000
# 2022-03-26T00:00:00.000000Z: 2611.230000
# 2022-03-27T00:00:00.000000Z: 2638.160000
# 2022-03-28T00:00:00.000000Z: 2768.160000
# 2022-03-29T00:00:00.000000Z: 2783.030000
# 2022-03-30T00:00:00.000000Z: 2817.140000
# 2022-03-31T00:00:00.000000Z: 2810.860000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 2     LUNA
# 68     AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# binancecoin
# solana
# ripple
# avalanche-2
# fantom
# shiba-inu
# gala
# cardano
# polkadot
# thorchain
# jasmycoin
# near
# cosmos
# the-sandbox
# matic-network
# waves
# tron
# chainlink
# smooth-love-potion
# dogecoin
# decentraland
# litecoin
# vechain
# constitutiondao
# oasis-network
# elrond-erd-2
# immutable-x
# moviebloc
# internet-computer
# axie-infinity
# zcash
# ethereum-classic
# filecoin
# origin-protocol
# harmony
# chiliz
# my-neighbor-alice
# anchor-protocol
# eos
# aave
# monero
# the-graph
# algorand
# theta-token
# alpine-f1-team-fan-token
# uniswap
# loopring
# pancakeswap-token
# curve-dao-token
# dydx
# alien-worlds
# ethereum-name-service
# kyber-network-crystal
# bitcoin-cash
# celo
# trust-wallet-token
# dash
# sushi
# stellar
# arweave
# moonbeam
# wink
# league-of-kingdoms
# mobox
# mines-of-dalarnia
# chromaway
# enjincoin
# ftx-token
# voxies
# mina-protocol
# keep3rv1
# swipe
# omisego
# iotex
# pax-gold
# just
# havven
# uma
# beta-finance
# neo
# api3
# hedera-hashgraph
# tezos
# 2022-04-01T00:00:00.000000Z: 2721.470000
# 2022-04-02T00:00:00.000000Z: 2801.670000
# 2022-04-03T00:00:00.000000Z: 2778.890000
# 2022-04-04T00:00:00.000000Z: 2830.810000
# 2022-04-05T00:00:00.000000Z: 2829.650000
# 2022-04-06T00:00:00.000000Z: 2762.750000
# 2022-04-07T00:00:00.000000Z: 2588.050000
# 2022-04-08T00:00:00.000000Z: 2627.270000
# 2022-04-09T00:00:00.000000Z: 2557.670000
# 2022-04-10T00:00:00.000000Z: 2596.210000
# 2022-04-11T00:00:00.000000Z: 2556.440000
# 2022-04-12T00:00:00.000000Z: 2382.050000
# 2022-04-13T00:00:00.000000Z: 2430.440000
# 2022-04-14T00:00:00.000000Z: 2494.810000
# 2022-04-15T00:00:00.000000Z: 2423.880000
# 2022-04-16T00:00:00.000000Z: 2457.860000
# 2022-04-17T00:00:00.000000Z: 2455.990000
# 2022-04-18T00:00:00.000000Z: 2402.610000
# 2022-04-19T00:00:00.000000Z: 2465.500000
# 2022-04-20T00:00:00.000000Z: 2508.530000
# 2022-04-21T00:00:00.000000Z: 2490.980000
# 2022-04-22T00:00:00.000000Z: 2426.840000
# 2022-04-23T00:00:00.000000Z: 2394.740000
# 2022-04-24T00:00:00.000000Z: 2375.130000
# 2022-04-25T00:00:00.000000Z: 2367.800000
# 2022-04-26T00:00:00.000000Z: 2427.910000
# 2022-04-27T00:00:00.000000Z: 2279.380000
# 2022-04-28T00:00:00.000000Z: 2341.090000
# 2022-04-29T00:00:00.000000Z: 2369.620000
# 2022-04-30T00:00:00.000000Z: 2288.010000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 3     LUNA
# 66     AUD
# 86     EPS
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# stepn
# binancecoin
# solana
# near
# apecoin
# dogecoin
# ripple
# shiba-inu
# avalanche-2
# cardano
# zilliqa
# polkadot
# smooth-love-potion
# jasmycoin
# fantom
# waves
# gala
# thorchain
# matic-network
# the-sandbox
# tron
# filecoin
# cosmos
# ethereum-classic
# litecoin
# axie-infinity
# vechain
# chainlink
# decentraland
# eos
# moonbeam
# kyber-network-crystal
# biswap
# monero
# oasis-network
# mines-of-dalarnia
# pancakeswap-token
# aave
# league-of-kingdoms
# internet-computer
# astar
# chiliz
# constitutiondao
# origin-protocol
# theta-token
# elrond-erd-2
# loopring
# vulcan-forged
# kava
# algorand
# harmony
# dydx
# zcash
# my-neighbor-alice
# curve-dao-token
# the-graph
# mina-protocol
# mobox
# iostoken
# celo
# wink
# immutable-x
# enjincoin
# ftx-token
# alien-worlds
# bitcoin-cash
# sushi
# binaryx
# audius
# havven
# anchor-protocol
# metal
# ethereum-name-service
# bakerytoken
# stellar
# chromaway
# voxies
# uniswap
# holotoken
# bitcoin-gold
# linear
# dash
# celer-network
# just
# reserve-rights-token
# kadena
# frax-share
# tezos
# alpine-f1-team-fan-token
# flow
# 2022-05-01T00:00:00.000000Z: 2209.420000
# 2022-05-02T00:00:00.000000Z: 2276.380000
# 2022-05-03T00:00:00.000000Z: 2282.240000
# 2022-05-04T00:00:00.000000Z: 2234.770000
# 2022-05-05T00:00:00.000000Z: 2366.020000
# 2022-05-06T00:00:00.000000Z: 2184.450000
# 2022-05-07T00:00:00.000000Z: 2151.120000
# 2022-05-08T00:00:00.000000Z: 2108.660000
# 2022-05-09T00:00:00.000000Z: 2025.810000
# 2022-05-10T00:00:00.000000Z: 1768.290000
# 2022-05-11T00:00:00.000000Z: 1844.550000
# 2022-05-12T00:00:00.000000Z: 1662.130000
# 2022-05-13T00:00:00.000000Z: 1619.410000
# 2022-05-14T00:00:00.000000Z: 1662.280000
# 2022-05-15T00:00:00.000000Z: 1706.320000
# 2022-05-16T00:00:00.000000Z: 1784.960000
# 2022-05-17T00:00:00.000000Z: 1690.710000
# 2022-05-18T00:00:00.000000Z: 1734.930000
# 2022-05-19T00:00:00.000000Z: 1613.560000
# 2022-05-20T00:00:00.000000Z: 1702.260000
# 2022-05-21T00:00:00.000000Z: 1644.260000
# 2022-05-22T00:00:00.000000Z: 1662.430000
# 2022-05-23T00:00:00.000000Z: 1711.740000
# 2022-05-24T00:00:00.000000Z: 1648.490000
# 2022-05-25T00:00:00.000000Z: 1673.550000
# 2022-05-26T00:00:00.000000Z: 1657.290000
# 2022-05-27T00:00:00.000000Z: 1594.710000
# 2022-05-28T00:00:00.000000Z: 1557.640000
# 2022-05-29T00:00:00.000000Z: 1591.810000
# 2022-05-30T00:00:00.000000Z: 1614.490000
# 2022-05-31T00:00:00.000000Z: 1747.410000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 59    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# stepn
# binancecoin
# solana
# apecoin
# ripple
# avalanche-2
# tron
# cardano
# fantom
# near
# polkadot
# shiba-inu
# dogecoin
# matic-network
# gala
# the-sandbox
# axie-infinity
# anchor-protocol
# litecoin
# cosmos
# jasmycoin
# zilliqa
# decentraland
# chainlink
# thorchain
# ethereum-name-service
# vechain
# mines-of-dalarnia
# waves
# monero
# filecoin
# oasis-network
# ethereum-classic
# smooth-love-potion
# kyber-network-crystal
# constitutiondao
# aave
# internet-computer
# algorand
# elrond-erd-2
# curve-dao-token
# loopring
# eos
# uniswap
# my-neighbor-alice
# harmony
# theta-token
# bitcoin-cash
# zcash
# the-graph
# sushi
# kava
# league-of-kingdoms
# dydx
# celo
# kusama
# chiliz
# pancakeswap-token
# alien-worlds
# immutable-x
# binaryx
# moonbeam
# enjincoin
# tezos
# wink
# 2022-06-01T00:00:00.000000Z: 1738.420000
# 2022-06-02T00:00:00.000000Z: 1625.130000
# 2022-06-03T00:00:00.000000Z: 1657.590000
# 2022-06-04T00:00:00.000000Z: 1609.680000
# 2022-06-05T00:00:00.000000Z: 1624.360000
# 2022-06-06T00:00:00.000000Z: 1625.430000
# 2022-06-07T00:00:00.000000Z: 1690.980000
# 2022-06-08T00:00:00.000000Z: 1668.510000
# 2022-06-09T00:00:00.000000Z: 1632.360000
# 2022-06-10T00:00:00.000000Z: 1629.600000
# 2022-06-11T00:00:00.000000Z: 1557.600000
# 2022-06-12T00:00:00.000000Z: 1493.560000
# 2022-06-13T00:00:00.000000Z: 1395.250000
# 2022-06-14T00:00:00.000000Z: 1190.980000
# 2022-06-15T00:00:00.000000Z: 1181.480000
# 2022-06-16T00:00:00.000000Z: 1220.150000
# 2022-06-17T00:00:00.000000Z: 1089.200000
# 2022-06-18T00:00:00.000000Z: 1099.690000
# 2022-06-19T00:00:00.000000Z: 1020.560000
# 2022-06-20T00:00:00.000000Z: 1115.820000
# 2022-06-21T00:00:00.000000Z: 1117.760000
# 2022-06-22T00:00:00.000000Z: 1128.080000
# 2022-06-23T00:00:00.000000Z: 1079.380000
# 2022-06-24T00:00:00.000000Z: 1148.690000
# 2022-06-25T00:00:00.000000Z: 1182.440000
# 2022-06-26T00:00:00.000000Z: 1196.050000
# 2022-06-27T00:00:00.000000Z: 1166.030000
# 2022-06-28T00:00:00.000000Z: 1153.590000
# 2022-06-29T00:00:00.000000Z: 1117.830000
# 2022-06-30T00:00:00.000000Z: 1099.710000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 10    LUNA
# 49     AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# solana
# binancecoin
# cardano
# ripple
# stepn
# avalanche-2
# tron
# dogecoin
# chainlink
# apecoin
# matic-network
# shiba-inu
# polkadot
# near
# waves
# fantom
# gala
# the-sandbox
# optimism
# litecoin
# terra-luna
# thorchain
# decentraland
# cosmos
# anchor-protocol
# constitutiondao
# unifi-protocol-dao
# bella-protocol
# elrond-erd-2
# jasmycoin
# vechain
# internet-computer
# filecoin
# axie-infinity
# zilliqa
# project-galaxy
# bitcoin-cash
# theta-token
# monero
# litentry
# aave
# uniswap
# oasis-network
# my-neighbor-alice
# ethereum-classic
# ethereum-name-service
# moviebloc
# origin-protocol
# reserve-rights-token
# ftx-token
# algorand
# eos
# harmony
# 2022-07-01T00:00:00.000000Z: 1086.280000
