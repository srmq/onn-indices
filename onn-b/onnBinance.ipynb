# %% [markdown]
# # Computing daily ONN index on Binance

# %% [markdown]
# ## Getting all available symbols on Binance

# %% [markdown]
# In this section, we just get all available assets on Binance, generating at the end a file named `all-binance-tokens.csv`. Each line in this file contains the asset symbol two times, separated by comma (e.g. `ETH,ETH`). This is because we will use it afterwards in the __[`bnbFetchCoinData.py`](https://github.com/srmq/bnbfetch-coin-data)__ script, which expects the CSV file of lines in the format `asset_description,asset_symbol`, and we don't care about descriptions here.

# %%
import httpx
import pandas as pd

# %%
binanceBaseURL = 'https://api.binance.com'

# %%
async def getExchangeInfo():
    spotExchangeInfoURL = binanceBaseURL + "/api/v3/exchangeInfo"

    async with httpx.AsyncClient() as client:
        r = await client.get(spotExchangeInfoURL)
    return r.json()

# %%
exchangeInfo = await getExchangeInfo()

# %%
#blacklist = None
#with open('blacklist.txt', 'r') as f:
#    blacklist = f.read().split(',')
# blacklist should be disabled for now, we need coin data for every coin

# %%
baseAssets = set()
#for coinSymbol in exchangeInfo['symbols']:
#    if not (coinSymbol['baseAsset'].lower() in blacklist):
#        baseAssets.add(coinSymbol['baseAsset'])

# %%
for coinSymbol in exchangeInfo['symbols']:
    baseAssets.add(coinSymbol['baseAsset'])

# %%
def notLeveraged(asset):
    return not (asset.endswith('UP') or asset.endswith('DOWN') or asset.endswith('BEAR') or asset.endswith('BULL'))

# %%
baseAssets = set(filter(notLeveraged, baseAssets))

# %%
baseAssets
# Out:
# {'1INCH',
#  'AAVE',
#  'ACA',
#  'ACH',
#  'ACM',
#  'ADA',
#  'ADX',
#  'AE',
#  'AERGO',
#  'AGI',
#  'AGIX',
#  'AGLD',
#  'AION',
#  'AKRO',
#  'ALCX',
#  'ALGO',
#  'ALICE',
#  'ALPACA',
#  'ALPHA',
#  'ALPINE',
#  'AMB',
#  'AMP',
#  'ANC',
#  'ANKR',
#  'ANT',
#  'ANY',
#  'APE',
#  'API3',
#  'APPC',
#  'AR',
#  'ARDR',
#  'ARK',
#  'ARN',
#  'ARPA',
#  'ASR',
#  'AST',
#  'ASTR',
#  'ATA',
#  'ATM',
#  'ATOM',
#  'AUCTION',
#  'AUD',
#  'AUDIO',
#  'AUTO',
#  'AVA',
#  'AVAX',
#  'AXS',
#  'BADGER',
#  'BAKE',
#  'BAL',
#  'BAND',
#  'BAR',
#  'BAT',
#  'BCC',
#  'BCD',
#  'BCH',
#  'BCHA',
#  'BCHABC',
#  'BCHSV',
#  'BCN',
#  'BCPT',
#  'BDOT',
#  'BEAM',
#  'BEL',
#  'BETA',
#  'BETH',
#  'BGBP',
#  'BICO',
#  'BIFI',
#  'BKRW',
#  'BLZ',
#  'BNB',
#  'BNT',
#  'BNX',
#  'BOND',
#  'BOT',
#  'BQX',
#  'BRD',
#  'BSW',
#  'BTC',
#  'BTCB',
#  'BTCST',
#  'BTG',
#  'BTS',
#  'BTT',
#  'BTTC',
#  'BURGER',
#  'BUSD',
#  'BZRX',
#  'C98',
#  'CAKE',
#  'CDT',
#  'CELO',
#  'CELR',
#  'CFX',
#  'CHAT',
#  'CHESS',
#  'CHR',
#  'CHZ',
#  'CITY',
#  'CKB',
#  'CLOAK',
#  'CLV',
#  'CMT',
#  'CND',
#  'COCOS',
#  'COMP',
#  'COS',
#  'COTI',
#  'COVER',
#  'CREAM',
#  'CRV',
#  'CTK',
#  'CTSI',
#  'CTXC',
#  'CVC',
#  'CVP',
#  'CVX',
#  'DAI',
#  'DAR',
#  'DASH',
#  'DATA',
#  'DCR',
#  'DEGO',
#  'DENT',
#  'DEXE',
#  'DF',
#  'DGB',
#  'DGD',
#  'DIA',
#  'DLT',
#  'DNT',
#  'DOCK',
#  'DODO',
#  'DOGE',
#  'DOT',
#  'DREP',
#  'DUSK',
#  'DYDX',
#  'EASY',
#  'EDO',
#  'EGLD',
#  'ELF',
#  'ENG',
#  'ENJ',
#  'ENS',
#  'EOS',
#  'EPS',
#  'EPX',
#  'ERD',
#  'ERN',
#  'ETC',
#  'ETH',
#  'EUR',
#  'EVX',
#  'EZ',
#  'FARM',
#  'FET',
#  'FIDA',
#  'FIL',
#  'FIO',
#  'FIRO',
#  'FIS',
#  'FLM',
#  'FLOW',
#  'FLUX',
#  'FOR',
#  'FORTH',
#  'FRONT',
#  'FTM',
#  'FTT',
#  'FUEL',
#  'FUN',
#  'FXS',
#  'GAL',
#  'GALA',
#  'GAS',
#  'GBP',
#  'GHST',
#  'GLM',
#  'GLMR',
#  'GMT',
#  'GNO',
#  'GNT',
#  'GO',
#  'GRS',
#  'GRT',
#  'GTC',
#  'GTO',
#  'GVT',
#  'GXS',
#  'HARD',
#  'HBAR',
#  'HC',
#  'HEGIC',
#  'HIGH',
#  'HIVE',
#  'HNT',
#  'HOT',
#  'HSR',
#  'ICN',
#  'ICP',
#  'ICX',
#  'IDEX',
#  'ILV',
#  'IMX',
#  'INJ',
#  'INS',
#  'IOST',
#  'IOTA',
#  'IOTX',
#  'IQ',
#  'IRIS',
#  'JASMY',
#  'JOE',
#  'JST',
#  'JUV',
#  'KAVA',
#  'KDA',
#  'KEEP',
#  'KEY',
#  'KLAY',
#  'KMD',
#  'KNC',
#  'KP3R',
#  'KSM',
#  'LAZIO',
#  'LDO',
#  'LEND',
#  'LINA',
#  'LINK',
#  'LIT',
#  'LOKA',
#  'LOOM',
#  'LPT',
#  'LRC',
#  'LSK',
#  'LTC',
#  'LTO',
#  'LUN',
#  'LUNA',
#  'LUNC',
#  'MANA',
#  'MASK',
#  'MATIC',
#  'MBL',
#  'MBOX',
#  'MC',
#  'MCO',
#  'MDA',
#  'MDT',
#  'MDX',
#  'MFT',
#  'MINA',
#  'MIR',
#  'MITH',
#  'MKR',
#  'MLN',
#  'MOB',
#  'MOD',
#  'MOVR',
#  'MTH',
#  'MTL',
#  'MULTI',
#  'NANO',
#  'NAS',
#  'NAV',
#  'NBS',
#  'NBT',
#  'NCASH',
#  'NEAR',
#  'NEBL',
#  'NEO',
#  'NEXO',
#  'NKN',
#  'NMR',
#  'NPXS',
#  'NU',
#  'NULS',
#  'NXS',
#  'OAX',
#  'OCEAN',
#  'OG',
#  'OGN',
#  'OM',
#  'OMG',
#  'ONE',
#  'ONG',
#  'ONT',
#  'OOKI',
#  'OP',
#  'ORN',
#  'OST',
#  'OXT',
#  'PAX',
#  'PAXG',
#  'PEOPLE',
#  'PERL',
#  'PERP',
#  'PHA',
#  'PHB',
#  'PHX',
#  'PIVX',
#  'PLA',
#  'PNT',
#  'POA',
#  'POE',
#  'POLS',
#  'POLY',
#  'POND',
#  'PORTO',
#  'POWR',
#  'PPT',
#  'PROM',
#  'PROS',
#  'PSG',
#  'PUNDIX',
#  'PYR',
#  'QI',
#  'QKC',
#  'QLC',
#  'QNT',
#  'QSP',
#  'QTUM',
#  'QUICK',
#  'RAD',
#  'RAMP',
#  'RARE',
#  'RAY',
#  'RCN',
#  'RDN',
#  'REEF',
#  'REI',
#  'REN',
#  'RENBTC',
#  'REP',
#  'REQ',
#  'RGT',
#  'RIF',
#  'RLC',
#  'RNDR',
#  'ROSE',
#  'RPX',
#  'RSR',
#  'RUNE',
#  'RVN',
#  'SALT',
#  'SAND',
#  'SANTOS',
#  'SC',
#  'SCRT',
#  'SFP',
#  'SHIB',
#  'SKL',
#  'SKY',
#  'SLP',
#  'SNGLS',
#  'SNM',
#  'SNT',
#  'SNX',
#  'SOL',
#  'SPARTA',
#  'SPELL',
#  'SRM',
#  'SSV',
#  'STEEM',
#  'STMX',
#  'STORJ',
#  'STORM',
#  'STPT',
#  'STRAT',
#  'STRAX',
#  'STX',
#  'SUB',
#  'SUN',
#  'SUPER',
#  'SUSD',
#  'SUSHI',
#  'SWRV',
#  'SXP',
#  'SYS',
#  'T',
#  'TCT',
#  'TFUEL',
#  'THETA',
#  'TKO',
#  'TLM',
#  'TNB',
#  'TNT',
#  'TOMO',
#  'TORN',
#  'TRB',
#  'TRIBE',
#  'TRIG',
#  'TROY',
#  'TRU',
#  'TRX',
#  'TUSD',
#  'TUSDB',
#  'TVK',
#  'TWT',
#  'UFT',
#  'UMA',
#  'UNFI',
#  'UNI',
#  'USDC',
#  'USDP',
#  'USDS',
#  'USDSB',
#  'USDT',
#  'UST',
#  'USTC',
#  'UTK',
#  'VEN',
#  'VET',
#  'VGX',
#  'VIA',
#  'VIB',
#  'VIBE',
#  'VIDT',
#  'VITE',
#  'VOXEL',
#  'VTHO',
#  'WABI',
#  'WAN',
#  'WAVES',
#  'WAXP',
#  'WBTC',
#  'WIN',
#  'WING',
#  'WINGS',
#  'WNXM',
#  'WOO',
#  'WPR',
#  'WRX',
#  'WTC',
#  'XEC',
#  'XEM',
#  'XLM',
#  'XMR',
#  'XNO',
#  'XRP',
#  'XTZ',
#  'XVG',
#  'XVS',
#  'XZC',
#  'YFI',
#  'YFII',
#  'YGG',
#  'YOYO',
#  'ZEC',
#  'ZEN',
#  'ZIL',
#  'ZRX'}

# %%
with open('all-binance-tokens.csv', 'w') as f:
    for asset in baseAssets:
        f.write(f"{asset},{asset}\n")

# %% [markdown]
# Now that we have our `all-binance-tokens.csv` file, we can download, for instance, the complete historical data for all assets on Binance, using something like:

# %% [markdown]
# `python <path_to_script>/bnbFetchCoinData.py --coins all-binance-tokens.csv --interval 1d`

# %% [markdown]
# This will create a `coindata` directory under the current one with everything we need.

# %% [markdown]
# ## Importing Data to QuestDB

# %% [markdown]
# We will use __[QuestDB](https://questdb.io/)__ in order to facilitate data manipulation and keep memory requirements low (we won't need to load everything on RAM). First we will create a table for holding the data. Here is what we did:

# %% [markdown]
# `CREATE TABLE binance_daily(symb SYMBOL capacity 2048, open_time TIMESTAMP, high DOUBLE, low DOUBLE, close DOUBLE, volume DOUBLE, close_time TIMESTAMP, quote_asset_vol DOUBLE, num_trades LONG, takerbuy_baseasset_vol DOUBLE, takerbuy_quoteasset_vol DOUBLE), index(symb) timestamp(open_time) PARTITION BY YEAR;`

# %% [markdown]
# Now we will import the data (that went to the `coindata` subdirectory)...

# %%
import glob

allCSVFiles = glob.glob('./coindata/*.csv')

# %%
import httpx
import csv

host = 'http://localhost:9000'

async def questInsert(symbol: str, filename: str, lotSize=300):
    async def executeQuery(valStrings):
        sql_query = "INSERT INTO binance_daily VALUES"
        sql_query += valStrings[0]
        for i in range(1, len(valStrings)):
            sql_query += f",{valStrings[i]}"
        query_params = {'query': sql_query, 'fmt': 'json'}
        async with httpx.AsyncClient() as client:
            await client.get(host + '/exec', params=query_params)
        
    with open(filename, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        valStrings = []
        for row in reader:
            if len(valStrings) == lotSize:
                await executeQuery(valStrings)
                valStrings = []
            val = f"(\'{symbol}\', {int(row['Open time'])*1000}, {float(row['High'])}, {float(row['Low'])}, {float(row['Close'])}, {float(row['Volume'])}, {int(row['Close time'] + '999')}, {float(row['Quote asset volume'])}, {int(row['Number of trades'])}, {float(row['Taker buy base asset volume'])}, {float(row['Taker buy quote asset volume'])})"
            valStrings.append(val)
        if len(valStrings) > 0:
            await executeQuery(valStrings)

# %%
from pathlib import Path
i = 0
for csvFile in allCSVFiles:
    symb = Path(csvFile).name.split('.')[0]
    await questInsert(symb, csvFile)
    i += 1
    if i % 100 == 0:
        print(f"Inserted {i} symbols out of {len(allCSVFiles)}")
# Out:
# Inserted 100 symbols out of 1819
# Inserted 200 symbols out of 1819
# Inserted 300 symbols out of 1819
# Inserted 400 symbols out of 1819
# Inserted 500 symbols out of 1819
# Inserted 600 symbols out of 1819
# Inserted 700 symbols out of 1819
# Inserted 800 symbols out of 1819
# Inserted 900 symbols out of 1819
# Inserted 1000 symbols out of 1819
# Inserted 1100 symbols out of 1819
# Inserted 1200 symbols out of 1819
# Inserted 1300 symbols out of 1819
# Inserted 1400 symbols out of 1819
# Inserted 1500 symbols out of 1819
# Inserted 1600 symbols out of 1819
# Inserted 1700 symbols out of 1819
# Inserted 1800 symbols out of 1819

# %% [markdown]
# Now QuestDB has ingested all data. Let's play!

# %% [markdown]
# ## Playing with the data

# %%
import pandas as pd
import httpx

# %%
host = 'http://localhost:9000'

# %%
async def daysTradedInMonthBySymbol(year: int, month: int) -> pd.DataFrame:
    assert(month >= 1 and month <= 12)
    assert(year >= 2000 and year <= 9999)
    if month == 12:
        nextMonth = 1
        nextMonthYear = year + 1
    else:
        nextMonth = month + 1
        nextMonthYear = year
    sql_query = "select symb, count(*) as daystraded from 'binance_daily' where open_time >= '%d-%02d-01T00:00:00.000000Z' and open_time < '%d-%02d-01T00:00:00.000000Z' and num_trades >= 1 group by symb"%(year, month, nextMonthYear, nextMonth)
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
            r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    return pd.DataFrame(columns=['symb', 'daysTraded'], data=jsonR['dataset'])

# %%
# simple test for daysTradedInMonthBySymbol
resp = await daysTradedInMonthBySymbol(2020, 11)
resp
# Out:
#           symb  daysTraded
# 0       FTTBNB          30
# 1      WBTCBTC          30
# 2      WINUSDC          30
# 3       BELBTC          30
# 4      TRBUSDT          30
# ..         ...         ...
# 812    AVAUSDT           7
# 813   HEGICETH           6
# 814  HEGICBUSD           6
# 815   PROMBUSD           5
# 816    PROMBNB           5
#
# [817 rows x 2 columns]

# %%
import calendar
import datetime
from typing import List

# we will consider that an eligible asset should have at least one trade
# pair that was negotiated every day of the month
async def symbolsTradedEveryDay(year: int, month: int) -> List[str]:
    firstDayOfMonth = datetime.date(year, month, 1)
    daysInMonth = calendar.monthrange(firstDayOfMonth.year, firstDayOfMonth.month)[1]
    df = await daysTradedInMonthBySymbol(year, month)
    return df[df['daysTraded']==daysInMonth]['symb'].tolist()

# %%
# simple test for symbolsTradedEveryDay
await symbolsTradedEveryDay(2020, 11)
# Out:
# ['FTTBNB',
#  'WBTCBTC',
#  'WINUSDC',
#  'BELBTC',
#  'TRBUSDT',
#  'BTCGBP',
#  'BCHBNB',
#  'WTCBTC',
#  'BCHUSDC',
#  'QKCETH',
#  'SCUSDT',
#  'XRPBNB',
#  'NKNUSDT',
#  'WAVESETH',
#  'AUDIOBUSD',
#  'SOLBNB',
#  'BUSDUSDT',
#  'NPXSUSDT',
#  'BEAMUSDT',
#  'YFIIBUSD',
#  'BLZBTC',
#  'BNBBKRW',
#  'EOSUSDT',
#  'BNBPAX',
#  'EOSBTC',
#  'ZENBTC',
#  'NANOBUSD',
#  'OXTBTC',
#  'BELBUSD',
#  'ADAETH',
#  'BCPTBTC',
#  'DIABTC',
#  'USDTBKRW',
#  'LSKETH',
#  'BTTBUSD',
#  'NKNBNB',
#  'LTCUSDT',
#  'WAVESUSDT',
#  'LOOMBTC',
#  'DATABUSD',
#  'CDTBTC',
#  'WTCBNB',
#  'RVNUSDT',
#  'PNTUSDT',
#  'ORNBTC',
#  'THETAUSDT',
#  'SRMBTC',
#  'BTCUSDT',
#  'STORJBTC',
#  'ORNUSDT',
#  'AUDIOBTC',
#  'SWRVBNB',
#  'RLCBTC',
#  'LRCETH',
#  'SANDBUSD',
#  'SUSHIBUSD',
#  'WRXUSDT',
#  'CMTBTC',
#  'PERLBTC',
#  'XRPAUD',
#  'WNXMBTC',
#  'SNXUSDT',
#  'FETUSDT',
#  'STPTUSDT',
#  'YFIBUSD',
#  'NBSUSDT',
#  'TRBBTC',
#  'NEOUSDC',
#  'MKRBUSD',
#  'NKNBTC',
#  'GOBTC',
#  'ENJETH',
#  'APPCBTC',
#  'OCEANUSDT',
#  'MDTBNB',
#  'UMABTC',
#  'POWRBTC',
#  'XVGBTC',
#  'ARPABTC',
#  'VIDTBUSD',
#  'ADABNB',
#  'ANTBNB',
#  'MFTETH',
#  'DENTUSDT',
#  'ZRXBNB',
#  'ADABKRW',
#  'DOTUSDT',
#  'ADATUSD',
#  'EGLDUSDT',
#  'XRPBUSD',
#  'TRXBNB',
#  'COSBTC',
#  'AUDBUSD',
#  'HIVEBTC',
#  'SOLBTC',
#  'NMRUSDT',
#  'RUNEBNB',
#  'ALGOBNB',
#  'SWRVBUSD',
#  'DOGEUSDT',
#  'CHRBNB',
#  'GTOUSDT',
#  'TFUELUSDT',
#  'ZENUSDT',
#  'LSKUSDT',
#  'MDTBTC',
#  'HOTBNB',
#  'AVAXBNB',
#  'QTUMUSDT',
#  'EGLDBTC',
#  'STEEMETH',
#  'REPBTC',
#  'XRPPAX',
#  'NEOBUSD',
#  'BTCEUR',
#  'RENBTC',
#  'MITHBTC',
#  'DOTBUSD',
#  'COCOSBNB',
#  'RLCETH',
#  'BNBBTC',
#  'LUNABTC',
#  'UNIBNB',
#  'RSRUSDT',
#  'COTIBNB',
#  'ZECUSDT',
#  'LINKEUR',
#  'LOOMETH',
#  'IRISBTC',
#  'COTIUSDT',
#  'NEARBUSD',
#  'SXPUSDT',
#  'BNTETH',
#  'SXPBUSD',
#  'GXSBTC',
#  'CHZBTC',
#  'SNGLSBTC',
#  'AAVEBUSD',
#  'XZCETH',
#  'ENJBTC',
#  'ZECUSDC',
#  'XRPTUSD',
#  'TROYBTC',
#  'OSTBTC',
#  'LTOBTC',
#  'ZILUSDT',
#  'BZRXBTC',
#  'IRISUSDT',
#  'STEEMBTC',
#  'XMRBNB',
#  'ELFBTC',
#  'IOTXUSDT',
#  'DIABUSD',
#  'TRXETH',
#  'ONEBUSD',
#  'KEYUSDT',
#  'NEARBTC',
#  'SNTBTC',
#  'KSMUSDT',
#  'KMDBTC',
#  'FLMBNB',
#  'BATUSDC',
#  'KAVABTC',
#  'GNTBTC',
#  'MBLBNB',
#  'CTXCBTC',
#  'LUNABNB',
#  'YFIIBNB',
#  'MANABTC',
#  'ONTBUSD',
#  'IRISBNB',
#  'BLZETH',
#  'DNTBTC',
#  'BALUSDT',
#  'SCRTBTC',
#  'ALGOTUSD',
#  'SXPAUD',
#  'MFTUSDT',
#  'BTTTUSD',
#  'ZRXUSDT',
#  'COMPUSDT',
#  'OCEANBTC',
#  'EGLDBNB',
#  'LSKBTC',
#  'XLMBTC',
#  'BNTUSDT',
#  'UTKUSDT',
#  'AAVEETH',
#  'DENTETH',
#  'CREAMBUSD',
#  'QTUMBUSD',
#  'ONTBTC',
#  'LTCETH',
#  'FIOUSDT',
#  'KMDUSDT',
#  'CTKBUSD',
#  'BCHBUSD',
#  'VITEUSDT',
#  'SUNUSDT',
#  'PHBTUSD',
#  'CRVUSDT',
#  'WINGUSDT',
#  'XEMBTC',
#  'SCRTETH',
#  'WPRBTC',
#  'ARPABNB',
#  'DATABTC',
#  'GXSUSDT',
#  'LINKAUD',
#  'SANDBTC',
#  'RUNEBTC',
#  'XLMETH',
#  'KAVABNB',
#  'WNXMBUSD',
#  'CHRBTC',
#  'WANBNB',
#  'RVNBTC',
#  'VETETH',
#  'HNTUSDT',
#  'NXSBTC',
#  'DOCKUSDT',
#  'KEYETH',
#  'BTSUSDT',
#  'STMXBTC',
#  'XRPBKRW',
#  'BNBUSDT',
#  'LTCTUSD',
#  'MTHBTC',
#  'XMRUSDT',
#  'CRVBTC',
#  'RCNBTC',
#  'KAVAUSDT',
#  'ONTBNB',
#  'FUNBTC',
#  'SXPBTC',
#  'DOTBKRW',
#  'UNIUSDT',
#  'DREPUSDT',
#  'FTTUSDT',
#  'LUNABUSD',
#  'BOTBUSD',
#  'GXSETH',
#  'SXPGBP',
#  'TRXPAX',
#  'WINGBUSD',
#  'LRCUSDT',
#  'BALBNB',
#  'AGIBTC',
#  'AVABTC',
#  'DASHUSDT',
#  'RENUSDT',
#  'BLZBNB',
#  'WINGBTC',
#  'TRXBUSD',
#  'DCRUSDT',
#  'LTCBUSD',
#  'ETHDAI',
#  'AIONBTC',
#  'TRXUSDT',
#  'ETCBUSD',
#  'HCBTC',
#  'ATOMBUSD',
#  'MTLETH',
#  'RDNBTC',
#  'LINKTUSD',
#  'INJBNB',
#  'ZECBTC',
#  'ICXETH',
#  'BNTBUSD',
#  'IOTAUSDT',
#  'ICXUSDT',
#  'QSPETH',
#  'XLMBNB',
#  'CTXCUSDT',
#  'ETHPAX',
#  'CVCETH',
#  'ONEBTC',
#  'SUSHIBNB',
#  'CREAMBNB',
#  'TCTBTC',
#  'COMPBNB',
#  'UTKBTC',
#  'BNBEUR',
#  'RSRBTC',
#  'DREPBTC',
#  'ALGOBTC',
#  'VIBETH',
#  'TNBBTC',
#  'LINKBKRW',
#  'ALPHABTC',
#  'YFIIBTC',
#  'ONGBTC',
#  'TFUELBTC',
#  'BUSDBKRW',
#  'QKCBTC',
#  'QTUMBTC',
#  'NMRBTC',
#  'AMBBTC',
#  'CELRBTC',
#  'HIVEUSDT',
#  'XLMBUSD',
#  'CELRUSDT',
#  'XVSBTC',
#  'WANETH',
#  'GRSBTC',
#  'EOSBUSD',
#  'FLMUSDT',
#  'ZENBNB',
#  'IDEXBTC',
#  'MANAUSDT',
#  'COMPBUSD',
#  'RVNBUSD',
#  'CTSIBTC',
#  'RUNEUSDT',
#  'SCBTC',
#  'NCASHETH',
#  'FILUSDT',
#  'STMXETH',
#  'FTMBTC',
#  'ETHBKRW',
#  'BCHPAX',
#  'BCDBTC',
#  'DASHBNB',
#  'CRVBUSD',
#  'ADAUSDT',
#  'WINTRX',
#  'ETCBTC',
#  'DOCKBTC',
#  'EOSBNB',
#  'AIONUSDT',
#  'HBARBNB',
#  'DASHBUSD',
#  'NULSUSDT',
#  'DOTBTC',
#  'MITHBNB',
#  'ANTBUSD',
#  'CTKBTC',
#  'EOSETH',
#  'SANDUSDT',
#  'HBARUSDT',
#  'BNBETH',
#  'ARPAUSDT',
#  'ADABUSD',
#  'NBSBTC',
#  'PPTBTC',
#  'COCOSUSDT',
#  'TOMOUSDT',
#  'KSMBUSD',
#  'DATAUSDT',
#  'NEOBTC',
#  'AERGOBUSD',
#  'EURBUSD',
#  'VETBUSD',
#  'THETAETH',
#  'ETHBTC',
#  'BATBUSD',
#  'PAXUSDT',
#  'ZECBUSD',
#  'ANTBTC',
#  'TOMOBNB',
#  'SPARTABNB',
#  'DUSKBTC',
#  'XZCUSDT',
#  'SXPEUR',
#  'OGNBTC',
#  'SUSHIBTC',
#  'USDCUSDT',
#  'WTCETH',
#  'LRCBTC',
#  'CELRBNB',
#  'SUSHIUSDT',
#  'BRDETH',
#  'WAVESBUSD',
#  'ETCBNB',
#  'FTTBTC',
#  'AERGOBTC',
#  'WTCUSDT',
#  'SKYBTC',
#  'WANBTC',
#  'SNXBUSD',
#  'HNTBTC',
#  'TRXXRP',
#  'QLCBTC',
#  'SANDBNB',
#  'WANUSDT',
#  'MATICBNB',
#  'CVCBTC',
#  'VIBBTC',
#  'DOTBNB',
#  'TOMOBTC',
#  'BTCDAI',
#  'SCETH',
#  'LUNAUSDT',
#  'IOTABNB',
#  'ALPHABUSD',
#  'MANABUSD',
#  'LTCBNB',
#  'VIDTBTC',
#  'KNCETH',
#  'MKRBTC',
#  'UNIBTC',
#  'THETABNB',
#  'AVABNB',
#  'BZRXBUSD',
#  'ANTUSDT',
#  'BUSDDAI',
#  'WRXBUSD',
#  'ANKRBTC',
#  'GNTETH',
#  'CAKEBUSD',
#  'DIABNB',
#  'YFIBTC',
#  'ARKBTC',
#  'ONTETH',
#  'IDEXBUSD',
#  'YFIUSDT',
#  'FUNETH',
#  'ENJBUSD',
#  'ICXBNB',
#  'DATAETH',
#  'ANKRUSDT',
#  'RLCUSDT',
#  'BTGBTC',
#  'KNCBTC',
#  'LTOUSDT',
#  'BTCBKRW',
#  'STEEMBNB',
#  'OAXBTC',
#  'BELUSDT',
#  'SRMBNB',
#  'VETBNB',
#  'ONEBNB',
#  'AIONETH',
#  'BNBGBP',
#  'BZRXBNB',
#  'WINUSDT',
#  'ZILBNB',
#  'STMXUSDT',
#  'ETCETH',
#  'MBLBTC',
#  'IOSTETH',
#  'BNBTUSD',
#  'HBARBUSD',
#  'XZCBTC',
#  'BAKEBNB',
#  'XTZBTC',
#  'BANDBNB',
#  'LTCPAX',
#  'ZRXBUSD',
#  'TROYBNB',
#  'NEOUSDT',
#  'EGLDBUSD',
#  'EURUSDT',
#  'WRXBNB',
#  'STORJETH',
#  'DASHETH',
#  'TRBBUSD',
#  'TRXBTC',
#  'NULSBTC',
#  'GVTBTC',
#  'HBARBTC',
#  'TRXUSDC',
#  'REQBTC',
#  'XRPEUR',
#  'XVSUSDT',
#  'NEBLBTC',
#  'NEOETH',
#  'BNBBUSD',
#  'KNCBUSD',
#  'CHZBNB',
#  'DOTEUR',
#  'BTCUSDC',
#  'ETHGBP',
#  'ETHUSDT',
#  'HOTETH',
#  'QLCETH',
#  'REPUSDT',
#  'SOLBUSD',
#  'AVAXBTC',
#  'STORJBUSD',
#  'TCTUSDT',
#  'SNTETH',
#  'NANOUSDT',
#  'QSPBTC',
#  'ELFETH',
#  'BRDBNB',
#  'BRDBTC',
#  'ALPHAUSDT',
#  'SNXBNB',
#  'BLZUSDT',
#  'CTSIBNB',
#  'IOSTUSDT',
#  'BTCBUSD',
#  'POABTC',
#  'FUNUSDT',
#  'ADABTC',
#  'BANDUSDT',
#  'UMAUSDT',
#  'FTMUSDT',
#  'WAVESBNB',
#  'LINKBUSD',
#  'ATOMBNB',
#  'DCRBTC',
#  'VETUSDT',
#  'ANKRBNB',
#  'EASYETH',
#  'MATICUSDT',
#  'BOTBTC',
#  'NASETH',
#  'MDABTC',
#  'MFTBNB',
#  'SOLUSDT',
#  'TRXTUSD',
#  'XVGETH',
#  'LINKBTC',
#  'FETBTC',
#  'DGBUSDT',
#  'STPTBTC',
#  'POWRETH',
#  'AUDUSDT',
#  'SYSBTC',
#  'XRPBTC',
#  'CTKUSDT',
#  'IRISBUSD',
#  'XMRBUSD',
#  'SXPBNB',
#  'IOTXETH',
#  'ONTUSDT',
#  'MBLUSDT',
#  'BURGERBNB',
#  'GBPBUSD',
#  'ETHUSDC',
#  'MTLBTC',
#  'NAVBTC',
#  'CNDBTC',
#  'BZRXUSDT',
#  'CTKBNB',
#  'FILBTC',
#  'ICXBTC',
#  'JSTBTC',
#  'AVAXBUSD',
#  'XRPUSDC',
#  'QTUMETH',
#  'POLYBTC',
#  'VIBEBTC',
#  'AVAXUSDT',
#  'STXBTC',
#  'SRMBUSD',
#  'BATETH',
#  'NANOETH',
#  'BATUSDT',
#  'WABIBTC',
#  'COMPBTC',
#  'FTMBNB',
#  'COSBNB',
#  'PHBBTC',
#  'NMRBUSD',
#  'TRBBNB',
#  'CTSIBUSD',
#  'BTTBNB',
#  'LINKETH',
#  'ZRXETH',
#  'VETBTC',
#  'THETABTC',
#  'RSRBUSD',
#  'RLCBNB',
#  'XRPUSDT',
#  'RSRBNB',
#  'CMTETH',
#  'BNTBTC',
#  'CVCUSDT',
#  'VTHOUSDT',
#  'PERLBNB',
#  'PERLUSDT',
#  'BTTUSDT',
#  'AAVEBTC',
#  'AAVEUSDT',
#  'AUDIOUSDT',
#  'STORJUSDT',
#  'ENJUSDT',
#  'BTSBTC',
#  'ADXETH',
#  'ARDRUSDT',
#  'SRMUSDT',
#  'BNBUSDC',
#  'NEOBNB',
#  'SNMBTC',
#  'INJBUSD',
#  'NEARUSDT',
#  'HOTBTC',
#  'USDTDAI',
#  'EVXBTC',
#  'BNBDAI',
#  'WNXMBNB',
#  'NANOBTC',
#  'BATBNB',
#  'IOTABUSD',
#  'AAVEBNB',
#  'PAXGBNB',
#  'XTZBUSD',
#  'MANAETH',
#  'AIONBNB',
#  'HOTUSDT',
#  'GBPUSDT',
#  'ZRXBTC',
#  'BQXETH',
#  'OXTUSDT',
#  'DLTBTC',
#  'KMDETH',
#  'MATICBTC',
#  'MITHUSDT',
#  'DIAUSDT',
#  'KSMBNB',
#  'ETHBUSD',
#  'ICXBUSD',
#  'FLMBUSD',
#  'DOGEBUSD',
#  'YFIBNB',
#  'FIOBTC',
#  'NASBTC',
#  'MKRUSDT',
#  'PAXGUSDT',
#  'DUSKUSDT',
#  'XTZUSDT',
#  'BCHUSDT',
#  'OCEANBNB',
#  'XVSBNB',
#  'IOTABTC',
#  'BCHBTC',
#  'IQBNB',
#  'ENJBNB',
#  'ZILBTC',
#  'YOYOBTC',
#  'HIVEBNB',
#  'FILBUSD',
#  'BALBUSD',
#  'CHRUSDT',
#  'ALPHABNB',
#  'ZECBNB',
#  'SNXBTC',
#  'JSTBUSD',
#  'ZILBUSD',
#  'XEMETH',
#  'EOSTUSD',
#  'BATBTC',
#  'BEAMBTC',
#  'ASTBTC',
#  'XMRETH',
#  'CTSIUSDT',
#  'ALGOBUSD',
#  'TUSDUSDT',
#  'LINKUSDC',
#  'IOTAETH',
#  'GASBTC',
#  'DASHBTC',
#  'VIABTC',
#  'ATOMUSDC',
#  'OMGBTC',
#  'MATICBUSD',
#  'ZILETH',
#  'DOGEBTC',
#  'MDTUSDT',
#  'BTTTRX',
#  'BTTUSDC',
#  'OMGUSDT',
#  'OSTETH',
#  'AVABUSD',
#  'COSUSDT',
#  'BALBTC',
#  'COTIBTC',
#  'ATOMBTC',
#  'OMGETH',
#  'WINGBNB',
#  'GTOBTC',
#  'WNXMUSDT',
#  'AEBTC',
#  'BTCPAX',
#  'BTCAUD',
#  'FIOBUSD',
#  'NEARBNB',
#  'YFIIUSDT',
#  'BQXBTC',
#  'VITEBTC',
#  'VTHOBNB',
#  'UNIBUSD',
#  'DGBBTC',
#  'LTCUSDC',
#  'ATOMUSDT',
#  'NPXSETH',
#  'TROYUSDT',
#  'IOSTBTC',
#  'ADAUSDC',
#  'CRVBNB',
#  'MTLUSDT',
#  'BNBAUD',
#  'PAXGBTC',
#  'CHZUSDT',
#  'SUNBTC',
#  'INJUSDT',
#  'TOMOBUSD',
#  'KSMBTC',
#  'WBTCETH',
#  'JSTUSDT',
#  'LINKUSDT',
#  'PIVXBTC',
#  'LRCBUSD',
#  'OGNUSDT',
#  'ONEUSDT',
#  'ZECETH',
#  'WRXBTC',
#  'BCHTUSD',
#  'WABIBNB',
#  'FETBNB',
#  'XMRBTC',
#  'PNTBTC',
#  'STXBNB',
#  'XTZBNB',
#  'RUNEBUSD',
#  'DGBBUSD',
#  'ETCUSDT',
#  'IOTXBTC',
#  'FILBNB',
#  'LTCBTC',
#  'ETHEUR',
#  'JSTBNB',
#  'ADXBTC',
#  'XVSBUSD',
#  'XRPGBP',
#  'EOSUSDC',
#  'KNCUSDT',
#  'ETHAUD',
#  'IQBUSD',
#  'OCEANBUSD',
#  'BANDBTC',
#  'CAKEBNB',
#  'XLMUSDT',
#  'ALGOUSDT',
#  'STXUSDT',
#  'INJBTC',
#  'WAVESBTC',
#  'FIOBNB',
#  'BELBNB',
#  'ZENETH',
#  'ONGUSDT',
#  'WINBNB',
#  'FLMBTC',
#  'CDTETH',
#  'XRPETH',
#  'AAVEBKRW',
#  'OGNBNB',
#  'MKRBNB',
#  'ARDRBTC',
#  'BTCTUSD',
#  'ETHTUSD']

# %%
import json
with open('coindata/coin-metadata.json', 'r') as f:
    coinMetadata = json.loads(f.read())
symbols = coinMetadata['exchange-info']['symbols']
symbolDict = {}
symbolsByBaseDict = {}
for symbol in symbols:
    symbolDict[symbol['symbol']] = symbol
    baseSymbols = symbolsByBaseDict.get(symbol['baseAsset'], [])
    baseSymbols.append(symbol)
    symbolsByBaseDict[symbol['baseAsset']] = baseSymbols
del symbols

# %%
from typing import Set
async def initialAssetCandidateSet(year: int, month: int) -> Set[str]:
    symbols = await symbolsTradedEveryDay(year, month)
    candidateAssets = set()
    def getBlacklist() -> List[str]:
        blacklist = None
        with open('blacklist.txt', 'r') as f:
            blacklist = f.read().split(',')
        return blacklist

    blackListSet = set(getBlacklist())
    for symbol in symbols:
        baseAsset = symbolDict[symbol]['baseAsset']
        #if symbolDict[symbol]['status'] == 'TRADING' and (baseAsset.lower() not in blackListSet):
        if symbolDict[symbol]['status'] == 'TRADING':
            candidateAssets.add(baseAsset)
    
    return candidateAssets

# %%
t = await initialAssetCandidateSet(2020, 11)
str(t)
# Out:
# "{'WIN', 'STEEM', 'TROY', 'TRB', 'TFUEL', 'BTS', 'IOTA', 'RSR', 'ARPA', 'SOL', 'NXS', 'SRM', 'YFII', 'SUSHI', 'AION', 'XLM', 'SAND', 'VITE', 'ATOM', 'COS', 'VET', 'NMR', 'OXT', 'KAVA', 'GTO', 'KSM', 'SC', 'COMP', 'VIDT', 'CTK', 'AAVE', 'MDT', 'DOGE', 'BTG', 'CRV', 'NKN', 'QSP', 'XRP', 'OCEAN', 'HIVE', 'CHZ', 'XVS', 'BURGER', 'POLY', 'POWR', 'IQ', 'BEAM', 'KEY', 'WNXM', 'DENT', 'CTSI', 'LTC', 'WTC', 'MFT', 'ARDR', 'GAS', 'WABI', 'GO', 'JST', 'BEL', 'WING', 'DOT', 'ANKR', 'CHR', 'ANT', 'IRIS', 'NEBL', 'EGLD', 'HOT', 'LSK', 'DASH', 'SNM', 'UMA', 'NULS', 'BLZ', 'ZIL', 'TCT', 'BAND', 'ALGO', 'PNT', 'ORN', 'CVC', 'QTUM', 'YFI', 'VIB', 'DATA', 'XMR', 'ZEC', 'BNT', 'TOMO', 'NAV', 'COTI', 'KMD', 'FLM', 'VTHO', 'AST', 'HBAR', 'CTXC', 'CREAM', 'INJ', 'GRS', 'DIA', 'AVAX', 'ETH', 'SYS', 'MKR', 'WRX', 'THETA', 'DGB', 'LINK', 'QKC', 'FTM', 'BAT', 'ADA', 'AUD', 'REQ', 'RUNE', 'IDEX', 'ONE', 'SNX', 'SNT', 'PIVX', 'SXP', 'CELR', 'STX', 'PHB', 'WBTC', 'NBS', 'UNI', 'OAX', 'KNC', 'LTO', 'AUDIO', 'SCRT', 'FIO', 'ZEN', 'AVA', 'BNB', 'SUN', 'ICX', 'IOTX', 'IOST', 'LRC', 'NAS', 'EOS', 'ELF', 'DREP', 'XEM', 'BAKE', 'STORJ', 'TRX', 'MITH', 'ETC', 'AMB', 'DUSK', 'MBL', 'XTZ', 'WAVES', 'DNT', 'LUNA', 'MTL', 'FTT', 'BTC', 'RLC', 'ONG', 'STPT', 'DOCK', 'REN', 'PERL', 'LOOM', 'ENJ', 'FIL', 'FUN', 'BRD', 'UTK', 'BCH', 'ARK', 'MANA', 'STMX', 'COCOS', 'OMG', 'SPARTA', 'QLC', 'PAXG', 'WAN', 'OGN', 'AERGO', 'ZRX', 'XVG', 'FET', 'MATIC', 'REP', 'CAKE', 'BAL', 'ONT', 'ALPHA', 'HNT', 'RVN', 'MDA', 'NEO', 'DCR', 'ADX', 'NEAR'}"

# %%
def getTradeSymbols(baseAssetSet):
    symbols = []
    for base in baseAssetSet:
        baseInfo = symbolsByBaseDict[base]
        for el in baseInfo:
            symbols.append(el['symbol'])
    return symbols

# %%
getTradeSymbols(t)
# Out:
# ['WINBNB',
#  'WINBTC',
#  'WINUSDT',
#  'WINUSDC',
#  'WINTRX',
#  'WINEUR',
#  'WINBRL',
#  'WINBUSD',
#  'STEEMBTC',
#  'STEEMETH',
#  'STEEMBNB',
#  'STEEMUSDT',
#  'STEEMBUSD',
#  'TROYBNB',
#  'TROYBTC',
#  'TROYUSDT',
#  'TROYBUSD',
#  'TRBBNB',
#  'TRBBTC',
#  'TRBBUSD',
#  'TRBUSDT',
#  'TFUELBNB',
#  'TFUELBTC',
#  'TFUELUSDT',
#  'TFUELUSDC',
#  'TFUELTUSD',
#  'TFUELPAX',
#  'TFUELBUSD',
#  'BTSBTC',
#  'BTSETH',
#  'BTSBNB',
#  'BTSUSDT',
#  'BTSBUSD',
#  'IOTABTC',
#  'IOTAETH',
#  'IOTABNB',
#  'IOTAUSDT',
#  'IOTABUSD',
#  'RSRBNB',
#  'RSRBTC',
#  'RSRBUSD',
#  'RSRUSDT',
#  'ARPABNB',
#  'ARPABTC',
#  'ARPAUSDT',
#  'ARPATRY',
#  'ARPARUB',
#  'ARPABUSD',
#  'SOLBNB',
#  'SOLBTC',
#  'SOLUSDT',
#  'SOLBUSD',
#  'SOLEUR',
#  'SOLGBP',
#  'SOLTRY',
#  'SOLBRL',
#  'SOLRUB',
#  'SOLAUD',
#  'SOLBIDR',
#  'SOLUSDC',
#  'SOLETH',
#  'NXSBTC',
#  'NXSETH',
#  'NXSBNB',
#  'SRMBNB',
#  'SRMBTC',
#  'SRMBUSD',
#  'SRMUSDT',
#  'SRMBIDR',
#  'YFIIBNB',
#  'YFIIBTC',
#  'YFIIBUSD',
#  'YFIIUSDT',
#  'SUSHIBNB',
#  'SUSHIBTC',
#  'SUSHIBUSD',
#  'SUSHIUSDT',
#  'AIONBTC',
#  'AIONETH',
#  'AIONBNB',
#  'AIONBUSD',
#  'AIONUSDT',
#  'XLMBTC',
#  'XLMETH',
#  'XLMBNB',
#  'XLMUSDT',
#  'XLMPAX',
#  'XLMTUSD',
#  'XLMUSDC',
#  'XLMBUSD',
#  'XLMEUR',
#  'XLMTRY',
#  'SANDBNB',
#  'SANDBTC',
#  'SANDUSDT',
#  'SANDBUSD',
#  'SANDETH',
#  'SANDTRY',
#  'SANDAUD',
#  'SANDBRL',
#  'SANDBIDR',
#  'VITEBNB',
#  'VITEBTC',
#  'VITEUSDT',
#  'ATOMBNB',
#  'ATOMBTC',
#  'ATOMUSDT',
#  'ATOMUSDC',
#  'ATOMPAX',
#  'ATOMTUSD',
#  'ATOMBUSD',
#  'ATOMETH',
#  'ATOMTRY',
#  'ATOMBIDR',
#  'ATOMBRL',
#  'ATOMEUR',
#  'COSBNB',
#  'COSBTC',
#  'COSUSDT',
#  'COSBUSD',
#  'COSTRY',
#  'VETBTC',
#  'VETETH',
#  'VETUSDT',
#  'VETBNB',
#  'VETBUSD',
#  'VETEUR',
#  'VETGBP',
#  'VETTRY',
#  'NMRBTC',
#  'NMRBUSD',
#  'NMRUSDT',
#  'OXTBTC',
#  'OXTUSDT',
#  'OXTBUSD',
#  'KAVABNB',
#  'KAVABTC',
#  'KAVAUSDT',
#  'KAVABUSD',
#  'KAVAETH',
#  'GTOBTC',
#  'GTOETH',
#  'GTOBNB',
#  'GTOUSDT',
#  'GTOPAX',
#  'GTOTUSD',
#  'GTOUSDC',
#  'GTOBUSD',
#  'KSMBNB',
#  'KSMBTC',
#  'KSMBUSD',
#  'KSMUSDT',
#  'KSMAUD',
#  'KSMETH',
#  'SCBTC',
#  'SCETH',
#  'SCUSDT',
#  'SCBUSD',
#  'COMPBTC',
#  'COMPBNB',
#  'COMPBUSD',
#  'COMPUSDT',
#  'VIDTBTC',
#  'VIDTBUSD',
#  'VIDTUSDT',
#  'CTKBNB',
#  'CTKBTC',
#  'CTKBUSD',
#  'CTKUSDT',
#  'AAVEBNB',
#  'AAVEBTC',
#  'AAVEETH',
#  'AAVEBUSD',
#  'AAVEUSDT',
#  'AAVEBKRW',
#  'AAVEBRL',
#  'MDTBNB',
#  'MDTBTC',
#  'MDTUSDT',
#  'MDTBUSD',
#  'DOGEBNB',
#  'DOGEBTC',
#  'DOGEUSDT',
#  'DOGEPAX',
#  'DOGEUSDC',
#  'DOGEBUSD',
#  'DOGEEUR',
#  'DOGETRY',
#  'DOGEAUD',
#  'DOGEBRL',
#  'DOGEGBP',
#  'DOGERUB',
#  'DOGEBIDR',
#  'BTGBTC',
#  'BTGETH',
#  'BTGBUSD',
#  'BTGUSDT',
#  'CRVBNB',
#  'CRVBTC',
#  'CRVBUSD',
#  'CRVUSDT',
#  'CRVETH',
#  'NKNBNB',
#  'NKNBTC',
#  'NKNUSDT',
#  'NKNBUSD',
#  'QSPBTC',
#  'QSPETH',
#  'QSPBNB',
#  'XRPBTC',
#  'XRPETH',
#  'XRPUSDT',
#  'XRPBNB',
#  'XRPPAX',
#  'XRPTUSD',
#  'XRPUSDC',
#  'XRPBUSD',
#  'XRPRUB',
#  'XRPTRY',
#  'XRPEUR',
#  'XRPGBP',
#  'XRPBKRW',
#  'XRPAUD',
#  'XRPBRL',
#  'XRPNGN',
#  'XRPBIDR',
#  'OCEANBNB',
#  'OCEANBTC',
#  'OCEANBUSD',
#  'OCEANUSDT',
#  'HIVEBNB',
#  'HIVEBTC',
#  'HIVEUSDT',
#  'HIVEBUSD',
#  'CHZBNB',
#  'CHZBTC',
#  'CHZUSDT',
#  'CHZTRY',
#  'CHZBRL',
#  'CHZBUSD',
#  'CHZEUR',
#  'CHZGBP',
#  'XVSBNB',
#  'XVSBTC',
#  'XVSBUSD',
#  'XVSUSDT',
#  'BURGERBNB',
#  'BURGERBUSD',
#  'BURGERUSDT',
#  'POLYBTC',
#  'POLYBNB',
#  'POLYBUSD',
#  'POLYUSDT',
#  'POWRBTC',
#  'POWRETH',
#  'POWRBNB',
#  'POWRUSDT',
#  'POWRBUSD',
#  'IQBNB',
#  'IQBUSD',
#  'BEAMBNB',
#  'BEAMBTC',
#  'BEAMUSDT',
#  'KEYBTC',
#  'KEYETH',
#  'KEYUSDT',
#  'KEYBUSD',
#  'WNXMBNB',
#  'WNXMBTC',
#  'WNXMBUSD',
#  'WNXMUSDT',
#  'DENTBTC',
#  'DENTETH',
#  'DENTUSDT',
#  'DENTBUSD',
#  'DENTTRY',
#  'CTSIBTC',
#  'CTSIUSDT',
#  'CTSIBNB',
#  'CTSIBUSD',
#  'LTCBTC',
#  'LTCETH',
#  'LTCUSDT',
#  'LTCBNB',
#  'LTCTUSD',
#  'LTCPAX',
#  'LTCUSDC',
#  'LTCBUSD',
#  'LTCEUR',
#  'LTCNGN',
#  'LTCRUB',
#  'LTCBRL',
#  'LTCGBP',
#  'LTCUAH',
#  'WTCBTC',
#  'WTCETH',
#  'WTCBNB',
#  'WTCUSDT',
#  'MFTBTC',
#  'MFTETH',
#  'MFTBNB',
#  'MFTUSDT',
#  'ARDRBTC',
#  'ARDRETH',
#  'ARDRBNB',
#  'ARDRUSDT',
#  'GASBTC',
#  'WABIBTC',
#  'WABIETH',
#  'WABIBNB',
#  'GOBTC',
#  'GOBNB',
#  'JSTBNB',
#  'JSTBTC',
#  'JSTBUSD',
#  'JSTUSDT',
#  'BELBNB',
#  'BELBTC',
#  'BELBUSD',
#  'BELUSDT',
#  'BELTRY',
#  'WINGBNB',
#  'WINGBTC',
#  'WINGBUSD',
#  'WINGUSDT',
#  'DOTBNB',
#  'DOTBTC',
#  'DOTBUSD',
#  'DOTUSDT',
#  'DOTBIDR',
#  'DOTBKRW',
#  'DOTEUR',
#  'DOTNGN',
#  'DOTTRY',
#  'DOTGBP',
#  'DOTBRL',
#  'DOTRUB',
#  'DOTAUD',
#  'DOTETH',
#  'ANKRBNB',
#  'ANKRBTC',
#  'ANKRUSDT',
#  'ANKRTUSD',
#  'ANKRPAX',
#  'ANKRUSDC',
#  'ANKRBUSD',
#  'CHRBNB',
#  'CHRBTC',
#  'CHRUSDT',
#  'CHRBUSD',
#  'CHRETH',
#  'ANTBNB',
#  'ANTBTC',
#  'ANTBUSD',
#  'ANTUSDT',
#  'IRISBNB',
#  'IRISBTC',
#  'IRISBUSD',
#  'IRISUSDT',
#  'NEBLBTC',
#  'NEBLBNB',
#  'EGLDBNB',
#  'EGLDBTC',
#  'EGLDBUSD',
#  'EGLDUSDT',
#  'EGLDEUR',
#  'EGLDETH',
#  'HOTBTC',
#  'HOTETH',
#  'HOTBNB',
#  'HOTUSDT',
#  'HOTTRY',
#  'HOTEUR',
#  'HOTBUSD',
#  'HOTBRL',
#  'LSKBTC',
#  'LSKETH',
#  'LSKBNB',
#  'LSKUSDT',
#  'LSKBUSD',
#  'DASHBTC',
#  'DASHETH',
#  'DASHBNB',
#  'DASHUSDT',
#  'DASHBUSD',
#  'SNMBTC',
#  'SNMETH',
#  'UMABTC',
#  'UMAUSDT',
#  'UMABUSD',
#  'UMATRY',
#  'NULSBNB',
#  'NULSBTC',
#  'NULSETH',
#  'NULSUSDT',
#  'NULSBUSD',
#  'BLZBTC',
#  'BLZETH',
#  'BLZBNB',
#  'BLZBUSD',
#  'BLZUSDT',
#  'ZILBTC',
#  'ZILETH',
#  'ZILBNB',
#  'ZILUSDT',
#  'ZILBUSD',
#  'ZILBIDR',
#  'ZILTRY',
#  'ZILEUR',
#  'TCTBNB',
#  'TCTBTC',
#  'TCTUSDT',
#  'BANDBNB',
#  'BANDBTC',
#  'BANDUSDT',
#  'BANDBUSD',
#  'ALGOBNB',
#  'ALGOBTC',
#  'ALGOUSDT',
#  'ALGOTUSD',
#  'ALGOPAX',
#  'ALGOUSDC',
#  'ALGOBUSD',
#  'ALGOBIDR',
#  'ALGORUB',
#  'ALGOETH',
#  'ALGOTRY',
#  'PNTBTC',
#  'PNTUSDT',
#  'ORNBTC',
#  'ORNUSDT',
#  'ORNBUSD',
#  'CVCBTC',
#  'CVCETH',
#  'CVCBNB',
#  'CVCUSDT',
#  'CVCBUSD',
#  'QTUMETH',
#  'QTUMBTC',
#  'QTUMBNB',
#  'QTUMUSDT',
#  'QTUMBUSD',
#  'YFIBNB',
#  'YFIBTC',
#  'YFIBUSD',
#  'YFIUSDT',
#  'YFIEUR',
#  'VIBBTC',
#  'VIBETH',
#  'DATABTC',
#  'DATAETH',
#  'DATABUSD',
#  'DATAUSDT',
#  'XMRBTC',
#  'XMRETH',
#  'XMRBNB',
#  'XMRUSDT',
#  'XMRBUSD',
#  'ZECBTC',
#  'ZECETH',
#  'ZECBNB',
#  'ZECUSDT',
#  'ZECPAX',
#  'ZECTUSD',
#  'ZECUSDC',
#  'ZECBUSD',
#  'BNTETH',
#  'BNTBTC',
#  'BNTUSDT',
#  'BNTBUSD',
#  'TOMOBNB',
#  'TOMOBTC',
#  'TOMOUSDT',
#  'TOMOUSDC',
#  'TOMOBUSD',
#  'NAVBTC',
#  'NAVETH',
#  'NAVBNB',
#  'COTIBNB',
#  'COTIBTC',
#  'COTIUSDT',
#  'COTIBUSD',
#  'KMDBTC',
#  'KMDETH',
#  'KMDBUSD',
#  'KMDUSDT',
#  'FLMBNB',
#  'FLMBTC',
#  'FLMBUSD',
#  'FLMUSDT',
#  'VTHOBNB',
#  'VTHOBUSD',
#  'VTHOUSDT',
#  'ASTBTC',
#  'ASTETH',
#  'HBARBNB',
#  'HBARBTC',
#  'HBARUSDT',
#  'HBARBUSD',
#  'CTXCBNB',
#  'CTXCBTC',
#  'CTXCUSDT',
#  'CTXCBUSD',
#  'CREAMBNB',
#  'CREAMBUSD',
#  'INJBNB',
#  'INJBTC',
#  'INJBUSD',
#  'INJUSDT',
#  'INJTRY',
#  'GRSBTC',
#  'GRSETH',
#  'DIABNB',
#  'DIABTC',
#  'DIABUSD',
#  'DIAUSDT',
#  'AVAXBNB',
#  'AVAXBTC',
#  'AVAXBUSD',
#  'AVAXUSDT',
#  'AVAXTRY',
#  'AVAXEUR',
#  'AVAXBIDR',
#  'AVAXBRL',
#  'AVAXAUD',
#  'AVAXETH',
#  'AVAXGBP',
#  'ETHBTC',
#  'ETHUSDT',
#  'ETHTUSD',
#  'ETHPAX',
#  'ETHUSDC',
#  'ETHBUSD',
#  'ETHRUB',
#  'ETHTRY',
#  'ETHEUR',
#  'ETHZAR',
#  'ETHBKRW',
#  'ETHGBP',
#  'ETHBIDR',
#  'ETHAUD',
#  'ETHDAI',
#  'ETHNGN',
#  'ETHBRL',
#  'ETHUAH',
#  'ETHUSDP',
#  'ETHUST',
#  'SYSBTC',
#  'SYSETH',
#  'SYSBNB',
#  'SYSBUSD',
#  'SYSUSDT',
#  'MKRBNB',
#  'MKRBTC',
#  'MKRUSDT',
#  'MKRBUSD',
#  'WRXBNB',
#  'WRXBTC',
#  'WRXUSDT',
#  'WRXBUSD',
#  'WRXEUR',
#  'THETABTC',
#  'THETAETH',
#  'THETABNB',
#  'THETAUSDT',
#  'THETAEUR',
#  'THETABUSD',
#  'DGBBTC',
#  'DGBBUSD',
#  'DGBUSDT',
#  'LINKBTC',
#  'LINKETH',
#  'LINKUSDT',
#  'LINKTUSD',
#  'LINKPAX',
#  'LINKUSDC',
#  'LINKBUSD',
#  'LINKAUD',
#  'LINKTRY',
#  'LINKBKRW',
#  'LINKEUR',
#  'LINKBRL',
#  'LINKNGN',
#  'LINKGBP',
#  'LINKBNB',
#  'QKCBTC',
#  'QKCETH',
#  'FTMBNB',
#  'FTMBTC',
#  'FTMUSDT',
#  'FTMTUSD',
#  'FTMPAX',
#  'FTMUSDC',
#  'FTMBUSD',
#  'FTMBIDR',
#  'FTMETH',
#  'FTMAUD',
#  'FTMBRL',
#  'FTMRUB',
#  'FTMTRY',
#  'FTMEUR',
#  'BATBTC',
#  'BATETH',
#  'BATBNB',
#  'BATUSDT',
#  'BATUSDC',
#  'BATPAX',
#  'BATTUSD',
#  'BATBUSD',
#  'ADABTC',
#  'ADAETH',
#  'ADAUSDT',
#  'ADABNB',
#  'ADATUSD',
#  'ADAPAX',
#  'ADAUSDC',
#  'ADABUSD',
#  'ADABKRW',
#  'ADAEUR',
#  'ADATRY',
#  'ADABRL',
#  'ADAGBP',
#  'ADAAUD',
#  'ADARUB',
#  'ADABIDR',
#  'AUDBUSD',
#  'AUDUSDT',
#  'AUDUSDC',
#  'REQBTC',
#  'REQETH',
#  'REQUSDT',
#  'REQBUSD',
#  'RUNEBNB',
#  'RUNEBTC',
#  'RUNEBUSD',
#  'RUNEUSDT',
#  'RUNEGBP',
#  'RUNEEUR',
#  'RUNEAUD',
#  'RUNEETH',
#  'RUNETRY',
#  'IDEXBTC',
#  'IDEXBUSD',
#  'IDEXUSDT',
#  'IDEXBNB',
#  'ONEBNB',
#  'ONEBTC',
#  'ONEUSDT',
#  'ONETUSD',
#  'ONEPAX',
#  'ONEUSDC',
#  'ONEBIDR',
#  'ONEBUSD',
#  'ONEETH',
#  'ONETRY',
#  'SNXBTC',
#  'SNXBNB',
#  'SNXBUSD',
#  'SNXUSDT',
#  'SNXETH',
#  'SNTETH',
#  'SNTBTC',
#  'PIVXBTC',
#  'PIVXBNB',
#  'SXPBTC',
#  'SXPBNB',
#  'SXPBUSD',
#  'SXPUSDT',
#  'SXPAUD',
#  'SXPEUR',
#  'SXPBIDR',
#  'SXPTRY',
#  'SXPGBP',
#  'CELRBNB',
#  'CELRBTC',
#  'CELRUSDT',
#  'CELRBUSD',
#  'CELRETH',
#  'STXBNB',
#  'STXBTC',
#  'STXUSDT',
#  'STXBUSD',
#  'PHBBNB',
#  'PHBBTC',
#  'PHBUSDC',
#  'PHBTUSD',
#  'PHBPAX',
#  'WBTCBTC',
#  'WBTCETH',
#  'WBTCBUSD',
#  'NBSBTC',
#  'NBSUSDT',
#  'UNIBNB',
#  'UNIBTC',
#  'UNIBUSD',
#  'UNIUSDT',
#  'UNIEUR',
#  'UNIAUD',
#  'UNIETH',
#  'OAXETH',
#  'OAXBTC',
#  'KNCBTC',
#  'KNCETH',
#  'KNCBUSD',
#  'KNCUSDT',
#  'KNCBNB',
#  'LTOBNB',
#  'LTOBTC',
#  'LTOUSDT',
#  'LTOBUSD',
#  'AUDIOBTC',
#  'AUDIOBUSD',
#  'AUDIOUSDT',
#  'AUDIOTRY',
#  'SCRTBTC',
#  'SCRTETH',
#  'SCRTBUSD',
#  'SCRTUSDT',
#  'FIOBNB',
#  'FIOBTC',
#  'FIOBUSD',
#  'FIOUSDT',
#  'ZENBTC',
#  'ZENETH',
#  'ZENBNB',
#  'ZENUSDT',
#  'ZENBUSD',
#  'AVABNB',
#  'AVABTC',
#  'AVABUSD',
#  'AVAUSDT',
#  'BNBBTC',
#  'BNBETH',
#  'BNBUSDT',
#  'BNBPAX',
#  'BNBTUSD',
#  'BNBUSDC',
#  'BNBUSDS',
#  'BNBBUSD',
#  'BNBNGN',
#  'BNBRUB',
#  'BNBTRY',
#  'BNBEUR',
#  'BNBZAR',
#  'BNBBKRW',
#  'BNBIDRT',
#  'BNBGBP',
#  'BNBBIDR',
#  'BNBAUD',
#  'BNBDAI',
#  'BNBBRL',
#  'BNBUAH',
#  'BNBUSDP',
#  'BNBUST',
#  'SUNBTC',
#  'SUNUSDT',
#  'SUNBUSD',
#  'ICXBTC',
#  'ICXETH',
#  'ICXBNB',
#  'ICXUSDT',
#  'ICXBUSD',
#  'IOTXBTC',
#  'IOTXETH',
#  'IOTXUSDT',
#  'IOTXBUSD',
#  'IOSTBTC',
#  'IOSTETH',
#  'IOSTUSDT',
#  'IOSTBUSD',
#  'LRCBTC',
#  'LRCETH',
#  'LRCBUSD',
#  'LRCUSDT',
#  'LRCTRY',
#  'LRCBNB',
#  'NASBTC',
#  'NASETH',
#  'NASBNB',
#  'EOSETH',
#  'EOSBTC',
#  'EOSUSDT',
#  'EOSBNB',
#  'EOSPAX',
#  'EOSTUSD',
#  'EOSUSDC',
#  'EOSBUSD',
#  'EOSEUR',
#  'EOSTRY',
#  'EOSAUD',
#  'ELFBTC',
#  'ELFETH',
#  'ELFUSDT',
#  'ELFBUSD',
#  'DREPBNB',
#  'DREPBTC',
#  'DREPUSDT',
#  'DREPBUSD',
#  'XEMBTC',
#  'XEMETH',
#  'XEMBNB',
#  'XEMUSDT',
#  'XEMBUSD',
#  'BAKEBNB',
#  'BAKEBUSD',
#  'BAKEUSDT',
#  'BAKEBTC',
#  'STORJBTC',
#  'STORJETH',
#  'STORJBUSD',
#  'STORJUSDT',
#  'TRXBTC',
#  'TRXETH',
#  'TRXBNB',
#  'TRXUSDT',
#  'TRXTUSD',
#  'TRXXRP',
#  'TRXPAX',
#  'TRXUSDC',
#  'TRXBUSD',
#  'TRXNGN',
#  'TRXTRY',
#  'TRXAUD',
#  'TRXEUR',
#  'MITHBTC',
#  'MITHBNB',
#  'MITHUSDT',
#  'ETCETH',
#  'ETCBTC',
#  'ETCUSDT',
#  'ETCBNB',
#  'ETCUSDC',
#  'ETCPAX',
#  'ETCTUSD',
#  'ETCBUSD',
#  'ETCEUR',
#  'ETCBRL',
#  'ETCGBP',
#  'AMBBTC',
#  'AMBETH',
#  'AMBBNB',
#  'DUSKBNB',
#  'DUSKBTC',
#  'DUSKUSDT',
#  'DUSKUSDC',
#  'DUSKPAX',
#  'DUSKBUSD',
#  'MBLBNB',
#  'MBLBTC',
#  'MBLUSDT',
#  'MBLBUSD',
#  'XTZBNB',
#  'XTZBTC',
#  'XTZUSDT',
#  'XTZBUSD',
#  'XTZTRY',
#  'XTZETH',
#  'WAVESBTC',
#  'WAVESETH',
#  'WAVESBNB',
#  'WAVESUSDT',
#  'WAVESTUSD',
#  'WAVESPAX',
#  'WAVESUSDC',
#  'WAVESBUSD',
#  'WAVESRUB',
#  'WAVESEUR',
#  'WAVESTRY',
#  'DNTETH',
#  'DNTBTC',
#  'DNTBUSD',
#  'DNTUSDT',
#  'LUNABNB',
#  'LUNABTC',
#  'LUNABUSD',
#  'LUNAUSDT',
#  'LUNAEUR',
#  'LUNAAUD',
#  'LUNABIDR',
#  'LUNATRY',
#  'LUNAETH',
#  'LUNABRL',
#  'LUNAUST',
#  'LUNAGBP',
#  'MTLBTC',
#  'MTLETH',
#  'MTLUSDT',
#  'MTLBUSD',
#  'FTTBNB',
#  'FTTBTC',
#  'FTTUSDT',
#  'FTTBUSD',
#  'FTTETH',
#  'BTCUSDT',
#  'BTCTUSD',
#  'BTCPAX',
#  'BTCUSDC',
#  'BTCUSDS',
#  'BTCBUSD',
#  'BTCNGN',
#  'BTCRUB',
#  'BTCTRY',
#  'BTCEUR',
#  'BTCZAR',
#  'BTCBKRW',
#  'BTCIDRT',
#  'BTCGBP',
#  'BTCUAH',
#  'BTCBIDR',
#  'BTCAUD',
#  'BTCDAI',
#  'BTCBRL',
#  'BTCVAI',
#  'BTCUSDP',
#  'BTCUST',
#  'RLCBTC',
#  'RLCETH',
#  'RLCBNB',
#  'RLCUSDT',
#  'RLCBUSD',
#  'ONGBNB',
#  'ONGBTC',
#  'ONGUSDT',
#  'STPTBNB',
#  'STPTBTC',
#  'STPTUSDT',
#  'STPTBUSD',
#  'DOCKBTC',
#  'DOCKETH',
#  'DOCKUSDT',
#  'DOCKBUSD',
#  'RENBTC',
#  'RENBNB',
#  'RENUSDT',
#  'RENBUSD',
#  'PERLBNB',
#  'PERLBTC',
#  'PERLUSDC',
#  'PERLUSDT',
#  'LOOMBTC',
#  'LOOMETH',
#  'LOOMBNB',
#  'ENJBTC',
#  'ENJETH',
#  'ENJBNB',
#  'ENJUSDT',
#  'ENJBUSD',
#  'ENJBRL',
#  'ENJEUR',
#  'ENJGBP',
#  'ENJTRY',
#  'FILBNB',
#  'FILBTC',
#  'FILBUSD',
#  'FILUSDT',
#  'FILTRY',
#  'FUNBTC',
#  'FUNETH',
#  'FUNUSDT',
#  'FUNBNB',
#  'BRDBTC',
#  'BRDETH',
#  'BRDBNB',
#  'UTKBTC',
#  'UTKUSDT',
#  'UTKBUSD',
#  'BCHBNB',
#  'BCHBTC',
#  'BCHUSDT',
#  'BCHUSDC',
#  'BCHTUSD',
#  'BCHPAX',
#  'BCHBUSD',
#  'BCHEUR',
#  'ARKBTC',
#  'ARKETH',
#  'MANABTC',
#  'MANAETH',
#  'MANABUSD',
#  'MANAUSDT',
#  'MANATRY',
#  'MANABRL',
#  'MANABIDR',
#  'MANABNB',
#  'STMXBTC',
#  'STMXETH',
#  'STMXUSDT',
#  'STMXBUSD',
#  'COCOSBNB',
#  'COCOSBTC',
#  'COCOSUSDT',
#  'COCOSBUSD',
#  'COCOSTRY',
#  'OMGBTC',
#  'OMGETH',
#  'OMGBNB',
#  'OMGUSDT',
#  'OMGBUSD',
#  'SPARTABNB',
#  'QLCBTC',
#  ...]

# %%
async def getMedianUSDTTradeVol(baseAssetSet, isoInstantFrom, isoInstantTo):
    def listToStr(l):
        result = l[0]
        for i in range(1, len(l)):
            result += f", {l[i]}"
        return result
    symbolList = getTradeSymbols(baseAssetSet)
    columns = ['symb', 'open_time', 'close', 'volume', 'close_time', 'quote_asset_vol']
    # sql_query = "SELECT %s FROM 'binance_daily' WHERE open_time >= '%s' and open_time < '%s' AND symb IN (%s)"%(listToStr(columns), isoInstantFrom, isoInstantTo, str(symbolList)[1:len(str(symbolList))-1])
    sql_query = "SELECT %s FROM 'binance_daily' WHERE open_time >= '%s' and open_time < '%s'"%(listToStr(columns), isoInstantFrom, isoInstantTo)    
    #print(sql_query)
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
            r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    return pd.DataFrame(columns=columns, data=jsonR['dataset'])

# %%
df = await getMedianUSDTTradeVol(t, '2020-11-01T00:00:00.000000Z', '2020-12-01T00:00:00.000000Z')
df
# Out:
#             symb                    open_time         close        volume  \
# 0         FTTBNB  2020-11-01T00:00:00.000000Z  1.277000e-01  1.289160e+03
# 1        WBTCBTC  2020-11-01T00:00:00.000000Z  9.999800e-01  5.322180e+01
# 2        WINUSDC  2020-11-01T00:00:00.000000Z  9.630000e-05  3.859144e+08
# 3         BELBTC  2020-11-01T00:00:00.000000Z  5.778000e-05  9.035000e+04
# 4        TRBUSDT  2020-11-01T00:00:00.000000Z  2.083800e+01  1.141019e+05
# ...          ...                          ...           ...           ...
# 23592     MKRBNB  2020-11-30T00:00:00.000000Z  1.807400e+01  1.275830e+02
# 23593    ARDRBTC  2020-11-30T00:00:00.000000Z  3.750000e-06  1.574673e+07
# 23594      SCETH  2020-11-30T00:00:00.000000Z  5.520000e-06  2.430436e+07
# 23595      SCBTC  2020-11-30T00:00:00.000000Z  1.800000e-07  1.355248e+08
# 23596  THETAUSDT  2020-11-30T00:00:00.000000Z  6.428000e-01  6.735687e+06
#
#                         close_time  quote_asset_vol
# 0      2020-11-01T23:59:59.999999Z     1.668520e+02
# 1      2020-11-01T23:59:59.999999Z     5.320581e+01
# 2      2020-11-01T23:59:59.999999Z     3.568064e+04
# 3      2020-11-01T23:59:59.999999Z     5.203148e+00
# 4      2020-11-01T23:59:59.999999Z     2.320366e+06
# ...                            ...              ...
# 23592  2020-11-30T23:59:59.999999Z     2.321074e+03
# 23593  2020-11-30T23:59:59.999999Z     6.263127e+01
# 23594  2020-11-30T23:59:59.999999Z     1.346971e+02
# 23595  2020-11-30T23:59:59.999999Z     2.312523e+01
# 23596  2020-11-30T23:59:59.999999Z     4.197483e+06
#
# [23597 rows x 6 columns]

# %%
df['baseAsset'] = df.apply(lambda row: symbolDict[row['symb']]['baseAsset'], axis = 1)
df['quoteAsset'] = df.apply(lambda row: symbolDict[row['symb']]['quoteAsset'], axis = 1)
df
# Out:
#             symb                    open_time         close        volume  \
# 0         FTTBNB  2020-11-01T00:00:00.000000Z  1.277000e-01  1.289160e+03
# 1        WBTCBTC  2020-11-01T00:00:00.000000Z  9.999800e-01  5.322180e+01
# 2        WINUSDC  2020-11-01T00:00:00.000000Z  9.630000e-05  3.859144e+08
# 3         BELBTC  2020-11-01T00:00:00.000000Z  5.778000e-05  9.035000e+04
# 4        TRBUSDT  2020-11-01T00:00:00.000000Z  2.083800e+01  1.141019e+05
# ...          ...                          ...           ...           ...
# 23592     MKRBNB  2020-11-30T00:00:00.000000Z  1.807400e+01  1.275830e+02
# 23593    ARDRBTC  2020-11-30T00:00:00.000000Z  3.750000e-06  1.574673e+07
# 23594      SCETH  2020-11-30T00:00:00.000000Z  5.520000e-06  2.430436e+07
# 23595      SCBTC  2020-11-30T00:00:00.000000Z  1.800000e-07  1.355248e+08
# 23596  THETAUSDT  2020-11-30T00:00:00.000000Z  6.428000e-01  6.735687e+06
#
#                         close_time  quote_asset_vol baseAsset quoteAsset
# 0      2020-11-01T23:59:59.999999Z     1.668520e+02       FTT        BNB
# 1      2020-11-01T23:59:59.999999Z     5.320581e+01      WBTC        BTC
# 2      2020-11-01T23:59:59.999999Z     3.568064e+04       WIN       USDC
# 3      2020-11-01T23:59:59.999999Z     5.203148e+00       BEL        BTC
# 4      2020-11-01T23:59:59.999999Z     2.320366e+06       TRB       USDT
# ...                            ...              ...       ...        ...
# 23592  2020-11-30T23:59:59.999999Z     2.321074e+03       MKR        BNB
# 23593  2020-11-30T23:59:59.999999Z     6.263127e+01      ARDR        BTC
# 23594  2020-11-30T23:59:59.999999Z     1.346971e+02        SC        ETH
# 23595  2020-11-30T23:59:59.999999Z     2.312523e+01        SC        BTC
# 23596  2020-11-30T23:59:59.999999Z     4.197483e+06     THETA       USDT
#
# [23597 rows x 8 columns]

# %%
from collections import defaultdict
coinGraph = defaultdict(set)
for key in symbolDict:
    symbol = symbolDict[key]
    coinGraph[symbol['baseAsset']].add(symbol['quoteAsset'])
    coinGraph[symbol['quoteAsset']].add(symbol['baseAsset'])

# %%
# We will use USDT to compare apples to apples
def shortestPathToUSDT(fromBaseAsset):
    if fromBaseAsset == 'USDT':
        return [fromBaseAsset]
    parent = {}
    explored = set()
    frontier = [fromBaseAsset]
    def solution(baseAsset):
        if parent.get(baseAsset) is None:
            return [baseAsset]
        else:
            result = solution(parent[baseAsset])
            result.append(baseAsset)
            return result
  
    while len(frontier) > 0:
        node = frontier.pop(0)
        explored.add(node)
        for coin in coinGraph[node]:
            if coin not in explored and coin not in frontier:
                parent[coin] = node
                if coin == 'USDT':
                    return solution(coin)
                else:
                    frontier.append(coin)
    assert False, "Should never get here"

# %%
shortestPathToUSDT('GAS')
# Out:
# ['GAS', 'BTC', 'USDT']

# %%
valInUSDT = []
for (_, row) in df.iterrows():
    # print("(Base asset: %s, Quote asset: %s)"%(row['baseAsset'],row['quoteAsset']))
    if row['quoteAsset'] == 'USDT':
        val = row['volume'] * row['close']
    else:
        path = shortestPathToUSDT(row['quoteAsset'])
        multiplier = 1.0
        assert len(path) > 1
        i = 0
        while i + 1 < len(path):
            dfFiltered = df[(df['baseAsset'] == path[i])
                                 & (df['quoteAsset'] == path[i + 1])
                                 & (df['open_time'] == row['open_time'])]
            if dfFiltered.shape[0] > 0:
                # print(dfFiltered)
                pathRow = dfFiltered.iloc[0]
                multiplier *= pathRow['close']
            else:
                dfFiltered = df[(df['baseAsset'] == path[i + 1]) 
                        & (df['quoteAsset'] == path[i])
                        & (df['open_time'] == row['open_time'])]
                # print(dfFiltered)
                pathRow = dfFiltered.iloc[0]
                multiplier *= 1.0 / pathRow['close']
            i += 1
        assert path[i] == 'USDT'
        val = row['volume'] * row['close'] * multiplier
    valInUSDT.append(val)
df.insert(df.shape[1], 'valInUSDT', valInUSDT)
df
# Out:
#             symb                    open_time         close        volume  \
# 0         FTTBNB  2020-11-01T00:00:00.000000Z  1.277000e-01  1.289160e+03
# 1        WBTCBTC  2020-11-01T00:00:00.000000Z  9.999800e-01  5.322180e+01
# 2        WINUSDC  2020-11-01T00:00:00.000000Z  9.630000e-05  3.859144e+08
# 3         BELBTC  2020-11-01T00:00:00.000000Z  5.778000e-05  9.035000e+04
# 4        TRBUSDT  2020-11-01T00:00:00.000000Z  2.083800e+01  1.141019e+05
# ...          ...                          ...           ...           ...
# 23592     MKRBNB  2020-11-30T00:00:00.000000Z  1.807400e+01  1.275830e+02
# 23593    ARDRBTC  2020-11-30T00:00:00.000000Z  3.750000e-06  1.574673e+07
# 23594      SCETH  2020-11-30T00:00:00.000000Z  5.520000e-06  2.430436e+07
# 23595      SCBTC  2020-11-30T00:00:00.000000Z  1.800000e-07  1.355248e+08
# 23596  THETAUSDT  2020-11-30T00:00:00.000000Z  6.428000e-01  6.735687e+06
#
#                         close_time  quote_asset_vol baseAsset quoteAsset  \
# 0      2020-11-01T23:59:59.999999Z     1.668520e+02       FTT        BNB
# 1      2020-11-01T23:59:59.999999Z     5.320581e+01      WBTC        BTC
# 2      2020-11-01T23:59:59.999999Z     3.568064e+04       WIN       USDC
# 3      2020-11-01T23:59:59.999999Z     5.203148e+00       BEL        BTC
# 4      2020-11-01T23:59:59.999999Z     2.320366e+06       TRB       USDT
# ...                            ...              ...       ...        ...
# 23592  2020-11-30T23:59:59.999999Z     2.321074e+03       MKR        BNB
# 23593  2020-11-30T23:59:59.999999Z     6.263127e+01      ARDR        BTC
# 23594  2020-11-30T23:59:59.999999Z     1.346971e+02        SC        ETH
# 23595  2020-11-30T23:59:59.999999Z     2.312523e+01        SC        BTC
# 23596  2020-11-30T23:59:59.999999Z     4.197483e+06     THETA       USDT
#
#           valInUSDT
# 0      4.697068e+03
# 1      7.323972e+05
# 2      3.714126e+04
# 3      7.184085e+04
# 4      2.377656e+06
# ...             ...
# 23592  7.262197e+04
# 23593  1.163046e+06
# 23594  8.273114e+04
# 23595  4.804702e+05
# 23596  4.329700e+06
#
# [23597 rows x 9 columns]

# %%
df = df[['open_time', 'baseAsset', 'valInUSDT']].groupby(['baseAsset', 'open_time'], as_index=False).sum()
# df = df[['open_time', 'baseAsset', 'valInUSDT']].groupby(['baseAsset', 'open_time'], as_index=False).sum().sort_values(['baseAsset', 'open_time']).set_index(['baseAsset', 'open_time'])

# %%
df
# Out:
#      baseAsset                    open_time     valInUSDT
# 0         AAVE  2020-11-01T00:00:00.000000Z  3.883287e+06
# 1         AAVE  2020-11-02T00:00:00.000000Z  8.351446e+06
# 2         AAVE  2020-11-03T00:00:00.000000Z  4.287112e+06
# 3         AAVE  2020-11-04T00:00:00.000000Z  3.590022e+06
# 4         AAVE  2020-11-05T00:00:00.000000Z  1.069242e+07
# ...        ...                          ...           ...
# 7715       ZRX  2020-11-26T00:00:00.000000Z  1.297749e+07
# 7716       ZRX  2020-11-27T00:00:00.000000Z  4.116352e+06
# 7717       ZRX  2020-11-28T00:00:00.000000Z  4.290210e+06
# 7718       ZRX  2020-11-29T00:00:00.000000Z  2.343936e+06
# 7719       ZRX  2020-11-30T00:00:00.000000Z  3.733755e+06
#
# [7720 rows x 3 columns]
