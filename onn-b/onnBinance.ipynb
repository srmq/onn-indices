# %% [markdown]
# # Computing daily ONN index on Binance

# %% [markdown]
# ## Getting all available symbols on Binance

# %% [markdown]
# In this section, we just get all available assets on Binance, generating at the end a file named `all-binance-tokens.csv`. Each line in this file contains the asset symbol two times, separated by comma (e.g. `ETH,ETH`). This is because we will use it afterwards in the __[`bnbFetchCoinData.py`](https://github.com/srmq/bnbfetch-coin-data)__ script, which expects the CSV file of lines in the format `asset_description,asset_symbol`, and we don't care about descriptions here.

# %%
import httpx
import pandas as pd

# %%
binanceBaseURL = 'https://api.binance.com'

# %%
async def getExchangeInfo():
    spotExchangeInfoURL = binanceBaseURL + "/api/v3/exchangeInfo"

    async with httpx.AsyncClient() as client:
        r = await client.get(spotExchangeInfoURL)
    return r.json()

# %%
exchangeInfo = await getExchangeInfo()

# %%
#blacklist = None
#with open('blacklist.txt', 'r') as f:
#    blacklist = f.read().split(',')
# blacklist should be disabled for now, we need coin data for every coin

# %%
baseAssets = set()
#for coinSymbol in exchangeInfo['symbols']:
#    if not (coinSymbol['baseAsset'].lower() in blacklist):
#        baseAssets.add(coinSymbol['baseAsset'])

# %%
for coinSymbol in exchangeInfo['symbols']:
    baseAssets.add(coinSymbol['baseAsset'])

# %%
def notLeveraged(asset):
    return not (asset.endswith('UP') or asset.endswith('DOWN') or asset.endswith('BEAR') or asset.endswith('BULL'))

# %%
baseAssets = set(filter(notLeveraged, baseAssets))

# %%
baseAssets
# Out:
# {'1INCH',
#  'AAVE',
#  'ACA',
#  'ACH',
#  'ACM',
#  'ADA',
#  'ADX',
#  'AE',
#  'AERGO',
#  'AGI',
#  'AGIX',
#  'AGLD',
#  'AION',
#  'AKRO',
#  'ALCX',
#  'ALGO',
#  'ALICE',
#  'ALPACA',
#  'ALPHA',
#  'ALPINE',
#  'AMB',
#  'AMP',
#  'ANC',
#  'ANKR',
#  'ANT',
#  'ANY',
#  'APE',
#  'API3',
#  'APPC',
#  'AR',
#  'ARDR',
#  'ARK',
#  'ARN',
#  'ARPA',
#  'ASR',
#  'AST',
#  'ASTR',
#  'ATA',
#  'ATM',
#  'ATOM',
#  'AUCTION',
#  'AUD',
#  'AUDIO',
#  'AUTO',
#  'AVA',
#  'AVAX',
#  'AXS',
#  'BADGER',
#  'BAKE',
#  'BAL',
#  'BAND',
#  'BAR',
#  'BAT',
#  'BCC',
#  'BCD',
#  'BCH',
#  'BCHA',
#  'BCHABC',
#  'BCHSV',
#  'BCN',
#  'BCPT',
#  'BDOT',
#  'BEAM',
#  'BEL',
#  'BETA',
#  'BETH',
#  'BGBP',
#  'BICO',
#  'BIFI',
#  'BKRW',
#  'BLZ',
#  'BNB',
#  'BNT',
#  'BNX',
#  'BOND',
#  'BOT',
#  'BQX',
#  'BRD',
#  'BSW',
#  'BTC',
#  'BTCB',
#  'BTCST',
#  'BTG',
#  'BTS',
#  'BTT',
#  'BTTC',
#  'BURGER',
#  'BUSD',
#  'BZRX',
#  'C98',
#  'CAKE',
#  'CDT',
#  'CELO',
#  'CELR',
#  'CFX',
#  'CHAT',
#  'CHESS',
#  'CHR',
#  'CHZ',
#  'CITY',
#  'CKB',
#  'CLOAK',
#  'CLV',
#  'CMT',
#  'CND',
#  'COCOS',
#  'COMP',
#  'COS',
#  'COTI',
#  'COVER',
#  'CREAM',
#  'CRV',
#  'CTK',
#  'CTSI',
#  'CTXC',
#  'CVC',
#  'CVP',
#  'CVX',
#  'DAI',
#  'DAR',
#  'DASH',
#  'DATA',
#  'DCR',
#  'DEGO',
#  'DENT',
#  'DEXE',
#  'DF',
#  'DGB',
#  'DGD',
#  'DIA',
#  'DLT',
#  'DNT',
#  'DOCK',
#  'DODO',
#  'DOGE',
#  'DOT',
#  'DREP',
#  'DUSK',
#  'DYDX',
#  'EASY',
#  'EDO',
#  'EGLD',
#  'ELF',
#  'ENG',
#  'ENJ',
#  'ENS',
#  'EOS',
#  'EPS',
#  'EPX',
#  'ERD',
#  'ERN',
#  'ETC',
#  'ETH',
#  'EUR',
#  'EVX',
#  'EZ',
#  'FARM',
#  'FET',
#  'FIDA',
#  'FIL',
#  'FIO',
#  'FIRO',
#  'FIS',
#  'FLM',
#  'FLOW',
#  'FLUX',
#  'FOR',
#  'FORTH',
#  'FRONT',
#  'FTM',
#  'FTT',
#  'FUEL',
#  'FUN',
#  'FXS',
#  'GAL',
#  'GALA',
#  'GAS',
#  'GBP',
#  'GHST',
#  'GLM',
#  'GLMR',
#  'GMT',
#  'GNO',
#  'GNT',
#  'GO',
#  'GRS',
#  'GRT',
#  'GTC',
#  'GTO',
#  'GVT',
#  'GXS',
#  'HARD',
#  'HBAR',
#  'HC',
#  'HEGIC',
#  'HIGH',
#  'HIVE',
#  'HNT',
#  'HOT',
#  'HSR',
#  'ICN',
#  'ICP',
#  'ICX',
#  'IDEX',
#  'ILV',
#  'IMX',
#  'INJ',
#  'INS',
#  'IOST',
#  'IOTA',
#  'IOTX',
#  'IQ',
#  'IRIS',
#  'JASMY',
#  'JOE',
#  'JST',
#  'JUV',
#  'KAVA',
#  'KDA',
#  'KEEP',
#  'KEY',
#  'KLAY',
#  'KMD',
#  'KNC',
#  'KP3R',
#  'KSM',
#  'LAZIO',
#  'LDO',
#  'LEND',
#  'LINA',
#  'LINK',
#  'LIT',
#  'LOKA',
#  'LOOM',
#  'LPT',
#  'LRC',
#  'LSK',
#  'LTC',
#  'LTO',
#  'LUN',
#  'LUNA',
#  'LUNC',
#  'MANA',
#  'MASK',
#  'MATIC',
#  'MBL',
#  'MBOX',
#  'MC',
#  'MCO',
#  'MDA',
#  'MDT',
#  'MDX',
#  'MFT',
#  'MINA',
#  'MIR',
#  'MITH',
#  'MKR',
#  'MLN',
#  'MOB',
#  'MOD',
#  'MOVR',
#  'MTH',
#  'MTL',
#  'MULTI',
#  'NANO',
#  'NAS',
#  'NAV',
#  'NBS',
#  'NBT',
#  'NCASH',
#  'NEAR',
#  'NEBL',
#  'NEO',
#  'NEXO',
#  'NKN',
#  'NMR',
#  'NPXS',
#  'NU',
#  'NULS',
#  'NXS',
#  'OAX',
#  'OCEAN',
#  'OG',
#  'OGN',
#  'OM',
#  'OMG',
#  'ONE',
#  'ONG',
#  'ONT',
#  'OOKI',
#  'OP',
#  'ORN',
#  'OST',
#  'OXT',
#  'PAX',
#  'PAXG',
#  'PEOPLE',
#  'PERL',
#  'PERP',
#  'PHA',
#  'PHB',
#  'PHX',
#  'PIVX',
#  'PLA',
#  'PNT',
#  'POA',
#  'POE',
#  'POLS',
#  'POLY',
#  'POND',
#  'PORTO',
#  'POWR',
#  'PPT',
#  'PROM',
#  'PROS',
#  'PSG',
#  'PUNDIX',
#  'PYR',
#  'QI',
#  'QKC',
#  'QLC',
#  'QNT',
#  'QSP',
#  'QTUM',
#  'QUICK',
#  'RAD',
#  'RAMP',
#  'RARE',
#  'RAY',
#  'RCN',
#  'RDN',
#  'REEF',
#  'REI',
#  'REN',
#  'RENBTC',
#  'REP',
#  'REQ',
#  'RGT',
#  'RIF',
#  'RLC',
#  'RNDR',
#  'ROSE',
#  'RPX',
#  'RSR',
#  'RUNE',
#  'RVN',
#  'SALT',
#  'SAND',
#  'SANTOS',
#  'SC',
#  'SCRT',
#  'SFP',
#  'SHIB',
#  'SKL',
#  'SKY',
#  'SLP',
#  'SNGLS',
#  'SNM',
#  'SNT',
#  'SNX',
#  'SOL',
#  'SPARTA',
#  'SPELL',
#  'SRM',
#  'SSV',
#  'STEEM',
#  'STMX',
#  'STORJ',
#  'STORM',
#  'STPT',
#  'STRAT',
#  'STRAX',
#  'STX',
#  'SUB',
#  'SUN',
#  'SUPER',
#  'SUSD',
#  'SUSHI',
#  'SWRV',
#  'SXP',
#  'SYS',
#  'T',
#  'TCT',
#  'TFUEL',
#  'THETA',
#  'TKO',
#  'TLM',
#  'TNB',
#  'TNT',
#  'TOMO',
#  'TORN',
#  'TRB',
#  'TRIBE',
#  'TRIG',
#  'TROY',
#  'TRU',
#  'TRX',
#  'TUSD',
#  'TUSDB',
#  'TVK',
#  'TWT',
#  'UFT',
#  'UMA',
#  'UNFI',
#  'UNI',
#  'USDC',
#  'USDP',
#  'USDS',
#  'USDSB',
#  'USDT',
#  'UST',
#  'USTC',
#  'UTK',
#  'VEN',
#  'VET',
#  'VGX',
#  'VIA',
#  'VIB',
#  'VIBE',
#  'VIDT',
#  'VITE',
#  'VOXEL',
#  'VTHO',
#  'WABI',
#  'WAN',
#  'WAVES',
#  'WAXP',
#  'WBTC',
#  'WIN',
#  'WING',
#  'WINGS',
#  'WNXM',
#  'WOO',
#  'WPR',
#  'WRX',
#  'WTC',
#  'XEC',
#  'XEM',
#  'XLM',
#  'XMR',
#  'XNO',
#  'XRP',
#  'XTZ',
#  'XVG',
#  'XVS',
#  'XZC',
#  'YFI',
#  'YFII',
#  'YGG',
#  'YOYO',
#  'ZEC',
#  'ZEN',
#  'ZIL',
#  'ZRX'}

# %%
with open('all-binance-tokens.csv', 'w') as f:
    for asset in baseAssets:
        f.write(f"{asset},{asset}\n")

# %% [markdown]
# Now that we have our `all-binance-tokens.csv` file, we can download, for instance, the complete historical data for all assets on Binance, using something like:

# %% [raw]
# `python <path_to_script>/bnbFetchCoinData.py --coins all-binance-tokens.csv --interval 1d`

# %% [markdown]
# This will create a `coindata` directory under the current one with everything we need.

# %% [markdown]
# ## Importing Data to QuestDB

# %% [markdown]
# We will use __[QuestDB](https://questdb.io/)__ in order to facilitate data manipulation and keep memory requirements low (we won't need to load everything on RAM). First we will create a table for holding the data. Here is what we did:

# %% [markdown]
# `CREATE TABLE binance_daily(symb SYMBOL capacity 2048, open_time TIMESTAMP, high DOUBLE, low DOUBLE, close DOUBLE, volume DOUBLE, close_time TIMESTAMP, quote_asset_vol DOUBLE, num_trades LONG, takerbuy_baseasset_vol DOUBLE, takerbuy_quoteasset_vol DOUBLE), index(symb) timestamp(open_time) PARTITION BY YEAR;`

# %% [markdown]
# Now we will import the data (that went to the `coindata` subdirectory)...

# %%
import glob

allCSVFiles = glob.glob('./coindata/*.csv')

# %%
import httpx
import csv

host = 'http://localhost:9000'

async def questInsert(symbol: str, filename: str, lotSize=300):
    async def executeQuery(valStrings):
        sql_query = "INSERT INTO binance_daily VALUES"
        sql_query += valStrings[0]
        for i in range(1, len(valStrings)):
            sql_query += f",{valStrings[i]}"
        query_params = {'query': sql_query, 'fmt': 'json'}
        async with httpx.AsyncClient() as client:
            await client.get(host + '/exec', params=query_params)
        
    with open(filename, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        valStrings = []
        for row in reader:
            if len(valStrings) == lotSize:
                await executeQuery(valStrings)
                valStrings = []
            val = f"(\'{symbol}\', {int(row['Open time'])*1000}, {float(row['High'])}, {float(row['Low'])}, {float(row['Close'])}, {float(row['Volume'])}, {int(row['Close time'] + '999')}, {float(row['Quote asset volume'])}, {int(row['Number of trades'])}, {float(row['Taker buy base asset volume'])}, {float(row['Taker buy quote asset volume'])})"
            valStrings.append(val)
        if len(valStrings) > 0:
            await executeQuery(valStrings)

# %%
from pathlib import Path
i = 0
for csvFile in allCSVFiles:
    symb = Path(csvFile).name.split('.')[0]
    await questInsert(symb, csvFile)
    i += 1
    if i % 100 == 0:
        print(f"Inserted {i} symbols out of {len(allCSVFiles)}")
# Out:
# Inserted 100 symbols out of 1821
# Inserted 200 symbols out of 1821
# Inserted 300 symbols out of 1821
# Inserted 400 symbols out of 1821
# Inserted 500 symbols out of 1821
# Inserted 600 symbols out of 1821
# Inserted 700 symbols out of 1821
# Inserted 800 symbols out of 1821
# Inserted 900 symbols out of 1821
# Inserted 1000 symbols out of 1821
# Inserted 1100 symbols out of 1821
# Inserted 1200 symbols out of 1821
# Inserted 1300 symbols out of 1821
# Inserted 1400 symbols out of 1821
# Inserted 1500 symbols out of 1821
# Inserted 1600 symbols out of 1821
# Inserted 1700 symbols out of 1821
# Inserted 1800 symbols out of 1821

# %% [markdown]
# Now QuestDB has ingested all data. Let's play!

# %% [markdown]
# ## Playing with the data

# %%
import pandas as pd
import httpx

# %%
host = 'http://localhost:9000'

# %%
async def daysTradedInMonthBySymbol(year: int, month: int) -> pd.DataFrame:
    assert(month >= 1 and month <= 12)
    assert(year >= 2000 and year <= 9999)
    if month == 12:
        nextMonth = 1
        nextMonthYear = year + 1
    else:
        nextMonth = month + 1
        nextMonthYear = year
    sql_query = "select symb, count(*) as daystraded from 'binance_daily' where open_time >= '%d-%02d-01T00:00:00.000000Z' and open_time < '%d-%02d-01T00:00:00.000000Z' and num_trades >= 1 group by symb"%(year, month, nextMonthYear, nextMonth)
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
            r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    return pd.DataFrame(columns=['symb', 'daysTraded'], data=jsonR['dataset'])

# %%
import json
with open('coindata/coin-metadata.json', 'r') as f:
    coinMetadata = json.loads(f.read())
symbols = coinMetadata['exchange-info']['symbols']
symbolDict = {}
symbolsByBaseDict = {}
for symbol in symbols:
    symbolDict[symbol['symbol']] = symbol
    baseSymbols = symbolsByBaseDict.get(symbol['baseAsset'], [])
    baseSymbols.append(symbol)
    symbolsByBaseDict[symbol['baseAsset']] = baseSymbols
del symbols

# %%
from typing import Set
# It starts as all assets with TRADING status
async def initialAssetCandidateSet() -> Set[str]:
    candidateAssets = set()
    for symbol in symbolDict:
        baseAsset = symbolDict[symbol]['baseAsset']
        if symbolDict[symbol]['status'] == 'TRADING':
            if not baseAsset.endswith('UP') and not baseAsset.endswith('DOWN') and not baseAsset.endswith('BEAR') and not baseAsset.endswith('BULL'):
                candidateAssets.add(baseAsset)
    
    return candidateAssets

# %%
def getTradeSymbols(baseAssetSet):
    symbols = []
    for base in baseAssetSet:
        baseInfo = symbolsByBaseDict[base]
        for el in baseInfo:
            symbols.append(el['symbol'])
    return symbols

# %%
# We will use USDT to compare apples to apples
def shortestPathToUSDT(fromBaseAsset, coinGraph):
        
    if fromBaseAsset == 'USDT':
        return [fromBaseAsset]
    parent = {}
    explored = set()
    frontier = [fromBaseAsset]
    def solution(baseAsset):
        if parent.get(baseAsset) is None:
            return [baseAsset]
        else:
            result = solution(parent[baseAsset])
            result.append(baseAsset)
            return result

    while len(frontier) > 0:
        node = frontier.pop(0)
        explored.add(node)
        for coin in coinGraph[node]:
            if coin not in explored and coin not in frontier:
                parent[coin] = node
                if coin == 'USDT':
                    return solution(coin)
                else:
                    frontier.append(coin)
    assert False, "Should never get here"

# %%
import psutil
import numpy as np
import concurrent.futures
def splitAddUSDTInfo(df, splittedDf, coinGraph):
    volInUSDT = []
    closePricesInUSDT = []

    for (_, row) in splittedDf.iterrows():
        # print("(Base asset: %s, Quote asset: %s)"%(row['baseAsset'],row['quoteAsset']))
        if row['quoteAsset'] == 'USDT':
            val = row['volume'] * row['close']
            closePriceUSDT = row['close']
        else:
            path = shortestPathToUSDT(row['quoteAsset'], coinGraph)
            multiplier = 1.0
            assert len(path) > 1
            i = 0
            while i + 1 < len(path):
                dfFiltered = df[(df['baseAsset'] == path[i])
                                     & (df['quoteAsset'] == path[i + 1])
                                     & (df['open_time'] == row['open_time'])]
                if dfFiltered.shape[0] > 0:
                    # print(dfFiltered)
                    pathRow = dfFiltered.iloc[0]
                    multiplier *= pathRow['close']
                else:
                    dfFiltered = df[(df['baseAsset'] == path[i + 1]) 
                            & (df['quoteAsset'] == path[i])
                            & (df['open_time'] == row['open_time'])]
                    # print(dfFiltered)
                    pathRow = dfFiltered.iloc[0]
                    multiplier *= 1.0 / pathRow['close']
                i += 1
            assert path[i] == 'USDT'
            val = row['volume'] * row['close'] * multiplier
            closePriceUSDT = row['close'] * multiplier
        volInUSDT.append(val)
        closePricesInUSDT.append(closePriceUSDT)
    splittedDf.insert(splittedDf.shape[1], 'volInUSDT', volInUSDT)
    splittedDf.insert(splittedDf.shape[1], 'closePriceUSDT', closePricesInUSDT)
    del volInUSDT
    del closePricesInUSDT
    return splittedDf
    
def addUSDTInfo(df: pd.DataFrame, coinGraph) -> pd.DataFrame:
    numprocs = psutil.cpu_count(logical=False)
    splittedDfs = np.array_split(df, numprocs)
    dfResults = []
    with concurrent.futures.ProcessPoolExecutor(max_workers=numprocs) as executor:
        results = [ executor.submit(splitAddUSDTInfo, df=df, splittedDf=splittedDf, coinGraph=coinGraph) for splittedDf in splittedDfs ]
        for result in concurrent.futures.as_completed(results):
            try:
                dfResults.append(result.result())
            except Exception as ex:
                print("BOOOO! Exception!")
                print(ex)
                pass
    
    df = pd.concat(dfResults)
    return df

# %%
async def getMedianUSDTTradeVol(baseAssetSet: Set[str], isoInstantFrom: str, isoInstantTo: str) -> pd.DataFrame:
    def listToStr(l):
        result = l[0]
        for i in range(1, len(l)):
            result += f", {l[i]}"
        return result
    
    def genCoinGraph():
        from collections import defaultdict
        coinGraph = defaultdict(set)
        for key in symbolDict:
            symbol = symbolDict[key]
            coinGraph[symbol['baseAsset']].add(symbol['quoteAsset'])
            coinGraph[symbol['quoteAsset']].add(symbol['baseAsset'])
        return coinGraph
    
    coinGraph = genCoinGraph()
     
    columns = ['symb', 'open_time', 'close', 'volume', 'close_time', 'quote_asset_vol']
    sql_query = "SELECT %s FROM 'binance_daily' WHERE open_time >= '%s' and open_time < '%s'"%(listToStr(columns), isoInstantFrom, isoInstantTo)    
    #print(sql_query)
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
            r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    df = pd.DataFrame(columns=columns, data=jsonR['dataset'])
    del r
    del jsonR
    df['baseAsset'] = df.apply(lambda row: symbolDict[row['symb']]['baseAsset'], axis = 1)
    df['quoteAsset'] = df.apply(lambda row: symbolDict[row['symb']]['quoteAsset'], axis = 1)
      
    df = addUSDTInfo(df, coinGraph)
    df.sort_values(['close_time'], ascending=[True], ignore_index=True, inplace=True)
    dfSymbLastPrices = df[['symb', 'baseAsset', 'quoteAsset', 'volInUSDT', 'closePriceUSDT']].groupby(['symb', 'baseAsset', 'quoteAsset'], as_index=False).last()
    dfBaseAssetLastPrices = pd.DataFrame(columns= ['baseAsset', 'lastAvgPriceUSDT'])
    for _, group in dfSymbLastPrices.groupby('baseAsset'):
        num = 0.0
        den = 0.0
        for (_, row) in group.iterrows():
            num += row['closePriceUSDT']*row['volInUSDT']
            den += row['volInUSDT']
        avgPrice = num / den
        dfBaseAssetLastPrices.loc[len(dfBaseAssetLastPrices)] = [row['baseAsset'], avgPrice]
    dfBaseAssetLastPrices = dfBaseAssetLastPrices.set_index('baseAsset')

    df = df[['open_time', 'baseAsset', 'volInUSDT']].groupby(['baseAsset', 'open_time'], as_index=False).sum()    
    df = df[['baseAsset', 'volInUSDT']].groupby(['baseAsset'], as_index=True).median()
    df = pd.concat([df, dfBaseAssetLastPrices], axis=1, join='inner')
    df.reset_index(inplace=True)
    df.sort_values(['volInUSDT'], ascending=[False], ignore_index=True, inplace=True)
    return df

# %%
def getBlacklistSet(blackListFile) -> Set[str]:
    blacklist = None
    with open(blackListFile, 'r') as f:
        blacklist = f.read().split(',')
    return set(blacklist)

# %%
async def daysTradedBetweenBySymbol(isoInstantFrom: str, isoInstantTo: str) -> pd.DataFrame:
    sql_query = "select symb, count(*) as daystraded from 'binance_daily' where open_time >= '%s' and open_time < '%s' and num_trades >= 1 group by symb"%(isoInstantFrom, isoInstantTo)
    query_params = {'query': sql_query, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
            r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    return pd.DataFrame(columns=['symb', 'daysTraded'], data=jsonR['dataset'])

# %%
from datetime import date
from typing import List

# we will consider that an eligible asset should have at least one trade
# pair that was negotiated every day of the month
async def symbolsTradedEveryDay(isoInstantFrom: str, isoInstantTo: str) -> List[str]:
    fromDate = date.fromisoformat(isoInstantFrom[:10])
    toDate = date.fromisoformat(isoInstantTo[:10])
    daysBetween = abs(toDate - fromDate).days    
    df = await daysTradedBetweenBySymbol(isoInstantFrom, isoInstantTo)
    return df[df['daysTraded']==daysBetween]['symb'].tolist()

# %%
async def assetsTradedEveryDay(isoInstantFrom: str, isoInstantTo: str) -> Set[str]:
    result = set()
    symbols = await symbolsTradedEveryDay(isoInstantFrom, isoInstantTo)
    for symbol in symbols:
        symbolInfo = symbolDict[symbol]
        result.add(symbolInfo['baseAsset'])
        result.add(symbolInfo['quoteAsset'])
    return result

# %%
async def eligibleAssetsAndMedianVolumes(isoInstantFrom: str, isoInstantTo: str, getBlacklistFunc, whitelistFunc=None) -> pd.DataFrame:
    initialAssets = await initialAssetCandidateSet()
    df = await getMedianUSDTTradeVol(initialAssets, isoInstantFrom, isoInstantTo)
    blackListSet = getBlacklistFunc()
    print('blackListSet')
    print(blackListSet)
    df = df[~df['baseAsset'].str.lower().isin(blackListSet)]
    if whitelistFunc is not None:
        print('whitelist is present')
        whitelistSet = whitelistFunc()
        df = df[df['baseAsset'].str.lower().isin(whitelistSet)]
    else:
        print('no whitelist being used')
    everydayAssets = await assetsTradedEveryDay(isoInstantFrom, isoInstantTo)
    df = df[df['baseAsset'].isin(everydayAssets)]
    df.reset_index(drop=True, inplace=True)
    maxVolume = df['volInUSDT'][0]
    df = df[df['volInUSDT'] >= (0.005 * maxVolume)]
    df.reset_index(inplace=True, drop=True)
    return df

# %% [markdown]
# Now we have everything to compute our eligibleAssets, and we will proceed to select among then the ones that will be part of the index constituents... For this we will need market cap data, which is not available from Binance API, so we will get them from Coin Gecko.

# %%
geckoBaseURL = "https://api.coingecko.com:443/api/v3"

# %%
from typing import Dict
import asyncio
async def baseAsset2GeckoId(exchangeId = 'binance') -> Dict[str, str]:
    result = {}
    done = False
    page = 1
    while not done:
        query_params = {'page': page, 'order': 'trust_score_desc'}
        print(f"Page {page}. Pausing...")
        await asyncio.sleep(4)
        async with httpx.AsyncClient() as client:
            r = await client.get(geckoBaseURL + f"/exchanges/{exchangeId}/tickers", params=query_params, timeout=30)
        tickerInfo = r.json()
        if len(tickerInfo['tickers']) == 0:
            done = True
        else:
            page += 1
            for ticker in tickerInfo['tickers']:
                baseAsset = ticker['base']
                quoteAsset = ticker['target']
                if "coin_id" in ticker:
                    if not baseAsset in result:
                        result[baseAsset] = ticker['coin_id']
                if "target_coin_id" in ticker:
                    if not quoteAsset in result:
                        result[quoteAsset] = ticker['target_coin_id']
    return result

# %%
baseAssets2GeckoDict = await baseAsset2GeckoId()
# Out:
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Page 4. Pausing...
# Page 5. Pausing...
# Page 6. Pausing...
# Page 7. Pausing...
# Page 8. Pausing...
# Page 9. Pausing...
# Page 10. Pausing...
# Page 11. Pausing...
# Page 12. Pausing...
# Page 13. Pausing...
# Page 14. Pausing...
# Page 15. Pausing...
# Page 16. Pausing...

# %%
baseAssets2GeckoDict
# Out:
# {'BUSD': 'binance-usd',
#  'USDT': 'tether',
#  'BTC': 'bitcoin',
#  'USDC': 'usd-coin',
#  'ETH': 'ethereum',
#  'WBTC': 'wrapped-bitcoin',
#  'SOL': 'solana',
#  'MATIC': 'matic-network',
#  'XRP': 'ripple',
#  'ADA': 'cardano',
#  'AVAX': 'avalanche-2',
#  'BNB': 'binancecoin',
#  'SAND': 'the-sandbox',
#  'ATOM': 'cosmos',
#  'GMT': 'stepn',
#  'TUSD': 'true-usd',
#  'FTM': 'fantom',
#  'LINK': 'chainlink',
#  'USDP': 'paxos-standard',
#  'ETC': 'ethereum-classic',
#  'DOT': 'polkadot',
#  'DOGE': 'dogecoin',
#  'APE': 'apecoin',
#  'LTC': 'litecoin',
#  'TRX': 'tron',
#  'SHIB': 'shiba-inu',
#  'FTT': 'ftx-token',
#  'BCH': 'bitcoin-cash',
#  'DYDX': 'dydx',
#  'DAI': 'dai',
#  'BIDR': 'binanceidr',
#  'MANA': 'decentraland',
#  'NEAR': 'near',
#  'XMR': 'monero',
#  'AAVE': 'aave',
#  'PAXG': 'pax-gold',
#  'WAVES': 'waves',
#  'RUNE': 'thorchain',
#  'GALA': 'gala',
#  'EOS': 'eos',
#  'UNI': 'uniswap',
#  'OP': 'optimism',
#  'SUSHI': 'sushi',
#  'SRM': 'serum',
#  'ENS': 'ethereum-name-service',
#  'FIL': 'filecoin',
#  'AXS': 'axie-infinity',
#  'VET': 'vechain',
#  'ALGO': 'algorand',
#  'LUNC': 'terra-luna',
#  'CRV': 'curve-dao-token',
#  'THETA': 'theta-token',
#  'XTZ': 'tezos',
#  'KNC': 'kyber-network-crystal',
#  'MITH': 'mithril',
#  'ICP': 'internet-computer',
#  'BAT': 'basic-attention-token',
#  'GRT': 'the-graph',
#  'LRC': 'loopring',
#  'ONE': 'harmony',
#  'KAVA': 'kava',
#  'NEO': 'neo',
#  'CHZ': 'chiliz',
#  'XLM': 'stellar',
#  'JASMY': 'jasmycoin',
#  'SNX': 'havven',
#  'ZIL': 'zilliqa',
#  'USTC': 'terrausd',
#  'EGLD': 'elrond-erd-2',
#  'UNFI': 'unifi-protocol-dao',
#  'ENJ': 'enjincoin',
#  'FLOW': 'flow',
#  'BOND': 'barnbridge',
#  'ZEC': 'zcash',
#  'NMR': 'numeraire',
#  'BNX': 'binaryx',
#  'YFI': 'yearn-finance',
#  'ZRX': '0x',
#  'IDRT': 'rupiah-token',
#  'LEVER': 'lever',
#  'ALICE': 'my-neighbor-alice',
#  'DASH': 'dash',
#  'STORJ': 'storj',
#  'PEOPLE': 'constitutiondao',
#  'AR': 'arweave',
#  'COMP': 'compound-governance-token',
#  'GAL': 'project-galaxy',
#  'ROSE': 'oasis-network',
#  'MTL': 'metal',
#  'OMG': 'omisego',
#  'ACH': 'alchemy-pay',
#  'IOTX': 'iotex',
#  'FIDA': 'bonfida',
#  'HBAR': 'hedera-hashgraph',
#  'SLP': 'smooth-love-potion',
#  '1INCH': '1inch',
#  'MIR': 'mirror-protocol',
#  'ANC': 'anchor-protocol',
#  'RAY': 'raydium',
#  'FLM': 'flamingo-finance',
#  'BAKE': 'bakerytoken',
#  'JST': 'just',
#  'LDO': 'lido-dao',
#  'OGN': 'origin-protocol',
#  'BEL': 'bella-protocol',
#  'BURGER': 'burger-swap',
#  'QNT': 'quant-network',
#  'SKL': 'skale',
#  'GTO': 'gifto',
#  'BAND': 'band-protocol',
#  'IMX': 'immutable-x',
#  'XEC': 'ecash',
#  'HNT': 'helium',
#  'HOT': 'holotoken',
#  'RSR': 'reserve-rights-token',
#  'GHST': 'aavegotchi',
#  'CELR': 'celer-network',
#  'TRB': 'tellor',
#  'DAR': 'mines-of-dalarnia',
#  'OCEAN': 'ocean-protocol',
#  'ETHDOWN': 'ethdown',
#  'IOST': 'iostoken',
#  'SYS': 'syscoin',
#  'MINA': 'mina-protocol',
#  'TLM': 'alien-worlds',
#  'MBL': 'moviebloc',
#  'MASK': 'mask-network',
#  'XEM': 'nem',
#  'CAKE': 'pancakeswap-token',
#  'LIT': 'litentry',
#  'API3': 'api3',
#  'YFII': 'yfii-finance',
#  'KLAY': 'klay-token',
#  'REN': 'republic-protocol',
#  'KSM': 'kusama',
#  'QTUM': 'qtum',
#  'BSW': 'biswap',
#  'CELO': 'celo',
#  'WOO': 'woo-network',
#  'IOTA': 'iota',
#  'YGG': 'yield-guild-games',
#  'ARPA': 'arpa-chain',
#  'PERL': 'perlin',
#  'BTCST': 'btc-standard-hashrate-token',
#  'CHR': 'chromaway',
#  'COTI': 'coti',
#  'DENT': 'dent',
#  'PORTO': 'fc-porto',
#  'MFT': 'mainframe',
#  'ATA': 'automata',
#  'RLC': 'iexec-rlc',
#  'AUDIO': 'audius',
#  'REEF': 'reef',
#  'T': 'threshold-network-token',
#  'ICX': 'icon',
#  'VGX': 'ethos',
#  'BLZ': 'bluzelle',
#  'STX': 'blockstack',
#  'C98': 'coin98',
#  'WIN': 'wink',
#  'BETA': 'beta-finance',
#  'RVN': 'ravencoin',
#  'ANKR': 'ankr',
#  'MKR': 'maker',
#  'SXP': 'swipe',
#  'SANTOS': 'santos-fc-fan-token',
#  'FIRO': 'zcoin',
#  'BAL': 'balancer',
#  'ZEN': 'zencash',
#  'ONT': 'ontology',
#  'VIDT': 'v-id-blockchain',
#  'CTSI': 'cartesi',
#  'POND': 'marlin',
#  'KDA': 'kadena',
#  'MBOX': 'mobox',
#  'GLMR': 'moonbeam',
#  'ACM': 'ac-milan-fan-token',
#  'LPT': 'livepeer',
#  'DUSK': 'dusk-network',
#  'CTK': 'certik',
#  'ASR': 'as-roma-fan-token',
#  'PYR': 'vulcan-forged',
#  'PROM': 'prometeus',
#  'FXS': 'frax-share',
#  'TCT': 'tokenclub',
#  'ANT': 'aragon',
#  'STPT': 'stp-network',
#  'MOB': 'mobilecoin',
#  'ALPHA': 'alpha-finance',
#  'TRIBE': 'tribe-2',
#  'FET': 'fetch-ai',
#  'REI': 'rei-network',
#  'NKN': 'nkn',
#  'JOE': 'joe',
#  'ETHUP': 'ethup',
#  'SFP': 'safepal',
#  'PERP': 'perpetual-protocol',
#  'BICO': 'biconomy',
#  'DODO': 'dodo',
#  'KP3R': 'keep3rv1',
#  'KEY': 'selfkey',
#  'SPELL': 'spell-token',
#  'POLY': 'polymath',
#  'CVX': 'convex-finance',
#  'IDEX': 'aurora-dao',
#  'FRONT': 'frontier-token',
#  'AUTO': 'auto',
#  'HIVE': 'hive',
#  'SUN': 'sun-token',
#  'AUCTION': 'auction',
#  'GTC': 'gitcoin',
#  'MOVR': 'moonriver',
#  'WAXP': 'wax',
#  'STRAX': 'stratis',
#  'CHESS': 'tranchess',
#  'CVC': 'civic',
#  'LINA': 'linear',
#  'TWT': 'trust-wallet-token',
#  'WRX': 'wazirx',
#  'FIS': 'stafi',
#  'RAD': 'radicle',
#  'RIF': 'rif-token',
#  'CITY': 'manchester-city-fan-token',
#  'ASTR': 'astar',
#  'QUICK': 'quick',
#  'NBS': 'new-bitshares',
#  'WTC': 'waltonchain',
#  'ILV': 'illuvium',
#  'BDOT': 'binance-wrapped-dot',
#  'POWR': 'power-ledger',
#  'STMX': 'storm',
#  'WING': 'wing-finance',
#  'VAI': 'vai',
#  'CTXC': 'cortex',
#  'ELF': 'aelf',
#  'SC': 'siacoin',
#  'TOMO': 'tomochain',
#  'ERN': 'ethernity-chain',
#  'UFT': 'unlend-finance',
#  'OXT': 'orchid-protocol',
#  'TFUEL': 'theta-fuel',
#  'CLV': 'clover-finance',
#  'PUNDIX': 'pundi-x-2',
#  'AMP': 'amp-token',
#  'DGB': 'digibyte',
#  'LAZIO': 'lazio-fan-token',
#  'COCOS': 'cocos-bcx',
#  'BTS': 'bitshares',
#  'DEGO': 'dego-finance',
#  'NEXO': 'nexo',
#  'QI': 'benqi',
#  'EPX': 'ellipsis-x',
#  'SCRT': 'secret',
#  'VOXEL': 'voxies',
#  'OM': 'mantra-dao',
#  'PHA': 'pha',
#  'FARM': 'harvest-finance',
#  'TVK': 'the-virtua-kolect',
#  'AGLD': 'adventure-gold',
#  'RNDR': 'render-token',
#  'JUV': 'juventus-fan-token',
#  'LOKA': 'league-of-kingdoms',
#  'CVP': 'concentrated-voting-power',
#  'ATM': 'atletico-madrid',
#  'PSG': 'paris-saint-germain-fan-token',
#  'NULS': 'nuls',
#  'INJ': 'injective-protocol',
#  'BEAM': 'beam',
#  'VITE': 'vite',
#  'BTG': 'bitcoin-gold',
#  'AION': 'aion',
#  'REQ': 'request-network',
#  'PLA': 'playdapp',
#  'FORTH': 'ampleforth-governance-token',
#  'XNO': 'nano',
#  'TROY': 'troy',
#  'FIO': 'fio-protocol',
#  'SUPER': 'superfarm',
#  'OG': 'og-fan-token',
#  'KMD': 'komodo',
#  'DOCK': 'dock',
#  'ACA': 'acala',
#  'HIGH': 'highstreet',
#  'STEEM': 'steem',
#  'FUN': 'funfair',
#  'TKO': 'tokocrypto',
#  'BAR': 'fc-barcelona-fan-token',
#  'XVS': 'venus',
#  'WAN': 'wanchain',
#  'PNT': 'pnetwork',
#  'POLS': 'polkastarter',
#  'AVA': 'concierge-io',
#  'OOKI': 'ooki',
#  'LSK': 'lisk',
#  'ALPINE': 'alpine-f1-team-fan-token',
#  'AKRO': 'akropolis',
#  'UMA': 'uma',
#  'BADGER': 'badger-dao',
#  'TORN': 'tornado-cash',
#  'DEXE': 'dexe',
#  'FOR': 'force-protocol',
#  'TRU': 'truefi',
#  'DREP': 'drep-new',
#  'DATA': 'streamr',
#  'ADX': 'adex',
#  'UTK': 'utrust',
#  'MC': 'merit-circle',
#  'AERGO': 'aergo',
#  'WNXM': 'wrapped-nxm',
#  'FLUX': 'zelcash',
#  'RARE': 'superrare',
#  'DNT': 'district0x',
#  'REP': 'augur',
#  'GNO': 'gnosis',
#  'BNT': 'bancor',
#  'SSV': 'ssv-network',
#  'MLN': 'melon',
#  'IRIS': 'iris-network',
#  'HARD': 'kava-lend',
#  'CREAM': 'cream-2',
#  'MDT': 'measurable-data-token',
#  'VTHO': 'vethor-token',
#  'COS': 'contentos',
#  'CFX': 'conflux-token',
#  'ORN': 'orion-protocol',
#  'DF': 'dforce-token',
#  'CKB': 'nervos-network',
#  'DIA': 'dia-data',
#  'ALPACA': 'alpaca-finance',
#  'ARDR': 'ardor',
#  'MDX': 'mdex',
#  'BIFI': 'beefy-finance',
#  'MULTI': 'multichain',
#  'LOOM': 'loom-network-new',
#  'ARK': 'ark',
#  'SNT': 'status',
#  'ALCX': 'alchemix',
#  'LTO': 'lto-network',
#  'AGIX': 'singularitynet',
#  'GAS': 'gas',
#  'EZ': 'easyfi',
#  'GLM': 'golem',
#  'XVG': 'verge',
#  'SPARTA': 'spartan-protocol-token',
#  'PROS': 'prosper',
#  'VIB': 'viberate',
#  'NEBL': 'neblio',
#  'QLC': 'qlink',
#  'IQ': 'everipedia',
#  'DCR': 'decred',
#  'QSP': 'quantstamp',
#  'PIVX': 'pivx',
#  'ONG': 'ong',
#  'BRD': 'bread',
#  'AMB': 'amber',
#  'AST': 'airswap',
#  'QKC': 'quark-chain',
#  'SNM': 'sonm',
#  'OAX': 'openanx',
#  'PHB': 'phoenix-global',
#  'NAV': 'nav-coin',
#  'WABI': 'wabi',
#  'MDA': 'moeda-loyalty-points',
#  'NXS': 'nexus',
#  'BETH': 'binance-eth',
#  'BTTC': 'bittorrent'}

# %%
import dateutil
from dateutil.parser import parse
import datetime as dt
import pytz

async def computeMedianDailyMarketCapAndLastCirSupply(geckoCoinId: str, isoInstantFrom: str, isoInstantTo: str, maxDelaySeconds=7200) -> (float, float):
    dtFrom = parse(isoInstantFrom)
    dtTo = parse(isoInstantTo)
    epochSecondsFrom = dtFrom.timestamp()
    epochSecondsTo = dtTo.timestamp()
    query_params = {'vs_currency': 'usd', 'from': epochSecondsFrom, 'to': epochSecondsTo}
    async with httpx.AsyncClient() as client:
        r = await client.get(geckoBaseURL + f"/coins/{geckoCoinId}/market_chart/range", params=query_params, timeout=30)
    jsonR = r.json()
    if jsonR is None or not 'market_caps' in jsonR:
        print("WARNING: Could not find market_caps for %s, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)
    df = pd.DataFrame(columns=['epoch', 'market_cap'], data=jsonR['market_caps'])
    if (df.shape[0] < 1 or df.shape[1] != 2):
        print("WARNING: Unexpected shape for %s, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)
    if df['epoch'].isnull().values.any():
        print("WARNING: coingecko data for %s, contains empty epochs, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)

    df['isodate'] = df.apply(lambda row: dt.datetime.fromtimestamp(int(row['epoch'])/1000, tz=pytz.utc).isoformat()[:10] if (len(str(row['epoch'])) >= 13) else dt.datetime.fromtimestamp(int(row['epoch']), tz=pytz.utc).isoformat()[:10], axis = 1)
    df.sort_values(['epoch'], ascending=[True], ignore_index=True, inplace=True)
    lastMarketCap = df.iloc[-1]
    lastMarketCapDT = dt.datetime.fromtimestamp(int(lastMarketCap['epoch']/1000), tz=pytz.utc) if (len(str(lastMarketCap['epoch'])) >= 13) else dt.datetime.fromtimestamp(int(lastMarketCap['epoch']), tz=pytz.utc)
    if (abs(dtTo - lastMarketCapDT).total_seconds() > maxDelaySeconds):
        print("computeMedianDailyMarketCapAndLastCirSupply: WARNING last market cap data for %s is too old, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)    
    dfPrices = pd.DataFrame(columns=['epoch', 'price'], data=jsonR['prices'])
    dfPrices.sort_values(['epoch'], ascending=[True], ignore_index=True, inplace=True)
    lastPrice = dfPrices.iloc[-1]
    lastPriceDT = dt.datetime.fromtimestamp(int(lastPrice['epoch']/1000), tz=pytz.utc) if (len(str(lastPrice['epoch'])) >= 13) else dt.datetime.fromtimestamp(int(lastPrice['epoch']), tz=pytz.utc)
    if (abs(dtTo - lastPriceDT).total_seconds() >= maxDelaySeconds):
        print("computeMedianDailyMarketCapAndLastCirSupply: WARNING last price data for %s is too old, ignoring (returning 0,0)"%geckoCoinId)
        return (0,0)                                                                                                                                         
    df = df[['isodate', 'market_cap']].groupby(['isodate'], as_index=False).last()
    return (df['market_cap'].median(), float(lastMarketCap['market_cap'])/float(lastPrice['price']))

# %%
def addWeights(indexConstituents: pd.DataFrame):
    indexConstituents['lastMarketcap'] = indexConstituents['lastCircSupply']*indexConstituents['lastAvgPriceUSDT']
    totalLastMarketcap = indexConstituents['lastMarketcap'].sum()
    indexConstituents['weight'] = indexConstituents['lastMarketcap']/totalLastMarketcap
    print(indexConstituents)
    assert(abs(indexConstituents['weight'].sum() - 1.0) < 0.0000001)

# %%
# as we are severely rate limited by coingecko (poor free user) we will build a cache
# of median daily market cap and last circulating supply data that will benefit
# us over repeated runs
import sqlite3
from sqlite3 import Error
def createCacheDBConnection(dbFile):
    conn = None
    try:
        conn = sqlite3.connect(dbFile)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        return conn
    
def createTable(conn, sqlStmt):
    try:
        c = conn.cursor()
        c.execute(sqlStmt)
    except Error as e:
        print(e)
        
def createGeckoCacheDataBase(conn=None):
    sqlStmt = """CREATE TABLE IF NOT EXISTS MedianDailyMarketCapAndLastCirSupply (
                    id text PRIMARY KEY,
                    medDailyMarketCap real NOT NULL,
                    lastCirSupply real NOT NULL
                 );"""
    if conn is None:
        conn = createCacheDBConnection("geckoCache.db")
    if conn is not None:
        createTable(conn, sqlStmt)
        return conn
    else:
        print("Error, could not create cache database")
        
def insertCacheData(geckoId: str, isoInstantFrom: str, isoInstantTo: str, marketCap: float, cirSupply: float, conn):
    sql = 'INSERT INTO MedianDailyMarketCapAndLastCirSupply(id, medDailyMarketCap, lastCirSupply) VALUES(?, ?, ?)'
    key = geckoId + "_" + isoInstantFrom + "_" + isoInstantTo
    value = (key, marketCap, cirSupply)
    cur = conn.cursor()
    cur.execute(sql, value)
    conn.commit()
    
def getCachedData(geckoId: str, isoInstantFrom: str, isoInstantTo: str, conn):
    key = geckoId + "_" + isoInstantFrom + "_" + isoInstantTo
    cur = conn.cursor()
    cur.execute("SELECT medDailyMarketCap, lastCirSupply FROM MedianDailyMarketCapAndLastCirSupply WHERE id=?", (key,))
    rows = cur.fetchall()
    if (len(rows) > 0):
        for row in rows:
            return (row[0], row[1])
    else:
        return (None, None)

# %%
import asyncio
import pandas as pd
async def selectIndexConstituents(isoInstantFrom: str, isoInstantTo: str, eligibleAssets: pd.DataFrame, cacheConn=None) -> pd.DataFrame:
    def getGeckoId(baseAsset: str):
        if (baseAsset == 'LUNA'):
            if isoInstantTo < '2022-05-31':
                return 'terra-luna'
            else:
                return 'terra-luna-2'
        elif (baseAsset == 'ANY'):
            return 'anyswap'
        elif (baseAsset == 'EPS'):
            return 'ellipsis'
        elif (baseAsset == 'NPXS'):
            return 'pundi-x'
        elif (baseAsset == 'BTT'):
            if isoInstantTo < '2022-01-17':
                return 'bittorrent-old'
            else:
                return 'bittorrent'
        elif (baseAsset == 'NANO'):
            return 'nano'
        elif (baseAsset == 'NU'):
            return 'nucypher'
        elif (baseAsset == 'KEEP'):
            return 'keep-network'
        elif (baseAsset == 'GXS'):
            return 'gxchain'
        elif (baseAsset in baseAssets2GeckoDict):
            return baseAssets2GeckoDict[baseAsset]
        else:
            return None
        
    indexConstituents = eligibleAssets.copy()
    eligibleAssets = None
    indexConstituents['geckoId'] = indexConstituents.apply(lambda row: getGeckoId(row['baseAsset']), axis = 1)
    geckoUnsupported = indexConstituents[indexConstituents['geckoId'].isna()]
    if geckoUnsupported.shape[0] > 0:
        print("WARNING: coingecko seems to not support the following eligible assets. Ignoring them")
        print(geckoUnsupported['baseAsset'])
        indexConstituents = indexConstituents[~indexConstituents['geckoId'].isna()]
    medians = []
    lastCircSupplies = []
    for geckoId in indexConstituents['geckoId']:
        print(geckoId)
        (medianDailyMarketCap, lastCircSupply) = (None, None)
        if cacheConn is not None:
            (medianDailyMarketCap, lastCircSupply) = getCachedData(geckoId, isoInstantFrom, isoInstantTo, cacheConn)
        if medianDailyMarketCap is None or lastCircSupply is None:
            await asyncio.sleep(4)
            (medianDailyMarketCap, lastCircSupply) = await computeMedianDailyMarketCapAndLastCirSupply(geckoId, isoInstantFrom, isoInstantTo)
            if (cacheConn is not None):
                insertCacheData(geckoId, isoInstantFrom, isoInstantTo, medianDailyMarketCap, lastCircSupply, cacheConn)
                
        medians.append(medianDailyMarketCap)
        lastCircSupplies.append(lastCircSupply)
    indexConstituents['medianMarketcap'] = medians
    indexConstituents['lastCircSupply'] = lastCircSupplies
    del medians
    del lastCircSupplies
    totalMarketCap = indexConstituents['medianMarketcap'].sum()
    indexConstituents.sort_values(['medianMarketcap'], ascending=[False], ignore_index=True, inplace=True)
    indexConstituents['fracTotalMarketCap'] = indexConstituents.apply(lambda row: row['medianMarketcap']/totalMarketCap, axis = 1)
    accumulatedPerc = []
    cumul = 0.0
    for _, row in indexConstituents.iterrows():
        cumul += row['fracTotalMarketCap']
        accumulatedPerc.append(cumul)
    indexConstituents.insert(indexConstituents.shape[1], 'accumulatedPerc', accumulatedPerc)
    del accumulatedPerc
    lastIndex = 0
    cutFrame = False
    for lastIndex, row in indexConstituents.iterrows():
        if row['fracTotalMarketCap'] < 0.005 and row['accumulatedPerc'] > 0.75:
            cutFrame = True
            break
    if cutFrame:
        indexConstituents = indexConstituents[:lastIndex]
    addWeights(indexConstituents)
    return indexConstituents

# %%
import json
import pandas as pd
class IndexData:
    indexId: str
    _indexValue: float
    isoInstant: str
    isRebalanceDay: bool
    _divisor: float
    lastRebalanceISOInstant: str
    indexConstituents: pd.DataFrame
    
    class IndexDataEncoder(json.JSONEncoder):
        def default(self, obj):
            if isinstance(obj, IndexData):
                return {"indexId": obj.indexId, "isoInstant": obj.isoInstant, "indexValue": obj.indexValue, "isRebalanceDay": obj.isRebalanceDay, "divisor": obj.divisor, "lastRebalanceISOInstant": obj.lastRebalanceISOInstant, "indexConstituents": json.loads(obj.indexConstituents.to_json(orient='split', index=False))}
            return json.JSONEncoder.default(self, obj)
    
    def set_indexValue(self, value):
        self._indexValue = round(value, 2)
    
    def get_indexValue(self):
        return self._indexValue
    
    def del_indexValue(self):
        del self._indexValue
        
    indexValue = property(get_indexValue, set_indexValue, del_indexValue)
    
    def set_divisor(self, value):
        self._divisor = round(value, 4)
    
    def get_divisor(self):
        return self._divisor
    
    def del_divisor(self):
        del self._divisor
       
    divisor = property(get_divisor, set_divisor, del_divisor)
    
    def toJSON(self):
        return json.dumps(self, cls=IndexData.IndexDataEncoder)
    
    def __repr__(self):
        return self.toJSON()
    
    def __jsonDecode(dct):
        attrs = ["indexId", "isoInstant", "indexValue", "isRebalanceDay", "divisor", "lastRebalanceISOInstant", "indexConstituents"]
        for attr in attrs:
            if attr not in dct:
                return dct
        result = IndexData()
        result.indexId = dct['indexId']
        result.isoInstant = dct['isoInstant']
        result.indexValue = dct['indexValue']
        result.isRebalanceDay = dct['isRebalanceDay']
        result.divisor = dct['divisor']
        result.lastRebalanceISOInstant = dct['lastRebalanceISOInstant']
        result.indexConstituents = pd.read_json(json.dumps(dct['indexConstituents']), orient='split')
        return result
    
    def fromJSON(jsStr):
        return json.loads(jsStr, object_hook=IndexData.__jsonDecode)

# %%
from functools import partial
async def startIndex(isoInstantFrom: str, isoInstantTo: str, startValue: int, name: str, cacheConn=None, whitelistFunc=None, getBlacklistFunc=partial(getBlacklistSet, 'blacklist.txt')) -> IndexData:
    assert(startValue >= 1)
    eligibleAssets = await eligibleAssetsAndMedianVolumes(isoInstantFrom, isoInstantTo, getBlacklistFunc, whitelistFunc)
    indexConstituents = await selectIndexConstituents(isoInstantFrom, isoInstantTo, eligibleAssets, cacheConn)
    indexData = IndexData()
    indexData.indexId = name
    indexData.isoInstant = isoInstantTo
    indexData.isRebalanceDay = True
    indexData.lastRebalanceISOInstant = isoInstantTo
    indexData.indexValue = startValue
    dInitial = indexConstituents['lastMarketcap'].sum() / float(startValue)
    indexData.indexConstituents = indexConstituents
    indexData.divisor = dInitial
    return indexData

# %%
cacheConn = createGeckoCacheDataBase()
# Out:
# 2.6.0

# %%
firstIndexData = await startIndex('2020-11-01T00:00:00.000000Z', '2020-12-01T00:00:00.000000Z', 1000, 'ONN-B-30dW-30dR', cacheConn, None, partial(getBlacklistSet, 'blacklist.txt'))

# %%
jsonstr = firstIndexData.toJSON()
print(jsonstr)
# Out:
# {"indexId": "ONN-B-30dW-30dR", "isoInstant": "2020-12-01T00:00:00.000000Z", "indexValue": 1000, "isRebalanceDay": true, "divisor": 501919066.7321, "lastRebalanceISOInstant": "2020-12-01T00:00:00.000000Z", "indexConstituents": {"columns": ["baseAsset", "volInUSDT", "lastAvgPriceUSDT", "geckoId", "medianMarketcap", "lastCircSupply", "fracTotalMarketCap", "accumulatedPerc", "lastMarketcap", "weight"], "data": [["BTC", 1799611405.9828906, 19695.4272907278, "bitcoin", 306147758877.22736, 18484272.8757997, 0.731884735, 0.731884735, 364055652447.28534, 0.7253274015], ["ETH", 865675388.9247065, 616.6642866534, "ethereum", 53055352961.21584, 113526863.21730871, 0.1268354963, 0.8587202313, 70007962121.89664, 0.1394805792], ["XRP", 125602872.32016027, 0.6642120677, "ripple", 12588025364.86216, 45334295892.0, 0.0300932584, 0.8888134897, 30111586410.965424, 0.059992912], ["LINK", 175712200.03103828, 14.2654541803, "chainlink", 5041331272.175043, 394509556.43444437, 0.0120519367, 0.9008654263, 5627858001.016893, 0.0112126802], ["BCH", 72645155.4878704, 317.4848991238, "bitcoin-cash", 4805315865.255434, 18609552.35687388, 0.0114877121, 0.9123531385, 5908251852.760923, 0.0117713238], ["LTC", 148938351.85278848, 87.654204986, "litecoin", 4428630444.208554, 65671923.166139364, 0.0105871983, 0.9229403367, 5756420215.0315275, 0.0114688216], ["DOT", 38331548.011242315, 5.3767464744, "polkadot", 4275686537.1120396, 936924830.6575856, 0.0102215666, 0.9331619033, 5037607280.013776, 0.0100366924], ["BNB", 100443709.85004002, 31.4885701412, "binancecoin", 4163544804.623246, 148037411.3518485, 0.0099534777, 0.943115381, 4661486410.87813, 0.0092873268], ["ADA", 52945441.86356232, 0.1720600782, "cardano", 3307419813.606379, 31015275423.33924, 0.0079068032, 0.9510221842, 5336490715.90245, 0.0106321737], ["EOS", 45500819.808965966, 3.2615074879, "eos", 2455376713.169034, 948063614.7929999, 0.005869887, 0.9568920712, 3092116578.6897902, 0.006160588], ["XMR", 23495277.596826173, 130.6779146358, "monero", 2119402070.5132182, 17781387.957983844, 0.0050666973, 0.9619587685, 2323634697.678604, 0.0046295008]]}}

# %%
async def computeUpdatedPrices(indexData: IndexData, beginIsoInstant: str, endIsoInstant: str):
    baseAssetSet = set(indexData.indexConstituents['baseAsset'])
    dfNewPrices = await getMedianUSDTTradeVol(baseAssetSet, beginIsoInstant, endIsoInstant)
    dfNewPrices = dfNewPrices[dfNewPrices['baseAsset'].isin(baseAssetSet)]
    dfNewPrices.set_index('baseAsset', inplace=True)
    dfNewPrices.drop(columns=['volInUSDT'], inplace=True)
    dfNewPrices.rename(columns={'lastAvgPriceUSDT':'endAvgPriceUSDT'}, inplace=True)
    return dfNewPrices

# %%
import copy
async def lastIndexDataNoRebalance(beginIsoInstant: str, endIsoInstant: str, lastPoint: IndexData) -> IndexData:
    baseAssetSet = set(lastPoint.indexConstituents['baseAsset'])
    dfNewPrices = await computeUpdatedPrices(lastPoint, beginIsoInstant, endIsoInstant)
    dfLastCircSupplies = lastPoint.indexConstituents.copy()
    dfLastCircSupplies.set_index('baseAsset', inplace=True)
    if('endAvgPriceUSDT' in dfLastCircSupplies.columns):
        dfLastCircSupplies.drop(columns=['endAvgPriceUSDT'], inplace=True)
    #dfNew = pd.join([dfLastCircSupplies, dfNewPrices], axis=1, join='inner')
    dfNew = pd.merge(dfLastCircSupplies, dfNewPrices, how='right', on='baseAsset')
    dfNew.fillna(value=0, inplace=True)
    #assert(dfNew.shape[0] == dfLastCircSupplies.shape[0])
    assert(dfNew.shape[0] == dfNewPrices.shape[0])
    del dfNewPrices
    del dfLastCircSupplies
    dfNew.reset_index(inplace=True)
    dfNew.sort_values(['volInUSDT'], ascending=[False], ignore_index=True, inplace=True)
    dfNew['instantDummyMarketCap'] = dfNew['lastCircSupply']*dfNew['endAvgPriceUSDT']
    indexAtEnd = dfNew['instantDummyMarketCap'].sum() / lastPoint.divisor
    endIndex = copy.copy(lastPoint)
    endIndex.indexValue = indexAtEnd
    endIndex.isoInstant = endIsoInstant
    endIndex.isRebalanceDay = False
    dfNew.drop(columns=['instantDummyMarketCap'], inplace=True)
    endIndex.indexConstituents = dfNew
    return endIndex

# %%
async def lastIndexDataRebalance(beginIsoInstant: str, endIsoInstant:str, lastPoint: IndexData, cacheConn=None, whitelistFunc=None, getBlacklistFunc=partial(getBlacklistSet, 'blacklist.txt')) -> IndexData:
    updatedPricesOldConstituents = await computeUpdatedPrices(lastPoint, beginIsoInstant, endIsoInstant)
    dfLastCircSupplies = lastPoint.indexConstituents.copy()
    dfLastCircSupplies.set_index('baseAsset', inplace=True)
    if('endAvgPriceUSDT' in dfLastCircSupplies.columns):
        dfLastCircSupplies.drop(columns=['endAvgPriceUSDT'], inplace=True)
    dfNew = pd.concat([dfLastCircSupplies, updatedPricesOldConstituents], axis=1, join='inner')
    assert(dfNew.shape[0] == dfLastCircSupplies.shape[0])
    assert(dfNew.shape[0] == updatedPricesOldConstituents.shape[0])
    del updatedPricesOldConstituents
    del dfLastCircSupplies
    dfNew.reset_index(inplace=True)
    dfNew['instantDummyMarketCap'] = dfNew['lastCircSupply']*dfNew['endAvgPriceUSDT']
    oldConstituentsNewMarketcap = dfNew['instantDummyMarketCap'].sum()
    
    eligibleAssets = await eligibleAssetsAndMedianVolumes(lastPoint.lastRebalanceISOInstant, endIsoInstant, getBlacklistFunc, whitelistFunc)
    indexConstituents = await selectIndexConstituents(lastPoint.lastRebalanceISOInstant, endIsoInstant, eligibleAssets, cacheConn)
    newConstituentsMarketcap = indexConstituents['lastMarketcap'].sum()
    
    newDivisor = (newConstituentsMarketcap/oldConstituentsNewMarketcap)*lastPoint.divisor
    newValue = newConstituentsMarketcap/newDivisor

    endIndex = copy.copy(lastPoint)
    endIndex.indexValue = newValue
    endIndex.isoInstant = endIsoInstant
    endIndex.isRebalanceDay = True
    endIndex.indexConstituents = indexConstituents
    endIndex.divisor = newDivisor
    endIndex.lastRebalanceISOInstant = endIsoInstant
    return endIndex

# %%
import datetime
computeDay = parse(firstIndexData.isoInstant) + datetime.timedelta(days = 1)
endDate = parse("2022-06-30T00:00:00.000000Z") + datetime.timedelta(days = 1)
lastIndex = firstIndexData
fileName = f"{firstIndexData.indexId}_{firstIndexData.isoInstant[:10]}_{str(endDate)[:10]}.json"
with open(fileName, 'w') as f:
    print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
    f.write('[\n')
    f.write(lastIndex.toJSON())
    while computeDay <= endDate:
        if(computeDay.day == 1):
            lastIndex = await lastIndexDataRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex, cacheConn, None, partial(getBlacklistSet, 'blacklist.txt'))
        else:
            lastIndex = await lastIndexDataNoRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex)
        print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
        f.write(',\n')
        f.write(lastIndex.toJSON())
        computeDay = computeDay + datetime.timedelta(days = 1)
    f.write('\n]\n')
# Out:
# 2020-12-01T00:00:00.000000Z: 1000.000000
# 2020-12-02T00:00:00.000000Z: 949.040000
# 2020-12-03T00:00:00.000000Z: 971.890000
# 2020-12-04T00:00:00.000000Z: 984.790000
# 2020-12-05T00:00:00.000000Z: 932.790000
# 2020-12-06T00:00:00.000000Z: 963.710000
# 2020-12-07T00:00:00.000000Z: 975.780000
# 2020-12-08T00:00:00.000000Z: 964.340000
# 2020-12-09T00:00:00.000000Z: 916.170000
# 2020-12-10T00:00:00.000000Z: 931.640000
# 2020-12-11T00:00:00.000000Z: 915.200000
# 2020-12-12T00:00:00.000000Z: 900.560000
# 2020-12-13T00:00:00.000000Z: 932.960000
# 2020-12-14T00:00:00.000000Z: 955.370000
# 2020-12-15T00:00:00.000000Z: 957.050000
# 2020-12-16T00:00:00.000000Z: 960.870000
# 2020-12-17T00:00:00.000000Z: 1056.540000
# 2020-12-18T00:00:00.000000Z: 1112.800000
# 2020-12-19T00:00:00.000000Z: 1128.720000
# 2020-12-20T00:00:00.000000Z: 1157.470000
# 2020-12-21T00:00:00.000000Z: 1137.750000
# 2020-12-22T00:00:00.000000Z: 1094.240000
# 2020-12-23T00:00:00.000000Z: 1138.330000
# 2020-12-24T00:00:00.000000Z: 1079.940000
# 2020-12-25T00:00:00.000000Z: 1116.780000
# 2020-12-26T00:00:00.000000Z: 1158.090000
# 2020-12-27T00:00:00.000000Z: 1224.320000
# 2020-12-28T00:00:00.000000Z: 1227.090000
# 2020-12-29T00:00:00.000000Z: 1270.140000
# 2020-12-30T00:00:00.000000Z: 1281.360000
# 2020-12-31T00:00:00.000000Z: 1338.490000
# bitcoin
# ethereum
# ripple
# litecoin
# bitcoin-cash
# binancecoin
# chainlink
# cardano
# yearn-finance
# eos
# stellar
# sushi
# polkadot
# tron
# aave
# vechain
# zilliqa
# uniswap
# monero
# filecoin
# elrond-erd-2
# theta-token
# nem
# ethereum-classic
# zcash
# unifi-protocol-dao
# waves
# neo
# dash
# swipe
# algorand
# injective-protocol
# havven
# cosmos
# tezos
# oasis-network
# curve-dao-token
# 2021-03-28T00:00:00.000000Z: 2794.620000
# 2021-03-29T00:00:00.000000Z: 2787.330000
# 2021-03-30T00:00:00.000000Z: 2896.810000
# 2021-03-31T00:00:00.000000Z: 2953.730000
# bitcoin
# ethereum
# binancecoin
# cardano
# chiliz
# ripple
# polkadot
# enjincoin
# litecoin
# theta-token
# swipe
# chainlink
# terra-luna
# vechain
# harmony
# filecoin
# uniswap
# nem
# pancakeswap-token
# eos
# holotoken
# tron
# dogecoin
# matic-network
# bitcoin-cash
# avalanche-2
# stellar
# theta-fuel
# reef
# coti
# decentraland
# sushi
# bittorrent-old
# algorand
# ankr
# ontology
# the-graph
# fantom
# hedera-hashgraph
# aave
# the-sandbox
# chromaway
# cosmos
# pundi-x
# iostoken
# sun-token
# celer-network
# zilliqa
# solana
# curve-dao-token
# neo
# elrond-erd-2
# ravencoin
# 1inch
# dent
# fetch-ai
# venus
# safepal
# storm
# basic-attention-token
# iota
# tezos
# kusama
# monero
# alpha-finance
# qtum
# reserve-rights-token
# audius
# dash
# siacoin
# icon
# zcash
# omisego
# ethereum-classic
# ocean-protocol
# kava
# origin-protocol
# skale
# bluzelle
# selfkey
# serum
# axie-infinity
# near
# yearn-finance
# litentry
# oasis-network
# republic-protocol
# band-protocol
# thorchain
# dodo
# 2021-04-01T00:00:00.000000Z: 2975.990000
# 2021-04-02T00:00:00.000000Z: 2999.560000
# 2021-04-03T00:00:00.000000Z: 3062.990000
# 2021-04-04T00:00:00.000000Z: 2948.280000
# 2021-04-05T00:00:00.000000Z: 3031.020000
# 2021-04-06T00:00:00.000000Z: 3119.180000
# 2021-04-07T00:00:00.000000Z: 3108.430000
# 2021-04-08T00:00:00.000000Z: 2951.200000
# 2021-04-09T00:00:00.000000Z: 3093.300000
# 2021-04-10T00:00:00.000000Z: 3093.970000
# 2021-04-11T00:00:00.000000Z: 3217.770000
# 2021-04-12T00:00:00.000000Z: 3250.010000
# 2021-04-13T00:00:00.000000Z: 3280.040000
# 2021-04-14T00:00:00.000000Z: 3487.540000
# 2021-04-15T00:00:00.000000Z: 3508.160000
# 2021-04-16T00:00:00.000000Z: 3533.500000
# 2021-04-17T00:00:00.000000Z: 3417.680000
# 2021-04-18T00:00:00.000000Z: 3336.440000
# 2021-04-19T00:00:00.000000Z: 3130.860000
# 2021-04-20T00:00:00.000000Z: 3073.440000
# 2021-04-21T00:00:00.000000Z: 3184.180000
# 2021-04-22T00:00:00.000000Z: 3061.630000
# 2021-04-23T00:00:00.000000Z: 2960.650000
# 2021-04-24T00:00:00.000000Z: 2937.340000
# 2021-04-25T00:00:00.000000Z: 2822.120000
# 2021-04-26T00:00:00.000000Z: 2816.290000
# 2021-04-27T00:00:00.000000Z: 3114.560000
# 2021-04-28T00:00:00.000000Z: 3208.980000
# 2021-04-29T00:00:00.000000Z: 3218.810000
# 2021-04-30T00:00:00.000000Z: 3186.990000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 104    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# binancecoin
# ripple
# dogecoin
# cardano
# wink
# vechain
# tron
# litecoin
# polkadot
# bittorrent-old
# chiliz
# eos
# pancakeswap-token
# holotoken
# swipe
# filecoin
# chainlink
# bitcoin-cash
# dent
# stellar
# theta-token
# solana
# uniswap
# neo
# enjincoin
# ontology
# terra-luna
# ethereum-classic
# harmony
# iostoken
# cosmos
# aave
# avalanche-2
# elrond-erd-2
# matic-network
# siacoin
# qtum
# zcash
# iota
# wazirx
# monero
# sushi
# dash
# algorand
# tezos
# thorchain
# the-graph
# nkn
# zilliqa
# curve-dao-token
# nem
# omisego
# reef
# ankr
# 1inch
# hedera-hashgraph
# decentraland
# serum
# mithril
# ftx-token
# sun-token
# venus
# yearn-finance
# origin-protocol
# basic-attention-token
# fantom
# storm
# kusama
# reserve-rights-token
# band-protocol
# ravencoin
# coti
# theta-fuel
# verge
# alpha-finance
# chromaway
# icon
# compound-governance-token
# waves
# paris-saint-germain-fan-token
# storj
# fetch-ai
# celer-network
# btc-standard-hashrate-token
# dodo
# zencash
# safepal
# the-sandbox
# digibyte
# wrapped-bitcoin
# near
# vethor-token
# linear
# 0x
# audius
# republic-protocol
# axie-infinity
# litentry
# my-neighbor-alice
# kava
# cartesi
# maker
# metal
# flamingo-finance
# havven
# gifto
# vite
# kyber-network-crystal
# just
# ocean-protocol
# dia-data
# tellor
# nano
# tomochain
# akropolis
# loopring
# 2021-05-01T00:00:00.000000Z: 3379.040000
# 2021-05-02T00:00:00.000000Z: 3441.710000
# 2021-05-03T00:00:00.000000Z: 3386.250000
# 2021-05-04T00:00:00.000000Z: 3551.750000
# 2021-05-05T00:00:00.000000Z: 3344.840000
# 2021-05-06T00:00:00.000000Z: 3672.150000
# 2021-05-07T00:00:00.000000Z: 3617.930000
# 2021-05-08T00:00:00.000000Z: 3661.920000
# 2021-05-09T00:00:00.000000Z: 3800.900000
# 2021-05-10T00:00:00.000000Z: 3787.090000
# 2021-05-11T00:00:00.000000Z: 3621.130000
# 2021-05-12T00:00:00.000000Z: 3761.290000
# 2021-05-13T00:00:00.000000Z: 3314.030000
# 2021-05-14T00:00:00.000000Z: 3356.610000
# 2021-05-15T00:00:00.000000Z: 3498.030000
# 2021-05-16T00:00:00.000000Z: 3265.580000
# 2021-05-17T00:00:00.000000Z: 3243.570000
# 2021-05-18T00:00:00.000000Z: 3020.840000
# 2021-05-19T00:00:00.000000Z: 3031.940000
# 2021-05-20T00:00:00.000000Z: 2344.930000
# 2021-05-21T00:00:00.000000Z: 2645.200000
# 2021-05-22T00:00:00.000000Z: 2365.650000
# 2021-05-23T00:00:00.000000Z: 2304.860000
# 2021-05-24T00:00:00.000000Z: 2100.890000
# 2021-05-25T00:00:00.000000Z: 2478.690000
# 2021-05-26T00:00:00.000000Z: 2464.990000
# 2021-05-27T00:00:00.000000Z: 2588.140000
# 2021-05-28T00:00:00.000000Z: 2506.150000
# 2021-05-29T00:00:00.000000Z: 2282.330000
# 2021-05-30T00:00:00.000000Z: 2182.470000
# 2021-05-31T00:00:00.000000Z: 2271.650000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 71    AUD
# Name: baseAsset, dtype: object
# ethereum
# bitcoin
# dogecoin
# binancecoin
# ripple
# cardano
# matic-network
# polkadot
# ethereum-classic
# eos
# litecoin
# chainlink
# vechain
# bitcoin-cash
# tron
# pancakeswap-token
# solana
# stellar
# swipe
# uniswap
# theta-token
# chiliz
# bakerytoken
# terra-luna
# sushi
# filecoin
# aave
# neo
# bittorrent-old
# venus
# zcash
# thorchain
# ontology
# fantom
# avalanche-2
# yearn-finance
# cosmos
# qtum
# reef
# omisego
# monero
# holotoken
# dash
# wink
# kusama
# iexec-rlc
# enjincoin
# tezos
# dent
# curve-dao-token
# waves
# alien-worlds
# zilliqa
# harmony
# iota
# algorand
# hedera-hashgraph
# 1inch
# my-neighbor-alice
# compound-governance-token
# iostoken
# the-graph
# elrond-erd-2
# serum
# cartesi
# wrapped-bitcoin
# nano
# maker
# zencash
# havven
# decentraland
# wazirx
# nem
# coti
# smooth-love-potion
# siacoin
# near
# kava
# chromaway
# theta-fuel
# tokocrypto
# alpha-finance
# 2021-06-01T00:00:00.000000Z: 2452.410000
# 2021-06-02T00:00:00.000000Z: 2423.940000
# 2021-06-03T00:00:00.000000Z: 2505.090000
# 2021-06-04T00:00:00.000000Z: 2618.920000
# 2021-06-05T00:00:00.000000Z: 2449.430000
# 2021-06-06T00:00:00.000000Z: 2376.910000
# 2021-06-07T00:00:00.000000Z: 2412.770000
# 2021-06-08T00:00:00.000000Z: 2257.620000
# 2021-06-09T00:00:00.000000Z: 2232.310000
# 2021-06-10T00:00:00.000000Z: 2422.590000
# 2021-06-11T00:00:00.000000Z: 2336.560000
# 2021-06-12T00:00:00.000000Z: 2309.720000
# 2021-06-13T00:00:00.000000Z: 2249.890000
# 2021-06-14T00:00:00.000000Z: 2430.420000
# 2021-06-15T00:00:00.000000Z: 2513.660000
# 2021-06-16T00:00:00.000000Z: 2479.790000
# 2021-06-17T00:00:00.000000Z: 2356.780000
# 2021-06-18T00:00:00.000000Z: 2351.520000
# 2021-06-19T00:00:00.000000Z: 2215.630000
# 2021-06-20T00:00:00.000000Z: 2174.540000
# 2021-06-21T00:00:00.000000Z: 2203.060000
# 2021-06-22T00:00:00.000000Z: 1875.250000
# 2021-06-23T00:00:00.000000Z: 1895.660000
# 2021-06-24T00:00:00.000000Z: 2000.360000
# 2021-06-25T00:00:00.000000Z: 2064.010000
# 2021-06-26T00:00:00.000000Z: 1878.300000
# 2021-06-27T00:00:00.000000Z: 1911.250000
# 2021-06-28T00:00:00.000000Z: 2049.950000
# 2021-06-29T00:00:00.000000Z: 2066.600000
# 2021-06-30T00:00:00.000000Z: 2155.440000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 46    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# binancecoin
# cardano
# matic-network
# dogecoin
# ripple
# polkadot
# solana
# vechain
# chainlink
# shiba-inu
# litecoin
# theta-fuel
# theta-token
# filecoin
# ethereum-classic
# eos
# tron
# pancakeswap-token
# kusama
# chiliz
# internet-computer
# swipe
# thorchain
# terra-luna
# bakerytoken
# bitcoin-cash
# aave
# uniswap
# stellar
# sushi
# monero
# fantom
# neo
# bittorrent-old
# waves
# enjincoin
# curve-dao-token
# cosmos
# zcash
# kava
# zilliqa
# 1inch
# wink
# holotoken
# avalanche-2
# omisego
# streamr
# dash
# ontology
# hedera-hashgraph
# yearn-finance
# algorand
# the-graph
# venus
# wazirx
# iota
# dexe
# dent
# elrond-erd-2
# 2021-07-01T00:00:00.000000Z: 2150.110000
# 2021-07-02T00:00:00.000000Z: 2034.350000
# 2021-07-03T00:00:00.000000Z: 2058.660000
# 2021-07-04T00:00:00.000000Z: 2114.670000
# 2021-07-05T00:00:00.000000Z: 2167.750000
# 2021-07-06T00:00:00.000000Z: 2066.310000
# 2021-07-07T00:00:00.000000Z: 2125.940000
# 2021-07-08T00:00:00.000000Z: 2111.910000
# 2021-07-09T00:00:00.000000Z: 2006.370000
# 2021-07-10T00:00:00.000000Z: 2055.330000
# 2021-07-11T00:00:00.000000Z: 2029.070000
# 2021-07-12T00:00:00.000000Z: 2067.130000
# 2021-07-13T00:00:00.000000Z: 1990.590000
# 2021-07-14T00:00:00.000000Z: 1945.800000
# 2021-07-15T00:00:00.000000Z: 1959.200000
# 2021-07-16T00:00:00.000000Z: 1898.580000
# 2021-07-17T00:00:00.000000Z: 1852.740000
# 2021-07-18T00:00:00.000000Z: 1864.990000
# 2021-07-19T00:00:00.000000Z: 1873.120000
# 2021-07-20T00:00:00.000000Z: 1802.620000
# 2021-07-21T00:00:00.000000Z: 1741.140000
# 2021-07-22T00:00:00.000000Z: 1905.910000
# 2021-07-23T00:00:00.000000Z: 1926.480000
# 2021-07-24T00:00:00.000000Z: 2004.070000
# 2021-07-25T00:00:00.000000Z: 2045.590000
# 2021-07-26T00:00:00.000000Z: 2085.530000
# 2021-07-27T00:00:00.000000Z: 2164.130000
# 2021-07-28T00:00:00.000000Z: 2266.800000
# 2021-07-29T00:00:00.000000Z: 2294.600000
# 2021-07-30T00:00:00.000000Z: 2319.410000
# 2021-07-31T00:00:00.000000Z: 2422.400000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 59    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# binancecoin
# axie-infinity
# dogecoin
# cardano
# ripple
# polkadot
# matic-network
# alien-worlds
# solana
# chainlink
# ethereum-classic
# theta-token
# litecoin
# my-neighbor-alice
# vechain
# terra-luna
# eos
# internet-computer
# the-sandbox
# shiba-inu
# filecoin
# aave
# pancakeswap-token
# smooth-love-potion
# tron
# uniswap
# thorchain
# chromaway
# chiliz
# bitcoin-cash
# enjincoin
# bakerytoken
# sushi
# compound-governance-token
# swipe
# cosmos
# stellar
# theta-fuel
# kusama
# havven
# monero
# decentraland
# neo
# dexe
# zcash
# the-graph
# alpha-finance
# linear
# bittorrent-old
# omisego
# kava
# fetch-ai
# ontology
# elrond-erd-2
# waves
# fantom
# mdex
# iostoken
# dash
# curve-dao-token
# holotoken
# dodo
# yearn-finance
# origin-protocol
# ellipsis
# hedera-hashgraph
# tezos
# ftx-token
# superfarm
# 1inch
# harmony
# audius
# algorand
# zilliqa
# the-virtua-kolect
# near
# wink
# unifi-protocol-dao
# avalanche-2
# iota
# sun-token
# litentry
# blockstack
# dent
# nem
# dego-finance
# wrapped-bitcoin
# tomochain
# 2021-08-01T00:00:00.000000Z: 2419.970000
# 2021-08-02T00:00:00.000000Z: 2365.800000
# 2021-08-03T00:00:00.000000Z: 2353.680000
# 2021-08-04T00:00:00.000000Z: 2295.230000
# 2021-08-05T00:00:00.000000Z: 2408.770000
# 2021-08-06T00:00:00.000000Z: 2474.680000
# 2021-08-07T00:00:00.000000Z: 2566.870000
# 2021-08-08T00:00:00.000000Z: 2720.710000
# 2021-08-09T00:00:00.000000Z: 2636.760000
# 2021-08-10T00:00:00.000000Z: 2776.810000
# 2021-08-11T00:00:00.000000Z: 2771.470000
# 2021-08-12T00:00:00.000000Z: 2808.150000
# 2021-08-13T00:00:00.000000Z: 2737.070000
# 2021-08-14T00:00:00.000000Z: 2972.880000
# 2021-08-15T00:00:00.000000Z: 2954.970000
# 2021-08-16T00:00:00.000000Z: 2981.640000
# 2021-08-17T00:00:00.000000Z: 2893.240000
# 2021-08-18T00:00:00.000000Z: 2788.240000
# 2021-08-19T00:00:00.000000Z: 2806.770000
# 2021-08-20T00:00:00.000000Z: 2968.060000
# 2021-08-21T00:00:00.000000Z: 3102.950000
# 2021-08-22T00:00:00.000000Z: 3057.210000
# 2021-08-23T00:00:00.000000Z: 3091.670000
# 2021-08-24T00:00:00.000000Z: 3150.540000
# 2021-08-25T00:00:00.000000Z: 3001.080000
# 2021-08-26T00:00:00.000000Z: 3078.070000
# 2021-08-27T00:00:00.000000Z: 2930.030000
# 2021-08-28T00:00:00.000000Z: 3111.160000
# 2021-08-29T00:00:00.000000Z: 3086.770000
# 2021-08-30T00:00:00.000000Z: 3072.790000
# 2021-08-31T00:00:00.000000Z: 2998.720000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 89    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# cardano
# binancecoin
# ripple
# dogecoin
# polkadot
# solana
# axie-infinity
# matic-network
# terra-luna
# chainlink
# filecoin
# internet-computer
# vechain
# my-neighbor-alice
# litecoin
# ethereum-classic
# eos
# alien-worlds
# coin98
# theta-token
# thorchain
# pancakeswap-token
# tron
# chiliz
# shiba-inu
# uniswap
# avalanche-2
# bitcoin-cash
# bakerytoken
# sushi
# smooth-love-potion
# kava
# fantom
# dent
# aave
# the-graph
# swipe
# cosmos
# stellar
# bittorrent-old
# neo
# ftx-token
# the-sandbox
# qtum
# enjincoin
# kusama
# chromaway
# holotoken
# iotex
# audius
# algorand
# monero
# wink
# elrond-erd-2
# near
# coti
# curve-dao-token
# omisego
# ellipsis
# dash
# tezos
# serum
# 1inch
# decentraland
# zcash
# linear
# compound-governance-token
# ravencoin
# alpha-finance
# ontology
# superfarm
# zilliqa
# reef
# havven
# truefi
# dodo
# venus
# iostoken
# paris-saint-germain-fan-token
# dego-finance
# origin-protocol
# iota
# the-virtua-kolect
# harmony
# fetch-ai
# hedera-hashgraph
# reserve-rights-token
# waves
# yearn-finance
# helium
# siacoin
# trust-wallet-token
# litentry
# unifi-protocol-dao
# theta-fuel
# tokocrypto
# perpetual-protocol
# cartesi
# automata
# funfair
# certik
# clover-finance
# wazirx
# ankr
# arweave
# verge
# ocean-protocol
# wrapped-bitcoin
# skale
# mask-network
# stafi
# celer-network
# iexec-rlc
# 2021-09-01T00:00:00.000000Z: 3071.490000
# 2021-09-02T00:00:00.000000Z: 3249.550000
# 2021-09-03T00:00:00.000000Z: 3266.940000
# 2021-09-04T00:00:00.000000Z: 3347.600000
# 2021-09-05T00:00:00.000000Z: 3325.430000
# 2021-09-06T00:00:00.000000Z: 3432.550000
# 2021-09-07T00:00:00.000000Z: 3466.740000
# 2021-09-08T00:00:00.000000Z: 3050.100000
# 2021-09-09T00:00:00.000000Z: 3037.500000
# 2021-09-10T00:00:00.000000Z: 3040.300000
# 2021-09-11T00:00:00.000000Z: 2919.680000
# 2021-09-12T00:00:00.000000Z: 2964.490000
# 2021-09-13T00:00:00.000000Z: 3038.190000
# 2021-09-14T00:00:00.000000Z: 2939.900000
# 2021-09-15T00:00:00.000000Z: 3060.960000
# 2021-09-16T00:00:00.000000Z: 3152.760000
# 2021-09-17T00:00:00.000000Z: 3110.060000
# 2021-09-18T00:00:00.000000Z: 3033.910000
# 2021-09-19T00:00:00.000000Z: 3095.320000
# 2021-09-20T00:00:00.000000Z: 3010.880000
# 2021-09-21T00:00:00.000000Z: 2709.910000
# 2021-09-22T00:00:00.000000Z: 2552.200000
# 2021-09-23T00:00:00.000000Z: 2796.320000
# 2021-09-24T00:00:00.000000Z: 2870.810000
# 2021-09-25T00:00:00.000000Z: 2716.770000
# 2021-09-26T00:00:00.000000Z: 2705.500000
# 2021-09-27T00:00:00.000000Z: 2743.420000
# 2021-09-28T00:00:00.000000Z: 2664.900000
# 2021-09-29T00:00:00.000000Z: 2581.940000
# 2021-09-30T00:00:00.000000Z: 2630.620000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 91    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# solana
# cardano
# binancecoin
# polkadot
# ripple
# avalanche-2
# terra-luna
# fantom
# filecoin
# dogecoin
# chainlink
# cosmos
# ftx-token
# matic-network
# algorand
# litecoin
# vechain
# eos
# tron
# omisego
# celer-network
# near
# axie-infinity
# tezos
# theta-token
# internet-computer
# harmony
# elrond-erd-2
# serum
# pancakeswap-token
# hedera-hashgraph
# coin98
# aurora-dao
# iostoken
# ethereum-classic
# sushi
# uniswap
# ecash
# my-neighbor-alice
# coti
# bitcoin-cash
# smooth-love-potion
# shiba-inu
# curve-dao-token
# chiliz
# aave
# swipe
# mina-protocol
# iota
# thorchain
# alien-worlds
# fetch-ai
# kusama
# celo
# stellar
# kava
# the-graph
# arweave
# automata
# oasis-network
# mobox
# bittorrent-old
# monero
# quant-network
# neo
# audius
# raydium
# trust-wallet-token
# the-sandbox
# dent
# 1inch
# waves
# marlin
# zilliqa
# chromaway
# qtum
# holotoken
# dash
# zcash
# ellipsis
# reef
# havven
# bakerytoken
# ontology
# mask-network
# compound-governance-token
# icon
# republic-protocol
# origin-protocol
# funfair
# perpetual-protocol
# iotex
# enjincoin
# venus
# arpa-chain
# dodo
# yearn-finance
# v-id-blockchain
# decentraland
# reserve-rights-token
# force-protocol
# wink
# ravencoin
# alpha-finance
# dexe
# skale
# injective-protocol
# tokocrypto
# wrapped-bitcoin
# theta-fuel
# siacoin
# linear
# aelf
# zencash
# superfarm
# cartesi
# civic
# loopring
# litentry
# 2021-10-01T00:00:00.000000Z: 2766.320000
# 2021-10-02T00:00:00.000000Z: 3032.430000
# 2021-10-03T00:00:00.000000Z: 3040.340000
# 2021-10-04T00:00:00.000000Z: 3075.980000
# 2021-10-05T00:00:00.000000Z: 3095.940000
# 2021-10-06T00:00:00.000000Z: 3212.220000
# 2021-10-07T00:00:00.000000Z: 3342.360000
# 2021-10-08T00:00:00.000000Z: 3303.470000
# 2021-10-09T00:00:00.000000Z: 3292.260000
# 2021-10-10T00:00:00.000000Z: 3346.140000
# 2021-10-11T00:00:00.000000Z: 3267.750000
# 2021-10-12T00:00:00.000000Z: 3389.570000
# 2021-10-13T00:00:00.000000Z: 3333.700000
# 2021-10-14T00:00:00.000000Z: 3433.040000
# 2021-10-15T00:00:00.000000Z: 3473.530000
# 2021-10-16T00:00:00.000000Z: 3653.080000
# 2021-10-17T00:00:00.000000Z: 3609.010000
# 2021-10-18T00:00:00.000000Z: 3629.810000
# 2021-10-19T00:00:00.000000Z: 3623.170000
# 2021-10-20T00:00:00.000000Z: 3731.890000
# 2021-10-21T00:00:00.000000Z: 3893.140000
# 2021-10-22T00:00:00.000000Z: 3722.840000
# 2021-10-23T00:00:00.000000Z: 3666.370000
# 2021-10-24T00:00:00.000000Z: 3738.460000
# 2021-10-25T00:00:00.000000Z: 3698.080000
# 2021-10-26T00:00:00.000000Z: 3823.130000
# 2021-10-27T00:00:00.000000Z: 3707.010000
# 2021-10-28T00:00:00.000000Z: 3526.020000
# 2021-10-29T00:00:00.000000Z: 3728.660000
# 2021-10-30T00:00:00.000000Z: 3837.920000
# 2021-10-31T00:00:00.000000Z: 3783.740000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 70    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# shiba-inu
# solana
# binancecoin
# polkadot
# ripple
# fantom
# dogecoin
# cardano
# terra-luna
# filecoin
# axie-infinity
# avalanche-2
# chainlink
# matic-network
# tron
# litecoin
# cosmos
# omisego
# vechain
# harmony
# smooth-love-potion
# dydx
# eos
# internet-computer
# ftx-token
# theta-token
# near
# algorand
# gala
# stellar
# ethereum-classic
# celer-network
# pancakeswap-token
# uniswap
# tezos
# bitcoin-cash
# elrond-erd-2
# coti
# chiliz
# kava
# coin98
# sushi
# curve-dao-token
# thorchain
# 1inch
# swipe
# hedera-hashgraph
# bittorrent-old
# my-neighbor-alice
# fetch-ai
# the-graph
# serum
# wink
# iota
# btc-standard-hashrate-token
# dent
# holotoken
# monero
# aave
# ecash
# reef
# alien-worlds
# zcash
# celo
# ontology
# iostoken
# arpa-chain
# qtum
# mina-protocol
# kusama
# oasis-network
# zilliqa
# enjincoin
# arweave
# flow
# compound-governance-token
# dash
# bakerytoken
# linear
# mobox
# neo
# aurora-dao
# the-sandbox
# wrapped-bitcoin
# automata
# iotex
# ellipsis
# waves
# dodo
# wax
# cartesi
# yearn-finance
# superfarm
# chromaway
# trust-wallet-token
# marlin
# mask-network
# 2021-11-01T00:00:00.000000Z: 3766.920000
# 2021-11-02T00:00:00.000000Z: 3785.500000
# 2021-11-03T00:00:00.000000Z: 3938.140000
# 2021-11-04T00:00:00.000000Z: 3953.840000
# 2021-11-05T00:00:00.000000Z: 3877.130000
# 2021-11-06T00:00:00.000000Z: 3860.580000
# 2021-11-07T00:00:00.000000Z: 3906.670000
# 2021-11-08T00:00:00.000000Z: 3996.240000
# 2021-11-09T00:00:00.000000Z: 4207.010000
# 2021-11-10T00:00:00.000000Z: 4162.210000
# 2021-11-11T00:00:00.000000Z: 4026.390000
# 2021-11-12T00:00:00.000000Z: 4059.530000
# 2021-11-13T00:00:00.000000Z: 4009.430000
# 2021-11-14T00:00:00.000000Z: 4035.700000
# 2021-11-15T00:00:00.000000Z: 4069.140000
# 2021-11-16T00:00:00.000000Z: 3972.410000
# 2021-11-17T00:00:00.000000Z: 3711.560000
# 2021-11-18T00:00:00.000000Z: 3741.160000
# 2021-11-19T00:00:00.000000Z: 3503.280000
# 2021-11-20T00:00:00.000000Z: 3660.480000
# 2021-11-21T00:00:00.000000Z: 3761.960000
# 2021-11-22T00:00:00.000000Z: 3679.930000
# 2021-11-23T00:00:00.000000Z: 3533.500000
# 2021-11-24T00:00:00.000000Z: 3646.050000
# 2021-11-25T00:00:00.000000Z: 3582.710000
# 2021-11-26T00:00:00.000000Z: 3730.250000
# 2021-11-27T00:00:00.000000Z: 3378.420000
# 2021-11-28T00:00:00.000000Z: 3436.750000
# 2021-11-29T00:00:00.000000Z: 3582.680000
# 2021-11-30T00:00:00.000000Z: 3654.690000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 76    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# shiba-inu
# the-sandbox
# binancecoin
# decentraland
# solana
# polkadot
# avalanche-2
# ripple
# tron
# gala
# cardano
# dogecoin
# loopring
# fantom
# litecoin
# terra-luna
# filecoin
# omisego
# chiliz
# chainlink
# matic-network
# vechain
# chromaway
# enjincoin
# alien-worlds
# axie-infinity
# smooth-love-potion
# my-neighbor-alice
# iotex
# elrond-erd-2
# internet-computer
# harmony
# theta-token
# cosmos
# zcash
# wax
# algorand
# dydx
# eos
# curve-dao-token
# holotoken
# pancakeswap-token
# near
# ethereum-classic
# the-graph
# oasis-network
# stellar
# wink
# bitcoin-cash
# ftx-token
# bittorrent-old
# arweave
# swipe
# sushi
# thorchain
# basic-attention-token
# uniswap
# celer-network
# ankr
# mina-protocol
# aave
# just
# dent
# dash
# tezos
# 1inch
# monero
# mobox
# hedera-hashgraph
# cartesi
# fetch-ai
# iota
# coti
# the-virtua-kolect
# arpa-chain
# storj
# qtum
# mask-network
# sun-token
# zencash
# kava
# audius
# superfarm
# reef
# livepeer
# helium
# flow
# kusama
# ontology
# linear
# beta-finance
# automata
# origin-protocol
# coin98
# serum
# keep3rv1
# aurora-dao
# bakerytoken
# ecash
# iostoken
# zilliqa
# icon
# siacoin
# keep-network
# yield-guild-games
# trust-wallet-token
# compound-governance-token
# neo
# ocean-protocol
# skale
# marlin
# ravencoin
# celo
# lto-network
# nucypher
# reserve-rights-token
# syscoin
# nervos-network
# havven
# blockstack
# wrapped-bitcoin
# quant-network
# nkn
# dodo
# 2021-12-01T00:00:00.000000Z: 3676.150000
# 2021-12-02T00:00:00.000000Z: 3682.560000
# 2021-12-03T00:00:00.000000Z: 3643.560000
# 2021-12-04T00:00:00.000000Z: 3438.830000
# 2021-12-05T00:00:00.000000Z: 3218.770000
# 2021-12-06T00:00:00.000000Z: 3219.050000
# 2021-12-07T00:00:00.000000Z: 3302.280000
# 2021-12-08T00:00:00.000000Z: 3295.450000
# 2021-12-09T00:00:00.000000Z: 3342.530000
# 2021-12-10T00:00:00.000000Z: 3126.260000
# 2021-12-11T00:00:00.000000Z: 3036.170000
# 2021-12-12T00:00:00.000000Z: 3178.750000
# 2021-12-13T00:00:00.000000Z: 3219.440000
# 2021-12-14T00:00:00.000000Z: 2969.730000
# 2021-12-15T00:00:00.000000Z: 3070.600000
# 2021-12-16T00:00:00.000000Z: 3146.360000
# 2021-12-17T00:00:00.000000Z: 3074.820000
# 2021-12-18T00:00:00.000000Z: 3003.560000
# 2021-12-19T00:00:00.000000Z: 3067.600000
# 2021-12-20T00:00:00.000000Z: 3049.910000
# 2021-12-21T00:00:00.000000Z: 3063.820000
# 2021-12-22T00:00:00.000000Z: 3170.760000
# 2021-12-23T00:00:00.000000Z: 3160.430000
# 2021-12-24T00:00:00.000000Z: 3307.920000
# 2021-12-25T00:00:00.000000Z: 3273.700000
# 2021-12-26T00:00:00.000000Z: 3283.050000
# 2021-12-27T00:00:00.000000Z: 3297.430000
# 2021-12-28T00:00:00.000000Z: 3290.770000
# 2021-12-29T00:00:00.000000Z: 3077.510000
# 2021-12-30T00:00:00.000000Z: 2983.120000
# 2021-12-31T00:00:00.000000Z: 3030.170000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 77    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# terra-luna
# binancecoin
# matic-network
# solana
# the-sandbox
# shiba-inu
# avalanche-2
# gala
# polkadot
# ripple
# cardano
# decentraland
# dogecoin
# fantom
# chainlink
# near
# tron
# filecoin
# litecoin
# curve-dao-token
# cosmos
# oasis-network
# vechain
# elrond-erd-2
# sushi
# axie-infinity
# internet-computer
# loopring
# eos
# theta-token
# omisego
# algorand
# harmony
# my-neighbor-alice
# enjincoin
# bittorrent-old
# mobox
# dydx
# chromaway
# stellar
# uniswap
# pancakeswap-token
# alien-worlds
# zcash
# smooth-love-potion
# chiliz
# mines-of-dalarnia
# gxchain
# aave
# ethereum-name-service
# wink
# tezos
# bitcoin-cash
# basic-attention-token
# iotex
# aragon
# the-graph
# just
# dusk-network
# sun-token
# ethereum-classic
# thorchain
# cortex
# contentos
# iota
# monero
# kava
# holotoken
# 1inch
# measurable-data-token
# celer-network
# vulcan-forged
# arweave
# yearn-finance
# ftx-token
# gitcoin
# cocos-bcx
# safepal
# hedera-hashgraph
# wax
# syscoin
# swipe
# coti
# lto-network
# mina-protocol
# jasmycoin
# zilliqa
# celo
# helium
# dash
# dent
# reserve-rights-token
# nuls
# superfarm
# coin98
# mask-network
# flow
# ocean-protocol
# ankr
# waves
# serum
# neo
# icon
# yield-guild-games
# reef
# audius
# request-network
# theta-fuel
# havven
# mithril
# compound-governance-token
# render-token
# iostoken
# quant-network
# marlin
# linear
# zencash
# qtum
# 2022-01-01T00:00:00.000000Z: 2986.170000
# 2022-01-02T00:00:00.000000Z: 3083.140000
# 2022-01-03T00:00:00.000000Z: 3082.060000
# 2022-01-04T00:00:00.000000Z: 3020.620000
# 2022-01-05T00:00:00.000000Z: 2990.350000
# 2022-01-06T00:00:00.000000Z: 2815.320000
# 2022-01-07T00:00:00.000000Z: 2776.050000
# 2022-01-08T00:00:00.000000Z: 2642.050000
# 2022-01-09T00:00:00.000000Z: 2608.290000
# 2022-01-10T00:00:00.000000Z: 2641.970000
# 2022-01-11T00:00:00.000000Z: 2603.880000
# 2022-01-12T00:00:00.000000Z: 2703.430000
# 2022-01-13T00:00:00.000000Z: 2812.440000
# 2022-01-14T00:00:00.000000Z: 2716.240000
# 2022-01-15T00:00:00.000000Z: 2766.950000
# 2022-01-16T00:00:00.000000Z: 2779.810000
# 2022-01-17T00:00:00.000000Z: 2788.990000
# 2022-01-18T00:00:00.000000Z: 2712.630000
# 2022-01-19T00:00:00.000000Z: 2694.230000
# 2022-01-20T00:00:00.000000Z: 2634.450000
# 2022-01-21T00:00:00.000000Z: 2557.870000
# 2022-01-22T00:00:00.000000Z: 2252.270000
# 2022-01-23T00:00:00.000000Z: 2136.860000
# 2022-01-24T00:00:00.000000Z: 2232.140000
# 2022-01-25T00:00:00.000000Z: 2203.730000
# 2022-01-26T00:00:00.000000Z: 2224.610000
# 2022-01-27T00:00:00.000000Z: 2214.810000
# 2022-01-28T00:00:00.000000Z: 2214.900000
# 2022-01-29T00:00:00.000000Z: 2259.650000
# 2022-01-30T00:00:00.000000Z: 2295.860000
# 2022-01-31T00:00:00.000000Z: 2269.850000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 75    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# terra-luna
# fantom
# binancecoin
# solana
# cosmos
# cardano
# matic-network
# polkadot
# near
# the-sandbox
# shiba-inu
# ripple
# chainlink
# avalanche-2
# dogecoin
# oasis-network
# gala
# harmony
# tron
# curve-dao-token
# decentraland
# internet-computer
# litecoin
# filecoin
# loopring
# axie-infinity
# vechain
# dusk-network
# sushi
# theta-token
# algorand
# chromaway
# ftx-token
# elrond-erd-2
# omisego
# aave
# enjincoin
# aragon
# kava
# eos
# pancakeswap-token
# uniswap
# wink
# dydx
# monero
# my-neighbor-alice
# stellar
# swipe
# yearn-finance
# sun-token
# just
# zcash
# arweave
# thorchain
# ethereum-classic
# keep3rv1
# chiliz
# celer-network
# syscoin
# constitutiondao
# bitcoin-cash
# smooth-love-potion
# the-graph
# tezos
# alien-worlds
# ethereum-name-service
# iota
# celo
# mina-protocol
# hedera-hashgraph
# zelcash
# 1inch
# gxchain
# basic-attention-token
# coti
# secret
# flow
# dash
# helium
# ravencoin
# vulcan-forged
# iotex
# voxies
# spell-token
# zilliqa
# klay-token
# holotoken
# dent
# wax
# mobox
# mines-of-dalarnia
# havven
# biconomy
# gitcoin
# jasmycoin
# anyswap
# ocean-protocol
# wrapped-bitcoin
# yield-guild-games
# linear
# coin98
# neo
# fetch-ai
# quant-network
# render-token
# 2022-02-01T00:00:00.000000Z: 2320.460000
# 2022-02-02T00:00:00.000000Z: 2363.850000
# 2022-02-03T00:00:00.000000Z: 2253.140000
# 2022-02-04T00:00:00.000000Z: 2280.270000
# 2022-02-05T00:00:00.000000Z: 2523.000000
# 2022-02-06T00:00:00.000000Z: 2527.530000
# 2022-02-07T00:00:00.000000Z: 2586.220000
# 2022-02-08T00:00:00.000000Z: 2689.070000
# 2022-02-09T00:00:00.000000Z: 2675.480000
# 2022-02-10T00:00:00.000000Z: 2724.690000
# 2022-02-11T00:00:00.000000Z: 2632.460000
# 2022-02-12T00:00:00.000000Z: 2528.340000
# 2022-02-13T00:00:00.000000Z: 2527.250000
# 2022-02-14T00:00:00.000000Z: 2504.250000
# 2022-02-15T00:00:00.000000Z: 2538.390000
# 2022-02-16T00:00:00.000000Z: 2696.700000
# 2022-02-17T00:00:00.000000Z: 2653.390000
# 2022-02-18T00:00:00.000000Z: 2453.720000
# 2022-02-19T00:00:00.000000Z: 2405.430000
# 2022-02-20T00:00:00.000000Z: 2410.600000
# 2022-02-21T00:00:00.000000Z: 2299.790000
# 2022-02-22T00:00:00.000000Z: 2209.300000
# 2022-02-23T00:00:00.000000Z: 2283.980000
# 2022-02-24T00:00:00.000000Z: 2232.530000
# 2022-02-25T00:00:00.000000Z: 2275.270000
# 2022-02-26T00:00:00.000000Z: 2370.370000
# 2022-02-27T00:00:00.000000Z: 2371.750000
# 2022-02-28T00:00:00.000000Z: 2266.580000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 69    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# terra-luna
# binancecoin
# ripple
# shiba-inu
# solana
# gala
# avalanche-2
# cardano
# fantom
# the-sandbox
# smooth-love-potion
# polkadot
# decentraland
# matic-network
# cosmos
# dogecoin
# tron
# chainlink
# near
# constitutiondao
# litecoin
# oasis-network
# axie-infinity
# filecoin
# internet-computer
# harmony
# theta-token
# vechain
# elrond-erd-2
# ethereum-classic
# curve-dao-token
# my-neighbor-alice
# loopring
# algorand
# eos
# enjincoin
# dydx
# beta-finance
# bitcoin-cash
# zcash
# ftx-token
# monero
# tezos
# alien-worlds
# mines-of-dalarnia
# uniswap
# chromaway
# kava
# jasmycoin
# wink
# pancakeswap-token
# omisego
# chiliz
# sushi
# aave
# stellar
# waves
# aurora-dao
# arweave
# neo
# flow
# vulcan-forged
# the-graph
# hedera-hashgraph
# just
# league-of-kingdoms
# sun-token
# aragon
# immutable-x
# thorchain
# mina-protocol
# render-token
# dusk-network
# moonbeam
# swipe
# mobox
# bittorrent
# ethereum-name-service
# api3
# syscoin
# quant-network
# celer-network
# ooki
# spell-token
# celo
# kyber-network-crystal
# dash
# voxies
# coti
# klay-token
# iotex
# anchor-protocol
# dent
# holotoken
# qtum
# keep3rv1
# helium
# iota
# 2022-03-01T00:00:00.000000Z: 2569.960000
# 2022-03-02T00:00:00.000000Z: 2627.830000
# 2022-03-03T00:00:00.000000Z: 2601.740000
# 2022-03-04T00:00:00.000000Z: 2516.640000
# 2022-03-05T00:00:00.000000Z: 2328.080000
# 2022-03-06T00:00:00.000000Z: 2360.490000
# 2022-03-07T00:00:00.000000Z: 2281.080000
# 2022-03-08T00:00:00.000000Z: 2247.580000
# 2022-03-09T00:00:00.000000Z: 2298.310000
# 2022-03-10T00:00:00.000000Z: 2466.590000
# 2022-03-11T00:00:00.000000Z: 2337.380000
# 2022-03-12T00:00:00.000000Z: 2297.800000
# 2022-03-13T00:00:00.000000Z: 2301.070000
# 2022-03-14T00:00:00.000000Z: 2243.790000
# 2022-03-15T00:00:00.000000Z: 2337.320000
# 2022-03-16T00:00:00.000000Z: 2325.780000
# 2022-03-17T00:00:00.000000Z: 2439.740000
# 2022-03-18T00:00:00.000000Z: 2441.860000
# 2022-03-19T00:00:00.000000Z: 2506.180000
# 2022-03-20T00:00:00.000000Z: 2539.030000
# 2022-03-21T00:00:00.000000Z: 2473.980000
# 2022-03-22T00:00:00.000000Z: 2481.960000
# 2022-03-23T00:00:00.000000Z: 2553.040000
# 2022-03-24T00:00:00.000000Z: 2602.340000
# 2022-03-25T00:00:00.000000Z: 2666.460000
# 2022-03-26T00:00:00.000000Z: 2659.810000
# 2022-03-27T00:00:00.000000Z: 2687.260000
# 2022-03-28T00:00:00.000000Z: 2818.530000
# 2022-03-29T00:00:00.000000Z: 2835.350000
# 2022-03-30T00:00:00.000000Z: 2877.100000
# 2022-03-31T00:00:00.000000Z: 2868.870000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 68    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# terra-luna
# binancecoin
# solana
# ripple
# avalanche-2
# fantom
# shiba-inu
# gala
# cardano
# polkadot
# thorchain
# jasmycoin
# near
# cosmos
# the-sandbox
# matic-network
# waves
# tron
# chainlink
# smooth-love-potion
# dogecoin
# decentraland
# litecoin
# vechain
# constitutiondao
# oasis-network
# elrond-erd-2
# immutable-x
# moviebloc
# internet-computer
# axie-infinity
# zcash
# ethereum-classic
# filecoin
# origin-protocol
# harmony
# chiliz
# my-neighbor-alice
# anchor-protocol
# eos
# aave
# monero
# the-graph
# algorand
# theta-token
# alpine-f1-team-fan-token
# uniswap
# loopring
# pancakeswap-token
# curve-dao-token
# dydx
# alien-worlds
# ethereum-name-service
# kyber-network-crystal
# bitcoin-cash
# celo
# trust-wallet-token
# dash
# sushi
# stellar
# arweave
# moonbeam
# wink
# league-of-kingdoms
# mobox
# mines-of-dalarnia
# chromaway
# enjincoin
# ftx-token
# voxies
# mina-protocol
# keep3rv1
# swipe
# omisego
# iotex
# pax-gold
# just
# havven
# uma
# beta-finance
# neo
# api3
# hedera-hashgraph
# tezos
# 2022-04-01T00:00:00.000000Z: 2777.880000
# 2022-04-02T00:00:00.000000Z: 2859.970000
# 2022-04-03T00:00:00.000000Z: 2842.900000
# 2022-04-04T00:00:00.000000Z: 2893.060000
# 2022-04-05T00:00:00.000000Z: 2894.570000
# 2022-04-06T00:00:00.000000Z: 2827.650000
# 2022-04-07T00:00:00.000000Z: 2648.690000
# 2022-04-08T00:00:00.000000Z: 2684.930000
# 2022-04-09T00:00:00.000000Z: 2609.960000
# 2022-04-10T00:00:00.000000Z: 2650.160000
# 2022-04-11T00:00:00.000000Z: 2607.110000
# 2022-04-12T00:00:00.000000Z: 2427.400000
# 2022-04-13T00:00:00.000000Z: 2476.930000
# 2022-04-14T00:00:00.000000Z: 2542.830000
# 2022-04-15T00:00:00.000000Z: 2468.150000
# 2022-04-16T00:00:00.000000Z: 2501.040000
# 2022-04-17T00:00:00.000000Z: 2499.110000
# 2022-04-18T00:00:00.000000Z: 2443.930000
# 2022-04-19T00:00:00.000000Z: 2515.330000
# 2022-04-20T00:00:00.000000Z: 2560.880000
# 2022-04-21T00:00:00.000000Z: 2543.080000
# 2022-04-22T00:00:00.000000Z: 2476.920000
# 2022-04-23T00:00:00.000000Z: 2446.610000
# 2022-04-24T00:00:00.000000Z: 2424.330000
# 2022-04-25T00:00:00.000000Z: 2417.820000
# 2022-04-26T00:00:00.000000Z: 2482.070000
# 2022-04-27T00:00:00.000000Z: 2328.590000
# 2022-04-28T00:00:00.000000Z: 2390.610000
# 2022-04-29T00:00:00.000000Z: 2418.940000
# 2022-04-30T00:00:00.000000Z: 2334.940000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 66    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# stepn
# terra-luna
# binancecoin
# solana
# near
# apecoin
# dogecoin
# ripple
# shiba-inu
# avalanche-2
# cardano
# zilliqa
# polkadot
# smooth-love-potion
# jasmycoin
# fantom
# waves
# gala
# thorchain
# matic-network
# the-sandbox
# tron
# filecoin
# cosmos
# ethereum-classic
# litecoin
# axie-infinity
# vechain
# chainlink
# decentraland
# eos
# moonbeam
# kyber-network-crystal
# biswap
# monero
# oasis-network
# mines-of-dalarnia
# pancakeswap-token
# aave
# league-of-kingdoms
# internet-computer
# astar
# chiliz
# constitutiondao
# origin-protocol
# theta-token
# elrond-erd-2
# loopring
# vulcan-forged
# kava
# algorand
# harmony
# dydx
# zcash
# my-neighbor-alice
# curve-dao-token
# the-graph
# mina-protocol
# mobox
# iostoken
# celo
# wink
# immutable-x
# enjincoin
# ftx-token
# alien-worlds
# bitcoin-cash
# sushi
# binaryx
# audius
# havven
# anchor-protocol
# metal
# ethereum-name-service
# bakerytoken
# stellar
# chromaway
# voxies
# uniswap
# holotoken
# bitcoin-gold
# linear
# dash
# ellipsis
# celer-network
# just
# reserve-rights-token
# kadena
# frax-share
# tezos
# alpine-f1-team-fan-token
# flow
# 2022-05-01T00:00:00.000000Z: 2252.350000
# 2022-05-02T00:00:00.000000Z: 2321.610000
# 2022-05-03T00:00:00.000000Z: 2328.570000
# 2022-05-04T00:00:00.000000Z: 2280.020000
# 2022-05-05T00:00:00.000000Z: 2413.100000
# 2022-05-06T00:00:00.000000Z: 2229.760000
# 2022-05-07T00:00:00.000000Z: 2193.270000
# 2022-05-08T00:00:00.000000Z: 2145.390000
# 2022-05-09T00:00:00.000000Z: 2059.970000
# 2022-05-10T00:00:00.000000Z: 1783.130000
# 2022-05-11T00:00:00.000000Z: 1851.340000
# 2022-05-12T00:00:00.000000Z: 1660.040000
# 2022-05-13T00:00:00.000000Z: 1616.790000
# 2022-05-14T00:00:00.000000Z: 1659.380000
# 2022-05-15T00:00:00.000000Z: 1703.450000
# 2022-05-16T00:00:00.000000Z: 1782.010000
# 2022-05-17T00:00:00.000000Z: 1687.980000
# 2022-05-18T00:00:00.000000Z: 1731.620000
# 2022-05-19T00:00:00.000000Z: 1610.740000
# 2022-05-20T00:00:00.000000Z: 1698.970000
# 2022-05-21T00:00:00.000000Z: 1641.220000
# 2022-05-22T00:00:00.000000Z: 1659.290000
# 2022-05-23T00:00:00.000000Z: 1708.540000
# 2022-05-24T00:00:00.000000Z: 1645.400000
# 2022-05-25T00:00:00.000000Z: 1670.400000
# 2022-05-26T00:00:00.000000Z: 1654.340000
# 2022-05-27T00:00:00.000000Z: 1592.130000
# 2022-05-28T00:00:00.000000Z: 1555.170000
# 2022-05-29T00:00:00.000000Z: 1589.280000
# 2022-05-30T00:00:00.000000Z: 1611.960000
# 2022-05-31T00:00:00.000000Z: 1744.630000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 59    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# stepn
# binancecoin
# solana
# apecoin
# ripple
# avalanche-2
# tron
# cardano
# fantom
# near
# polkadot
# shiba-inu
# dogecoin
# matic-network
# gala
# the-sandbox
# axie-infinity
# anchor-protocol
# litecoin
# cosmos
# jasmycoin
# zilliqa
# decentraland
# chainlink
# thorchain
# ethereum-name-service
# vechain
# mines-of-dalarnia
# waves
# monero
# filecoin
# oasis-network
# ethereum-classic
# smooth-love-potion
# kyber-network-crystal
# constitutiondao
# aave
# internet-computer
# algorand
# elrond-erd-2
# curve-dao-token
# loopring
# eos
# uniswap
# my-neighbor-alice
# harmony
# theta-token
# bitcoin-cash
# zcash
# the-graph
# sushi
# kava
# league-of-kingdoms
# dydx
# celo
# kusama
# chiliz
# pancakeswap-token
# alien-worlds
# immutable-x
# binaryx
# moonbeam
# enjincoin
# tezos
# wink
# 2022-06-01T00:00:00.000000Z: 1735.710000
# 2022-06-02T00:00:00.000000Z: 1622.590000
# 2022-06-03T00:00:00.000000Z: 1655.000000
# 2022-06-04T00:00:00.000000Z: 1607.170000
# 2022-06-05T00:00:00.000000Z: 1621.830000
# 2022-06-06T00:00:00.000000Z: 1622.890000
# 2022-06-07T00:00:00.000000Z: 1688.340000
# 2022-06-08T00:00:00.000000Z: 1665.900000
# 2022-06-09T00:00:00.000000Z: 1629.810000
# 2022-06-10T00:00:00.000000Z: 1627.050000
# 2022-06-11T00:00:00.000000Z: 1555.170000
# 2022-06-12T00:00:00.000000Z: 1491.230000
# 2022-06-13T00:00:00.000000Z: 1393.070000
# 2022-06-14T00:00:00.000000Z: 1189.120000
# 2022-06-15T00:00:00.000000Z: 1179.640000
# 2022-06-16T00:00:00.000000Z: 1218.240000
# 2022-06-17T00:00:00.000000Z: 1087.500000
# 2022-06-18T00:00:00.000000Z: 1097.970000
# 2022-06-19T00:00:00.000000Z: 1018.970000
# 2022-06-20T00:00:00.000000Z: 1114.080000
# 2022-06-21T00:00:00.000000Z: 1116.020000
# 2022-06-22T00:00:00.000000Z: 1126.320000
# 2022-06-23T00:00:00.000000Z: 1077.700000
# 2022-06-24T00:00:00.000000Z: 1146.900000
# 2022-06-25T00:00:00.000000Z: 1180.590000
# 2022-06-26T00:00:00.000000Z: 1194.180000
# 2022-06-27T00:00:00.000000Z: 1164.200000
# 2022-06-28T00:00:00.000000Z: 1151.790000
# 2022-06-29T00:00:00.000000Z: 1116.090000
# 2022-06-30T00:00:00.000000Z: 1097.990000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 49    AUD
# Name: baseAsset, dtype: object
# bitcoin
# ethereum
# solana
# binancecoin
# cardano
# ripple
# stepn
# avalanche-2
# tron
# dogecoin
# terra-luna-2
# chainlink
# apecoin
# matic-network
# shiba-inu
# polkadot
# near
# waves
# fantom
# gala
# the-sandbox
# optimism
# litecoin
# terra-luna
# thorchain
# decentraland
# cosmos
# anchor-protocol
# constitutiondao
# unifi-protocol-dao
# bella-protocol
# elrond-erd-2
# jasmycoin
# vechain
# internet-computer
# filecoin
# axie-infinity
# zilliqa
# project-galaxy
# bitcoin-cash
# theta-token
# monero
# litentry
# aave
# uniswap
# oasis-network
# my-neighbor-alice
# ethereum-classic
# ethereum-name-service
# moviebloc
# origin-protocol
# reserve-rights-token
# ftx-token
# algorand
# eos
# harmony
# 2022-07-01T00:00:00.000000Z: 1084.590000

# %% [markdown]
# ### Now computing the ONN-Alt index

# %%
import datetime
firstAltIndexData = await startIndex('2020-11-01T00:00:00.000000Z', '2020-12-01T00:00:00.000000Z', 1000, 'ONN-Alt-B-30dW-30dR', cacheConn, partial(getBlacklistSet, partial(getBlacklistSet, 'blacklist-alt.txt')))
computeDay = parse(firstAltIndexData.isoInstant) + datetime.timedelta(days = 1)
endDate = parse("2022-06-30T00:00:00.000000Z") + datetime.timedelta(days = 1)
lastIndex = firstAltIndexData
fileName = f"{firstAltIndexData.indexId}_{firstAltIndexData.isoInstant[:10]}_{str(endDate)[:10]}.json"
with open(fileName, 'w') as f:
    print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
    f.write('[\n')
    f.write(lastIndex.toJSON())
    while computeDay <= endDate:
        if(computeDay.day == 1):
            lastIndex = await lastIndexDataRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex, cacheConn, None, partial(getBlacklistSet, 'blacklist-alt.txt'))
        else:
            lastIndex = await lastIndexDataNoRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex)
        print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
        f.write(',\n')
        f.write(lastIndex.toJSON())
        computeDay = computeDay + datetime.timedelta(days = 1)
    f.write('\n]\n')
# Out:
# ethereum
# chainlink
# yearn-finance
# litecoin
# ripple
# binancecoin
# bitcoin-cash
# uniswap
# cardano
# eos
# polkadot
# yfii-finance
# aave
# tron
# swipe
# sushi
# vechain
# curve-dao-token
# monero
# zcash
# filecoin
# tezos
# ethereum-classic
# neo
# cosmos
# stellar
# reserve-rights-token
# waves
# dash
# omisego
# band-protocol
# near
# alpha-finance
# havven
# republic-protocol
# civic
# tellor
# ocean-protocol
# kava
# theta-token
# ontology
# qtum
# thorchain
# algorand
# solana
# zilliqa
# compound-governance-token
# matic-network
# dia-data
# ankr
# basic-attention-token
# iostoken
# bittorrent-old
# iota
# serum
# 2020-12-01T00:00:00.000000Z: 1000.000000
# 2020-12-02T00:00:00.000000Z: 938.540000
# 2020-12-03T00:00:00.000000Z: 964.350000
# 2020-12-04T00:00:00.000000Z: 981.630000
# 2020-12-05T00:00:00.000000Z: 896.070000
# 2020-12-06T00:00:00.000000Z: 942.470000
# 2020-12-07T00:00:00.000000Z: 955.830000
# 2020-12-08T00:00:00.000000Z: 940.690000
# 2020-12-09T00:00:00.000000Z: 878.010000
# 2020-12-10T00:00:00.000000Z: 906.050000
# 2020-12-11T00:00:00.000000Z: 882.580000
# 2020-12-12T00:00:00.000000Z: 858.560000
# 2020-12-13T00:00:00.000000Z: 875.310000
# 2020-12-14T00:00:00.000000Z: 908.990000
# 2020-12-15T00:00:00.000000Z: 902.200000
# 2020-12-16T00:00:00.000000Z: 895.850000
# 2020-12-17T00:00:00.000000Z: 985.300000
# 2020-12-18T00:00:00.000000Z: 990.770000
# 2020-12-19T00:00:00.000000Z: 1006.580000
# 2020-12-20T00:00:00.000000Z: 1014.200000
# ripple
# cardano
# bitcoin-cash
# binancecoin
# stellar
# eos
# uniswap
# sushi
# yearn-finance
# vechain
# aave
# tron
# curve-dao-token
# the-graph
# swipe
# cosmos
# neo
# theta-token
# iostoken
# ethereum-classic
# zcash
# zilliqa
# tezos
# havven
# monero
# elrond-erd-2
# algorand
# dogecoin
# omisego
# 1inch
# dash
# band-protocol
# reserve-rights-token
# filecoin
# alpha-finance
# solana
# nem
# qtum
# enjincoin
# ontology
# waves
# republic-protocol
# loopring
# avalanche-2
# near
# hedera-hashgraph
# 2021-02-01T00:00:00.000000Z: 1651.290000
# 2021-02-02T00:00:00.000000Z: 1700.370000
# 2021-02-03T00:00:00.000000Z: 1813.650000
# 2021-02-04T00:00:00.000000Z: 1978.250000
# 2021-02-05T00:00:00.000000Z: 1931.890000
# 2021-02-06T00:00:00.000000Z: 2098.060000
# 2021-02-07T00:00:00.000000Z: 2073.580000
# 2021-02-08T00:00:00.000000Z: 2019.730000
# 2021-02-09T00:00:00.000000Z: 2189.520000
# 2021-02-10T00:00:00.000000Z: 2272.910000
# 2021-02-11T00:00:00.000000Z: 2335.580000
# 2021-02-12T00:00:00.000000Z: 2410.920000
# 2021-02-13T00:00:00.000000Z: 2551.490000
# 2021-02-14T00:00:00.000000Z: 2578.990000
# 2021-02-15T00:00:00.000000Z: 2512.630000
# 2021-02-16T00:00:00.000000Z: 2479.760000
# 2021-02-17T00:00:00.000000Z: 2486.190000
# 2021-02-18T00:00:00.000000Z: 2612.350000
# 2021-02-19T00:00:00.000000Z: 2697.870000
# 2021-02-20T00:00:00.000000Z: 2891.570000
# 2021-02-21T00:00:00.000000Z: 2826.330000
# 2021-02-22T00:00:00.000000Z: 2902.640000
# 2021-02-23T00:00:00.000000Z: 2718.360000
# 2021-02-24T00:00:00.000000Z: 2382.470000
# 2021-02-25T00:00:00.000000Z: 2459.150000
# 2021-02-26T00:00:00.000000Z: 2288.660000
# 2021-02-27T00:00:00.000000Z: 2281.740000
# 2021-02-28T00:00:00.000000Z: 2340.640000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 83    BQX
# Name: baseAsset, dtype: object
# ethereum
# binancecoin
# cardano
# ripple
# polkadot
# dogecoin
# litecoin
# chainlink
# eos
# bitcoin-cash
# stellar
# swipe
# tron
# uniswap
# sushi
# aave
# the-graph
# vechain
# cosmos
# terra-luna
# elrond-erd-2
# reef
# matic-network
# avalanche-2
# filecoin
# 1inch
# algorand
# ontology
# neo
# iostoken
# yearn-finance
# tezos
# iota
# alpha-finance
# venus
# zcash
# dash
# monero
# curve-dao-token
# omisego
# ethereum-classic
# fantom
# pancakeswap-token
# band-protocol
# zilliqa
# theta-token
# havven
# nem
# icon
# solana
# republic-protocol
# qtum
# 0x
# compound-governance-token
# thorchain
# reserve-rights-token
# basic-attention-token
# serum
# chiliz
# ravencoin
# kava
# ocean-protocol
# near
# waves
# enjincoin
# unifi-protocol-dao
# hedera-hashgraph
# bittorrent-old
# yfii-finance
# kusama
# wrapped-bitcoin
# coti
# the-sandbox
# tomochain
# ankr
# fetch-ai
# nano
# loopring
# harmony
# kyber-network-crystal
# WARNING: Unexpected shape for kyber-network-crystal, ignoring (returning 0,0)
# mainframe
# holotoken
# decentraland
# injective-protocol
# dia-data
# maker
# flamingo-finance
# ftx-token
# storm
# pundi-x
# btc-standard-hashrate-token
# WARNING: Unexpected shape for btc-standard-hashrate-token, ignoring (returning 0,0)
# tellor
# 2021-03-01T00:00:00.000000Z: 2277.850000
# 2021-03-02T00:00:00.000000Z: 2486.860000
# 2021-03-03T00:00:00.000000Z: 2412.950000
# 2021-03-04T00:00:00.000000Z: 2497.580000
# 2021-03-05T00:00:00.000000Z: 2432.820000
# 2021-03-06T00:00:00.000000Z: 2409.610000
# 2021-03-07T00:00:00.000000Z: 2493.330000
# 2021-03-08T00:00:00.000000Z: 2596.490000
# 2021-03-09T00:00:00.000000Z: 2697.130000
# 2021-03-10T00:00:00.000000Z: 2829.470000
# 2021-03-11T00:00:00.000000Z: 2717.650000
# 2021-03-12T00:00:00.000000Z: 2749.360000
# 2021-03-13T00:00:00.000000Z: 2642.530000
# 2021-03-14T00:00:00.000000Z: 2820.200000
# 2021-03-15T00:00:00.000000Z: 2709.270000
# 2021-03-16T00:00:00.000000Z: 2634.640000
# 2021-03-17T00:00:00.000000Z: 2722.220000
# 2021-03-18T00:00:00.000000Z: 2799.410000
# 2021-03-19T00:00:00.000000Z: 2716.890000
# 2021-03-20T00:00:00.000000Z: 2783.420000
# 2021-03-21T00:00:00.000000Z: 2782.910000
# 2021-03-22T00:00:00.000000Z: 2763.810000
# 2021-03-23T00:00:00.000000Z: 2639.220000
# 2021-03-24T00:00:00.000000Z: 2634.200000
# 2021-03-25T00:00:00.000000Z: 2468.150000
# 2021-03-26T00:00:00.000000Z: 2472.980000
# 2021-03-27T00:00:00.000000Z: 2673.920000
# 2021-03-28T00:00:00.000000Z: 2674.520000
# 2021-03-29T00:00:00.000000Z: 2669.670000
# 2021-03-30T00:00:00.000000Z: 2807.500000
# 2021-03-31T00:00:00.000000Z: 2853.900000
# ethereum
# binancecoin
# cardano
# chiliz
# ripple
# polkadot
# enjincoin
# litecoin
# theta-token
# swipe
# chainlink
# terra-luna
# vechain
# harmony
# filecoin
# uniswap
# nem
# pancakeswap-token
# eos
# holotoken
# tron
# dogecoin
# matic-network
# bitcoin-cash
# avalanche-2
# stellar
# theta-fuel
# reef
# coti
# decentraland
# sushi
# bittorrent-old
# algorand
# ankr
# ontology
# the-graph
# fantom
# hedera-hashgraph
# aave
# the-sandbox
# chromaway
# cosmos
# pundi-x
# iostoken
# sun-token
# celer-network
# zilliqa
# solana
# curve-dao-token
# neo
# elrond-erd-2
# ravencoin
# 1inch
# dent
# fetch-ai
# venus
# safepal
# storm
# basic-attention-token
# iota
# tezos
# kusama
# monero
# alpha-finance
# qtum
# reserve-rights-token
# audius
# dash
# siacoin
# icon
# zcash
# omisego
# ethereum-classic
# ocean-protocol
# kava
# origin-protocol
# skale
# bluzelle
# selfkey
# serum
# axie-infinity
# near
# yearn-finance
# litentry
# oasis-network
# republic-protocol
# band-protocol
# thorchain
# dodo
# 0x
# tomochain
# arpa-chain
# vethor-token
# wrapped-bitcoin
# kyber-network-crystal
# WARNING: Unexpected shape for kyber-network-crystal, ignoring (returning 0,0)
# perlin
# vite
# kava-lend
# akropolis
# nervos-network
# the-virtua-kolect
# havven
# unifi-protocol-dao
# dia-data
# ftx-token
# contentos
# bancor
# iotex
# wink
# loopring
# troy
# compound-governance-token
# verge
# storj
# lto-network
# bakerytoken
# orion-protocol
# just
# pnetwork
# dock
# cartesi
# waltonchain
# orchid-protocol
# bella-protocol
# digibyte
# waves
# civic
# aion
# helium
# mithril
# flamingo-finance
# 2021-04-01T00:00:00.000000Z: 2930.340000
# 2021-04-02T00:00:00.000000Z: 2999.710000
# 2021-04-03T00:00:00.000000Z: 3163.130000
# 2021-04-04T00:00:00.000000Z: 3021.570000
# 2021-04-05T00:00:00.000000Z: 3171.770000
# 2021-04-06T00:00:00.000000Z: 3342.380000
# 2021-04-07T00:00:00.000000Z: 3433.150000
# 2021-04-08T00:00:00.000000Z: 3162.820000
# 2021-04-09T00:00:00.000000Z: 3379.310000
# 2021-04-10T00:00:00.000000Z: 3382.090000
# 2021-04-11T00:00:00.000000Z: 3576.670000
# 2021-04-12T00:00:00.000000Z: 3660.410000
# 2021-04-13T00:00:00.000000Z: 3745.530000
# 2021-04-14T00:00:00.000000Z: 3995.250000
# 2021-04-15T00:00:00.000000Z: 4144.500000
# 2021-04-16T00:00:00.000000Z: 4272.370000
# 2021-04-17T00:00:00.000000Z: 4292.460000
# 2021-04-18T00:00:00.000000Z: 4127.720000
# 2021-04-19T00:00:00.000000Z: 3948.460000
# 2021-04-20T00:00:00.000000Z: 3853.790000
# 2021-04-21T00:00:00.000000Z: 4044.870000
# 2021-04-22T00:00:00.000000Z: 3922.560000
# 2021-04-23T00:00:00.000000Z: 3787.250000
# 2021-04-24T00:00:00.000000Z: 3770.250000
# 2021-04-25T00:00:00.000000Z: 3543.650000
# 2021-04-26T00:00:00.000000Z: 3626.400000
# 2021-04-27T00:00:00.000000Z: 4039.170000
# 2021-04-28T00:00:00.000000Z: 4226.910000
# 2021-04-29T00:00:00.000000Z: 4298.810000
# 2021-04-30T00:00:00.000000Z: 4313.320000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 117    BZRX
# 134    RAMP
# Name: baseAsset, dtype: object
# ethereum
# binancecoin
# ripple
# dogecoin
# cardano
# wink
# vechain
# tron
# litecoin
# polkadot
# bittorrent-old
# chiliz
# eos
# pancakeswap-token
# holotoken
# swipe
# filecoin
# chainlink
# bitcoin-cash
# dent
# stellar
# theta-token
# solana
# uniswap
# neo
# enjincoin
# ontology
# terra-luna
# ethereum-classic
# harmony
# iostoken
# cosmos
# aave
# avalanche-2
# elrond-erd-2
# matic-network
# siacoin
# qtum
# zcash
# iota
# wazirx
# monero
# sushi
# dash
# algorand
# tezos
# thorchain
# the-graph
# nkn
# zilliqa
# curve-dao-token
# nem
# omisego
# reef
# ankr
# 1inch
# hedera-hashgraph
# decentraland
# serum
# mithril
# ftx-token
# sun-token
# venus
# yearn-finance
# origin-protocol
# basic-attention-token
# fantom
# storm
# kusama
# reserve-rights-token
# band-protocol
# ravencoin
# coti
# theta-fuel
# verge
# alpha-finance
# chromaway
# icon
# compound-governance-token
# waves
# paris-saint-germain-fan-token
# storj
# fetch-ai
# celer-network
# btc-standard-hashrate-token
# dodo
# zencash
# safepal
# the-sandbox
# digibyte
# wrapped-bitcoin
# near
# vethor-token
# linear
# 0x
# audius
# republic-protocol
# axie-infinity
# litentry
# my-neighbor-alice
# kava
# cartesi
# maker
# metal
# flamingo-finance
# havven
# gifto
# vite
# kyber-network-crystal
# just
# ocean-protocol
# dia-data
# tellor
# nano
# tomochain
# akropolis
# loopring
# bluzelle
# blockstack
# skale
# nervos-network
# civic
# helium
# oasis-network
# dego-finance
# force-protocol
# moviebloc
# bakerytoken
# bitshares
# iotex
# funfair
# arpa-chain
# bella-protocol
# bitcoin-gold
# yfii-finance
# injective-protocol
# marlin
# 2021-05-01T00:00:00.000000Z: 4486.350000
# 2021-05-02T00:00:00.000000Z: 4677.590000
# 2021-05-03T00:00:00.000000Z: 4628.370000
# 2021-05-04T00:00:00.000000Z: 5060.410000
# 2021-05-05T00:00:00.000000Z: 4817.010000
# 2021-05-06T00:00:00.000000Z: 5405.500000
# 2021-05-07T00:00:00.000000Z: 5377.460000
# 2021-05-08T00:00:00.000000Z: 5406.450000
# 2021-05-09T00:00:00.000000Z: 5662.800000
# 2021-05-10T00:00:00.000000Z: 5685.940000
# 2021-05-11T00:00:00.000000Z: 5400.670000
# 2021-05-12T00:00:00.000000Z: 5776.010000
# 2021-05-13T00:00:00.000000Z: 5113.970000
# 2021-05-14T00:00:00.000000Z: 5240.020000
# 2021-05-15T00:00:00.000000Z: 5658.490000
# 2021-05-16T00:00:00.000000Z: 5260.750000
# 2021-05-17T00:00:00.000000Z: 5239.540000
# 2021-05-18T00:00:00.000000Z: 4853.570000
# 2021-05-19T00:00:00.000000Z: 4983.190000
# 2021-05-20T00:00:00.000000Z: 3434.290000
# 2021-05-21T00:00:00.000000Z: 3979.550000
# 2021-05-22T00:00:00.000000Z: 3443.720000
# 2021-05-23T00:00:00.000000Z: 3214.830000
# 2021-05-24T00:00:00.000000Z: 2859.630000
# 2021-05-25T00:00:00.000000Z: 3602.250000
# 2021-05-26T00:00:00.000000Z: 3607.310000
# 2021-05-27T00:00:00.000000Z: 3906.670000
# 2021-05-28T00:00:00.000000Z: 3728.540000
# 2021-05-29T00:00:00.000000Z: 3331.470000
# 2021-05-30T00:00:00.000000Z: 3132.400000
# 2021-05-31T00:00:00.000000Z: 3299.740000
# ethereum
# dogecoin
# binancecoin
# ripple
# cardano
# matic-network
# polkadot
# ethereum-classic
# eos
# litecoin
# chainlink
# vechain
# bitcoin-cash
# tron
# pancakeswap-token
# solana
# stellar
# swipe
# uniswap
# theta-token
# chiliz
# bakerytoken
# terra-luna
# sushi
# filecoin
# aave
# neo
# bittorrent-old
# venus
# zcash
# thorchain
# ontology
# fantom
# avalanche-2
# yearn-finance
# cosmos
# qtum
# reef
# omisego
# monero
# holotoken
# dash
# wink
# kusama
# iexec-rlc
# enjincoin
# tezos
# dent
# curve-dao-token
# waves
# alien-worlds
# zilliqa
# harmony
# iota
# algorand
# hedera-hashgraph
# 1inch
# my-neighbor-alice
# compound-governance-token
# iostoken
# the-graph
# elrond-erd-2
# serum
# cartesi
# wrapped-bitcoin
# nano
# maker
# zencash
# havven
# decentraland
# wazirx
# nem
# coti
# smooth-love-potion
# siacoin
# near
# kava
# chromaway
# theta-fuel
# tokocrypto
# alpha-finance
# 2021-06-01T00:00:00.000000Z: 3690.050000
# 2021-06-02T00:00:00.000000Z: 3655.720000
# 2021-06-03T00:00:00.000000Z: 3814.820000
# 2021-06-04T00:00:00.000000Z: 3999.780000
# 2021-06-05T00:00:00.000000Z: 3723.260000
# 2021-06-06T00:00:00.000000Z: 3633.420000
# 2021-06-07T00:00:00.000000Z: 3714.300000
# 2021-06-08T00:00:00.000000Z: 3463.130000
# 2021-06-09T00:00:00.000000Z: 3405.060000
# 2021-06-10T00:00:00.000000Z: 3569.230000
# 2021-06-11T00:00:00.000000Z: 3375.560000
# 2021-06-12T00:00:00.000000Z: 3218.630000
# 2021-06-13T00:00:00.000000Z: 3221.870000
# 2021-06-14T00:00:00.000000Z: 3418.110000
# 2021-06-15T00:00:00.000000Z: 3519.700000
# 2021-06-16T00:00:00.000000Z: 3459.420000
# 2021-06-17T00:00:00.000000Z: 3267.300000
# 2021-06-18T00:00:00.000000Z: 3282.520000
# 2021-06-19T00:00:00.000000Z: 3097.980000
# 2021-06-20T00:00:00.000000Z: 3007.450000
# 2021-06-21T00:00:00.000000Z: 3080.860000
# 2021-06-22T00:00:00.000000Z: 2475.450000
# 2021-06-23T00:00:00.000000Z: 2442.140000
# 2021-06-24T00:00:00.000000Z: 2647.240000
# 2021-06-25T00:00:00.000000Z: 2742.100000
# 2021-06-26T00:00:00.000000Z: 2487.850000
# 2021-06-27T00:00:00.000000Z: 2518.230000
# 2021-06-28T00:00:00.000000Z: 2688.730000
# 2021-06-29T00:00:00.000000Z: 2761.920000
# 2021-06-30T00:00:00.000000Z: 2890.360000
# ethereum
# binancecoin
# cardano
# matic-network
# dogecoin
# ripple
# polkadot
# solana
# vechain
# chainlink
# shiba-inu
# litecoin
# theta-fuel
# theta-token
# filecoin
# ethereum-classic
# eos
# tron
# pancakeswap-token
# kusama
# chiliz
# internet-computer
# swipe
# thorchain
# terra-luna
# bakerytoken
# bitcoin-cash
# aave
# uniswap
# stellar
# sushi
# monero
# fantom
# neo
# bittorrent-old
# waves
# enjincoin
# curve-dao-token
# cosmos
# zcash
# kava
# zilliqa
# 1inch
# wink
# holotoken
# avalanche-2
# omisego
# streamr
# dash
# ontology
# hedera-hashgraph
# yearn-finance
# algorand
# the-graph
# venus
# wazirx
# iota
# dexe
# dent
# elrond-erd-2
# my-neighbor-alice
# qtum
# harmony
# fetch-ai
# wrapped-bitcoin
# tezos
# reef
# kava-lend
# near
# mdex
# cartesi
# origin-protocol
# iostoken
# compound-governance-token
# coti
# siacoin
# zencash
# alien-worlds
# 2021-07-01T00:00:00.000000Z: 2962.460000
# 2021-07-02T00:00:00.000000Z: 2767.640000
# 2021-07-03T00:00:00.000000Z: 2812.990000
# 2021-07-04T00:00:00.000000Z: 2893.840000
# 2021-07-05T00:00:00.000000Z: 2990.040000
# 2021-07-06T00:00:00.000000Z: 2847.990000
# 2021-07-07T00:00:00.000000Z: 2973.180000
# 2021-07-08T00:00:00.000000Z: 2965.430000
# 2021-07-09T00:00:00.000000Z: 2747.120000
# 2021-07-10T00:00:00.000000Z: 2802.750000
# 2021-07-11T00:00:00.000000Z: 2753.460000
# 2021-07-12T00:00:00.000000Z: 2792.650000
# 2021-07-13T00:00:00.000000Z: 2681.670000
# 2021-07-14T00:00:00.000000Z: 2580.940000
# 2021-07-15T00:00:00.000000Z: 2610.730000
# 2021-07-16T00:00:00.000000Z: 2521.800000
# 2021-07-17T00:00:00.000000Z: 2432.560000
# 2021-07-18T00:00:00.000000Z: 2455.850000
# 2021-07-19T00:00:00.000000Z: 2454.380000
# 2021-07-20T00:00:00.000000Z: 2334.800000
# 2021-07-21T00:00:00.000000Z: 2252.200000
# 2021-07-22T00:00:00.000000Z: 2511.400000
# 2021-07-23T00:00:00.000000Z: 2558.940000
# 2021-07-24T00:00:00.000000Z: 2655.770000
# 2021-07-25T00:00:00.000000Z: 2717.510000
# 2021-07-26T00:00:00.000000Z: 2723.660000
# 2021-07-27T00:00:00.000000Z: 2772.440000
# 2021-07-28T00:00:00.000000Z: 2855.950000
# 2021-07-29T00:00:00.000000Z: 2883.470000
# 2021-07-30T00:00:00.000000Z: 2958.180000
# 2021-07-31T00:00:00.000000Z: 3048.040000
# ethereum
# binancecoin
# axie-infinity
# dogecoin
# cardano
# ripple
# polkadot
# matic-network
# alien-worlds
# solana
# chainlink
# ethereum-classic
# theta-token
# litecoin
# my-neighbor-alice
# vechain
# terra-luna
# eos
# internet-computer
# the-sandbox
# shiba-inu
# filecoin
# aave
# pancakeswap-token
# smooth-love-potion
# tron
# uniswap
# thorchain
# chromaway
# chiliz
# bitcoin-cash
# enjincoin
# bakerytoken
# sushi
# compound-governance-token
# swipe
# cosmos
# stellar
# theta-fuel
# kusama
# havven
# monero
# decentraland
# neo
# dexe
# zcash
# the-graph
# alpha-finance
# linear
# bittorrent-old
# omisego
# kava
# fetch-ai
# ontology
# elrond-erd-2
# waves
# fantom
# mdex
# iostoken
# dash
# curve-dao-token
# holotoken
# dodo
# yearn-finance
# origin-protocol
# ellipsis
# hedera-hashgraph
# tezos
# ftx-token
# superfarm
# 1inch
# harmony
# audius
# algorand
# zilliqa
# the-virtua-kolect
# near
# wink
# unifi-protocol-dao
# avalanche-2
# iota
# sun-token
# litentry
# blockstack
# dent
# nem
# dego-finance
# wrapped-bitcoin
# tomochain
# 2021-08-01T00:00:00.000000Z: 3116.560000
# 2021-08-02T00:00:00.000000Z: 3116.290000
# 2021-08-03T00:00:00.000000Z: 3152.640000
# 2021-08-04T00:00:00.000000Z: 3080.470000
# 2021-08-05T00:00:00.000000Z: 3264.520000
# 2021-08-06T00:00:00.000000Z: 3354.270000
# 2021-08-07T00:00:00.000000Z: 3434.690000
# 2021-08-08T00:00:00.000000Z: 3728.480000
# 2021-08-09T00:00:00.000000Z: 3542.240000
# 2021-08-10T00:00:00.000000Z: 3718.830000
# 2021-08-11T00:00:00.000000Z: 3784.100000
# 2021-08-12T00:00:00.000000Z: 3907.860000
# 2021-08-13T00:00:00.000000Z: 3802.790000
# 2021-08-14T00:00:00.000000Z: 4170.110000
# 2021-08-15T00:00:00.000000Z: 4196.160000
# 2021-08-16T00:00:00.000000Z: 4291.240000
# 2021-08-17T00:00:00.000000Z: 4142.630000
# 2021-08-18T00:00:00.000000Z: 3944.760000
# 2021-08-19T00:00:00.000000Z: 4010.260000
# 2021-08-20T00:00:00.000000Z: 4288.040000
# 2021-08-21T00:00:00.000000Z: 4433.050000
# 2021-08-22T00:00:00.000000Z: 4344.560000
# 2021-08-23T00:00:00.000000Z: 4404.200000
# 2021-08-24T00:00:00.000000Z: 4560.720000
# 2021-08-25T00:00:00.000000Z: 4282.070000
# 2021-08-26T00:00:00.000000Z: 4385.620000
# 2021-08-27T00:00:00.000000Z: 4137.410000
# 2021-08-28T00:00:00.000000Z: 4473.940000
# 2021-08-29T00:00:00.000000Z: 4423.210000
# 2021-08-30T00:00:00.000000Z: 4395.040000
# 2021-08-31T00:00:00.000000Z: 4344.690000
# ethereum
# cardano
# binancecoin
# ripple
# dogecoin
# polkadot
# solana
# axie-infinity
# matic-network
# terra-luna
# chainlink
# filecoin
# internet-computer
# vechain
# my-neighbor-alice
# litecoin
# ethereum-classic
# eos
# alien-worlds
# coin98
# theta-token
# thorchain
# pancakeswap-token
# tron
# chiliz
# shiba-inu
# uniswap
# avalanche-2
# bitcoin-cash
# bakerytoken
# sushi
# smooth-love-potion
# kava
# fantom
# dent
# aave
# the-graph
# swipe
# cosmos
# stellar
# bittorrent-old
# neo
# ftx-token
# the-sandbox
# qtum
# enjincoin
# kusama
# chromaway
# holotoken
# iotex
# audius
# algorand
# monero
# wink
# elrond-erd-2
# near
# coti
# curve-dao-token
# omisego
# ellipsis
# dash
# tezos
# serum
# 1inch
# decentraland
# zcash
# linear
# compound-governance-token
# ravencoin
# alpha-finance
# ontology
# superfarm
# zilliqa
# reef
# havven
# truefi
# dodo
# venus
# iostoken
# paris-saint-germain-fan-token
# dego-finance
# origin-protocol
# iota
# the-virtua-kolect
# harmony
# fetch-ai
# hedera-hashgraph
# reserve-rights-token
# waves
# yearn-finance
# helium
# siacoin
# trust-wallet-token
# litentry
# unifi-protocol-dao
# theta-fuel
# tokocrypto
# perpetual-protocol
# cartesi
# automata
# funfair
# certik
# clover-finance
# wazirx
# ankr
# arweave
# verge
# ocean-protocol
# wrapped-bitcoin
# skale
# mask-network
# stafi
# celer-network
# iexec-rlc
# 2021-09-01T00:00:00.000000Z: 4546.300000
# 2021-09-02T00:00:00.000000Z: 4920.150000
# 2021-09-03T00:00:00.000000Z: 4923.270000
# 2021-09-04T00:00:00.000000Z: 5087.880000
# 2021-09-05T00:00:00.000000Z: 5043.290000
# 2021-09-06T00:00:00.000000Z: 5201.850000
# 2021-09-07T00:00:00.000000Z: 5217.060000
# 2021-09-08T00:00:00.000000Z: 4511.970000
# 2021-09-09T00:00:00.000000Z: 4554.890000
# 2021-09-10T00:00:00.000000Z: 4544.000000
# 2021-09-11T00:00:00.000000Z: 4332.540000
# 2021-09-12T00:00:00.000000Z: 4431.660000
# 2021-09-13T00:00:00.000000Z: 4583.230000
# 2021-09-14T00:00:00.000000Z: 4392.780000
# 2021-09-15T00:00:00.000000Z: 4542.030000
# 2021-09-16T00:00:00.000000Z: 4721.250000
# 2021-09-17T00:00:00.000000Z: 4628.850000
# 2021-09-18T00:00:00.000000Z: 4436.050000
# 2021-09-19T00:00:00.000000Z: 4529.540000
# 2021-09-20T00:00:00.000000Z: 4384.040000
# 2021-09-21T00:00:00.000000Z: 3879.850000
# 2021-09-22T00:00:00.000000Z: 3631.600000
# 2021-09-23T00:00:00.000000Z: 4097.340000
# 2021-09-24T00:00:00.000000Z: 4188.510000
# 2021-09-25T00:00:00.000000Z: 3923.490000
# 2021-09-26T00:00:00.000000Z: 3896.830000
# 2021-09-27T00:00:00.000000Z: 3955.620000
# 2021-09-28T00:00:00.000000Z: 3818.670000
# 2021-09-29T00:00:00.000000Z: 3675.770000
# 2021-09-30T00:00:00.000000Z: 3773.710000
# ethereum
# solana
# cardano
# binancecoin
# polkadot
# ripple
# avalanche-2
# terra-luna
# fantom
# filecoin
# dogecoin
# chainlink
# cosmos
# ftx-token
# matic-network
# algorand
# litecoin
# vechain
# eos
# tron
# omisego
# celer-network
# near
# axie-infinity
# tezos
# theta-token
# internet-computer
# harmony
# elrond-erd-2
# serum
# pancakeswap-token
# hedera-hashgraph
# coin98
# aurora-dao
# iostoken
# ethereum-classic
# sushi
# uniswap
# ecash
# my-neighbor-alice
# coti
# bitcoin-cash
# smooth-love-potion
# shiba-inu
# curve-dao-token
# chiliz
# aave
# swipe
# mina-protocol
# iota
# thorchain
# alien-worlds
# fetch-ai
# kusama
# celo
# stellar
# kava
# the-graph
# arweave
# automata
# oasis-network
# mobox
# bittorrent-old
# monero
# quant-network
# neo
# audius
# raydium
# trust-wallet-token
# the-sandbox
# dent
# 1inch
# waves
# marlin
# zilliqa
# chromaway
# qtum
# holotoken
# dash
# zcash
# ellipsis
# reef
# havven
# bakerytoken
# ontology
# mask-network
# compound-governance-token
# icon
# republic-protocol
# origin-protocol
# funfair
# perpetual-protocol
# iotex
# enjincoin
# venus
# arpa-chain
# dodo
# yearn-finance
# v-id-blockchain
# decentraland
# reserve-rights-token
# force-protocol
# wink
# ravencoin
# alpha-finance
# dexe
# skale
# injective-protocol
# tokocrypto
# wrapped-bitcoin
# theta-fuel
# siacoin
# linear
# aelf
# zencash
# superfarm
# cartesi
# civic
# loopring
# litentry
# clover-finance
# kava-lend
# wazirx
# flow
# conflux-token
# band-protocol
# metal
# ocean-protocol
# verge
# tomochain
# 2021-10-01T00:00:00.000000Z: 3954.340000
# 2021-10-02T00:00:00.000000Z: 4332.300000
# 2021-10-03T00:00:00.000000Z: 4407.230000
# 2021-10-04T00:00:00.000000Z: 4462.530000
# 2021-10-05T00:00:00.000000Z: 4414.860000
# 2021-10-06T00:00:00.000000Z: 4544.310000
# 2021-10-07T00:00:00.000000Z: 4545.060000
# 2021-10-08T00:00:00.000000Z: 4576.260000
# 2021-10-09T00:00:00.000000Z: 4531.740000
# 2021-10-10T00:00:00.000000Z: 4599.710000
# 2021-10-11T00:00:00.000000Z: 4378.870000
# 2021-10-12T00:00:00.000000Z: 4459.420000
# 2021-10-13T00:00:00.000000Z: 4431.910000
# 2021-10-14T00:00:00.000000Z: 4592.740000
# 2021-10-15T00:00:00.000000Z: 4711.880000
# 2021-10-16T00:00:00.000000Z: 4818.110000
# 2021-10-17T00:00:00.000000Z: 4772.040000
# 2021-10-18T00:00:00.000000Z: 4760.960000
# 2021-10-19T00:00:00.000000Z: 4692.950000
# 2021-10-20T00:00:00.000000Z: 4785.680000
# 2021-10-21T00:00:00.000000Z: 5095.130000
# 2021-10-22T00:00:00.000000Z: 4967.080000
# 2021-10-23T00:00:00.000000Z: 4956.580000
# 2021-10-24T00:00:00.000000Z: 5110.060000
# 2021-10-25T00:00:00.000000Z: 5026.530000
# 2021-10-26T00:00:00.000000Z: 5187.640000
# 2021-10-27T00:00:00.000000Z: 5117.850000
# 2021-10-28T00:00:00.000000Z: 4752.820000
# 2021-10-29T00:00:00.000000Z: 5145.320000
# 2021-10-30T00:00:00.000000Z: 5305.870000
# 2021-10-31T00:00:00.000000Z: 5185.840000
# ethereum
# shiba-inu
# solana
# binancecoin
# polkadot
# ripple
# fantom
# dogecoin
# cardano
# terra-luna
# filecoin
# axie-infinity
# avalanche-2
# chainlink
# matic-network
# tron
# litecoin
# cosmos
# omisego
# vechain
# harmony
# smooth-love-potion
# dydx
# eos
# internet-computer
# ftx-token
# theta-token
# near
# algorand
# gala
# stellar
# ethereum-classic
# celer-network
# pancakeswap-token
# uniswap
# tezos
# bitcoin-cash
# elrond-erd-2
# coti
# chiliz
# kava
# coin98
# sushi
# curve-dao-token
# thorchain
# 1inch
# swipe
# hedera-hashgraph
# bittorrent-old
# my-neighbor-alice
# fetch-ai
# the-graph
# serum
# wink
# iota
# btc-standard-hashrate-token
# dent
# holotoken
# monero
# aave
# ecash
# reef
# alien-worlds
# zcash
# celo
# ontology
# iostoken
# arpa-chain
# qtum
# mina-protocol
# kusama
# oasis-network
# zilliqa
# enjincoin
# arweave
# flow
# compound-governance-token
# dash
# bakerytoken
# linear
# mobox
# neo
# aurora-dao
# the-sandbox
# wrapped-bitcoin
# automata
# iotex
# ellipsis
# waves
# dodo
# wax
# cartesi
# yearn-finance
# superfarm
# chromaway
# trust-wallet-token
# marlin
# mask-network
# icon
# audius
# just
# decentraland
# safepal
# havven
# reserve-rights-token
# funfair
# theta-fuel
# blockstack
# force-protocol
# nucypher
# origin-protocol
# ravencoin
# venus
# quant-network
# republic-protocol
# siacoin
# troy
# stp-network
# zencash
# secret
# keep-network
# raydium
# sun-token
# kava-lend
# 2021-11-01T00:00:00.000000Z: 5195.290000
# 2021-11-02T00:00:00.000000Z: 5277.200000
# 2021-11-03T00:00:00.000000Z: 5494.460000
# 2021-11-04T00:00:00.000000Z: 5568.140000
# 2021-11-05T00:00:00.000000Z: 5491.240000
# 2021-11-06T00:00:00.000000Z: 5489.340000
# 2021-11-07T00:00:00.000000Z: 5568.690000
# 2021-11-08T00:00:00.000000Z: 5655.990000
# 2021-11-09T00:00:00.000000Z: 5865.130000
# 2021-11-10T00:00:00.000000Z: 5790.390000
# 2021-11-11T00:00:00.000000Z: 5572.680000
# 2021-11-12T00:00:00.000000Z: 5677.100000
# 2021-11-13T00:00:00.000000Z: 5589.960000
# 2021-11-14T00:00:00.000000Z: 5642.950000
# 2021-11-15T00:00:00.000000Z: 5630.410000
# 2021-11-16T00:00:00.000000Z: 5534.250000
# 2021-11-17T00:00:00.000000Z: 5102.460000
# 2021-11-18T00:00:00.000000Z: 5165.250000
# 2021-11-19T00:00:00.000000Z: 4793.360000
# 2021-11-20T00:00:00.000000Z: 5142.830000
# 2021-11-21T00:00:00.000000Z: 5276.390000
# 2021-11-22T00:00:00.000000Z: 5146.190000
# 2021-11-23T00:00:00.000000Z: 4948.890000
# 2021-11-24T00:00:00.000000Z: 5155.300000
# 2021-11-25T00:00:00.000000Z: 5008.850000
# 2021-11-26T00:00:00.000000Z: 5266.600000
# 2021-11-27T00:00:00.000000Z: 4739.930000
# 2021-11-28T00:00:00.000000Z: 4812.590000
# 2021-11-29T00:00:00.000000Z: 4985.080000
# 2021-11-30T00:00:00.000000Z: 5148.060000
# ethereum
# shiba-inu
# the-sandbox
# binancecoin
# decentraland
# solana
# polkadot
# avalanche-2
# ripple
# tron
# gala
# cardano
# dogecoin
# loopring
# fantom
# litecoin
# terra-luna
# filecoin
# omisego
# chiliz
# chainlink
# matic-network
# vechain
# chromaway
# enjincoin
# alien-worlds
# axie-infinity
# smooth-love-potion
# my-neighbor-alice
# iotex
# elrond-erd-2
# internet-computer
# harmony
# theta-token
# cosmos
# zcash
# wax
# algorand
# dydx
# eos
# curve-dao-token
# holotoken
# pancakeswap-token
# near
# ethereum-classic
# the-graph
# oasis-network
# stellar
# wink
# bitcoin-cash
# ftx-token
# bittorrent-old
# arweave
# swipe
# sushi
# thorchain
# basic-attention-token
# uniswap
# celer-network
# ankr
# mina-protocol
# aave
# just
# dent
# dash
# tezos
# 1inch
# monero
# mobox
# hedera-hashgraph
# cartesi
# fetch-ai
# iota
# coti
# the-virtua-kolect
# arpa-chain
# storj
# qtum
# mask-network
# sun-token
# zencash
# kava
# audius
# superfarm
# reef
# livepeer
# helium
# flow
# kusama
# ontology
# linear
# beta-finance
# automata
# origin-protocol
# coin98
# monero
# kava
# holotoken
# 1inch
# measurable-data-token
# celer-network
# vulcan-forged
# arweave
# yearn-finance
# ftx-token
# gitcoin
# cocos-bcx
# safepal
# hedera-hashgraph
# wax
# syscoin
# swipe
# coti
# lto-network
# mina-protocol
# jasmycoin
# zilliqa
# celo
# helium
# dash
# dent
# reserve-rights-token
# nuls
# superfarm
# coin98
# mask-network
# flow
# ocean-protocol
# ankr
# waves
# serum
# neo
# icon
# yield-guild-games
# reef
# audius
# request-network
# theta-fuel
# havven
# mithril
# compound-governance-token
# render-token
# iostoken
# quant-network
# marlin
# linear
# zencash
# qtum
# 2022-01-01T00:00:00.000000Z: 4306.170000
# 2022-01-02T00:00:00.000000Z: 4451.610000
# 2022-01-03T00:00:00.000000Z: 4490.800000
# 2022-01-04T00:00:00.000000Z: 4416.970000
# 2022-01-05T00:00:00.000000Z: 4386.000000
# 2022-01-06T00:00:00.000000Z: 4105.920000
# 2022-01-07T00:00:00.000000Z: 4036.410000
# 2022-01-08T00:00:00.000000Z: 3792.320000
# 2022-01-09T00:00:00.000000Z: 3672.740000
# 2022-01-10T00:00:00.000000Z: 3756.120000
# 2022-01-11T00:00:00.000000Z: 3659.470000
# 2022-01-12T00:00:00.000000Z: 3862.950000
# 2022-01-13T00:00:00.000000Z: 4065.070000
# 2022-01-14T00:00:00.000000Z: 3912.020000
# 2022-01-15T00:00:00.000000Z: 4016.940000
# 2022-01-16T00:00:00.000000Z: 4046.510000
# 2022-01-17T00:00:00.000000Z: 4088.930000
# 2022-01-18T00:00:00.000000Z: 3934.400000
# 2022-01-19T00:00:00.000000Z: 3863.550000
# 2022-01-20T00:00:00.000000Z: 3749.070000
# 2022-01-21T00:00:00.000000Z: 3616.410000
# 2022-01-22T00:00:00.000000Z: 3124.640000
# 2022-01-23T00:00:00.000000Z: 2901.530000
# 2022-01-24T00:00:00.000000Z: 3070.840000
# 2022-01-25T00:00:00.000000Z: 2944.130000
# 2022-01-26T00:00:00.000000Z: 2979.270000
# 2022-01-27T00:00:00.000000Z: 2957.560000
# 2022-01-28T00:00:00.000000Z: 2920.500000
# 2022-01-29T00:00:00.000000Z: 2997.780000
# 2022-01-30T00:00:00.000000Z: 3061.170000
# 2022-01-31T00:00:00.000000Z: 3011.470000
# ethereum
# terra-luna
# fantom
# binancecoin
# solana
# cosmos
# cardano
# matic-network
# polkadot
# near
# the-sandbox
# shiba-inu
# ripple
# chainlink
# avalanche-2
# dogecoin
# oasis-network
# gala
# harmony
# tron
# curve-dao-token
# decentraland
# internet-computer
# litecoin
# filecoin
# loopring
# axie-infinity
# vechain
# dusk-network
# sushi
# theta-token
# algorand
# chromaway
# ftx-token
# elrond-erd-2
# omisego
# aave
# enjincoin
# aragon
# kava
# eos
# pancakeswap-token
# uniswap
# wink
# dydx
# monero
# my-neighbor-alice
# stellar
# swipe
# yearn-finance
# sun-token
# just
# zcash
# arweave
# thorchain
# ethereum-classic
# keep3rv1
# chiliz
# celer-network
# syscoin
# constitutiondao
# bitcoin-cash
# smooth-love-potion
# the-graph
# tezos
# alien-worlds
# ethereum-name-service
# iota
# celo
# mina-protocol
# hedera-hashgraph
# zelcash
# 1inch
# gxchain
# basic-attention-token
# coti
# secret
# flow
# dash
# helium
# ravencoin
# vulcan-forged
# iotex
# voxies
# spell-token
# zilliqa
# klay-token
# holotoken
# dent
# wax
# mobox
# mines-of-dalarnia
# havven
# biconomy
# gitcoin
# jasmycoin
# anyswap
# ocean-protocol
# wrapped-bitcoin
# yield-guild-games
# linear
# coin98
# neo
# fetch-ai
# quant-network
# render-token
# convex-finance
# mask-network
# compound-governance-token
# zencash
# ooki
# kusama
# 2022-02-01T00:00:00.000000Z: 3102.160000
# 2022-02-02T00:00:00.000000Z: 3201.010000
# 2022-02-03T00:00:00.000000Z: 3051.620000
# 2022-02-04T00:00:00.000000Z: 3090.310000
# 2022-02-05T00:00:00.000000Z: 3387.640000
# 2022-02-06T00:00:00.000000Z: 3420.830000
# 2022-02-07T00:00:00.000000Z: 3501.180000
# 2022-02-08T00:00:00.000000Z: 3661.220000
# 2022-02-09T00:00:00.000000Z: 3600.740000
# 2022-02-10T00:00:00.000000Z: 3709.240000
# 2022-02-11T00:00:00.000000Z: 3525.110000
# 2022-02-12T00:00:00.000000Z: 3327.950000
# 2022-02-13T00:00:00.000000Z: 3340.090000
# 2022-02-14T00:00:00.000000Z: 3289.780000
# 2022-02-15T00:00:00.000000Z: 3342.450000
# 2022-02-16T00:00:00.000000Z: 3606.930000
# 2022-02-17T00:00:00.000000Z: 3546.710000
# 2022-02-18T00:00:00.000000Z: 3283.810000
# 2022-02-19T00:00:00.000000Z: 3198.370000
# 2022-02-20T00:00:00.000000Z: 3203.990000
# 2022-02-21T00:00:00.000000Z: 3042.450000
# 2022-02-22T00:00:00.000000Z: 2905.430000
# 2022-02-23T00:00:00.000000Z: 3010.110000
# 2022-02-24T00:00:00.000000Z: 2951.200000
# 2022-02-25T00:00:00.000000Z: 2971.810000
# 2022-02-26T00:00:00.000000Z: 3158.410000
# 2022-02-27T00:00:00.000000Z: 3172.060000
# 2022-02-28T00:00:00.000000Z: 3005.130000
# ethereum
# terra-luna
# binancecoin
# ripple
# shiba-inu
# solana
# gala
# avalanche-2
# cardano
# fantom
# the-sandbox
# smooth-love-potion
# polkadot
# decentraland
# matic-network
# cosmos
# dogecoin
# tron
# chainlink
# near
# constitutiondao
# litecoin
# oasis-network
# axie-infinity
# filecoin
# internet-computer
# harmony
# theta-token
# vechain
# elrond-erd-2
# ethereum-classic
# curve-dao-token
# my-neighbor-alice
# loopring
# algorand
# eos
# enjincoin
# dydx
# beta-finance
# bitcoin-cash
# zcash
# ftx-token
# monero
# tezos
# alien-worlds
# mines-of-dalarnia
# uniswap
# chromaway
# kava
# jasmycoin
# wink
# pancakeswap-token
# omisego
# chiliz
# sushi
# aave
# stellar
# waves
# aurora-dao
# arweave
# neo
# flow
# vulcan-forged
# the-graph
# hedera-hashgraph
# just
# league-of-kingdoms
# sun-token
# aragon
# immutable-x
# thorchain
# mina-protocol
# render-token
# dusk-network
# moonbeam
# swipe
# mobox
# bittorrent
# ethereum-name-service
# api3
# syscoin
# quant-network
# celer-network
# ooki
# spell-token
# celo
# kyber-network-crystal
# dash
# voxies
# coti
# klay-token
# iotex
# anchor-protocol
# dent
# holotoken
# qtum
# keep3rv1
# helium
# iota
# superfarm
# 1inch
# yearn-finance
# theta-fuel
# cocos-bcx
# wax
# pax-gold
# 2022-03-01T00:00:00.000000Z: 3365.750000
# 2022-03-02T00:00:00.000000Z: 3414.300000
# 2022-03-03T00:00:00.000000Z: 3386.280000
# 2022-03-04T00:00:00.000000Z: 3278.260000
# 2022-03-05T00:00:00.000000Z: 3044.630000
# 2022-03-06T00:00:00.000000Z: 3114.700000
# 2022-03-07T00:00:00.000000Z: 2974.320000
# 2022-03-08T00:00:00.000000Z: 2916.370000
# 2022-03-09T00:00:00.000000Z: 2992.650000
# 2022-03-10T00:00:00.000000Z: 3176.210000
# 2022-03-11T00:00:00.000000Z: 3040.070000
# 2022-03-12T00:00:00.000000Z: 2989.670000
# 2022-03-13T00:00:00.000000Z: 2992.050000
# 2022-03-14T00:00:00.000000Z: 2921.270000
# 2022-03-15T00:00:00.000000Z: 3011.330000
# 2022-03-16T00:00:00.000000Z: 3017.050000
# 2022-03-17T00:00:00.000000Z: 3172.060000
# 2022-03-18T00:00:00.000000Z: 3193.430000
# 2022-03-19T00:00:00.000000Z: 3299.600000
# 2022-03-20T00:00:00.000000Z: 3353.910000
# 2022-03-21T00:00:00.000000Z: 3254.980000
# 2022-03-22T00:00:00.000000Z: 3306.060000
# 2022-03-23T00:00:00.000000Z: 3385.050000
# 2022-03-24T00:00:00.000000Z: 3479.760000
# 2022-03-25T00:00:00.000000Z: 3564.010000
# 2022-03-26T00:00:00.000000Z: 3512.170000
# 2022-03-27T00:00:00.000000Z: 3574.170000
# 2022-03-28T00:00:00.000000Z: 3737.690000
# 2022-03-29T00:00:00.000000Z: 3749.320000
# 2022-03-30T00:00:00.000000Z: 3843.250000
# 2022-03-31T00:00:00.000000Z: 3857.430000
# ethereum
# terra-luna
# binancecoin
# solana
# ripple
# avalanche-2
# fantom
# shiba-inu
# gala
# cardano
# polkadot
# thorchain
# jasmycoin
# near
# cosmos
# the-sandbox
# matic-network
# waves
# tron
# chainlink
# smooth-love-potion
# dogecoin
# decentraland
# litecoin
# vechain
# constitutiondao
# oasis-network
# elrond-erd-2
# immutable-x
# moviebloc
# internet-computer
# axie-infinity
# zcash
# ethereum-classic
# filecoin
# origin-protocol
# harmony
# chiliz
# my-neighbor-alice
# anchor-protocol
# eos
# aave
# monero
# the-graph
# algorand
# theta-token
# alpine-f1-team-fan-token
# uniswap
# loopring
# pancakeswap-token
# curve-dao-token
# dydx
# alien-worlds
# ethereum-name-service
# kyber-network-crystal
# bitcoin-cash
# celo
# trust-wallet-token
# dash
# sushi
# stellar
# arweave
# moonbeam
# wink
# league-of-kingdoms
# mobox
# mines-of-dalarnia
# chromaway
# enjincoin
# ftx-token
# voxies
# mina-protocol
# keep3rv1
# swipe
# omisego
# iotex
# pax-gold
# just
# havven
# uma
# beta-finance
# neo
# api3
# hedera-hashgraph
# tezos
# helium
# flow
# sun-token
# spell-token
# mirror-protocol
# fetch-ai
# basic-attention-token
# 1inch
# bittorrent
# klay-token
# dent
# holotoken
# biconomy
# republic-protocol
# 2022-04-01T00:00:00.000000Z: 3743.600000
# 2022-04-02T00:00:00.000000Z: 3903.910000
# 2022-04-03T00:00:00.000000Z: 3896.790000
# 2022-04-04T00:00:00.000000Z: 3991.040000
# 2022-04-05T00:00:00.000000Z: 3972.490000
# 2022-04-06T00:00:00.000000Z: 3875.820000
# 2022-04-07T00:00:00.000000Z: 3573.160000
# 2022-04-08T00:00:00.000000Z: 3663.210000
# 2022-04-09T00:00:00.000000Z: 3556.440000
# 2022-04-10T00:00:00.000000Z: 3625.860000
# 2022-04-11T00:00:00.000000Z: 3551.660000
# 2022-04-12T00:00:00.000000Z: 3283.620000
# 2022-04-13T00:00:00.000000Z: 3376.090000
# 2022-04-14T00:00:00.000000Z: 3467.700000
# 2022-04-15T00:00:00.000000Z: 3366.830000
# 2022-04-16T00:00:00.000000Z: 3406.170000
# 2022-04-17T00:00:00.000000Z: 3417.290000
# 2022-04-18T00:00:00.000000Z: 3323.420000
# 2022-04-19T00:00:00.000000Z: 3421.170000
# 2022-04-20T00:00:00.000000Z: 3489.770000
# 2022-04-21T00:00:00.000000Z: 3446.290000
# 2022-04-22T00:00:00.000000Z: 3339.830000
# 2022-04-23T00:00:00.000000Z: 3324.940000
# 2022-04-24T00:00:00.000000Z: 3285.230000
# 2022-04-25T00:00:00.000000Z: 3262.640000
# 2022-04-26T00:00:00.000000Z: 3347.350000
# 2022-04-27T00:00:00.000000Z: 3119.750000
# 2022-04-28T00:00:00.000000Z: 3192.060000
# 2022-04-29T00:00:00.000000Z: 3223.150000
# 2022-04-30T00:00:00.000000Z: 3086.340000
# ethereum
# stepn
# terra-luna
# binancecoin
# solana
# near
# apecoin
# dogecoin
# ripple
# shiba-inu
# avalanche-2
# cardano
# zilliqa
# polkadot
# smooth-love-potion
# jasmycoin
# fantom
# waves
# gala
# thorchain
# matic-network
# the-sandbox
# tron
# filecoin
# cosmos
# ethereum-classic
# litecoin
# axie-infinity
# vechain
# chainlink
# decentraland
# eos
# moonbeam
# kyber-network-crystal
# biswap
# monero
# oasis-network
# mines-of-dalarnia
# pancakeswap-token
# aave
# league-of-kingdoms
# internet-computer
# astar
# chiliz
# constitutiondao
# origin-protocol
# theta-token
# elrond-erd-2
# loopring
# vulcan-forged
# kava
# algorand
# harmony
# dydx
# zcash
# my-neighbor-alice
# curve-dao-token
# the-graph
# mina-protocol
# mobox
# iostoken
# celo
# wink
# immutable-x
# enjincoin
# ftx-token
# alien-worlds
# bitcoin-cash
# sushi
# binaryx
# audius
# havven
# anchor-protocol
# metal
# ethereum-name-service
# bakerytoken
# stellar
# chromaway
# voxies
# uniswap
# holotoken
# bitcoin-gold
# linear
# dash
# ellipsis
# celer-network
# just
# reserve-rights-token
# kadena
# frax-share
# tezos
# alpine-f1-team-fan-token
# flow
# trust-wallet-token
# compound-governance-token
# skale
# 0x
# alpha-finance
# acala
# arweave
# coti
# klay-token
# swipe
# hedera-hashgraph
# sun-token
# moviebloc
# woo-network
# 2022-05-01T00:00:00.000000Z: 2932.630000
# 2022-05-02T00:00:00.000000Z: 3054.550000
# 2022-05-03T00:00:00.000000Z: 3065.890000
# 2022-05-04T00:00:00.000000Z: 3007.760000
# 2022-05-05T00:00:00.000000Z: 3216.340000
# 2022-05-06T00:00:00.000000Z: 2977.300000
# 2022-05-07T00:00:00.000000Z: 2935.370000
# 2022-05-08T00:00:00.000000Z: 2847.290000
# 2022-05-09T00:00:00.000000Z: 2744.530000
# 2022-05-10T00:00:00.000000Z: 2311.610000
# 2022-05-11T00:00:00.000000Z: 2420.960000
# 2022-05-12T00:00:00.000000Z: 2046.650000
# 2022-05-13T00:00:00.000000Z: 1927.690000
# 2022-05-14T00:00:00.000000Z: 2031.410000
# 2022-05-15T00:00:00.000000Z: 2082.060000
# 2022-05-16T00:00:00.000000Z: 2192.600000
# 2022-05-17T00:00:00.000000Z: 2057.690000
# 2022-05-18T00:00:00.000000Z: 2133.280000
# 2022-05-19T00:00:00.000000Z: 1945.660000
# 2022-05-20T00:00:00.000000Z: 2049.280000
# 2022-05-21T00:00:00.000000Z: 1989.180000
# 2022-05-22T00:00:00.000000Z: 2019.480000
# 2022-05-23T00:00:00.000000Z: 2083.290000
# 2022-05-24T00:00:00.000000Z: 2014.420000
# 2022-05-25T00:00:00.000000Z: 2038.710000
# 2022-05-26T00:00:00.000000Z: 2004.850000
# 2022-05-27T00:00:00.000000Z: 1856.020000
# 2022-05-28T00:00:00.000000Z: 1802.340000
# 2022-05-29T00:00:00.000000Z: 1861.270000
# 2022-05-30T00:00:00.000000Z: 1887.100000
# 2022-05-31T00:00:00.000000Z: 2055.650000
# ethereum
# stepn
# binancecoin
# solana
# apecoin
# ripple
# avalanche-2
# tron
# cardano
# fantom
# near
# polkadot
# shiba-inu
# dogecoin
# matic-network
# gala
# the-sandbox
# axie-infinity
# anchor-protocol
# litecoin
# cosmos
# jasmycoin
# zilliqa
# decentraland
# chainlink
# thorchain
# ethereum-name-service
# vechain
# mines-of-dalarnia
# waves
# monero
# filecoin
# oasis-network
# ethereum-classic
# smooth-love-potion
# kyber-network-crystal
# constitutiondao
# aave
# internet-computer
# algorand
# elrond-erd-2
# curve-dao-token
# loopring
# eos
# uniswap
# my-neighbor-alice
# harmony
# theta-token
# bitcoin-cash
# zcash
# the-graph
# sushi
# kava
# league-of-kingdoms
# dydx
# celo
# kusama
# chiliz
# pancakeswap-token
# alien-worlds
# immutable-x
# binaryx
# moonbeam
# enjincoin
# tezos
# wink
# stellar
# ftx-token
# chromaway
# arweave
# kadena
# bakerytoken
# astar
# just
# mina-protocol
# swipe
# audius
# klay-token
# 2022-06-01T00:00:00.000000Z: 2026.220000
# 2022-06-02T00:00:00.000000Z: 1884.190000
# 2022-06-03T00:00:00.000000Z: 1918.860000
# 2022-06-04T00:00:00.000000Z: 1850.540000
# 2022-06-05T00:00:00.000000Z: 1877.560000
# 2022-06-06T00:00:00.000000Z: 1874.990000
# 2022-06-07T00:00:00.000000Z: 1927.520000
# 2022-06-08T00:00:00.000000Z: 1886.310000
# 2022-06-09T00:00:00.000000Z: 1869.640000
# 2022-06-10T00:00:00.000000Z: 1872.410000
# 2022-06-11T00:00:00.000000Z: 1756.610000
# 2022-06-12T00:00:00.000000Z: 1631.890000
# 2022-06-13T00:00:00.000000Z: 1522.250000
# 2022-06-14T00:00:00.000000Z: 1323.810000
# 2022-06-15T00:00:00.000000Z: 1330.990000
# 2022-06-16T00:00:00.000000Z: 1405.840000
# 2022-06-17T00:00:00.000000Z: 1231.410000
# 2022-06-18T00:00:00.000000Z: 1258.980000
# 2022-06-19T00:00:00.000000Z: 1172.010000
# 2022-06-20T00:00:00.000000Z: 1297.270000
# 2022-06-21T00:00:00.000000Z: 1305.550000
# 2022-06-22T00:00:00.000000Z: 1322.950000
# 2022-06-23T00:00:00.000000Z: 1254.370000
# 2022-06-24T00:00:00.000000Z: 1352.850000
# 2022-06-25T00:00:00.000000Z: 1437.480000
# 2022-06-26T00:00:00.000000Z: 1454.520000
# 2022-06-27T00:00:00.000000Z: 1406.830000
# 2022-06-28T00:00:00.000000Z: 1396.610000
# 2022-06-29T00:00:00.000000Z: 1333.350000
# 2022-06-30T00:00:00.000000Z: 1297.970000
# ethereum
# solana
# binancecoin
# cardano
# ripple
# stepn
# avalanche-2
# tron
# dogecoin
# terra-luna-2
# chainlink
# apecoin
# matic-network
# shiba-inu
# polkadot
# near
# waves
# fantom
# gala
# the-sandbox
# optimism
# litecoin
# terra-luna
# thorchain
# decentraland
# cosmos
# anchor-protocol
# constitutiondao
# unifi-protocol-dao
# bella-protocol
# elrond-erd-2
# jasmycoin
# vechain
# internet-computer
# filecoin
# axie-infinity
# zilliqa
# project-galaxy
# bitcoin-cash
# theta-token
# monero
# litentry
# aave
# uniswap
# oasis-network
# my-neighbor-alice
# ethereum-classic
# ethereum-name-service
# moviebloc
# origin-protocol
# reserve-rights-token
# ftx-token
# algorand
# eos
# harmony
# stellar
# chiliz
# 2022-07-01T00:00:00.000000Z: 1277.150000

# %% [markdown]
# ## And now the ONN-Vapour Index

# %%
import datetime
firstVapIndexData = await startIndex('2020-11-01T00:00:00.000000Z', '2020-12-01T00:00:00.000000Z', 1000, 'ONN-Vap-B-30dW-30dR', cacheConn, partial(getBlacklistSet, 'blacklist-vapour.txt'))
computeDay = parse(firstVapIndexData.isoInstant) + datetime.timedelta(days = 1)
endDate = parse("2022-06-30T00:00:00.000000Z") + datetime.timedelta(days = 1)
lastIndex = firstVapIndexData
fileName = f"{firstVapIndexData.indexId}_{firstVapIndexData.isoInstant[:10]}_{str(endDate)[:10]}.json"
with open(fileName, 'w') as f:
    print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
    f.write('[\n')
    f.write(lastIndex.toJSON())
    while computeDay <= endDate:
        if(computeDay.day == 1):
            lastIndex = await lastIndexDataRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex, cacheConn, None, partial(getBlacklistSet, 'blacklist-vapour.txt'))
        else:
            lastIndex = await lastIndexDataNoRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex)
        print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
        f.write(',\n')
        f.write(lastIndex.toJSON())
        computeDay = computeDay + datetime.timedelta(days = 1)
    f.write('\n]\n')
# Out:
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 55    BZRX
# 94    EASY
# Name: baseAsset, dtype: object
# chainlink
# yearn-finance
# litecoin
# ripple
# binancecoin
# bitcoin-cash
# uniswap
# cardano
# eos
# polkadot
# yfii-finance
# aave
# tron
# swipe
# sushi
# vechain
# curve-dao-token
# monero
# zcash
# filecoin
# tezos
# ethereum-classic
# neo
# cosmos
# stellar
# reserve-rights-token
# waves
# dash
# omisego
# band-protocol
# near
# alpha-finance
# havven
# republic-protocol
# civic
# tellor
# ocean-protocol
# kava
# theta-token
# ontology
# qtum
# thorchain
# algorand
# solana
# zilliqa
# compound-governance-token
# matic-network
# dia-data
# ankr
# basic-attention-token
# iostoken
# bittorrent-old
# iota
# serum
# venus
# district0x
# certik
# kyber-network-crystal
# WARNING: Unexpected shape for kyber-network-crystal, ignoring (returning 0,0)
# fantom
# nem
# elrond-erd-2
# kusama
# coti
# loopring
# 0x
# balancer
# flamingo-finance
# injective-protocol
# bella-protocol
# icon
# fetch-ai
# dogecoin
# lto-network
# tomochain
# arpa-chain
# decentraland
# avalanche-2
# enjincoin
# iexec-rlc
# maker
# harmony
# the-sandbox
# origin-protocol
# aragon
# wing-finance
# blockstack
# wrapped-nxm
# storj
# ravencoin
# audius
# terra-luna
# digibyte
# bluzelle
# bancor
# utrust
# orchid-protocol
# hedera-hashgraph
# just
# celer-network
# wink
# decred
# ftx-token
# wanchain
# cartesi
# nano
# concierge-io
# theta-fuel
# chromaway
# 2020-12-01T00:00:00.000000Z: 1000.000000
# 2020-12-02T00:00:00.000000Z: 932.460000
# 2020-12-03T00:00:00.000000Z: 966.390000
# 2020-12-04T00:00:00.000000Z: 975.480000
# 2020-12-05T00:00:00.000000Z: 889.290000
# 2020-12-06T00:00:00.000000Z: 937.010000
# 2020-12-07T00:00:00.000000Z: 952.160000
# 2020-12-08T00:00:00.000000Z: 938.560000
# 2020-12-09T00:00:00.000000Z: 872.030000
# 2020-12-10T00:00:00.000000Z: 898.220000
# 2020-12-11T00:00:00.000000Z: 873.830000
# 2020-12-12T00:00:00.000000Z: 848.430000
# 2020-12-13T00:00:00.000000Z: 855.530000
# 2020-12-14T00:00:00.000000Z: 885.360000
# 2020-12-15T00:00:00.000000Z: 879.420000
# 2020-12-16T00:00:00.000000Z: 864.760000
# 2020-12-17T00:00:00.000000Z: 959.040000
# 2020-12-18T00:00:00.000000Z: 964.450000
# 2020-12-19T00:00:00.000000Z: 981.270000
# 2020-12-20T00:00:00.000000Z: 987.950000
# 2020-12-21T00:00:00.000000Z: 972.770000
# 2020-12-22T00:00:00.000000Z: 907.760000
# 2020-12-23T00:00:00.000000Z: 898.120000
# 2020-12-24T00:00:00.000000Z: 721.660000
# 2020-12-25T00:00:00.000000Z: 816.900000
# 2020-12-26T00:00:00.000000Z: 826.220000
# 2020-12-27T00:00:00.000000Z: 818.420000
# 2020-12-28T00:00:00.000000Z: 815.360000
# 2020-12-29T00:00:00.000000Z: 843.230000
# 2020-12-30T00:00:00.000000Z: 833.260000
# 2020-12-31T00:00:00.000000Z: 816.910000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 76    BZRX
# Name: baseAsset, dtype: object
# ripple
# litecoin
# bitcoin-cash
# binancecoin
# chainlink
# cardano
# yearn-finance
# eos
# stellar
# sushi
# polkadot
# tron
# aave
# vechain
# zilliqa
# uniswap
# monero
# filecoin
# elrond-erd-2
# theta-token
# nem
# ethereum-classic
# zcash
# unifi-protocol-dao
# waves
# neo
# dash
# swipe
# algorand
# injective-protocol
# havven
# cosmos
# tezos
# oasis-network
# curve-dao-token
# omisego
# band-protocol
# yfii-finance
# skale
# compound-governance-token
# theta-fuel
# kava-lend
# ontology
# ocean-protocol
# reserve-rights-token
# thorchain
# near
# kusama
# iostoken
# basic-attention-token
# coti
# iota
# terra-luna
# dogecoin
# qtum
# chiliz
# republic-protocol
# alpha-finance
# keep3rv1
# axie-infinity
# bittorrent-old
# certik
# civic
# matic-network
# ankr
# enjincoin
# icon
# tellor
# solana
# bella-protocol
# zencash
# wing-finance
# venus
# serum
# blockstack
# tomochain
# avalanche-2
# dia-data
# 2021-01-01T00:00:00.000000Z: 838.730000
# 2021-01-02T00:00:00.000000Z: 836.120000
# 2021-01-03T00:00:00.000000Z: 851.780000
# 2021-01-04T00:00:00.000000Z: 933.450000
# 2021-01-05T00:00:00.000000Z: 942.550000
# 2021-01-06T00:00:00.000000Z: 977.370000
# 2021-01-07T00:00:00.000000Z: 1103.240000
# 2021-01-08T00:00:00.000000Z: 1107.990000
# 2021-01-09T00:00:00.000000Z: 1087.300000
# 2021-01-10T00:00:00.000000Z: 1175.640000
# 2021-01-11T00:00:00.000000Z: 1154.660000
# 2021-01-12T00:00:00.000000Z: 1017.480000
# 2021-01-13T00:00:00.000000Z: 1019.660000
# 2021-01-14T00:00:00.000000Z: 1127.330000
# 2021-01-15T00:00:00.000000Z: 1181.390000
# 2021-01-16T00:00:00.000000Z: 1148.580000
# 2021-01-17T00:00:00.000000Z: 1231.190000
# 2021-01-18T00:00:00.000000Z: 1253.990000
# 2021-01-19T00:00:00.000000Z: 1274.150000
# 2021-01-20T00:00:00.000000Z: 1248.170000
# 2021-01-21T00:00:00.000000Z: 1274.320000
# 2021-01-22T00:00:00.000000Z: 1100.480000
# 2021-01-23T00:00:00.000000Z: 1188.150000
# 2021-01-24T00:00:00.000000Z: 1227.110000
# 2021-01-25T00:00:00.000000Z: 1248.780000
# 2021-01-26T00:00:00.000000Z: 1207.190000
# 2021-01-27T00:00:00.000000Z: 1220.830000
# 2021-01-28T00:00:00.000000Z: 1126.610000
# 2021-01-29T00:00:00.000000Z: 1217.590000
# 2021-01-30T00:00:00.000000Z: 1237.160000
# 2021-01-31T00:00:00.000000Z: 1350.830000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 68     BQX
# 84    BZRX
# Name: baseAsset, dtype: object
# polkadot
# litecoin
# chainlink
# ripple
# cardano
# bitcoin-cash
# binancecoin
# stellar
# eos
# uniswap
# sushi
# yearn-finance
# vechain
# aave
# tron
# curve-dao-token
# the-graph
# swipe
# cosmos
# neo
# theta-token
# iostoken
# ethereum-classic
# zcash
# zilliqa
# tezos
# havven
# monero
# elrond-erd-2
# algorand
# dogecoin
# omisego
# 1inch
# dash
# band-protocol
# reserve-rights-token
# filecoin
# alpha-finance
# solana
# nem
# qtum
# enjincoin
# ontology
# waves
# republic-protocol
# loopring
# avalanche-2
# near
# hedera-hashgraph
# basic-attention-token
# thorchain
# nano
# iota
# matic-network
# icon
# serum
# reef
# compound-governance-token
# ocean-protocol
# yfii-finance
# kusama
# terra-luna
# kava
# zencash
# maker
# 0x
# kyber-network-crystal
# WARNING: Unexpected shape for kyber-network-crystal, ignoring (returning 0,0)
# injective-protocol
# chiliz
# tomochain
# civic
# tellor
# dia-data
# decentraland
# oasis-network
# blockstack
# kava-lend
# skale
# coti
# theta-fuel
# unifi-protocol-dao
# verge
# lto-network
# balancer
# fantom
# venus
# flamingo-finance
# certik
# fetch-ai
# ankr
# the-sandbox
# axie-infinity
# storj
# bittorrent-old
# iexec-rlc
# bella-protocol
# harmony
# bluzelle
# digibyte
# siacoin
# origin-protocol
# district0x
# ftx-token
# arpa-chain
# ravencoin
# funfair
# decred
# holotoken
# keep3rv1
# aragon
# bancor
# just
# pax-gold
# utrust
# orchid-protocol
# celer-network
# akropolis
# wink
# uma
# wanchain
# wing-finance
# perlin
# dock
# aion
# 2021-02-01T00:00:00.000000Z: 1336.970000
# 2021-02-02T00:00:00.000000Z: 1350.830000
# 2021-02-03T00:00:00.000000Z: 1378.030000
# 2021-02-04T00:00:00.000000Z: 1486.980000
# 2021-02-05T00:00:00.000000Z: 1514.970000
# 2021-02-06T00:00:00.000000Z: 1650.780000
# 2021-02-07T00:00:00.000000Z: 1666.810000
# 2021-02-08T00:00:00.000000Z: 1680.330000
# 2021-02-09T00:00:00.000000Z: 1817.900000
# 2021-02-10T00:00:00.000000Z: 1937.620000
# 2021-02-11T00:00:00.000000Z: 2096.460000
# 2021-02-12T00:00:00.000000Z: 2179.970000
# 2021-02-13T00:00:00.000000Z: 2351.040000
# 2021-02-14T00:00:00.000000Z: 2435.070000
# 2021-02-15T00:00:00.000000Z: 2325.190000
# 2021-02-16T00:00:00.000000Z: 2294.350000
# 2021-02-17T00:00:00.000000Z: 2297.090000
# 2021-02-18T00:00:00.000000Z: 2429.690000
# 2021-02-19T00:00:00.000000Z: 2486.950000
# 2021-02-20T00:00:00.000000Z: 2787.320000
# 2021-02-21T00:00:00.000000Z: 2717.420000
# 2021-02-22T00:00:00.000000Z: 2826.150000
# 2021-02-23T00:00:00.000000Z: 2696.220000
# 2021-02-24T00:00:00.000000Z: 2346.970000
# 2021-02-25T00:00:00.000000Z: 2444.310000
# 2021-02-26T00:00:00.000000Z: 2299.030000
# 2021-02-27T00:00:00.000000Z: 2325.390000
# 2021-02-28T00:00:00.000000Z: 2408.390000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 81      BQX
# 102    BZRX
# Name: baseAsset, dtype: object
# binancecoin
# cardano
# ripple
# polkadot
# dogecoin
# litecoin
# chainlink
# eos
# bitcoin-cash
# stellar
# swipe
# tron
# uniswap
# sushi
# aave
# the-graph
# vechain
# cosmos
# terra-luna
# elrond-erd-2
# reef
# matic-network
# avalanche-2
# filecoin
# 1inch
# algorand
# ontology
# neo
# iostoken
# yearn-finance
# tezos
# iota
# alpha-finance
# venus
# zcash
# dash
# monero
# curve-dao-token
# omisego
# ethereum-classic
# fantom
# pancakeswap-token
# band-protocol
# zilliqa
# theta-token
# havven
# nem
# icon
# solana
# republic-protocol
# qtum
# 0x
# compound-governance-token
# thorchain
# reserve-rights-token
# basic-attention-token
# serum
# chiliz
# ravencoin
# kava
# ocean-protocol
# near
# waves
# enjincoin
# unifi-protocol-dao
# hedera-hashgraph
# bittorrent-old
# yfii-finance
# kusama
# coti
# the-sandbox
# tomochain
# ankr
# fetch-ai
# nano
# loopring
# harmony
# kyber-network-crystal
# mainframe
# holotoken
# decentraland
# injective-protocol
# dia-data
# maker
# flamingo-finance
# ftx-token
# storm
# pundi-x
# btc-standard-hashrate-token
# tellor
# zencash
# trust-wallet-token
# bella-protocol
# balancer
# pnetwork
# kava-lend
# akropolis
# sun-token
# bancor
# civic
# certik
# digibyte
# oasis-network
# bakerytoken
# verge
# celer-network
# lisk
# siacoin
# theta-fuel
# blockstack
# skale
# iexec-rlc
# bluzelle
# cartesi
# dent
# just
# uma
# orchid-protocol
# origin-protocol
# storj
# axie-infinity
# lto-network
# decred
# aion
# iotex
# wink
# aragon
# wanchain
# vethor-token
# district0x
# wazirx
# 2021-03-01T00:00:00.000000Z: 2339.750000
# 2021-03-02T00:00:00.000000Z: 2540.960000
# 2021-03-03T00:00:00.000000Z: 2506.760000
# 2021-03-04T00:00:00.000000Z: 2564.440000
# 2021-03-05T00:00:00.000000Z: 2482.680000
# 2021-03-06T00:00:00.000000Z: 2452.980000
# 2021-03-07T00:00:00.000000Z: 2462.950000
# 2021-03-08T00:00:00.000000Z: 2554.050000
# 2021-03-09T00:00:00.000000Z: 2607.620000
# 2021-03-10T00:00:00.000000Z: 2801.900000
# 2021-03-11T00:00:00.000000Z: 2692.080000
# 2021-03-12T00:00:00.000000Z: 2720.150000
# 2021-03-13T00:00:00.000000Z: 2601.300000
# 2021-03-14T00:00:00.000000Z: 2741.350000
# 2021-03-15T00:00:00.000000Z: 2633.080000
# 2021-03-16T00:00:00.000000Z: 2567.490000
# 2021-03-17T00:00:00.000000Z: 2703.150000
# 2021-03-18T00:00:00.000000Z: 2828.520000
# 2021-03-19T00:00:00.000000Z: 2737.900000
# 2021-03-20T00:00:00.000000Z: 2817.230000
# 2021-03-21T00:00:00.000000Z: 2817.380000
# 2021-03-22T00:00:00.000000Z: 2808.450000
# 2021-03-23T00:00:00.000000Z: 2705.330000
# 2021-03-24T00:00:00.000000Z: 2710.650000
# 2021-03-25T00:00:00.000000Z: 2523.800000
# 2021-03-26T00:00:00.000000Z: 2527.160000
# 2021-03-27T00:00:00.000000Z: 2766.390000
# 2021-03-28T00:00:00.000000Z: 2756.000000
# 2021-03-29T00:00:00.000000Z: 2780.500000
# 2021-03-30T00:00:00.000000Z: 2876.770000
# 2021-03-31T00:00:00.000000Z: 2939.930000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 129     BQX
# 146    BZRX
# 155    EASY
# Name: baseAsset, dtype: object
# binancecoin
# cardano
# chiliz
# ripple
# polkadot
# enjincoin
# litecoin
# theta-token
# swipe
# chainlink
# terra-luna
# vechain
# harmony
# filecoin
# uniswap
# nem
# pancakeswap-token
# eos
# holotoken
# tron
# dogecoin
# matic-network
# bitcoin-cash
# avalanche-2
# stellar
# theta-fuel
# reef
# coti
# decentraland
# sushi
# bittorrent-old
# algorand
# ankr
# ontology
# the-graph
# fantom
# hedera-hashgraph
# aave
# the-sandbox
# chromaway
# cosmos
# pundi-x
# iostoken
# sun-token
# celer-network
# zilliqa
# solana
# curve-dao-token
# neo
# elrond-erd-2
# ravencoin
# 1inch
# dent
# fetch-ai
# venus
# safepal
# storm
# basic-attention-token
# iota
# tezos
# kusama
# monero
# alpha-finance
# qtum
# reserve-rights-token
# audius
# dash
# siacoin
# icon
# zcash
# omisego
# ethereum-classic
# ocean-protocol
# kava
# origin-protocol
# skale
# bluzelle
# selfkey
# serum
# axie-infinity
# near
# yearn-finance
# litentry
# oasis-network
# republic-protocol
# band-protocol
# thorchain
# dodo
# 0x
# tomochain
# arpa-chain
# vethor-token
# kyber-network-crystal
# perlin
# vite
# kava-lend
# akropolis
# nervos-network
# the-virtua-kolect
# havven
# unifi-protocol-dao
# dia-data
# ftx-token
# contentos
# bancor
# iotex
# wink
# loopring
# troy
# compound-governance-token
# verge
# storj
# lto-network
# bakerytoken
# orion-protocol
# just
# pnetwork
# dock
# cartesi
# waltonchain
# orchid-protocol
# bella-protocol
# digibyte
# waves
# civic
# aion
# helium
# mithril
# flamingo-finance
# dusk-network
# aragon
# zencash
# tellor
# yfii-finance
# blockstack
# pha
# nkn
# streamr
# WARNING: Unexpected shape for streamr, ignoring (returning 0,0)
# certik
# moviebloc
# measurable-data-token
# mainframe
# bitshares
# iexec-rlc
# lisk
# balancer
# cocos-bcx
# nano
# injective-protocol
# wazirx
# utrust
# iris-network
# trust-wallet-token
# fio-protocol
# funfair
# dexe
# wanchain
# frontier-token
# ong
# tokenclub
# maker
# metal
# beam
# gifto
# hive
# nuls
# uma
# 2021-04-01T00:00:00.000000Z: 2998.970000
# 2021-04-02T00:00:00.000000Z: 3068.070000
# 2021-04-03T00:00:00.000000Z: 3180.680000
# 2021-04-04T00:00:00.000000Z: 3059.000000
# 2021-04-05T00:00:00.000000Z: 3254.850000
# 2021-04-06T00:00:00.000000Z: 3499.100000
# 2021-04-07T00:00:00.000000Z: 3647.080000
# 2021-04-08T00:00:00.000000Z: 3345.350000
# 2021-04-09T00:00:00.000000Z: 3595.130000
# 2021-04-10T00:00:00.000000Z: 3617.630000
# 2021-04-11T00:00:00.000000Z: 3868.580000
# 2021-04-12T00:00:00.000000Z: 3993.820000
# 2021-04-13T00:00:00.000000Z: 4155.970000
# 2021-04-14T00:00:00.000000Z: 4396.470000
# 2021-04-15T00:00:00.000000Z: 4508.180000
# 2021-04-16T00:00:00.000000Z: 4655.620000
# 2021-04-17T00:00:00.000000Z: 4789.140000
# 2021-04-18T00:00:00.000000Z: 4613.020000
# 2021-04-19T00:00:00.000000Z: 4380.730000
# 2021-04-20T00:00:00.000000Z: 4285.220000
# 2021-04-21T00:00:00.000000Z: 4435.020000
# 2021-04-22T00:00:00.000000Z: 4208.110000
# 2021-04-23T00:00:00.000000Z: 3933.170000
# 2021-04-24T00:00:00.000000Z: 3937.960000
# 2021-04-25T00:00:00.000000Z: 3706.710000
# 2021-04-26T00:00:00.000000Z: 3734.260000
# 2021-04-27T00:00:00.000000Z: 4217.580000
# 2021-04-28T00:00:00.000000Z: 4410.940000
# 2021-04-29T00:00:00.000000Z: 4441.370000
# 2021-04-30T00:00:00.000000Z: 4455.920000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 115    BZRX
# 132    RAMP
# Name: baseAsset, dtype: object
# binancecoin
# ripple
# dogecoin
# cardano
# wink
# vechain
# tron
# litecoin
# polkadot
# bittorrent-old
# chiliz
# eos
# pancakeswap-token
# holotoken
# swipe
# filecoin
# chainlink
# bitcoin-cash
# dent
# stellar
# theta-token
# solana
# uniswap
# neo
# enjincoin
# ontology
# terra-luna
# ethereum-classic
# harmony
# iostoken
# cosmos
# aave
# avalanche-2
# elrond-erd-2
# matic-network
# siacoin
# qtum
# zcash
# iota
# wazirx
# monero
# sushi
# dash
# algorand
# tezos
# thorchain
# the-graph
# nkn
# zilliqa
# curve-dao-token
# nem
# omisego
# reef
# ankr
# 1inch
# hedera-hashgraph
# decentraland
# serum
# mithril
# ftx-token
# sun-token
# venus
# yearn-finance
# origin-protocol
# basic-attention-token
# fantom
# storm
# kusama
# reserve-rights-token
# band-protocol
# ravencoin
# coti
# theta-fuel
# verge
# alpha-finance
# chromaway
# icon
# compound-governance-token
# waves
# paris-saint-germain-fan-token
# storj
# fetch-ai
# celer-network
# btc-standard-hashrate-token
# dodo
# zencash
# safepal
# the-sandbox
# digibyte
# near
# vethor-token
# linear
# 0x
# audius
# republic-protocol
# axie-infinity
# litentry
# my-neighbor-alice
# kava
# cartesi
# maker
# metal
# flamingo-finance
# havven
# gifto
# vite
# kyber-network-crystal
# just
# ocean-protocol
# dia-data
# tellor
# nano
# tomochain
# akropolis
# loopring
# bluzelle
# blockstack
# skale
# nervos-network
# civic
# helium
# oasis-network
# dego-finance
# force-protocol
# moviebloc
# bakerytoken
# bitshares
# iotex
# funfair
# arpa-chain
# bella-protocol
# bitcoin-gold
# yfii-finance
# injective-protocol
# marlin
# aragon
# lisk
# superfarm
# aion
# unifi-protocol-dao
# 2021-05-01T00:00:00.000000Z: 4733.890000
# 2021-05-02T00:00:00.000000Z: 4876.510000
# 2021-05-03T00:00:00.000000Z: 4791.550000
# 2021-05-04T00:00:00.000000Z: 5035.440000
# 2021-05-05T00:00:00.000000Z: 4825.070000
# 2021-05-06T00:00:00.000000Z: 5540.200000
# 2021-05-07T00:00:00.000000Z: 5582.060000
# 2021-05-08T00:00:00.000000Z: 5619.410000
# 2021-05-09T00:00:00.000000Z: 5606.720000
# 2021-05-10T00:00:00.000000Z: 5616.630000
# 2021-05-11T00:00:00.000000Z: 5090.120000
# 2021-05-12T00:00:00.000000Z: 5496.050000
# 2021-05-13T00:00:00.000000Z: 4728.320000
# 2021-05-14T00:00:00.000000Z: 5048.720000
# 2021-05-15T00:00:00.000000Z: 5402.050000
# 2021-05-16T00:00:00.000000Z: 5163.130000
# 2021-05-17T00:00:00.000000Z: 5199.770000
# 2021-05-18T00:00:00.000000Z: 4863.920000
# 2021-05-19T00:00:00.000000Z: 4999.650000
# 2021-05-20T00:00:00.000000Z: 3297.300000
# 2021-05-21T00:00:00.000000Z: 3889.770000
# 2021-05-22T00:00:00.000000Z: 3326.150000
# 2021-05-23T00:00:00.000000Z: 3070.750000
# 2021-05-24T00:00:00.000000Z: 2665.540000
# 2021-05-25T00:00:00.000000Z: 3375.010000
# 2021-05-26T00:00:00.000000Z: 3332.950000
# 2021-05-27T00:00:00.000000Z: 3649.710000
# 2021-05-28T00:00:00.000000Z: 3491.290000
# 2021-05-29T00:00:00.000000Z: 3153.280000
# 2021-05-30T00:00:00.000000Z: 2954.540000
# 2021-05-31T00:00:00.000000Z: 3126.660000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 114    BZRX
# Name: baseAsset, dtype: object
# dogecoin
# binancecoin
# ripple
# cardano
# matic-network
# polkadot
# ethereum-classic
# eos
# litecoin
# chainlink
# vechain
# bitcoin-cash
# tron
# pancakeswap-token
# solana
# stellar
# swipe
# uniswap
# theta-token
# chiliz
# bakerytoken
# terra-luna
# sushi
# filecoin
# aave
# neo
# bittorrent-old
# venus
# zcash
# thorchain
# ontology
# fantom
# avalanche-2
# yearn-finance
# cosmos
# qtum
# reef
# omisego
# monero
# holotoken
# dash
# wink
# kusama
# iexec-rlc
# enjincoin
# tezos
# dent
# curve-dao-token
# waves
# alien-worlds
# zilliqa
# harmony
# iota
# algorand
# hedera-hashgraph
# 1inch
# my-neighbor-alice
# compound-governance-token
# iostoken
# the-graph
# elrond-erd-2
# serum
# cartesi
# nano
# maker
# zencash
# havven
# decentraland
# wazirx
# nem
# coti
# smooth-love-potion
# siacoin
# near
# kava
# chromaway
# theta-fuel
# tokocrypto
# alpha-finance
# icon
# basic-attention-token
# burger-swap
# origin-protocol
# band-protocol
# reserve-rights-token
# ftx-token
# lisk
# ravencoin
# linear
# celer-network
# verge
# paris-saint-germain-fan-token
# ankr
# ocean-protocol
# digibyte
# nkn
# injective-protocol
# fetch-ai
# the-sandbox
# tellor
# republic-protocol
# 0x
# atletico-madrid
# loopring
# ellipsis
# dexe
# storm
# dodo
# safepal
# stratis
# axie-infinity
# storj
# kyber-network-crystal
# vethor-token
# skale
# flamingo-finance
# btc-standard-hashrate-token
# iotex
# dego-finance
# dia-data
# utrust
# litentry
# pundi-x-2
# 2021-06-01T00:00:00.000000Z: 3456.310000
# 2021-06-02T00:00:00.000000Z: 3468.140000
# 2021-06-03T00:00:00.000000Z: 3668.450000
# 2021-06-04T00:00:00.000000Z: 3828.130000
# 2021-06-05T00:00:00.000000Z: 3532.560000
# 2021-06-06T00:00:00.000000Z: 3439.570000
# 2021-06-07T00:00:00.000000Z: 3493.530000
# 2021-06-08T00:00:00.000000Z: 3186.960000
# 2021-06-09T00:00:00.000000Z: 3177.630000
# 2021-06-10T00:00:00.000000Z: 3352.240000
# 2021-06-11T00:00:00.000000Z: 3164.180000
# 2021-06-12T00:00:00.000000Z: 3009.890000
# 2021-06-13T00:00:00.000000Z: 2999.390000
# 2021-06-14T00:00:00.000000Z: 3188.800000
# 2021-06-15T00:00:00.000000Z: 3283.550000
# 2021-06-16T00:00:00.000000Z: 3218.890000
# 2021-06-17T00:00:00.000000Z: 3075.710000
# 2021-06-18T00:00:00.000000Z: 3096.780000
# 2021-06-19T00:00:00.000000Z: 2924.470000
# 2021-06-20T00:00:00.000000Z: 2839.870000
# 2021-06-21T00:00:00.000000Z: 2885.240000
# 2021-06-22T00:00:00.000000Z: 2225.090000
# 2021-06-23T00:00:00.000000Z: 2172.570000
# 2021-06-24T00:00:00.000000Z: 2425.800000
# 2021-06-25T00:00:00.000000Z: 2562.040000
# 2021-06-26T00:00:00.000000Z: 2316.580000
# 2021-06-27T00:00:00.000000Z: 2345.460000
# 2021-06-28T00:00:00.000000Z: 2474.190000
# 2021-06-29T00:00:00.000000Z: 2500.560000
# 2021-06-30T00:00:00.000000Z: 2634.340000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 114    BZRX
# Name: baseAsset, dtype: object
# binancecoin
# cardano
# matic-network
# dogecoin
# ripple
# polkadot
# solana
# vechain
# chainlink
# shiba-inu
# litecoin
# theta-fuel
# theta-token
# filecoin
# ethereum-classic
# eos
# tron
# pancakeswap-token
# kusama
# chiliz
# internet-computer
# swipe
# thorchain
# terra-luna
# bakerytoken
# bitcoin-cash
# aave
# uniswap
# stellar
# sushi
# monero
# fantom
# neo
# bittorrent-old
# waves
# enjincoin
# curve-dao-token
# cosmos
# zcash
# kava
# zilliqa
# 1inch
# wink
# holotoken
# avalanche-2
# omisego
# streamr
# dash
# ontology
# hedera-hashgraph
# yearn-finance
# algorand
# the-graph
# venus
# wazirx
# iota
# dexe
# dent
# elrond-erd-2
# my-neighbor-alice
# qtum
# harmony
# fetch-ai
# tezos
# reef
# kava-lend
# near
# mdex
# cartesi
# origin-protocol
# iostoken
# compound-governance-token
# coti
# siacoin
# zencash
# alien-worlds
# icon
# dock
# celer-network
# nano
# serum
# maker
# iexec-rlc
# gifto
# chromaway
# verge
# kyber-network-crystal
# havven
# ftx-token
# nem
# reserve-rights-token
# ocean-protocol
# alpha-finance
# tokocrypto
# band-protocol
# smooth-love-potion
# ravencoin
# pax-gold
# decentraland
# storm
# basic-attention-token
# skale
# dodo
# digibyte
# linear
# trust-wallet-token
# ankr
# injective-protocol
# metal
# the-sandbox
# nervos-network
# axie-infinity
# perpetual-protocol
# aragon
# flamingo-finance
# helium
# iotex
# perlin
# safepal
# tellor
# audius
# lisk
# tomochain
# loopring
# republic-protocol
# 0x
# livepeer
# blockstack
# unifi-protocol-dao
# burger-swap
# arweave
# pha
# marlin
# bella-protocol
# superfarm
# nkn
# litentry
# 2021-07-01T00:00:00.000000Z: 2647.220000
# 2021-07-02T00:00:00.000000Z: 2489.610000
# 2021-07-03T00:00:00.000000Z: 2517.080000
# 2021-07-04T00:00:00.000000Z: 2577.450000
# 2021-07-05T00:00:00.000000Z: 2641.090000
# 2021-07-06T00:00:00.000000Z: 2538.460000
# 2021-07-07T00:00:00.000000Z: 2625.860000
# 2021-07-08T00:00:00.000000Z: 2624.190000
# 2021-07-09T00:00:00.000000Z: 2460.360000
# 2021-07-10T00:00:00.000000Z: 2527.300000
# 2021-07-11T00:00:00.000000Z: 2484.990000
# 2021-07-12T00:00:00.000000Z: 2521.610000
# 2021-07-13T00:00:00.000000Z: 2443.980000
# 2021-07-14T00:00:00.000000Z: 2364.420000
# 2021-07-15T00:00:00.000000Z: 2353.390000
# 2021-07-16T00:00:00.000000Z: 2279.560000
# 2021-07-17T00:00:00.000000Z: 2170.100000
# 2021-07-18T00:00:00.000000Z: 2185.070000
# 2021-07-19T00:00:00.000000Z: 2190.840000
# 2021-07-20T00:00:00.000000Z: 2059.060000
# 2021-07-21T00:00:00.000000Z: 1952.500000
# 2021-07-22T00:00:00.000000Z: 2176.440000
# 2021-07-23T00:00:00.000000Z: 2228.780000
# 2021-07-24T00:00:00.000000Z: 2290.810000
# 2021-07-25T00:00:00.000000Z: 2335.950000
# 2021-07-26T00:00:00.000000Z: 2341.790000
# 2021-07-27T00:00:00.000000Z: 2380.210000
# 2021-07-28T00:00:00.000000Z: 2450.890000
# 2021-07-29T00:00:00.000000Z: 2497.550000
# 2021-07-30T00:00:00.000000Z: 2541.280000
# 2021-07-31T00:00:00.000000Z: 2608.860000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 117    BZRX
# 157    RAMP
# Name: baseAsset, dtype: object
# binancecoin
# axie-infinity
# dogecoin
# cardano
# ripple
# polkadot
# matic-network
# alien-worlds
# solana
# chainlink
# ethereum-classic
# theta-token
# litecoin
# my-neighbor-alice
# vechain
# terra-luna
# eos
# internet-computer
# the-sandbox
# shiba-inu
# filecoin
# aave
# pancakeswap-token
# smooth-love-potion
# tron
# uniswap
# thorchain
# chromaway
# chiliz
# bitcoin-cash
# enjincoin
# bakerytoken
# sushi
# compound-governance-token
# swipe
# cosmos
# stellar
# theta-fuel
# kusama
# havven
# monero
# decentraland
# neo
# dexe
# zcash
# the-graph
# alpha-finance
# linear
# bittorrent-old
# omisego
# kava
# fetch-ai
# ontology
# elrond-erd-2
# waves
# fantom
# mdex
# iostoken
# dash
# curve-dao-token
# holotoken
# dodo
# yearn-finance
# origin-protocol
# ellipsis
# hedera-hashgraph
# tezos
# ftx-token
# superfarm
# 1inch
# harmony
# audius
# algorand
# zilliqa
# the-virtua-kolect
# near
# wink
# unifi-protocol-dao
# avalanche-2
# iota
# sun-token
# litentry
# blockstack
# dent
# nem
# dego-finance
# tomochain
# venus
# qtum
# perpetual-protocol
# reef
# siacoin
# icon
# streamr
# WARNING: Unexpected shape for streamr, ignoring (returning 0,0)
# tokocrypto
# serum
# zencash
# automata
# coti
# adex
# wazirx
# ravencoin
# storm
# celer-network
# basic-attention-token
# band-protocol
# yfii-finance
# cartesi
# skale
# maker
# reserve-rights-token
# injective-protocol
# paris-saint-germain-fan-token
# helium
# safepal
# ampleforth-governance-token
# iexec-rlc
# keep-network
# bella-protocol
# nano
# bluzelle
# gitcoin
# metal
# lisk
# kyber-network-crystal
# pax-gold
# certik
# tellor
# verge
# storj
# ankr
# fio-protocol
# iotex
# 0x
# kava-lend
# dock
# celo
# ocean-protocol
# mithril
# marlin
# pundi-x-2
# trust-wallet-token
# cocos-bcx
# flamingo-finance
# akropolis
# republic-protocol
# aragon
# digibyte
# loopring
# nkn
# augur
# dia-data
# btc-standard-hashrate-token
# pha
# komodo
# contentos
# ong
# mantra-dao
# binance-eth
# stratis
# vite
# atletico-madrid
# mainframe
# burger-swap
# 2021-08-01T00:00:00.000000Z: 2656.560000
# 2021-08-02T00:00:00.000000Z: 2630.310000
# 2021-08-03T00:00:00.000000Z: 2645.290000
# 2021-08-04T00:00:00.000000Z: 2619.190000
# 2021-08-05T00:00:00.000000Z: 2713.710000
# 2021-08-06T00:00:00.000000Z: 2763.180000
# 2021-08-07T00:00:00.000000Z: 2829.980000
# 2021-08-08T00:00:00.000000Z: 3042.950000
# 2021-08-09T00:00:00.000000Z: 2877.190000
# 2021-08-10T00:00:00.000000Z: 3022.330000
# 2021-08-11T00:00:00.000000Z: 3150.620000
# 2021-08-12T00:00:00.000000Z: 3338.610000
# 2021-08-13T00:00:00.000000Z: 3283.150000
# 2021-08-14T00:00:00.000000Z: 3612.570000
# 2021-08-15T00:00:00.000000Z: 3710.110000
# 2021-08-16T00:00:00.000000Z: 3823.350000
# 2021-08-17T00:00:00.000000Z: 3736.170000
# 2021-08-18T00:00:00.000000Z: 3549.540000
# 2021-08-19T00:00:00.000000Z: 3659.050000
# 2021-08-20T00:00:00.000000Z: 3953.870000
# 2021-08-21T00:00:00.000000Z: 4106.920000
# 2021-08-22T00:00:00.000000Z: 4028.610000
# 2021-08-23T00:00:00.000000Z: 4112.290000
# 2021-08-24T00:00:00.000000Z: 4290.010000
# 2021-08-25T00:00:00.000000Z: 3986.370000
# 2021-08-26T00:00:00.000000Z: 4097.910000
# 2021-08-27T00:00:00.000000Z: 3808.520000
# 2021-08-28T00:00:00.000000Z: 4195.490000
# 2021-08-29T00:00:00.000000Z: 4143.080000
# 2021-08-30T00:00:00.000000Z: 4111.090000
# 2021-08-31T00:00:00.000000Z: 4007.990000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 149    BZRX
# 176    RAMP
# Name: baseAsset, dtype: object
# cardano
# binancecoin
# ripple
# dogecoin
# polkadot
# solana
# axie-infinity
# matic-network
# terra-luna
# chainlink
# filecoin
# internet-computer
# vechain
# my-neighbor-alice
# litecoin
# ethereum-classic
# eos
# alien-worlds
# coin98
# theta-token
# thorchain
# pancakeswap-token
# tron
# chiliz
# shiba-inu
# uniswap
# avalanche-2
# bitcoin-cash
# bakerytoken
# sushi
# smooth-love-potion
# kava
# fantom
# dent
# aave
# the-graph
# swipe
# cosmos
# stellar
# bittorrent-old
# neo
# ftx-token
# the-sandbox
# qtum
# enjincoin
# kusama
# chromaway
# holotoken
# iotex
# audius
# algorand
# monero
# wink
# elrond-erd-2
# near
# coti
# curve-dao-token
# omisego
# ellipsis
# dash
# tezos
# serum
# 1inch
# decentraland
# zcash
# linear
# compound-governance-token
# ravencoin
# alpha-finance
# ontology
# superfarm
# zilliqa
# reef
# havven
# truefi
# dodo
# venus
# iostoken
# paris-saint-germain-fan-token
# dego-finance
# origin-protocol
# iota
# the-virtua-kolect
# harmony
# fetch-ai
# hedera-hashgraph
# reserve-rights-token
# waves
# yearn-finance
# helium
# siacoin
# trust-wallet-token
# litentry
# unifi-protocol-dao
# theta-fuel
# tokocrypto
# perpetual-protocol
# cartesi
# automata
# funfair
# certik
# clover-finance
# wazirx
# ankr
# arweave
# verge
# ocean-protocol
# skale
# mask-network
# stafi
# celer-network
# iexec-rlc
# arpa-chain
# storm
# zencash
# injective-protocol
# kava-lend
# loopring
# mdex
# icon
# flow
# mirror-protocol
# streamr
# computeMedianDailyMarketCapAndLastCirSupply: WARNING last market cap data for streamr is too old, ignoring (returning 0,0)
# band-protocol
# force-protocol
# nano
# adex
# basic-attention-token
# nem
# safepal
# flamingo-finance
# marlin
# keep-network
# yfii-finance
# gitcoin
# nkn
# dexe
# quant-network
# burger-swap
# lisk
# maker
# ethernity-chain
# bella-protocol
# kyber-network-crystal
# oasis-network
# tellor
# digibyte
# republic-protocol
# metal
# balancer
# lto-network
# storj
# 0x
# dia-data
# utrust
# akropolis
# orion-protocol
# aavegotchi
# civic
# bluzelle
# fio-protocol
# tomochain
# celo
# badger-dao
# nucypher
# conflux-token
# dock
# sun-token
# uma
# btc-standard-hashrate-token
# mithril
# aion
# vethor-token
# nervos-network
# blockstack
# mantra-dao
# ampleforth-governance-token
# orchid-protocol
# polkastarter
# vite
# pundi-x-2
# klay-token
# perlin
# contentos
# atletico-madrid
# 2021-09-01T00:00:00.000000Z: 4142.730000
# 2021-09-02T00:00:00.000000Z: 4370.060000
# 2021-09-03T00:00:00.000000Z: 4424.820000
# 2021-09-04T00:00:00.000000Z: 4540.790000
# 2021-09-05T00:00:00.000000Z: 4537.610000
# 2021-09-06T00:00:00.000000Z: 4732.920000
# 2021-09-07T00:00:00.000000Z: 4776.940000
# 2021-09-08T00:00:00.000000Z: 4076.260000
# 2021-09-09T00:00:00.000000Z: 4104.410000
# 2021-09-10T00:00:00.000000Z: 4190.080000
# 2021-09-11T00:00:00.000000Z: 4070.290000
# 2021-09-12T00:00:00.000000Z: 4181.680000
# 2021-09-13T00:00:00.000000Z: 4318.980000
# 2021-09-14T00:00:00.000000Z: 4108.210000
# 2021-09-15T00:00:00.000000Z: 4203.760000
# 2021-09-16T00:00:00.000000Z: 4322.140000
# 2021-09-17T00:00:00.000000Z: 4236.940000
# 2021-09-18T00:00:00.000000Z: 4085.010000
# 2021-09-19T00:00:00.000000Z: 4198.600000
# 2021-09-20T00:00:00.000000Z: 4063.320000
# 2021-09-21T00:00:00.000000Z: 3546.510000
# 2021-09-22T00:00:00.000000Z: 3349.330000
# 2021-09-23T00:00:00.000000Z: 3838.010000
# 2021-09-24T00:00:00.000000Z: 3926.020000
# 2021-09-25T00:00:00.000000Z: 3708.750000
# 2021-09-26T00:00:00.000000Z: 3658.090000
# 2021-09-27T00:00:00.000000Z: 3614.090000
# 2021-09-28T00:00:00.000000Z: 3516.530000
# 2021-09-29T00:00:00.000000Z: 3391.050000
# 2021-09-30T00:00:00.000000Z: 3509.630000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 145    BZRX
# 152    RAMP
# 177    SWRV
# Name: baseAsset, dtype: object
# solana
# cardano
# binancecoin
# polkadot
# ripple
# avalanche-2
# terra-luna
# fantom
# filecoin
# dogecoin
# chainlink
# cosmos
# ftx-token
# matic-network
# algorand
# litecoin
# vechain
# eos
# tron
# omisego
# celer-network
# near
# axie-infinity
# tezos
# theta-token
# internet-computer
# harmony
# elrond-erd-2
# serum
# pancakeswap-token
# hedera-hashgraph
# coin98
# aurora-dao
# iostoken
# ethereum-classic
# sushi
# uniswap
# ecash
# my-neighbor-alice
# coti
# bitcoin-cash
# smooth-love-potion
# shiba-inu
# curve-dao-token
# chiliz
# aave
# swipe
# mina-protocol
# iota
# thorchain
# alien-worlds
# fetch-ai
# kusama
# celo
# stellar
# kava
# the-graph
# arweave
# automata
# oasis-network
# mobox
# bittorrent-old
# monero
# quant-network
# neo
# audius
# raydium
# trust-wallet-token
# the-sandbox
# dent
# 1inch
# waves
# marlin
# zilliqa
# chromaway
# qtum
# holotoken
# dash
# zcash
# ellipsis
# reef
# havven
# bakerytoken
# ontology
# mask-network
# compound-governance-token
# icon
# republic-protocol
# origin-protocol
# funfair
# perpetual-protocol
# iotex
# enjincoin
# venus
# arpa-chain
# dodo
# yearn-finance
# v-id-blockchain
# decentraland
# reserve-rights-token
# force-protocol
# wink
# ravencoin
# alpha-finance
# dexe
# skale
# injective-protocol
# tokocrypto
# theta-fuel
# siacoin
# linear
# aelf
# zencash
# superfarm
# cartesi
# civic
# loopring
# litentry
# clover-finance
# kava-lend
# wazirx
# flow
# conflux-token
# band-protocol
# metal
# ocean-protocol
# verge
# tomochain
# unifi-protocol-dao
# truefi
# nervos-network
# nano
# maker
# orion-protocol
# the-virtua-kolect
# certik
# wax
# adex
# helium
# tellor
# dego-finance
# ankr
# mdex
# frontier-token
# iexec-rlc
# storm
# bluzelle
# basic-attention-token
# nem
# keep-network
# paris-saint-germain-fan-token
# pha
# mirror-protocol
# polymath
# dforce-token
# flamingo-finance
# harvest-finance
# dia-data
# mantra-dao
# alpaca-finance
# blockstack
# safepal
# balancer
# utrust
# digibyte
# stafi
# 0x
# bella-protocol
# akropolis
# yfii-finance
# concierge-io
# dock
# streamr
# contentos
# waltonchain
# 2021-10-01T00:00:00.000000Z: 3661.300000
# 2021-10-02T00:00:00.000000Z: 4000.770000
# 2021-10-03T00:00:00.000000Z: 4047.760000
# 2021-10-04T00:00:00.000000Z: 4123.860000
# 2021-10-05T00:00:00.000000Z: 4085.020000
# 2021-10-06T00:00:00.000000Z: 4183.420000
# 2021-10-07T00:00:00.000000Z: 4162.640000
# 2021-10-08T00:00:00.000000Z: 4190.520000
# 2021-10-09T00:00:00.000000Z: 4171.240000
# 2021-10-10T00:00:00.000000Z: 4262.180000
# 2021-10-11T00:00:00.000000Z: 4041.060000
# 2021-10-12T00:00:00.000000Z: 4070.690000
# 2021-10-13T00:00:00.000000Z: 4063.270000
# 2021-10-14T00:00:00.000000Z: 4207.740000
# 2021-10-15T00:00:00.000000Z: 4229.010000
# 2021-10-16T00:00:00.000000Z: 4296.110000
# 2021-10-17T00:00:00.000000Z: 4268.650000
# 2021-10-18T00:00:00.000000Z: 4238.840000
# 2021-10-19T00:00:00.000000Z: 4223.340000
# 2021-10-20T00:00:00.000000Z: 4246.650000
# 2021-10-21T00:00:00.000000Z: 4484.430000
# 2021-10-22T00:00:00.000000Z: 4380.240000
# 2021-10-23T00:00:00.000000Z: 4453.350000
# 2021-10-24T00:00:00.000000Z: 4532.840000
# 2021-10-25T00:00:00.000000Z: 4497.570000
# 2021-10-26T00:00:00.000000Z: 4669.760000
# 2021-10-27T00:00:00.000000Z: 4666.930000
# 2021-10-28T00:00:00.000000Z: 4376.890000
# 2021-10-29T00:00:00.000000Z: 4616.510000
# 2021-10-30T00:00:00.000000Z: 4774.740000
# 2021-10-31T00:00:00.000000Z: 4636.120000
# shiba-inu
# solana
# binancecoin
# polkadot
# ripple
# fantom
# dogecoin
# cardano
# terra-luna
# filecoin
# axie-infinity
# avalanche-2
# chainlink
# matic-network
# tron
# litecoin
# cosmos
# omisego
# vechain
# harmony
# smooth-love-potion
# dydx
# eos
# internet-computer
# ftx-token
# theta-token
# near
# algorand
# gala
# stellar
# ethereum-classic
# celer-network
# pancakeswap-token
# uniswap
# tezos
# bitcoin-cash
# elrond-erd-2
# coti
# chiliz
# kava
# coin98
# sushi
# curve-dao-token
# thorchain
# 1inch
# swipe
# hedera-hashgraph
# bittorrent-old
# my-neighbor-alice
# fetch-ai
# the-graph
# serum
# wink
# iota
# btc-standard-hashrate-token
# dent
# holotoken
# monero
# aave
# ecash
# reef
# alien-worlds
# zcash
# celo
# ontology
# iostoken
# arpa-chain
# qtum
# mina-protocol
# kusama
# oasis-network
# zilliqa
# enjincoin
# arweave
# flow
# compound-governance-token
# dash
# bakerytoken
# linear
# mobox
# neo
# aurora-dao
# the-sandbox
# automata
# iotex
# ellipsis
# waves
# dodo
# wax
# cartesi
# yearn-finance
# superfarm
# chromaway
# trust-wallet-token
# marlin
# mask-network
# icon
# audius
# just
# decentraland
# safepal
# havven
# reserve-rights-token
# funfair
# theta-fuel
# blockstack
# force-protocol
# nucypher
# origin-protocol
# ravencoin
# venus
# quant-network
# republic-protocol
# siacoin
# troy
# stp-network
# zencash
# secret
# keep-network
# raydium
# sun-token
# kava-lend
# perpetual-protocol
# conflux-token
# ocean-protocol
# wazirx
# ankr
# yield-guild-games
# litentry
# loopring
# metal
# mdex
# helium
# alpha-finance
# polymath
# skale
# unifi-protocol-dao
# certik
# nervos-network
# basic-attention-token
# klay-token
# injective-protocol
# civic
# badger-dao
# storm
# verge
# tokocrypto
# iexec-rlc
# v-id-blockchain
# 2021-11-01T00:00:00.000000Z: 4696.940000
# 2021-11-02T00:00:00.000000Z: 4793.300000
# 2021-11-03T00:00:00.000000Z: 4901.910000
# 2021-11-04T00:00:00.000000Z: 5005.080000
# 2021-11-05T00:00:00.000000Z: 4951.730000
# 2021-11-06T00:00:00.000000Z: 4996.400000
# 2021-11-07T00:00:00.000000Z: 5078.520000
# 2021-11-08T00:00:00.000000Z: 5136.680000
# 2021-11-09T00:00:00.000000Z: 5294.350000
# 2021-11-10T00:00:00.000000Z: 5259.350000
# 2021-11-11T00:00:00.000000Z: 4985.250000
# 2021-11-12T00:00:00.000000Z: 5082.470000
# 2021-11-13T00:00:00.000000Z: 4989.880000
# 2021-11-14T00:00:00.000000Z: 5092.460000
# 2021-11-15T00:00:00.000000Z: 5088.620000
# 2021-11-16T00:00:00.000000Z: 4987.040000
# 2021-11-17T00:00:00.000000Z: 4596.820000
# 2021-11-18T00:00:00.000000Z: 4630.630000
# 2021-11-19T00:00:00.000000Z: 4279.230000
# 2021-11-20T00:00:00.000000Z: 4588.650000
# 2021-11-21T00:00:00.000000Z: 4703.980000
# 2021-11-22T00:00:00.000000Z: 4638.980000
# 2021-11-23T00:00:00.000000Z: 4481.650000
# 2021-11-24T00:00:00.000000Z: 4586.610000
# 2021-11-25T00:00:00.000000Z: 4408.080000
# 2021-11-26T00:00:00.000000Z: 4590.770000
# 2021-11-27T00:00:00.000000Z: 4157.560000
# 2021-11-28T00:00:00.000000Z: 4236.410000
# 2021-11-29T00:00:00.000000Z: 4328.740000
# 2021-11-30T00:00:00.000000Z: 4457.430000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 151    BZRX
# 189    RAMP
# Name: baseAsset, dtype: object
# shiba-inu
# the-sandbox
# binancecoin
# decentraland
# solana
# polkadot
# avalanche-2
# ripple
# tron
# gala
# cardano
# dogecoin
# loopring
# fantom
# litecoin
# terra-luna
# filecoin
# omisego
# chiliz
# chainlink
# matic-network
# vechain
# chromaway
# enjincoin
# alien-worlds
# axie-infinity
# smooth-love-potion
# my-neighbor-alice
# iotex
# elrond-erd-2
# internet-computer
# harmony
# theta-token
# cosmos
# zcash
# wax
# algorand
# dydx
# eos
# curve-dao-token
# holotoken
# pancakeswap-token
# near
# ethereum-classic
# the-graph
# oasis-network
# stellar
# wink
# bitcoin-cash
# ftx-token
# bittorrent-old
# arweave
# swipe
# sushi
# thorchain
# basic-attention-token
# uniswap
# celer-network
# ankr
# mina-protocol
# aave
# just
# dent
# dash
# tezos
# 1inch
# monero
# mobox
# hedera-hashgraph
# cartesi
# fetch-ai
# iota
# coti
# the-virtua-kolect
# arpa-chain
# storj
# qtum
# mask-network
# sun-token
# zencash
# kava
# audius
# superfarm
# reef
# livepeer
# helium
# flow
# kusama
# ontology
# linear
# beta-finance
# automata
# origin-protocol
# coin98
# serum
# keep3rv1
# aurora-dao
# bakerytoken
# ecash
# iostoken
# zilliqa
# icon
# siacoin
# keep-network
# yield-guild-games
# trust-wallet-token
# compound-governance-token
# neo
# ocean-protocol
# skale
# marlin
# ravencoin
# celo
# lto-network
# nucypher
# reserve-rights-token
# syscoin
# nervos-network
# havven
# blockstack
# quant-network
# nkn
# dodo
# litentry
# yearn-finance
# ellipsis
# hive
# illuvium
# injective-protocol
# wazirx
# civic
# bluzelle
# theta-fuel
# alpha-finance
# orchid-protocol
# waves
# uma
# safepal
# flamingo-finance
# btc-standard-hashrate-token
# adventure-gold
# verge
# klay-token
# venus
# raydium
# 0x
# radicle
# digibyte
# maker
# mithril
# secret
# funfair
# band-protocol
# selfkey
# nem
# republic-protocol
# dego-finance
# tranchess
# clover-finance
# polymath
# adex
# vethor-token
# iexec-rlc
# storm
# unifi-protocol-dao
# dusk-network
# superrare
# nano
# stp-network
# tokocrypto
# gitcoin
# balancer
# mirror-protocol
# streamr
# orion-protocol
# aavegotchi
# lazio-fan-token
# kyber-network-crystal
# tomochain
# tellor
# perpetual-protocol
# conflux-token
# bella-protocol
# mdex
# ethos
# v-id-blockchain
# force-protocol
# ethernity-chain
# tribe-2
# badger-dao
# polkastarter
# certik
# troy
# gifto
# cocos-bcx
# 2021-12-01T00:00:00.000000Z: 4491.070000
# 2021-12-02T00:00:00.000000Z: 4535.570000
# 2021-12-03T00:00:00.000000Z: 4526.080000
# 2021-12-04T00:00:00.000000Z: 4293.960000
# 2021-12-05T00:00:00.000000Z: 3955.900000
# 2021-12-06T00:00:00.000000Z: 3809.710000
# 2021-12-07T00:00:00.000000Z: 3906.180000
# 2021-12-08T00:00:00.000000Z: 3901.250000
# 2021-12-09T00:00:00.000000Z: 4046.390000
# 2021-12-10T00:00:00.000000Z: 3738.250000
# 2021-12-11T00:00:00.000000Z: 3569.010000
# 2021-12-12T00:00:00.000000Z: 3731.720000
# 2021-12-13T00:00:00.000000Z: 3769.270000
# 2021-12-14T00:00:00.000000Z: 3394.950000
# 2021-12-15T00:00:00.000000Z: 3556.170000
# 2021-12-16T00:00:00.000000Z: 3703.280000
# 2021-12-17T00:00:00.000000Z: 3597.980000
# 2021-12-18T00:00:00.000000Z: 3562.510000
# 2021-12-19T00:00:00.000000Z: 3691.690000
# 2021-12-20T00:00:00.000000Z: 3660.880000
# 2021-12-21T00:00:00.000000Z: 3646.120000
# 2021-12-22T00:00:00.000000Z: 3797.590000
# 2021-12-23T00:00:00.000000Z: 3868.440000
# 2021-12-24T00:00:00.000000Z: 4129.700000
# 2021-12-25T00:00:00.000000Z: 4027.180000
# 2021-12-26T00:00:00.000000Z: 4114.300000
# 2021-12-27T00:00:00.000000Z: 4186.810000
# 2021-12-28T00:00:00.000000Z: 4186.770000
# 2021-12-29T00:00:00.000000Z: 3864.400000
# 2021-12-30T00:00:00.000000Z: 3756.700000
# 2021-12-31T00:00:00.000000Z: 3818.240000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 209    RAMP
# Name: baseAsset, dtype: object
# terra-luna
# binancecoin
# matic-network
# solana
# the-sandbox
# shiba-inu
# avalanche-2
# gala
# polkadot
# ripple
# cardano
# decentraland
# dogecoin
# fantom
# chainlink
# near
# tron
# filecoin
# litecoin
# curve-dao-token
# cosmos
# oasis-network
# vechain
# elrond-erd-2
# sushi
# axie-infinity
# internet-computer
# loopring
# eos
# theta-token
# omisego
# algorand
# harmony
# my-neighbor-alice
# enjincoin
# bittorrent-old
# mobox
# dydx
# chromaway
# stellar
# uniswap
# pancakeswap-token
# alien-worlds
# zcash
# smooth-love-potion
# chiliz
# mines-of-dalarnia
# gxchain
# aave
# ethereum-name-service
# wink
# tezos
# bitcoin-cash
# basic-attention-token
# iotex
# aragon
# the-graph
# just
# dusk-network
# sun-token
# ethereum-classic
# thorchain
# cortex
# contentos
# iota
# monero
# kava
# holotoken
# 1inch
# measurable-data-token
# celer-network
# vulcan-forged
# arweave
# yearn-finance
# ftx-token
# gitcoin
# cocos-bcx
# safepal
# hedera-hashgraph
# wax
# syscoin
# swipe
# coti
# lto-network
# mina-protocol
# jasmycoin
# zilliqa
# celo
# helium
# dash
# dent
# reserve-rights-token
# nuls
# superfarm
# coin98
# mask-network
# flow
# ocean-protocol
# ankr
# waves
# serum
# neo
# icon
# yield-guild-games
# reef
# audius
# request-network
# theta-fuel
# havven
# mithril
# compound-governance-token
# render-token
# iostoken
# quant-network
# marlin
# linear
# zencash
# qtum
# fetch-ai
# cartesi
# kusama
# ontology
# aurora-dao
# origin-protocol
# ravencoin
# blockstack
# storj
# dodo
# benqi
# binaryx
# illuvium
# unifi-protocol-dao
# bakerytoken
# the-virtua-kolect
# ecash
# beta-finance
# nervos-network
# arpa-chain
# keep3rv1
# certik
# tranchess
# waltonchain
# automata
# siacoin
# gifto
# republic-protocol
# trust-wallet-token
# litentry
# klay-token
# keep-network
# skale
# ellipsis
# hive
# bluzelle
# selfkey
# nucypher
# livepeer
# moonriver
# iexec-rlc
# frontier-token
# injective-protocol
# adventure-gold
# tokenclub
# wazirx
# maker
# lazio-fan-token
# venus
# mirror-protocol
# adex
# clover-finance
# mdex
# fio-protocol
# raydium
# v-id-blockchain
# bread
# digibyte
# band-protocol
# nano
# nkn
# storm
# conflux-token
# force-protocol
# dexe
# superrare
# yfii-finance
# bella-protocol
# radicle
# btc-standard-hashrate-token
# beam
# balancer
# uma
# pax-gold
# tellor
# troy
# nem
# pnetwork
# streamr
# verge
# ethos
# flamingo-finance
# metal
# drep-new
# vethor-token
# amp-token
# truefi
# mantra-dao
# polkastarter
# pha
# dock
# utrust
# dego-finance
# 0x
# aion
# 2022-01-01T00:00:00.000000Z: 3780.810000
# 2022-01-02T00:00:00.000000Z: 3947.570000
# 2022-01-03T00:00:00.000000Z: 3952.240000
# 2022-01-04T00:00:00.000000Z: 3897.380000
# 2022-01-05T00:00:00.000000Z: 3841.380000
# 2022-01-06T00:00:00.000000Z: 3593.230000
# 2022-01-07T00:00:00.000000Z: 3609.950000
# 2022-01-08T00:00:00.000000Z: 3391.180000
# 2022-01-09T00:00:00.000000Z: 3293.490000
# 2022-01-10T00:00:00.000000Z: 3372.770000
# 2022-01-11T00:00:00.000000Z: 3265.820000
# 2022-01-12T00:00:00.000000Z: 3458.940000
# 2022-01-13T00:00:00.000000Z: 3677.020000
# 2022-01-14T00:00:00.000000Z: 3537.510000
# 2022-01-15T00:00:00.000000Z: 3645.640000
# 2022-01-16T00:00:00.000000Z: 3675.040000
# 2022-01-17T00:00:00.000000Z: 3727.020000
# 2022-01-18T00:00:00.000000Z: 3587.710000
# 2022-01-19T00:00:00.000000Z: 3519.790000
# 2022-01-20T00:00:00.000000Z: 3396.210000
# 2022-01-21T00:00:00.000000Z: 3251.140000
# 2022-01-22T00:00:00.000000Z: 2833.650000
# 2022-01-23T00:00:00.000000Z: 2594.770000
# 2022-01-24T00:00:00.000000Z: 2754.600000
# 2022-01-25T00:00:00.000000Z: 2637.640000
# 2022-01-26T00:00:00.000000Z: 2680.130000
# 2022-01-27T00:00:00.000000Z: 2648.740000
# 2022-01-28T00:00:00.000000Z: 2623.930000
# 2022-01-29T00:00:00.000000Z: 2642.280000
# 2022-01-30T00:00:00.000000Z: 2696.080000
# 2022-01-31T00:00:00.000000Z: 2617.810000
# terra-luna
# fantom
# binancecoin
# solana
# cosmos
# cardano
# matic-network
# polkadot
# near
# the-sandbox
# shiba-inu
# ripple
# chainlink
# avalanche-2
# dogecoin
# oasis-network
# gala
# harmony
# tron
# curve-dao-token
# decentraland
# internet-computer
# litecoin
# filecoin
# loopring
# axie-infinity
# vechain
# dusk-network
# sushi
# theta-token
# algorand
# chromaway
# ftx-token
# elrond-erd-2
# omisego
# aave
# enjincoin
# aragon
# kava
# eos
# pancakeswap-token
# uniswap
# wink
# dydx
# monero
# my-neighbor-alice
# stellar
# swipe
# yearn-finance
# sun-token
# just
# zcash
# arweave
# thorchain
# ethereum-classic
# keep3rv1
# chiliz
# celer-network
# syscoin
# constitutiondao
# bitcoin-cash
# smooth-love-potion
# the-graph
# tezos
# alien-worlds
# ethereum-name-service
# iota
# celo
# mina-protocol
# hedera-hashgraph
# zelcash
# 1inch
# gxchain
# basic-attention-token
# coti
# secret
# flow
# dash
# helium
# ravencoin
# vulcan-forged
# iotex
# voxies
# spell-token
# zilliqa
# klay-token
# holotoken
# dent
# wax
# mobox
# mines-of-dalarnia
# havven
# biconomy
# gitcoin
# jasmycoin
# anyswap
# ocean-protocol
# yield-guild-games
# linear
# coin98
# neo
# fetch-ai
# quant-network
# render-token
# convex-finance
# mask-network
# compound-governance-token
# zencash
# ooki
# kusama
# waves
# cortex
# cartesi
# blockstack
# icon
# beta-finance
# frax-share
# kyber-network-crystal
# power-ledger
# marlin
# iostoken
# unifi-protocol-dao
# ankr
# serum
# republic-protocol
# cocos-bcx
# reef
# harvest-finance
# measurable-data-token
# qtum
# skale
# ontology
# lto-network
# joe
# theta-fuel
# highstreet
# ecash
# superfarm
# bakerytoken
# adex
# safepal
# cream-2
# band-protocol
# reserve-rights-token
# tranchess
# merit-circle
# dodo
# keep-network
# nervos-network
# moonriver
# audius
# origin-protocol
# the-virtua-kolect
# request-network
# binaryx
# siacoin
# contentos
# litentry
# maker
# benqi
# utrust
# storj
# illuvium
# livepeer
# nucypher
# certik
# pax-gold
# force-protocol
# ellipsis
# aurora-dao
# prosper
# nuls
# superrare
# digibyte
# radicle
# wazirx
# clover-finance
# venus
# trust-wallet-token
# metal
# iris-network
# arpa-chain
# alchemix
# verge
# automata
# kava-lend
# raydium
# polymath
# lazio-fan-token
# iexec-rlc
# bluzelle
# bella-protocol
# uma
# amp-token
# mithril
# 2022-02-01T00:00:00.000000Z: 2691.250000
# 2022-02-02T00:00:00.000000Z: 2759.170000
# 2022-02-03T00:00:00.000000Z: 2611.330000
# 2022-02-04T00:00:00.000000Z: 2663.490000
# 2022-02-05T00:00:00.000000Z: 2878.200000
# 2022-02-06T00:00:00.000000Z: 2923.070000
# 2022-02-07T00:00:00.000000Z: 3019.990000
# 2022-02-08T00:00:00.000000Z: 3204.590000
# 2022-02-09T00:00:00.000000Z: 3129.330000
# 2022-02-10T00:00:00.000000Z: 3192.950000
# 2022-02-11T00:00:00.000000Z: 3047.060000
# 2022-02-12T00:00:00.000000Z: 2857.400000
# 2022-02-13T00:00:00.000000Z: 2882.540000
# 2022-02-14T00:00:00.000000Z: 2835.510000
# 2022-02-15T00:00:00.000000Z: 2867.080000
# 2022-02-16T00:00:00.000000Z: 3079.080000
# 2022-02-17T00:00:00.000000Z: 3034.880000
# 2022-02-18T00:00:00.000000Z: 2803.840000
# 2022-02-19T00:00:00.000000Z: 2762.110000
# 2022-02-20T00:00:00.000000Z: 2781.240000
# 2022-02-21T00:00:00.000000Z: 2639.700000
# 2022-02-22T00:00:00.000000Z: 2457.880000
# 2022-02-23T00:00:00.000000Z: 2572.080000
# 2022-02-24T00:00:00.000000Z: 2521.100000
# 2022-02-25T00:00:00.000000Z: 2534.550000
# 2022-02-26T00:00:00.000000Z: 2687.720000
# 2022-02-27T00:00:00.000000Z: 2700.800000
# 2022-02-28T00:00:00.000000Z: 2573.350000
# terra-luna
# binancecoin
# ripple
# shiba-inu
# solana
# gala
# avalanche-2
# cardano
# fantom
# the-sandbox
# smooth-love-potion
# polkadot
# decentraland
# matic-network
# cosmos
# dogecoin
# tron
# chainlink
# near
# constitutiondao
# litecoin
# oasis-network
# axie-infinity
# filecoin
# internet-computer
# harmony
# theta-token
# vechain
# elrond-erd-2
# ethereum-classic
# curve-dao-token
# my-neighbor-alice
# loopring
# algorand
# eos
# enjincoin
# dydx
# beta-finance
# bitcoin-cash
# zcash
# ftx-token
# monero
# tezos
# alien-worlds
# mines-of-dalarnia
# uniswap
# chromaway
# kava
# jasmycoin
# wink
# pancakeswap-token
# omisego
# chiliz
# sushi
# aave
# stellar
# waves
# aurora-dao
# arweave
# neo
# flow
# vulcan-forged
# the-graph
# hedera-hashgraph
# just
# league-of-kingdoms
# sun-token
# aragon
# immutable-x
# thorchain
# mina-protocol
# render-token
# dusk-network
# moonbeam
# swipe
# mobox
# bittorrent
# ethereum-name-service
# api3
# syscoin
# quant-network
# celer-network
# ooki
# spell-token
# celo
# kyber-network-crystal
# dash
# voxies
# coti
# klay-token
# iotex
# anchor-protocol
# dent
# holotoken
# qtum
# keep3rv1
# helium
# iota
# superfarm
# 1inch
# yearn-finance
# theta-fuel
# cocos-bcx
# wax
# pax-gold
# basic-attention-token
# ontology
# yield-guild-games
# injective-protocol
# secret
# adex
# alchemy-pay
# havven
# fetch-ai
# zilliqa
# kusama
# iostoken
# compound-governance-token
# serum
# ankr
# adventure-gold
# linear
# unifi-protocol-dao
# reef
# zelcash
# ocean-protocol
# coin98
# bluzelle
# acala
# zencash
# biconomy
# ravencoin
# arpa-chain
# gitcoin
# wazirx
# marlin
# audius
# gxchain
# band-protocol
# icon
# reserve-rights-token
# dodo
# ampleforth-governance-token
# benqi
# binaryx
# skale
# mask-network
# litentry
# cartesi
# origin-protocol
# joe
# moonriver
# metal
# republic-protocol
# highstreet
# bonfida
# bakerytoken
# ecash
# ellipsis
# automata
# clover-finance
# measurable-data-token
# maker
# tranchess
# livepeer
# siacoin
# blockstack
# power-ledger
# nervos-network
# venus
# tornado-cash
# safepal
# mirror-protocol
# frax-share
# nuls
# superrare
# cortex
# convex-finance
# alpha-finance
# fc-porto
# illuvium
# contentos
# ethernity-chain
# digibyte
# certik
# raydium
# merit-circle
# anyswap
# request-network
# kava-lend
# tokocrypto
# harvest-finance
# hive
# the-virtua-kolect
# bella-protocol
# 0x
# frontier-token
# lazio-fan-token
# trust-wallet-token
# streamr
# numeraire
# lto-network
# force-protocol
# nem
# pha
# civic
# radicle
# mdex
# ethos
# binance-eth
# paris-saint-germain-fan-token
# 2022-03-01T00:00:00.000000Z: 2887.820000
# 2022-03-02T00:00:00.000000Z: 2915.800000
# 2022-03-03T00:00:00.000000Z: 2893.470000
# 2022-03-04T00:00:00.000000Z: 2820.370000
# 2022-03-05T00:00:00.000000Z: 2626.670000
# 2022-03-06T00:00:00.000000Z: 2702.500000
# 2022-03-07T00:00:00.000000Z: 2575.050000
# 2022-03-08T00:00:00.000000Z: 2533.370000
# 2022-03-09T00:00:00.000000Z: 2586.370000
# 2022-03-10T00:00:00.000000Z: 2744.310000
# 2022-03-11T00:00:00.000000Z: 2630.770000
# 2022-03-12T00:00:00.000000Z: 2591.180000
# 2022-03-13T00:00:00.000000Z: 2588.220000
# 2022-03-14T00:00:00.000000Z: 2518.530000
# 2022-03-15T00:00:00.000000Z: 2601.580000
# 2022-03-16T00:00:00.000000Z: 2587.900000
# 2022-03-17T00:00:00.000000Z: 2706.070000
# 2022-03-18T00:00:00.000000Z: 2701.330000
# 2022-03-19T00:00:00.000000Z: 2759.010000
# 2022-03-20T00:00:00.000000Z: 2841.180000
# 2022-03-21T00:00:00.000000Z: 2764.910000
# 2022-03-22T00:00:00.000000Z: 2821.010000
# 2022-03-23T00:00:00.000000Z: 2888.660000
# 2022-03-24T00:00:00.000000Z: 2985.330000
# 2022-03-25T00:00:00.000000Z: 3064.980000
# 2022-03-26T00:00:00.000000Z: 2985.220000
# 2022-03-27T00:00:00.000000Z: 3049.290000
# 2022-03-28T00:00:00.000000Z: 3189.100000
# 2022-03-29T00:00:00.000000Z: 3170.310000
# 2022-03-30T00:00:00.000000Z: 3265.380000
# 2022-03-31T00:00:00.000000Z: 3305.810000
# terra-luna
# binancecoin
# solana
# ripple
# avalanche-2
# fantom
# shiba-inu
# gala
# cardano
# polkadot
# thorchain
# jasmycoin
# near
# cosmos
# the-sandbox
# matic-network
# waves
# tron
# chainlink
# smooth-love-potion
# dogecoin
# decentraland
# litecoin
# vechain
# constitutiondao
# oasis-network
# elrond-erd-2
# immutable-x
# moviebloc
# internet-computer
# axie-infinity
# zcash
# ethereum-classic
# filecoin
# origin-protocol
# harmony
# chiliz
# my-neighbor-alice
# anchor-protocol
# eos
# aave
# monero
# the-graph
# algorand
# theta-token
# alpine-f1-team-fan-token
# uniswap
# loopring
# pancakeswap-token
# curve-dao-token
# dydx
# alien-worlds
# ethereum-name-service
# kyber-network-crystal
# bitcoin-cash
# celo
# trust-wallet-token
# dash
# sushi
# stellar
# arweave
# moonbeam
# wink
# league-of-kingdoms
# mobox
# mines-of-dalarnia
# chromaway
# enjincoin
# ftx-token
# voxies
# mina-protocol
# keep3rv1
# swipe
# omisego
# iotex
# pax-gold
# just
# havven
# uma
# beta-finance
# neo
# api3
# hedera-hashgraph
# tezos
# helium
# flow
# sun-token
# spell-token
# mirror-protocol
# fetch-ai
# basic-attention-token
# 1inch
# bittorrent
# klay-token
# dent
# holotoken
# biconomy
# republic-protocol
# yearn-finance
# dusk-network
# coin98
# celer-network
# syscoin
# unifi-protocol-dao
# ankr
# kusama
# highstreet
# vulcan-forged
# kava
# icon
# qtum
# coti
# iota
# secret
# serum
# aragon
# aurora-dao
# quant-network
# zencash
# cartesi
# mask-network
# reserve-rights-token
# zilliqa
# adex
# ocean-protocol
# ecash
# troy
# marlin
# cocos-bcx
# reef
# contentos
# metal
# safepal
# compound-governance-token
# santos-fc-fan-token
# lazio-fan-token
# wax
# iostoken
# tornado-cash
# frontier-token
# linear
# render-token
# theta-fuel
# ooki
# benqi
# acala
# btc-standard-hashrate-token
# woo-network
# ravencoin
# gxchain
# injective-protocol
# bakerytoken
# convex-finance
# moonriver
# blockstack
# arpa-chain
# audius
# ontology
# maker
# binaryx
# superfarm
# ellipsis
# automata
# wazirx
# litentry
# alpha-finance
# yield-guild-games
# raydium
# dodo
# the-virtua-kolect
# adventure-gold
# alchemy-pay
# fc-porto
# tranchess
# gitcoin
# venus
# bonfida
# zelcash
# request-network
# selfkey
# superrare
# conflux-token
# astar
# threshold-network-token
# paris-saint-germain-fan-token
# clover-finance
# siacoin
# fc-barcelona-fan-token
# band-protocol
# measurable-data-token
# kava-lend
# livepeer
# harvest-finance
# joe
# 2022-04-01T00:00:00.000000Z: 3210.070000
# 2022-04-02T00:00:00.000000Z: 3313.990000
# 2022-04-03T00:00:00.000000Z: 3303.430000
# 2022-04-04T00:00:00.000000Z: 3388.950000
# 2022-04-05T00:00:00.000000Z: 3343.540000
# 2022-04-06T00:00:00.000000Z: 3277.540000
# 2022-04-07T00:00:00.000000Z: 2989.160000
# 2022-04-08T00:00:00.000000Z: 3087.400000
# 2022-04-09T00:00:00.000000Z: 2935.040000
# 2022-04-10T00:00:00.000000Z: 2992.480000
# 2022-04-11T00:00:00.000000Z: 2915.820000
# 2022-04-12T00:00:00.000000Z: 2679.450000
# 2022-04-13T00:00:00.000000Z: 2787.000000
# 2022-04-14T00:00:00.000000Z: 2853.170000
# 2022-04-15T00:00:00.000000Z: 2774.570000
# 2022-04-16T00:00:00.000000Z: 2822.960000
# 2022-04-17T00:00:00.000000Z: 2826.700000
# 2022-04-18T00:00:00.000000Z: 2733.090000
# 2022-04-19T00:00:00.000000Z: 2830.800000
# 2022-04-20T00:00:00.000000Z: 2901.880000
# 2022-04-21T00:00:00.000000Z: 2854.240000
# 2022-04-22T00:00:00.000000Z: 2767.070000
# 2022-04-23T00:00:00.000000Z: 2761.500000
# 2022-04-24T00:00:00.000000Z: 2723.000000
# 2022-04-25T00:00:00.000000Z: 2694.320000
# 2022-04-26T00:00:00.000000Z: 2746.970000
# 2022-04-27T00:00:00.000000Z: 2548.820000
# 2022-04-28T00:00:00.000000Z: 2595.570000
# 2022-04-29T00:00:00.000000Z: 2597.980000
# 2022-04-30T00:00:00.000000Z: 2477.050000
# stepn
# terra-luna
# binancecoin
# solana
# near
# apecoin
# dogecoin
# ripple
# shiba-inu
# avalanche-2
# cardano
# zilliqa
# polkadot
# smooth-love-potion
# jasmycoin
# fantom
# waves
# gala
# thorchain
# matic-network
# the-sandbox
# tron
# filecoin
# cosmos
# ethereum-classic
# litecoin
# axie-infinity
# vechain
# chainlink
# decentraland
# eos
# moonbeam
# kyber-network-crystal
# biswap
# monero
# oasis-network
# mines-of-dalarnia
# pancakeswap-token
# aave
# league-of-kingdoms
# internet-computer
# astar
# chiliz
# constitutiondao
# origin-protocol
# theta-token
# elrond-erd-2
# loopring
# vulcan-forged
# kava
# algorand
# harmony
# dydx
# zcash
# my-neighbor-alice
# curve-dao-token
# the-graph
# mina-protocol
# mobox
# iostoken
# celo
# wink
# immutable-x
# enjincoin
# ftx-token
# alien-worlds
# bitcoin-cash
# sushi
# binaryx
# audius
# havven
# anchor-protocol
# metal
# ethereum-name-service
# bakerytoken
# stellar
# chromaway
# voxies
# uniswap
# holotoken
# bitcoin-gold
# linear
# dash
# ellipsis
# celer-network
# just
# reserve-rights-token
# kadena
# frax-share
# tezos
# alpine-f1-team-fan-token
# flow
# trust-wallet-token
# compound-governance-token
# skale
# 0x
# alpha-finance
# acala
# arweave
# coti
# klay-token
# swipe
# hedera-hashgraph
# sun-token
# moviebloc
# woo-network
# kusama
# dent
# spell-token
# reef
# ecash
# iota
# coin98
# serum
# neo
# dodo
# omisego
# helium
# district0x
# dusk-network
# fetch-ai
# secret
# unifi-protocol-dao
# bittorrent
# ankr
# pax-gold
# basic-attention-token
# iotex
# drep-new
# beta-finance
# syscoin
# highstreet
# api3
# yearn-finance
# fc-porto
# alchemy-pay
# 1inch
# mirror-protocol
# aragon
# qtum
# wax
# ravencoin
# keep3rv1
# balancer
# icon
# cocos-bcx
# mask-network
# ontology
# lazio-fan-token
# alpaca-finance
# republic-protocol
# conflux-token
# render-token
# safepal
# troy
# superrare
# gifto
# moonriver
# arpa-chain
# biconomy
# marlin
# theta-fuel
# uma
# ooki
# adventure-gold
# zencash
# ocean-protocol
# civic
# litentry
# digibyte
# nuls
# yield-guild-games
# 2022-05-01T00:00:00.000000Z: 2295.630000
# 2022-05-02T00:00:00.000000Z: 2396.460000
# 2022-05-03T00:00:00.000000Z: 2379.340000
# 2022-05-04T00:00:00.000000Z: 2352.130000
# 2022-05-05T00:00:00.000000Z: 2555.300000
# 2022-05-06T00:00:00.000000Z: 2333.550000
# 2022-05-07T00:00:00.000000Z: 2312.120000
# 2022-05-08T00:00:00.000000Z: 2221.270000
# 2022-05-09T00:00:00.000000Z: 2163.290000
# 2022-05-10T00:00:00.000000Z: 1728.550000
# 2022-05-11T00:00:00.000000Z: 1801.920000
# 2022-05-12T00:00:00.000000Z: 1413.930000
# 2022-05-13T00:00:00.000000Z: 1338.530000
# 2022-05-14T00:00:00.000000Z: 1467.690000
# 2022-05-15T00:00:00.000000Z: 1512.700000
# 2022-05-16T00:00:00.000000Z: 1609.940000
# 2022-05-17T00:00:00.000000Z: 1496.110000
# 2022-05-18T00:00:00.000000Z: 1561.010000
# 2022-05-19T00:00:00.000000Z: 1414.240000
# 2022-05-20T00:00:00.000000Z: 1487.200000
# 2022-05-21T00:00:00.000000Z: 1443.050000
# 2022-05-22T00:00:00.000000Z: 1479.970000
# 2022-05-23T00:00:00.000000Z: 1522.410000
# 2022-05-24T00:00:00.000000Z: 1472.780000
# 2022-05-25T00:00:00.000000Z: 1505.540000
# 2022-05-26T00:00:00.000000Z: 1484.570000
# 2022-05-27T00:00:00.000000Z: 1377.610000
# 2022-05-28T00:00:00.000000Z: 1345.940000
# 2022-05-29T00:00:00.000000Z: 1383.040000
# 2022-05-30T00:00:00.000000Z: 1406.590000
# 2022-05-31T00:00:00.000000Z: 1517.300000
# stepn
# binancecoin
# solana
# apecoin
# ripple
# avalanche-2
# tron
# cardano
# fantom
# near
# polkadot
# shiba-inu
# dogecoin
# matic-network
# gala
# the-sandbox
# axie-infinity
# anchor-protocol
# litecoin
# cosmos
# jasmycoin
# zilliqa
# decentraland
# chainlink
# thorchain
# ethereum-name-service
# vechain
# mines-of-dalarnia
# waves
# monero
# filecoin
# oasis-network
# ethereum-classic
# smooth-love-potion
# kyber-network-crystal
# constitutiondao
# aave
# internet-computer
# algorand
# elrond-erd-2
# curve-dao-token
# loopring
# eos
# uniswap
# my-neighbor-alice
# harmony
# theta-token
# bitcoin-cash
# zcash
# the-graph
# sushi
# kava
# league-of-kingdoms
# dydx
# celo
# kusama
# chiliz
# pancakeswap-token
# alien-worlds
# immutable-x
# binaryx
# moonbeam
# enjincoin
# tezos
# wink
# stellar
# ftx-token
# chromaway
# arweave
# kadena
# bakerytoken
# astar
# just
# mina-protocol
# swipe
# audius
# klay-token
# voxies
# linear
# biswap
# sun-token
# celer-network
# vulcan-forged
# reserve-rights-token
# havven
# holotoken
# flow
# mobox
# origin-protocol
# dash
# iotex
# mirror-protocol
# iota
# dent
# neo
# iostoken
# pax-gold
# 1inch
# hedera-hashgraph
# basic-attention-token
# bittorrent
# 0x
# helium
# alpine-f1-team-fan-token
# compound-governance-token
# metal
# unifi-protocol-dao
# omisego
# yearn-finance
# coin98
# coti
# reef
# frax-share
# mask-network
# keep3rv1
# litentry
# trust-wallet-token
# theta-fuel
# acala
# alpha-finance
# skale
# ankr
# aragon
# ravencoin
# dusk-network
# serum
# uma
# syscoin
# aurora-dao
# woo-network
# beta-finance
# maker
# safepal
# santos-fc-fan-token
# render-token
# wax
# ecash
# biconomy
# republic-protocol
# alchemy-pay
# fetch-ai
# fc-porto
# yield-guild-games
# injective-protocol
# qtum
# binance-eth
# ontology
# mobilecoin
# moviebloc
# arpa-chain
# zencash
# api3
# gitcoin
# ocean-protocol
# quant-network
# cartesi
# dodo
# icon
# spell-token
# troy
# manchester-city-fan-token
# livepeer
# automata
# bella-protocol
# highstreet
# superfarm
# zelcash
# kava-lend
# marlin
# lazio-fan-token
# civic
# secret
# benqi
# ooki
# nem
# certik
# district0x
# stp-network
# moonriver
# adex
# storj
# balancer
# akropolis
# request-network
# band-protocol
# tomochain
# adventure-gold
# siacoin
# flamingo-finance
# 2022-06-01T00:00:00.000000Z: 1518.380000
# 2022-06-02T00:00:00.000000Z: 1400.160000
# 2022-06-03T00:00:00.000000Z: 1444.700000
# 2022-06-04T00:00:00.000000Z: 1385.470000
# 2022-06-05T00:00:00.000000Z: 1401.740000
# 2022-06-06T00:00:00.000000Z: 1395.470000
# 2022-06-07T00:00:00.000000Z: 1432.980000
# 2022-06-08T00:00:00.000000Z: 1404.990000
# 2022-06-09T00:00:00.000000Z: 1395.830000
# 2022-06-10T00:00:00.000000Z: 1403.470000
# 2022-06-11T00:00:00.000000Z: 1327.370000
# 2022-06-12T00:00:00.000000Z: 1241.950000
# 2022-06-13T00:00:00.000000Z: 1150.050000
# 2022-06-14T00:00:00.000000Z: 1039.010000
# 2022-06-15T00:00:00.000000Z: 1052.650000
# 2022-06-16T00:00:00.000000Z: 1148.750000
# 2022-06-17T00:00:00.000000Z: 1019.380000
# 2022-06-18T00:00:00.000000Z: 1047.740000
# 2022-06-19T00:00:00.000000Z: 990.460000
# 2022-06-20T00:00:00.000000Z: 1070.760000
# 2022-06-21T00:00:00.000000Z: 1087.100000
# 2022-06-22T00:00:00.000000Z: 1116.490000
# 2022-06-23T00:00:00.000000Z: 1074.130000
# 2022-06-24T00:00:00.000000Z: 1146.920000
# 2022-06-25T00:00:00.000000Z: 1210.730000
# 2022-06-26T00:00:00.000000Z: 1226.180000
# 2022-06-27T00:00:00.000000Z: 1184.070000
# 2022-06-28T00:00:00.000000Z: 1176.470000
# 2022-06-29T00:00:00.000000Z: 1117.500000
# 2022-06-30T00:00:00.000000Z: 1098.930000
# WARNING: coingecko seems to not support the following eligible assets. Ignoring them
# 194    RAMP
# Name: baseAsset, dtype: object
# solana
# binancecoin
# cardano
# ripple
# stepn
# avalanche-2
# tron
# dogecoin
# terra-luna-2
# chainlink
# apecoin
# matic-network
# shiba-inu
# polkadot
# near
# waves
# fantom
# gala
# the-sandbox
# optimism
# litecoin
# terra-luna
# thorchain
# decentraland
# cosmos
# anchor-protocol
# constitutiondao
# unifi-protocol-dao
# bella-protocol
# elrond-erd-2
# jasmycoin
# vechain
# internet-computer
# filecoin
# axie-infinity
# zilliqa
# project-galaxy
# bitcoin-cash
# theta-token
# monero
# litentry
# aave
# uniswap
# oasis-network
# my-neighbor-alice
# ethereum-classic
# ethereum-name-service
# moviebloc
# origin-protocol
# reserve-rights-token
# ftx-token
# algorand
# eos
# harmony
# stellar
# chiliz
# helium
# tezos
# curve-dao-token
# mines-of-dalarnia
# the-graph
# loopring
# dydx
# smooth-love-potion
# pancakeswap-token
# enjincoin
# zcash
# immutable-x
# sushi
# moonbeam
# bluzelle
# havven
# selfkey
# compound-governance-token
# basic-attention-token
# woo-network
# pax-gold
# wink
# bakerytoken
# automata
# celo
# just
# chromaway
# kava
# alien-worlds
# binaryx
# mina-protocol
# arweave
# swipe
# kadena
# coin98
# audius
# terrausd
# 1inch
# flamingo-finance
# fetch-ai
# hedera-hashgraph
# kyber-network-crystal
# kusama
# mask-network
# holotoken
# neo
# iotex
# as-roma-fan-token
# vulcan-forged
# bittorrent
# trust-wallet-token
# metal
# dodo
# iostoken
# dash
# ocean-protocol
# sun-token
# burger-swap
# league-of-kingdoms
# coti
# cartesi
# flow
# linear
# beta-finance
# serum
# wing-finance
# storj
# yearn-finance
# celer-network
# og-fan-token
# dusk-network
# mobox
# dent
# benqi
# keep3rv1
# gitcoin
# astar
# ankr
# omisego
# klay-token
# aurora-dao
# mirror-protocol
# ellipsis-x
# iota
# 0x
# ravencoin
# marlin
# auto
# maker
# binance-eth
# quant-network
# power-ledger
# render-token
# yfii-finance
# api3
# voxies
# safepal
# aragon
# reef
# skale
# syscoin
# santos-fc-fan-token
# biconomy
# biswap
# frax-share
# arpa-chain
# tellor
# ecash
# troy
# alchemy-pay
# theta-fuel
# ontology
# qtum
# republic-protocol
# cocos-bcx
# icon
# yield-guild-games
# alpine-f1-team-fan-token
# band-protocol
# adex
# stp-network
# lazio-fan-token
# wax
# perpetual-protocol
# alpha-finance
# injective-protocol
# threshold-network-token
# uma
# siacoin
# aelf
# convex-finance
# certik
# secret
# digibyte
# blockstack
# akropolis
# zencash
# spell-token
# superfarm
# fc-porto
# beefy-finance
# moonriver
# livepeer
# ooki
# acala
# highstreet
# hive
# venus
# stafi
# tomochain
# ethos
# adventure-gold
# polymath
# frontier-token
# juventus-fan-token
# request-network
# dia-data
# civic
# contentos
# bancor
# gifto
# 2022-07-01T00:00:00.000000Z: 1091.490000

# %% [markdown]
# ### Testing categories

# %%
categories = ['ethereum-ecosystem', 
              'binance-smart-chain', 
              'polygon-ecosystem', 
              'avalanche-ecosystem', 
              'moonriver-ecosystem', 
              'centralized-exchange-token-cex',
              'decentralized-finance-defi',
              'non-fungible-tokens-nft',
              'meme-token',
              'gaming',
              'Other'
             ]

# %%
async def getCategoryInfo(categories):
    result = {}
    for cat in categories:
        page = 1
        done = False
        perPage = 250
        result[cat] = {}
        result[cat]['totalMarketCap'] = 0
        result[cat]['tickers'] = {}
        print(f"Getting info for {cat}")
        while not done:
            query_params = {'vs_currency': 'usd', 'category': cat, 'order': 'market_cap_desc', 'per_page': 250, 'page': page, 'sparkline': 'false'}
            print(f"Page {page}. Pausing...")
            await asyncio.sleep(4)
            async with httpx.AsyncClient() as client:
                r = await client.get(geckoBaseURL + f"/coins/markets", params=query_params, timeout=30)
            catInfo = r.json()
            if len(catInfo) == 0:
                done = True
            else:
                for pt in catInfo:
                    marketCap = None
                    try:
                        if 'market_cap' in pt and pt['market_cap'] is not None:
                            marketCap = float(pt['market_cap'])
                    except ValueError:
                        marketCap = None
                    if not marketCap or marketCap < 1000000:
                        done = True
                    else:
                        result[cat]['tickers'][pt['id']] = pt
                        result[cat]['totalMarketCap'] += pt['market_cap']
                page += 1
    return result

# %%
catInfo = await getCategoryInfo(categories)
# Out:
# Getting info for ethereum-ecosystem
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Page 4. Pausing...
# Page 5. Pausing...
# Page 6. Pausing...
# Page 7. Pausing...
# Page 8. Pausing...
# Page 9. Pausing...
# Page 10. Pausing...
# Page 11. Pausing...
# Page 12. Pausing...
# Page 13. Pausing...
# Page 14. Pausing...
# Page 15. Pausing...
# Page 16. Pausing...
# Page 17. Pausing...
# Page 18. Pausing...
# Page 19. Pausing...
# Page 20. Pausing...
# Page 21. Pausing...
# Page 22. Pausing...
# Page 23. Pausing...
# Getting info for binance-smart-chain
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Page 4. Pausing...
# Page 5. Pausing...
# Page 6. Pausing...
# Page 7. Pausing...
# Page 8. Pausing...
# Page 9. Pausing...
# Page 10. Pausing...
# Page 11. Pausing...
# Getting info for polygon-ecosystem
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Page 4. Pausing...
# Page 5. Pausing...
# Page 6. Pausing...
# Page 7. Pausing...
# Getting info for avalanche-ecosystem
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Getting info for moonriver-ecosystem
# Page 1. Pausing...
# Getting info for centralized-exchange-token-cex
# Page 1. Pausing...
# Getting info for decentralized-finance-defi
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Page 4. Pausing...
# Page 5. Pausing...
# Page 6. Pausing...
# Getting info for non-fungible-tokens-nft
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Page 4. Pausing...
# Getting info for meme-token
# Page 1. Pausing...
# Getting info for gaming
# Page 1. Pausing...
# Page 2. Pausing...
# Page 3. Pausing...
# Getting info for Other
# Page 1. Pausing...

# %%
def getDominantCategoryFor(geckoId):
    maxParticipation = 0.0
    result = 'Other'
    for catName in catInfo:
        blacklist = None
        with open(f"blacklist-{catName}.txt", 'r') as f:
            blacklist = f.read().split(',')
        #print(f"blacklist is: {blacklist}")
        cat = catInfo[catName]
        if geckoId in cat['tickers']:
            assetSymbol = cat['tickers'][geckoId]['symbol'].lower()
            #print(f"assetSymbol is {assetSymbol}")
            if not assetSymbol in blacklist:
                thisParticipation = cat['tickers'][geckoId]['market_cap']/cat['totalMarketCap']
                if thisParticipation > maxParticipation:
                    maxParticipation = thisParticipation
                    result = catName
    return result

# %%
getDominantCategoryFor('matic-network')
# Out:
# 'polygon-ecosystem'

# %%
categWhiteLists = {}
for baseAsset in baseAssets2GeckoDict:
    geckoId = baseAssets2GeckoDict[baseAsset]
    dominantCateg = getDominantCategoryFor(geckoId)
    if dominantCateg in categWhiteLists:
        categWhiteLists[dominantCateg].append(baseAsset.lower())
    else:
        categWhiteLists[dominantCateg] = [baseAsset.lower()]
categWhiteLists['Other'] += ['luna','any','eps','npxs','btt','nano','nu','keep','gxs']
categWhiteLists
# Out:
# {'Other': ['busd',
#   'usdt',
#   'btc',
#   'usdc',
#   'wbtc',
#   'sol',
#   'xrp',
#   'ada',
#   'tusd',
#   'usdp',
#   'etc',
#   'dot',
#   'ltc',
#   'trx',
#   'bch',
#   'dai',
#   'bidr',
#   'near',
#   'xmr',
#   'eos',
#   'op',
#   'fil',
#   'vet',
#   'algo',
#   'lunc',
#   'xtz',
#   'icp',
#   'one',
#   'neo',
#   'xlm',
#   'ustc',
#   'egld',
#   'zec',
#   'bnx',
#   'lever',
#   'dash',
#   'ar',
#   'rose',
#   'hbar',
#   'burger',
#   'xec',
#   'hnt',
#   'dar',
#   'ethdown',
#   'iost',
#   'sys',
#   'mina',
#   'xem',
#   'klay',
#   'ksm',
#   'qtum',
#   'celo',
#   'iota',
#   'perl',
#   'porto',
#   't',
#   'icx',
#   'stx',
#   'win',
#   'rvn',
#   'firo',
#   'zen',
#   'kda',
#   'glmr',
#   'acm',
#   'asr',
#   'mob',
#   'rei',
#   'ethup',
#   'hive',
#   'sun',
#   'rif',
#   'city',
#   'astr',
#   'nbs',
#   'bdot',
#   'ctxc',
#   'sc',
#   'tomo',
#   'tfuel',
#   'dgb',
#   'bts',
#   'epx',
#   'scrt',
#   'juv',
#   'atm',
#   'psg',
#   'nuls',
#   'beam',
#   'btg',
#   'aion',
#   'xno',
#   'troy',
#   'fio',
#   'og',
#   'kmd',
#   'dock',
#   'aca',
#   'high',
#   'steem',
#   'tko',
#   'bar',
#   'ava',
#   'lsk',
#   'akro',
#   'drep',
#   'data',
#   'flux',
#   'iris',
#   'vtho',
#   'cfx',
#   'ckb',
#   'ardr',
#   'loom',
#   'ark',
#   'gas',
#   'xvg',
#   'nebl',
#   'qlc',
#   'dcr',
#   'pivx',
#   'ong',
#   'amb',
#   'phb',
#   'nav',
#   'nxs',
#   'beth',
#   'bttc',
#   'luna',
#   'any',
#   'eps',
#   'npxs',
#   'btt',
#   'nano',
#   'nu',
#   'keep',
#   'gxs'],
#  'ethereum-ecosystem': ['eth',
#   'paxg',
#   'waves',
#   'mith',
#   'jasmy',
#   'idrt',
#   'storj',
#   'people',
#   'mtl',
#   'omg',
#   'qnt',
#   'skl',
#   'gto',
#   'hot',
#   'celr',
#   'mbl',
#   'lit',
#   'arpa',
#   'coti',
#   'dent',
#   'mft',
#   'rlc',
#   'vgx',
#   'pond',
#   'lpt',
#   'dusk',
#   'tct',
#   'ant',
#   'nkn',
#   'bico',
#   'key',
#   'poly',
#   'gtc',
#   'strax',
#   'cvc',
#   'wtc',
#   'powr',
#   'stmx',
#   'elf',
#   'oxt',
#   'pundix',
#   'nexo',
#   'pha',
#   'agld',
#   'forth',
#   'fun',
#   'ooki',
#   'utk',
#   'aergo',
#   'dnt',
#   'ssv',
#   'mdt',
#   'snt',
#   'agix',
#   'vib',
#   'qsp',
#   'brd',
#   'qkc',
#   'snm',
#   'oax',
#   'wabi',
#   'mda'],
#  'polygon-ecosystem': ['matic',
#   'iotx',
#   'ocean',
#   'mask',
#   'ata',
#   'ctk',
#   'sfp',
#   'twt',
#   'wrx',
#   'voxel',
#   'om',
#   'req',
#   'adx',
#   'glm',
#   'iq'],
#  'avalanche-ecosystem': ['avax', 'bat', 'beta', 'ctsi'],
#  'centralized-exchange-token-cex': ['bnb', 'ftt', 'woo'],
#  'gaming': ['sand',
#   'gmt',
#   'gala',
#   'axs',
#   'enj',
#   'alice',
#   'slp',
#   'imx',
#   'ghst',
#   'tlm',
#   'ygg',
#   'blz',
#   'vidt',
#   'mbox',
#   'pyr',
#   'waxp',
#   'ilv',
#   'cocos',
#   'loka',
#   'mc'],
#  'binance-smart-chain': ['atom',
#   'zil',
#   'ach',
#   'bsw',
#   'btcst',
#   'chr',
#   'reef',
#   'sxp',
#   'santos',
#   'ont',
#   'prom',
#   'clv',
#   'lazio',
#   'vite',
#   'alpine',
#   'dexe',
#   'mdx',
#   'lto',
#   'sparta'],
#  'moonriver-ecosystem': ['ftm', 'ankr', 'movr', 'multi'],
#  'decentralized-finance-defi': ['link',
#   'dydx',
#   'aave',
#   'rune',
#   'uni',
#   'sushi',
#   'srm',
#   'crv',
#   'knc',
#   'grt',
#   'lrc',
#   'kava',
#   'snx',
#   'unfi',
#   'bond',
#   'nmr',
#   'yfi',
#   'zrx',
#   'comp',
#   'fida',
#   '1inch',
#   'mir',
#   'anc',
#   'ray',
#   'flm',
#   'jst',
#   'ldo',
#   'bel',
#   'band',
#   'rsr',
#   'trb',
#   'cake',
#   'api3',
#   'yfii',
#   'ren',
#   'c98',
#   'mkr',
#   'bal',
#   'fxs',
#   'stpt',
#   'alpha',
#   'tribe',
#   'joe',
#   'perp',
#   'dodo',
#   'kp3r',
#   'spell',
#   'cvx',
#   'idex',
#   'front',
#   'auto',
#   'auction',
#   'chess',
#   'lina',
#   'fis',
#   'quick',
#   'wing',
#   'vai',
#   'uft',
#   'amp',
#   'qi',
#   'farm',
#   'cvp',
#   'inj',
#   'xvs',
#   'wan',
#   'pnt',
#   'pols',
#   'uma',
#   'badger',
#   'torn',
#   'for',
#   'tru',
#   'wnxm',
#   'rep',
#   'gno',
#   'bnt',
#   'mln',
#   'hard',
#   'cream',
#   'orn',
#   'df',
#   'dia',
#   'alpaca',
#   'bifi',
#   'alcx',
#   'ez',
#   'pros',
#   'ast'],
#  'meme-token': ['doge', 'shib'],
#  'non-fungible-tokens-nft': ['ape',
#   'mana',
#   'ens',
#   'theta',
#   'chz',
#   'flow',
#   'gal',
#   'bake',
#   'ogn',
#   'audio',
#   'fet',
#   'rad',
#   'ern',
#   'dego',
#   'tvk',
#   'rndr',
#   'pla',
#   'super',
#   'rare',
#   'cos']}

# %%
def categWhiteList(categ):
    return set(categWhiteLists[categ])

# %%
import datetime
for categ in categories:
    whiteListFunc = partial(categWhiteList, categ)
    print(f"Doing index for category {categ}")
    firstCategIndexData = await startIndex('2020-11-01T00:00:00.000000Z', '2020-12-01T00:00:00.000000Z', 1000, f"ONN-({categ})-B-30dW-30dR", cacheConn, whiteListFunc, partial(getBlacklistSet, f"blacklist-{categ}.txt"))
    computeDay = parse(firstCategIndexData.isoInstant) + datetime.timedelta(days = 1)
    endDate = parse("2022-06-30T00:00:00.000000Z") + datetime.timedelta(days = 1)
    lastIndex = firstCategIndexData
    fileName = f"{firstCategIndexData.indexId}_{firstCategIndexData.isoInstant[:10]}_{str(endDate)[:10]}.json"
    with open(fileName, 'w') as f:
        print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
        f.write('[\n')
        f.write(lastIndex.toJSON())
        while computeDay <= endDate:
            if(computeDay.day == 1):
                lastIndex = await lastIndexDataRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex, cacheConn, whiteListFunc, partial(getBlacklistSet, f"blacklist-{categ}.txt"))
            else:
                lastIndex = await lastIndexDataNoRebalance(datetime.datetime.strftime(computeDay - datetime.timedelta(days = 1), "%Y-%m-%dT%H:%M:%S.%fZ"), datetime.datetime.strftime(computeDay, "%Y-%m-%dT%H:%M:%S.%fZ"), lastIndex)
            print("%s: %f"%(lastIndex.isoInstant, lastIndex.indexValue))
            f.write(',\n')
            f.write(lastIndex.toJSON())
            computeDay = computeDay + datetime.timedelta(days = 1)
        f.write('\n]\n')
# Out:
# Doing index for category ethereum-ecosystem
# blackListSet
# {'frax', 'gbp', 'usdn', 'tusd', 'wbtc', 'dai', 'usdd', 'mim', 'usdc', 'aud', 'mimatic', 'usdp', 'steth', 'ust', 'matic', 'busd', 'eur', 'ftt', 'hbtc', 'pax', 'usdt'}
# whitelist is present
# ethereum
# waves
# omisego
# civic
#   baseAsset     volInUSDT  lastAvgPriceUSDT   geckoId  medianMarketcap  \
# 0       ETH  8.656754e+08        616.664287  ethereum     5.305535e+10
# 1       OMG  1.298184e+07          3.953242   omisego     4.850075e+08
# 2     WAVES  1.346748e+07          7.084692     waves     4.605730e+08
#
#    lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap  \
# 0    1.135269e+08            0.981458         0.981458   7.000796e+10
# 1    1.404081e+08            0.008972         0.990430   5.550672e+08
# 2    9.998922e+07            0.008520         0.998950   7.083928e+08
#
#      weight
# 0  0.982273
# 1  0.007788
# 2  0.009939
# 2020-12-01T00:00:00.000000Z: 1000.000000
# 2020-12-02T00:00:00.000000Z: 949.050000
# 2020-12-03T00:00:00.000000Z: 968.160000
# 2020-12-04T00:00:00.000000Z: 998.820000
# 2020-12-05T00:00:00.000000Z: 920.660000
# 2020-12-06T00:00:00.000000Z: 969.480000
# 2020-12-07T00:00:00.000000Z: 977.330000
# 2020-12-08T00:00:00.000000Z: 961.440000
# 2020-12-09T00:00:00.000000Z: 901.270000
# 2020-12-10T00:00:00.000000Z: 931.390000
# 2020-12-11T00:00:00.000000Z: 907.960000
# 2020-12-12T00:00:00.000000Z: 884.470000
# 2020-12-13T00:00:00.000000Z: 923.010000
# 2020-12-14T00:00:00.000000Z: 959.620000
# 2020-12-15T00:00:00.000000Z: 952.340000
# 2020-12-16T00:00:00.000000Z: 955.280000
# 2020-12-17T00:00:00.000000Z: 1033.290000
# 2020-12-18T00:00:00.000000Z: 1041.240000
# 2020-12-19T00:00:00.000000Z: 1058.890000
# 2020-12-20T00:00:00.000000Z: 1065.340000
# 2020-12-21T00:00:00.000000Z: 1032.760000
# 2020-12-22T00:00:00.000000Z: 983.080000
# 2020-12-23T00:00:00.000000Z: 1029.680000
# 2020-12-24T00:00:00.000000Z: 945.510000
# 2020-12-25T00:00:00.000000Z: 989.550000
astCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap  weight
# 0    1.208870e+08            0.996488         0.996488   2.347535e+11     1.0
# 2022-06-01T00:00:00.000000Z: 3029.040000
# 2022-06-02T00:00:00.000000Z: 2835.670000
# 2022-06-03T00:00:00.000000Z: 2860.780000
# 2022-06-04T00:00:00.000000Z: 2768.860000
# 2022-06-05T00:00:00.000000Z: 2814.780000
# 2022-06-06T00:00:00.000000Z: 2817.310000
# 2022-06-07T00:00:00.000000Z: 2900.980000
# 2022-06-08T00:00:00.000000Z: 2828.540000
# 2022-06-09T00:00:00.000000Z: 2794.940000
# 2022-06-10T00:00:00.000000Z: 2790.190000
# 2022-06-11T00:00:00.000000Z: 2593.750000
# 2022-06-12T00:00:00.000000Z: 2391.050000
# 2022-06-13T00:00:00.000000Z: 2238.290000
# 2022-06-14T00:00:00.000000Z: 1886.860000
# 2022-06-15T00:00:00.000000Z: 1885.510000
# 2022-06-16T00:00:00.000000Z: 1930.390000
# 2022-06-17T00:00:00.000000Z: 1666.610000
# 2022-06-18T00:00:00.000000Z: 1695.310000
# 2022-06-19T00:00:00.000000Z: 1552.190000
# 2022-06-20T00:00:00.000000Z: 1760.260000
# 2022-06-21T00:00:00.000000Z: 1759.780000
# 2022-06-22T00:00:00.000000Z: 1756.190000
# 2022-06-23T00:00:00.000000Z: 1638.050000
# 2022-06-24T00:00:00.000000Z: 1785.550000
# 2022-06-25T00:00:00.000000Z: 1910.720000
# 2022-06-26T00:00:00.000000Z: 1937.700000
# 2022-06-27T00:00:00.000000Z: 1868.410000
# 2022-06-28T00:00:00.000000Z: 1860.030000
# 2022-06-29T00:00:00.000000Z: 1784.560000
# 2022-06-30T00:00:00.000000Z: 1716.100000
# blackListSet
# {'frax', 'gbp', 'usdn', 'tusd', 'wbtc', 'dai', 'usdd', 'mim', 'usdc', 'aud', 'mimatic', 'usdp', 'steth', 'ust', 'matic', 'busd', 'eur', 'ftt', 'hbtc', 'pax', 'usdt'}
# whitelist is present
# ethereum
# waves
# constitutiondao
# jasmycoin
# litentry
# moviebloc
#   baseAsset     volInUSDT  lastAvgPriceUSDT   geckoId  medianMarketcap  \
# 0       ETH  2.585964e+09       1071.069121  ethereum     1.477098e+11
#
#    lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap  weight
# 0    1.213593e+08            0.994429         0.994429   1.299842e+11     1.0
# 2022-07-01T00:00:00.000000Z: 1670.670000
# Doing index for category binance-smart-chain
# blackListSet
# {'frax', 'gbp', 'usdn', 'tusd', 'wbtc', 'dai', 'usdd', 'mim', 'usdc', 'aud', 'mimatic', 'usdp', 'ftm', 'steth', 'ust', 'matic', 'busd', 'eur', 'ftt', 'hbtc', 'pax', 'usdt'}
# whitelist is present
# swipe
# cosmos
# ontology
# zilliqa
# lto-network
# chromaway
# vite
#   baseAsset     volInUSDT  lastAvgPriceUSDT      geckoId  medianMarketcap  \
# 0      ATOM  1.492854e+07          5.570883       cosmos     1.217583e+09
# 1       ONT  8.031074e+06          0.598024     ontology     3.772416e+08
# 2       ZIL  6.642868e+06          0.029332      zilliqa     2.350856e+08
# 3       SXP  2.915320e+07          0.979139        swipe     7.367746e+07
# 4       LTO  2.841199e+06          0.138675  lto-network     1.901129e+07
# 5       CHR  8.797873e+05          0.027406    chromaway     1.166524e+07
#
#    lastCircSupply  fracTotalMarketCap  accumulatedPerc  lastMarketcap
# filecoin
# oasis-network
# ethereum-classic
# internet-computer
# algorand
# elrond-erd-2
# eos
# harmony
# bitcoin-cash
# zcash
# celo
# kusama
# binaryx
# moonbeam
# tezos
# wink
# stellar
# arweave
# kadena
# astar
# mina-protocol
# klay-token
# sun-token
# dash
# iota
# neo
# iostoken
# hedera-hashgraph
# bittorrent
# helium
# theta-fuel
# acala
# ravencoin
# syscoin
# ecash
# fc-porto
# qtum
# binance-eth
# mobilecoin
# zencash
# icon
# troy
# manchester-city-fan-token
# highstreet
# zelcash
# secret
# nem
# akropolis
# tomochain
# siacoin
# digibyte
# conflux-token
# blockstack
# ac-milan-fan-token
# burger-swap
# nervos-network
#    baseAsset     volInUSDT  lastAvgPriceUSDT            geckoId  \
# 0        XRP  2.322369e+08          0.421703             ripple
# 1        ADA  1.752495e+08          0.626798            cardano
# 2        SOL  3.715136e+08         45.770238             solana
# 3        DOT  1.368129e+08         10.351796           polkadot
# 4        TRX  2.049738e+08          0.084402               tron
# 5        LTC  7.067981e+07         68.386633           litecoin
# 6       NEAR  1.431479e+08          5.957113               near
# 7        BCH  2.266933e+07        204.604271       bitcoin-cash
# 8        XLM  1.400627e+07          0.150676            stellar
# 9        XMR  4.376902e+07        198.602399             monero
# 10       ETC  3.683922e+07         23.773167   ethereum-classic
# 11      ALGO  3.038549e+07          0.411236           algorand
# 12       VET  4.696954e+07          0.032857            vechain
# 13      HBAR  8.225598e+06          0.094309   hedera-hashgraph
# 14      EGLD  2.968065e+07         81.461067       elrond-erd-2
# 15       ICP  3.134962e+07          8.271038  internet-computer
# 16     TFUEL  6.276586e+06          0.063291         theta-fuel
# 17       XTZ  1.576914e+07          2.090778              tezos
# 18       FIL  4.318683e+07          8.090449           filecoin
# 19       EOS  2.751741e+07          1.380051                eos
# 20       ZEC  2.265951e+07         93.305624              zcash
# 21      KLAY  1.149895e+07          0.437095         klay-token
# 22      BTTC  8.136468e+06          0.000001         bittorrent
# 23      IOTA  9.128583e+06          0.352716               iota
# 24       XEC  4.869675e+06          0.000051              ecash
# 25       HNT  8.021744e+06          9.439599             helium
# 26       NEO  8.543707e+06         11.568041                neo
# 27        AR  1.343463e+07         15.271906            arweave
# 28       KSM  1.999170e+07         79.900772             kusama
#
#     medianMarketcap  lastCircSupply  fracTotalMarketCap  accumulatedPerc  \
# 0      2.052442e+10    4.834310e+10            0.153578         0.153578
# 1      1.846932e+10    3.333904e+10            0.138200         0.291778
# 2      1.728281e+10    3.392087e+08            0.129322         0.421099
# 3      1.178945e+10    1.114836e+09            0.088217         0.509316
# 4      7.447502e+09    9.375995e+10            0.055727         0.565043
# 5      4.929700e+09    7.040785e+07            0.036887         0.601930
# 6      4.335818e+09    6.971903e+08            0.032444         0.634374
# 7      3.837057e+09    1.907841e+07            0.028711         0.663085
# 8      3.403411e+09    2.492380e+10            0.025467         0.688552
# 9      3.335312e+09    1.812866e+07            0.024957         0.713509
# 10     3.074036e+09    1.350520e+08            0.023002         0.736511
# 11     3.056055e+09    6.849946e+09            0.022867         0.759379
# 2022-06-20T00:00:00.000000Z: 835.850000
# 2022-06-21T00:00:00.000000Z: 846.980000
# 2022-06-22T00:00:00.000000Z: 857.600000
# 2022-06-23T00:00:00.000000Z: 821.240000
# 2022-06-24T00:00:00.000000Z: 868.210000
# 2022-06-25T00:00:00.000000Z: 919.350000
# 2022-06-26T00:00:00.000000Z: 923.850000
# 2022-06-27T00:00:00.000000Z: 888.540000
# 2022-06-28T00:00:00.000000Z: 882.350000
# 2022-06-29T00:00:00.000000Z: 838.510000
# 2022-06-30T00:00:00.000000Z: 821.690000
# blackListSet
# {'eur', 'usdn', 'mimatic', 'usdp', 'tusd', 'usdc', 'btc', 'wbtc', 'frax', 'pax', 'dai', 'ust', 'usdd', 'mim', 'gbp', 'usdt', 'aud', 'busd'}
# whitelist is present
# solana
# cardano
# ripple
# tron
# terra-luna-2
# polkadot
# near
# optimism
# litecoin
# terra-luna
# elrond-erd-2
# vechain
# internet-computer
# filecoin
# bitcoin-cash
# monero
# oasis-network
# ethereum-classic
# algorand
# eos
# harmony
# stellar
# helium
# tezos
# mines-of-dalarnia
# zcash
# moonbeam
# wink
# celo
# binaryx
# mina-protocol
# arweave
# kadena
# terrausd
# hedera-hashgraph
# kusama
# neo
# as-roma-fan-token
# bittorrent
# iostoken
# dash
# sun-token
# burger-swap
# og-fan-token
# astar
# klay-token
# ellipsis-x
# iota
# ravencoin
# binance-eth
# syscoin
# ecash
# troy
# theta-fuel
# qtum
# icon
# threshold-network-token
# siacoin
# secret
# digibyte
# blockstack
# akropolis
# zencash
# fc-porto
# acala
# highstreet
# hive
# tomochain
# juventus-fan-token
#    baseAsset     volInUSDT  lastAvgPriceUSDT            geckoId  \
# 0        XRP  1.797717e+08      3.321038e-01             ripple
# 1        ADA  2.114560e+08      4.599136e-01            cardano
# 2        SOL  3.151529e+08      3.375638e+01             solana
# 3        DOT  7.366359e+07      7.062628e+00           polkadot
# 4        TRX  1.033111e+08      6.480778e-02               tron
# 5        LTC  5.509812e+07      5.383020e+01           litecoin
# 6        XLM  1.427031e+07      1.123319e-01            stellar
# 7       NEAR  6.587981e+07      3.338296e+00               near
# 8        BCH  2.296405e+07      1.031928e+02       bitcoin-cash
# 9       ALGO  1.690011e+07      3.147211e-01           algorand
# 10       XMR  2.272206e+07      1.130988e+02             monero
# 11       ETC  1.833119e+07      1.500777e+01   ethereum-classic
# 12     TFUEL  3.058868e+06      4.761566e-02         theta-fuel
# 13       VET  2.831633e+07      2.278992e-02            vechain
# 14      HBAR  6.614285e+06      6.348728e-02   hedera-hashgraph
# 15       ICP  2.626181e+07      5.351015e+00  internet-computer
# 16       XTZ  1.274550e+07      1.425847e+00              tezos
# 17       FIL  2.550040e+07      5.399735e+00           filecoin
# 18      EGLD  3.046498e+07      5.095637e+01       elrond-erd-2
# 19       HNT  1.284010e+07      9.417483e+00             helium
# 20       EOS  1.465302e+07      9.261118e-01                eos
# 21       ZEC  9.996291e+06      5.451390e+01              zcash
# 22      BTTC  6.024727e+06      8.101027e-07         bittorrent
