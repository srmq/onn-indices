# %%
categories = ['bitcoin',
              'smart-contract-platform', 
              'centralized-exchange-token-cex',
              'decentralized-finance-defi',
              'non-fungible-tokens-nft',
              'meme-token',
              'gaming',
              'Other',
              'sports'
             ]

# %%
from typing import Dict
def categs2IndexIds(categs: [str]) -> Dict[str, str]:
    result = {}
    for categ in categs:
        if categ != 'bitcoin' and categ != 'USDCUSDT':
            result[categ] = f"ONN-({categ})-B-30dW-30dR"
    return result

# %%
import pandas as pd
import httpx
host = 'http://localhost:9000'
async def getSymb(fromIsoInstant: str, toIsoInstant: str, symb: str) -> pd.DataFrame:
    def listToStr(l):
        result = l[0]
        for i in range(1, len(l)):
            result += f", {l[i]}"
        return result
    
    columns = ['symb', 'open_time', 'close', 'volume', 'close_time', 'quote_asset_vol']        
    sqlStmt = "SELECT %s FROM 'binance_daily' WHERE symb = '%s' AND open_time >= '%s' AND open_time < '%s'"%(listToStr(columns), symb, fromIsoInstant, toIsoInstant)

    query_params = {'query': sqlStmt, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
        r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    #print(jsonR)
    result = pd.DataFrame(columns=columns, data=jsonR['dataset'])
    result['strDate'] = result.apply(lambda row: row['open_time'][0:10], axis = 1)
    result.set_index('strDate', drop=True, inplace=True)
    result.rename(columns={'close':symb}, inplace=True)
    result = result[[symb]].sort_values('strDate')
    
    return result

# %%
res = await getSymb('2021-01-01T00:00:00.000000Z', '2022-08-30T00:00:00.000000Z', 'USDCUSDT')
res
# Out:
#             USDCUSDT
# strDate
# 2021-01-01    0.9974
# 2021-01-02    0.9989
# 2021-01-03    0.9992
# 2021-01-04    0.9994
# 2021-01-05    0.9969
# ...              ...
# 2022-08-25    1.0000
# 2022-08-26    1.0000
# 2022-08-27    1.0001
# 2022-08-28    1.0001
# 2022-08-29    1.0000
#
# [606 rows x 1 columns]

# %%
import pandas as pd
from typing import Dict
import httpx
host = 'http://localhost:9000'
async def getIndices(fromIsoInstant: str, toIsoInstant: str, catNames: [str]) -> pd.DataFrame:
    def listToStr(l):
        result = l[0]
        for i in range(1, len(l)):
            result += f", {l[i]}"
        return result    
    
    columns = ['indexId', 'isoInstant', 'indexValue', 'isRebalanceDay', 'divisor', 'lastRebalanceISOInstant', 'indexConstituents']
    indexIds = list(categs2IndexIds(catNames).values())
    sqlIn = f"\'{indexIds[0]}\'"
    for i in range(1, len(indexIds)):
        sqlIn += f", \'{indexIds[i]}\'"
    sqlIn = "(" + sqlIn + ")"
    sqlStmt = "SELECT %s FROM onn_daily2 WHERE isoInstant >= '%s' AND isoInstant < '%s' AND indexId IN %s"%(listToStr(columns), fromIsoInstant, toIsoInstant, sqlIn)
    # print(sqlStmt)
    query_params = {'query': sqlStmt, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
        r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    #print(jsonR)
    result = pd.DataFrame(columns=columns, data=jsonR['dataset'])
    return result

# %%
import json
import pandas as pd
class IndexData:
    indexId: str
    _indexValue: float
    isoInstant: str
    isRebalanceDay: bool
    _divisor: float
    lastRebalanceISOInstant: str
    indexConstituents: pd.DataFrame
    
    class IndexDataEncoder(json.JSONEncoder):
        def default(self, obj):
            if isinstance(obj, IndexData):
                return {"indexId": obj.indexId, "isoInstant": obj.isoInstant, "indexValue": obj.indexValue, "isRebalanceDay": obj.isRebalanceDay, "divisor": obj.divisor, "lastRebalanceISOInstant": obj.lastRebalanceISOInstant, "indexConstituents": json.loads(obj.indexConstituents.to_json(orient='split', index=False))}
            return json.JSONEncoder.default(self, obj)
    
    def set_indexValue(self, value):
        self._indexValue = round(value, 2)
    
    def get_indexValue(self):
        return self._indexValue
    
    def del_indexValue(self):
        del self._indexValue
        
    indexValue = property(get_indexValue, set_indexValue, del_indexValue)
    
    def set_divisor(self, value):
        self._divisor = round(value, 4)
    
    def get_divisor(self):
        return self._divisor
    
    def del_divisor(self):
        del self._divisor
       
    divisor = property(get_divisor, set_divisor, del_divisor)
    
    def toJSON(self):
        return json.dumps(self, cls=IndexData.IndexDataEncoder)
    
    def __repr__(self):
        return self.toJSON()
    
    def __jsonDecode(dct):
        attrs = ["indexId", "isoInstant", "indexValue", "isRebalanceDay", "divisor", "lastRebalanceISOInstant", "indexConstituents"]
        for attr in attrs:
            if attr not in dct:
                return dct
        result = IndexData()
        result.indexId = dct['indexId']
        result.isoInstant = dct['isoInstant']
        result.indexValue = dct['indexValue']
        result.isRebalanceDay = dct['isRebalanceDay']
        result.divisor = dct['divisor']
        result.lastRebalanceISOInstant = dct['lastRebalanceISOInstant']
        result.indexConstituents = pd.read_json(json.dumps(dct['indexConstituents']), orient='split')
        return result
    
    def fromJSON(jsStr):
        return json.loads(jsStr, object_hook=IndexData.__jsonDecode)

# %%
async def getDailyIndices(isoInstant: str, catNames: [str]) -> Dict[str, IndexData]:
    def listToStr(l):
        result = l[0]
        for i in range(1, len(l)):
            result += f", {l[i]}"
        return result    
    
    columns = ['indexId', 'isoInstant', 'indexValue', 'isRebalanceDay', 'divisor', 'lastRebalanceISOInstant', 'indexConstituents']
    indexIds = list(categs2IndexIds(catNames).values())
    sqlIn = f"\'{indexIds[0]}\'"
    for i in range(1, len(indexIds)):
        sqlIn += f", \'{indexIds[i]}\'"
    sqlIn = "(" + sqlIn + ")"
    sqlStmt = "SELECT %s FROM onn_daily2 WHERE isoInstant = '%s' AND indexId IN %s"%(listToStr(columns), isoInstant, sqlIn)
    # print(sqlStmt)
    query_params = {'query': sqlStmt, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
        r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    # print(jsonR)
    resultArray = pd.DataFrame(columns=columns, data=jsonR['dataset'])
    resultArray = resultArray.to_dict('records')
    result = {}
    for rec in resultArray:
        rec['indexConstituents'] = json.loads(rec['indexConstituents'])
        result[rec['indexId']] = IndexData.fromJSON(json.dumps(rec))
    return result

# %%
import pandas as pd
import httpx
host = 'http://localhost:9000'
async def getSymb(fromIsoInstant: str, toIsoInstant: str, symb: str) -> pd.DataFrame:
    def listToStr(l):
        result = l[0]
        for i in range(1, len(l)):
            result += f", {l[i]}"
        return result
    
    columns = ['symb', 'open_time', 'close', 'volume', 'close_time', 'quote_asset_vol']        
    sqlStmt = "SELECT %s FROM 'binance_daily' WHERE symb = '%s' AND open_time >= '%s' AND open_time < '%s'"%(listToStr(columns), symb, fromIsoInstant, toIsoInstant)

    query_params = {'query': sqlStmt, 'fmt': 'json'}
    async with httpx.AsyncClient() as client:
        r = await client.get(host + '/exec', params=query_params)
    jsonR = r.json()
    #print(jsonR)
    result = pd.DataFrame(columns=columns, data=jsonR['dataset'])
    result['strDate'] = result.apply(lambda row: row['open_time'][0:10], axis = 1)
    result.set_index('strDate', drop=True, inplace=True)
    result.rename(columns={'close':symb}, inplace=True)
    result = result[[symb]].sort_values('strDate')
    
    return result

# %%
btcDF = await getSymb('2020-12-01T00:00:00.000000Z', '2022-08-30T00:00:00.000000Z', 'BTCUSDT')
btcDF.rename(columns={'BTCUSDT':'BTC'}, inplace=True)
dfBTCIndex = btcDF[['BTC']].sort_values('strDate')
dfBTCIndex['BTC'] = 1000*(dfBTCIndex['BTC']/(dfBTCIndex['BTC'][0]))
del btcDF

# %%
dfBTCIndex.head()
# Out:
#                     BTC
# strDate
# 2020-12-01  1000.000000
# 2020-12-02  1023.401595
# 2020-12-03  1035.008868
# 2020-12-04   993.901399
# 2020-12-05  1020.394395

# %%
import riskfolio as rp
from dateutil.parser import parse
import datetime
from typing import Dict

async def computeOptimalWeights(isoInstant: str, categNames: [str]) -> Dict[str, float]:
    method_mu='hist' # Method to estimate expected returns based on historical data.
    method_cov='hist' # Method to estimate covariance matrix based on historical data.
    model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
    rm = 'MV' # Risk measure used, this time will be variance
    #rm = 'MDD' # Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio)
    #obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
    obj = 'Sharpe'
    hist = True # Use historical scenarios for risk measures that depend on scenarios
    rf = 0 # Risk free rate
    l = 0 # Risk aversion factor, only useful when obj is 'Utility'

    currentDay = parse(str(isoInstant))
    windowStart = currentDay - datetime.timedelta(days = 30)
    
    result = await getIndices(windowStart, str(currentDay), categNames)
    result["Date"] = result.isoInstant.astype('datetime64[ns]')
    result = result.pivot(index="Date", columns=["indexId"], values=["indexValue"])
    result.columns = result.columns.droplevel()
    result = result.reset_index()
    result['strDate'] = result['Date'].apply(lambda val : (val - datetime.timedelta(seconds=1)).strftime('%Y-%m-%d'))
    result.set_index('strDate', drop=True, inplace=True)
    result.drop('Date', axis=1, inplace=True)
    result = result.dropna(axis=1, how="any")
    if 'bitcoin' in categNames:
        result = pd.concat([result, dfBTCIndex], join='inner', axis=1).sort_values('strDate')
    if 'USDCUSDT' in categNames:
        usdcDF = await getSymb(str(windowStart), str(currentDay), 'USDCUSDT')
        result = pd.concat([result, usdcDF], join='inner', axis=1).sort_values('strDate')
    result.rename(index={'strDate':'Date'}, inplace=True)
        
    Y = result.pct_change().dropna()
    # Building the portfolio object
    port = rp.Portfolio(returns=Y)
    port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)
    w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)
    # display(w)
    if w is None:
        return None
    else:
        result = {}
        categIndices = categs2IndexIds(categNames)

        for cat, indexName in categIndices.items():
            if indexName in w.index:
                weight = w.loc[indexName][0]
                if weight < 0.001:
                    weight = 0
            else:
                weight = 0
            result[cat] = weight
        if 'bitcoin' in categNames:
            result['bitcoin'] = w.loc['BTC'][0]
        if 'USDCUSDT' in categNames:
            result['USDCUSDT'] = w.loc['USDCUSDT'][0]
        return result

# %%
from typing import Dict
from dateutil.parser import parse
import datetime

#falta levar em consideração o perdido mensalmente com rebalance dos índices, mas isso sera feito so quando for comprar as assets subjacentes
async def simulateDailyRebal(startValue: float, isoInstantStart: str, isoInstantEnd: str, 
                             categNames: [str], discountSell: float, 
                             discountBuy: float) -> Dict[str, object]:
    wallet = {}
    wallet['portfolio'] = {}
    wallet['totalValue'] = 0.0
    wallet['pocketMoney'] = 0.0

    async def categIndexVals(categNames: [str], isoInstant) -> Dict[str, float]:
        categIndexIds = categs2IndexIds(categNames)
        indices = await getDailyIndices(str(isoInstant), categNames)
        result = {}
        for cat in categNames:
            if cat == 'bitcoin':
                indexVal = float(dfBTCIndex.loc[isoInstant[:10]])
            elif cat == 'USDCUSDT':
                indexVal = await getSymb(str(isoInstant), str(parse(isoInstant) + datetime.timedelta(days = 1)), 'USDCUSDT')
                indexVal = indexVal['USDCUSDT'][0]
            else:
                indexId = categIndexIds[cat]
                indices = await getDailyIndices(isoInstant, categNames)
                if indexId in indices:
                    indexData = indices[indexId]
                    indexVal = indexData.indexValue
                else:
                    indexVal = 0
            result[cat] = indexVal
        return result
    
    lostToRebal = startValue*discountBuy
    startIndices = await categIndexVals(categNames, isoInstantStart)
    categWeights = await computeOptimalWeights(isoInstantStart, categNames)
    for cat in categWeights:
        buyCat = categWeights[cat]*startValue
        buyCat *= 1.0 - discountSell
        print(startIndices)
        if(buyCat > 0):
            wallet['portfolio'][cat] = buyCat/startIndices[cat]
            wallet['totalValue'] += buyCat
        else:
            wallet['portfolio'][cat] = 0
    result = {}
    result['days'] = {}
    result['days'][isoInstantStart] = wallet
    print(f"{isoInstantStart},{wallet}")
    currentDay = parse(isoInstantStart) + datetime.timedelta(days = 1)
    while (currentDay < parse(isoInstantEnd)):
        print(f"Today is {currentDay}")
        currIndices = await categIndexVals(categNames, str(currentDay))
        currWalletVals = {}
        totalValue = 0.0
        for cat in wallet['portfolio']:
            currWalletVals[cat] = wallet['portfolio'][cat]*currIndices[cat]
            totalValue += currWalletVals[cat]
        pocketMoney = 0.0
        if 'pocketMoney' in wallet:
            pocketMoney += wallet['pocketMoney']
            
        newWeights = await computeOptimalWeights(currentDay, categNames)
        print(f"START wallet (assetValue, pocketMoney): ({totalValue}, {pocketMoney})")
        
        if newWeights is not None:
            print(newWeights)
            categWeights = newWeights
            #selling excess
            excessCats = set()
            newPocketMoney = pocketMoney
            newTotalValue = totalValue
            for cat in wallet['portfolio']:
                excessWeight = (currWalletVals[cat]/(totalValue+pocketMoney)) - categWeights[cat]
                if excessWeight > 0:
                    excessCats.add(cat)
                    sellAmount = excessWeight*(totalValue+pocketMoney) #will sell this amount
                    newPocketMoney += sellAmount*(1.0 - discountSell) #but will receive less trade tax
                    currWalletVals[cat] -= sellAmount
                    lostToRebal += sellAmount*(discountSell) 
                    newTotalValue -= sellAmount
            notExcessCats = set(wallet['portfolio'].keys()) - excessCats
            for cat in notExcessCats:
                missingWeight = categWeights[cat] - (currWalletVals[cat]/(totalValue+pocketMoney))
                if missingWeight > 0:
                    buyAmount = missingWeight*(totalValue+pocketMoney)
                    if newPocketMoney < buyAmount:
                        print(f"Warning: {newPocketMoney} of new pocket money cannot buy {buyAmount}, buying MAX")
                        buyAmount = newPocketMoney
                    currWalletVals[cat] += buyAmount*(1.0 - discountBuy)
                    newPocketMoney -= buyAmount
                    lostToRebal += buyAmount*discountBuy
                    newTotalValue += buyAmount*(1.0 - discountBuy)
            newWallet = {}
            newWallet['totalValue'] = newTotalValue
            newWallet['pocketMoney'] = newPocketMoney
            newWallet['portfolio'] = {}
            for cat in categWeights:
                if currIndices[cat] != 0:
                    newWallet['portfolio'][cat] = currWalletVals[cat]/currIndices[cat]
                else:
                    newWallet['portfolio'][cat] = 0
        else:
            print("WARNING: inexistent optimal portfolio, keeping stablecoins")
            newWallet = {}
            newWallet['totalValue'] = 0
            newWallet['pocketMoney'] = pocketMoney + (totalValue*(1.0 - discountSell))
            newWallet['portfolio'] = {}
            for cat in categWeights:
                newWallet['portfolio'][cat] = 0
            
        
        wallet = newWallet
        result['days'][str(currentDay)] = wallet
        print(f"{currentDay},{wallet}")
        currentDay += datetime.timedelta(days = 1)
    result['totalLostToRebal'] = lostToRebal
    return result

# %%
result = await simulateDailyRebal(1000, '2021-01-01T00:00:00.000000Z', "2022-08-30T00:00:00.000000Z", categories, 0.001, 0.001)
# Out:
# {'bitcoin': 1563.1096469163806, 'smart-contract-platform': 1139.46, 'centralized-exchange-token-cex': 1190.09, 'decentralized-finance-defi': 971.8, 'non-fungible-tokens-nft': 2371.51, 'meme-token': 1296.95, 'gaming': 867.75, 'Other': 675.68, 'sports': 0}
# {'bitcoin': 1563.1096469163806, 'smart-contract-platform': 1139.46, 'centralized-exchange-token-cex': 1190.09, 'decentralized-finance-defi': 971.8, 'non-fungible-tokens-nft': 2371.51, 'meme-token': 1296.95, 'gaming': 867.75, 'Other': 675.68, 'sports': 0}
# {'bitcoin': 1563.1096469163806, 'smart-contract-platform': 1139.46, 'centralized-exchange-token-cex': 1190.09, 'decentralized-finance-defi': 971.8, 'non-fungible-tokens-nft': 2371.51, 'meme-token': 1296.95, 'gaming': 867.75, 'Other': 675.68, 'sports': 0}
# {'bitcoin': 1563.1096469163806, 'smart-contract-platform': 1139.46, 'centralized-exchange-token-cex': 1190.09, 'decentralized-finance-defi': 971.8, 'non-fungible-tokens-nft': 2371.51, 'meme-token': 1296.95, 'gaming': 867.75, 'Other': 675.68, 'sports': 0}
# {'bitcoin': 1563.1096469163806, 'smart-contract-platform': 1139.46, 'centralized-exchange-token-cex': 1190.09, 'decentralized-finance-defi': 971.8, 'non-fungible-tokens-nft': 2371.51, 'meme-token': 1296.95, 'gaming': 867.75, 'Other': 675.68, 'sports': 0}
# {'bitcoin': 1563.1096469163806, 'smart-contract-platform': 1139.46, 'centralized-exchange-token-cex': 1190.09, 'decentralized-finance-defi': 971.8, 'non-fungible-tokens-nft': 2371.51, 'meme-token': 1296.95, 'gaming': 867.75, 'Other': 675.68, 'sports': 0}
# {'bitcoin': 1563.1096469163806, 'smart-contract-platform': 1139.46, 'centralized-exchange-token-cex': 1190.09, 'decentralized-finance-defi': 971.8, 'non-fungible-tokens-nft': 2371.51, 'meme-token': 1296.95, 'gaming': 867.75, 'Other': 675.68, 'sports': 0}
# {'bitcoin': 1563.1096469163806, 'smart-contract-platform': 1139.46, 'centralized-exchange-token-cex': 1190.09, 'decentralized-finance-defi': 971.8, 'non-fungible-tokens-nft': 2371.51, 'meme-token': 1296.95, 'gaming': 867.75, 'Other': 675.68, 'sports': 0}
# {'bitcoin': 1563.1096469163806, 'smart-contract-platform': 1139.46, 'centralized-exchange-token-cex': 1190.09, 'decentralized-finance-defi': 971.8, 'non-fungible-tokens-nft': 2371.51, 'meme-token': 1296.95, 'gaming': 867.75, 'Other': 675.68, 'sports': 0}
# 2021-01-01T00:00:00.000000Z,{'portfolio': {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.08795212319517176, 'meme-token': 0.07125589155926419, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.44654910651687835}, 'totalValue': 998.9998844547924, 'pocketMoney': 0.0}
# Today is 2021-01-02 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1097.4461488683955, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.27461302503783613, 'meme-token': 0.09520459786669982, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.6301823660555893}
# Warning: 81.83384483658388 of new pocket money cannot buy 81.91574848151292, buying MAX
# 2021-01-02 00:00:00+00:00,{'totalValue': 1097.282399262962, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 0.0, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.12071596522393402, 'meme-token': 0.06632930376039486, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.4033050007682579}}
# Today is 2021-01-03 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1259.2092242325127, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.26717026181509196, 'meme-token': 0.15202033917660673, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.5808093538738299}
# Warning: 22.08645587536059 of new pocket money cannot buy 22.108507606057696, buying MAX
# 2021-01-03 00:00:00+00:00,{'totalValue': 1259.1650292121976, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex':
 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.11051455427014549, 'centralized-exchange-token-cex': 0.19085979135649664, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.09126468250717878, 'meme-token': 0.0072665991102024, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.30598150567232235}}
# Today is 2021-01-08 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1395.3214235865923, 0.0)
# {'smart-contract-platform': 0.07936572703020953, 'centralized-exchange-token-cex': 0.26872509521428206, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.06778321186761337, 'meme-token': 0.01255297018884354, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.5715729896900745}
# Warning: 100.07836916696658 of new pocket money cannot buy 100.3144598416631, buying MAX
# 2021-01-08 00:00:00+00:00,{'totalValue': 1394.8494615673499, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.06085289080935748, 'centralized-exchange-token-cex': 0.260338373962092, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.036257587646112345, 'meme-token': 0.006443949580642953, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.36870373769370673}}
# Today is 2021-01-09 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1373.7467221775728, 0.0)
# {'smart-contract-platform': 0.03595495164905139, 'centralized-exchange-token-cex': 0.27655022048594563, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.054490167095038206, 'meme-token': 0.010095087887153156, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.6229095520793495}
# Warning: 15.488022591346109 of new pocket money cannot buy 15.571611317584393, buying MAX
# 2021-01-09 00:00:00+00:00,{'totalValue': 1373.5795711850255, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.027424860759641678, 'centralized-exchange-token-cex': 0.2713942908517616, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0287263465771684, 'meme-token': 0.005061625233159175, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.40052349193265635}}
# Today is 2021-01-10 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1349.342613174867, 0.0)
# {'smart-contract-platform': 0.05402162225921881, 'centralized-exchange-token-cex': 0.21463127992823033, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.06384289548676328, 'meme-token': 0.002202203800932189, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.6653019857038958}
# Warning: 20.668948154831373 of new pocket money cannot buy 20.783150520589533, buying MAX
# 2021-01-10 00:00:00+00:00,{'totalValue': 1349.114288063282, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.038291689805531694, 'centralized-exchange-token-cex': 0.20024970242172843, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.03249456413369278, 'meme-token': 0.0010519239717129989, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.44152323349231376}}
# Today is 2021-01-11 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1270.626284874265, 0.0)
# {'smart-contract-platform': 0.04378962203069318, 'centralized-exchange-token-cex': 0.23798756313606856, 'decentralized-finance-defi': 0.06676338119811148, 'non-fungible-tokens-nft': 0.06855457201103266, 'meme-token': 0.004014337171031152, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.578890521822449}
# Warning: 21.920858084712332 of new pocket money cannot buy 22.03365731832148, buying MAX
# 2021-01-11 00:00:00+00:00,{'totalValue': 1270.400792524568, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.030024846885236912, 'centralized-exchange-token-cex': 0.21589124181434127, 'decentralized-finance-defi': 0.05803837589227585, 'non-fungible-tokens-nft': 0.03393494584721138, 'meme-token': 0.001872660063109122, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.3898556383144357}}
# Today is 2021-01-12 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1189.0356828507893, 0.0)
# {'smart-contract-platform': 0.16750168379040417, 'centralized-exchange-token-cex': 0.19598742998564325, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.11011416898729277, 'meme-token': 0.011005554636821204, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.5153911316954207}
# Warning: 8.27119342524989 of new pocket money cannot buy 8.48166914897734, buying MAX
# 2021-01-12 00:00:00+00:00,{'totalValue': 1188.614868422893, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.12286996847011383, 'centralized-exchange-token-cex': 0.18438438406401864, 'decentralized-finance-defi': -1.0842104443547393e-17, 'non-fungible-tokens-nft': 0.05591340264918741, 'meme-token': 0.005233333844004242, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.33771203722407883}}
# Today is 2021-01-13 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1243.7247636893958, 0.0)
# {'smart-contract-platform': 0.14544398133254827, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.10474628877574339, 'meme-token': 0.02291035256658224, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.7268993642181785}
# Warning: 16.46214140458109 of new pocket money cannot buy 16.710327348707327, buying MAX
# 2021-01-13 00:00:00+00:00,{'totalValue': 1243.228607400518, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.11448443813074725, 'centralized-exchange-token-cex': 0.0, 'decentralized-finance-defi': -1.0842104443547101e-20, 'non-fungible-tokens-nft': 0.05508969221577927, 'meme-token': 0.012537038733743285, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.45383277837451463}}
# Today is 2021-01-14 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1322.491327908269, 0.0)
# {'smart-contract-platform': 0.18727741389569297, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.14691429673168313, 'meme-token': 0.023480756150860774, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.6423274651432794}
# Warning: 0.729896387915133 of new pocket money cannot buy 0.8270482175110846, buying MAX
# 2021-01-14 00:00:00+00:00,{'totalValue': 1322.2969414245313, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.1438451086411871, 'centralized-exchange-token-cex': 0.0, 'decentralized-finance-defi': -1.084210444354738e-23, 'non-fungible-tokens-nft': 0.07207442503538417, 'meme-token': 0.012839479479480307, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.40721729814684055}}
# Today is 2021-01-15 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1302.3381640117993, 0.0)
# {'smart-contract-platform': 0.19159838212999514, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.14759424311976052, 'meme-token': 0.022482374419148115, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.638324933464775}
# Warning: 33.94027001102306 of new pocket money cannot buy 33.97415717271633, buying MAX
# Warning: 0.0 of new pocket money cannot buy 1.7305516586523718e-20, buying MAX
# 2021-01-15 00:00:00+00:00,{'totalValue': 1302.270249497533, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.13308898980777917, 'centralized-exchange-token-cex': 0.0, 'decentralized-finance-defi': -1.084210444354738e-23, 'non-fungible-tokens-nft': 0.06867024000346537, 'meme-token': 0.011202334698057244, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.42453391432672577}}
# Today is 2021-01-16 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1262.5831206648072, 0.0)
# {'smart-contract-platform': 0.21862657097255964, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.14532816677766933, 'meme-token': 0.025435018395157175, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.61061011464439}
# Warning: 3.001205943337041 of new pocket money cannot buy 3.044438498147656, buying MAX
# 2021-01-16 00:00:00+00:00,{'totalValue': 1262.4963726735837, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.1549438319585723, 'centralized-exchange-token-cex': 0.0, 'decentralized-finance-defi': -1.0842104443547925e-26, 'non-fungible-tokens-nft': 0.06919122111515842, 'meme-token': 0.012357738960735264, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.4019108026617204}}
# Today is 2021-01-17 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1279.50318946879, 0.0)
# {'smart-contract-platform': 0.02034890829114588, 'centralized-exchange-token-cex': 0.05054345474219741, 'decentralized-finance-defi': 0.34477986516341336, 'non-fungible-tokens-nft': 0.2141647032141171, 'meme-token': 0.041026880440898895, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.32913618726698235}
# Warning: 64.0532575642563 of new pocket money cannot buy 64.67051154941302, buying MAX
# 2021-01-17 00:00:00+00:00,{'totalValue': 1278.2692964984772, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.01358132840608064, 'centralized-exchange-token-cex': 0.04495644412284457, 'decentralized-finance-defi': 0.2512403884592078, 'non-fungible-tokens-nft': 0.1034519832183604, 'meme-token': 0.020348542742317722, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.2205640308853874}}
# Today is 2021-01-18 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1322.643268793688, 0.0)
# {'smart-contract-platform': 0.219340656668498, 'centralized-exchange-token-cex': 0.12034288763828624, 'decentralized-finance-defi': 0.2295436722223137, 'non-fungible-tokens-nft': 0.24059812883664553, 'meme-token': 0.04923935932007827, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.14093527949178714}
# Warning: 90.70374638968843 of new pocket money cannot buy 91.11924168434213, buying MAX
# 2021-01-18 00:00:00+00:00,{'totalValue': 1321.8126518658444, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.1502919426217409, 'centralized-exchange-token-cex': 0.10481760909608846, 'decentralized-finance-defi': 0.1605973080551545, 'non-fungible-tokens-nft': 0.12138470440365892, 'meme-token': 0.025627951617989937, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.0954900485803674}}
# Today is 2021-01-19 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1331.9901185841438, 0.0)
# {'smart-contract-platform': 0.1789563117564909, 'centralized-exchange-token-cex': 0.04161418559685788, 'decentralized-finance-defi': 0.40169509623486566, 'non-fungible-tokens-nft': 0.2662505204910795, 'meme-token': 0.05256479753347396, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.058919085870620364}
# Warning: 3.8564374114097575 of new pocket money cannot buy 4.119664022690685, buying MAX
# 2021-01-19 00:00:00+00:00,{'totalValue': 1331.4639218873417, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.1216318606546291, 'centralized-exchange-token-cex': 0.03669552012071346, 'decentralized-finance-defi': 0.2823000547799632, 'non-fungible-tokens-nft': 0.13190501119725298, 'meme-token': 0.02712627577579519, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.041031099815331463}}
# Today is 2021-01-20 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1306.2742723109695, 0.0)
# {'smart-contract-platform': 0.14621747751797218, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0.41499201486175274, 'non-fungible-tokens-nft': 0.23642940129371245, 'meme-token': 0.002516956533765328, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 0.19984412763487377}
# Warning: 35.44771992302043 of new pocket money cannot buy 35.66685495697965, buying MAX
# 2021-01-20 00:00:00+00:00,{'totalValue': 1305.836163518379, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.09203361828910807, 'centralized-exchange-token-cex': 0.0, 'decentralized-finance-defi': 0.30204010718061286, 'non-fungible-tokens-nft': 0.11679037824235367, 'meme-token': 0.0012984004409500953, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.1380157060553934}}
# Today is 2021-01-21 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1306.4122178589134, 0.0)
# {'smart-contract-platform': 0.2946845947942239, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0.16251709778209422, 'non-fungible-tokens-nft': 0.20718361894869752, 'meme-token': 0, 'gaming': 0.20088894426244147, 'Other': 0, 'sports': 0, 'bitcoin': 0.13472573737904528}
# Warning: 261.99046951541277 of new pocket money cannot buy 262.4437712172318, buying MAX
# 2021-01-21 00:00:00+00:00,{'totalValue': 1305.5060499111744, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.1824378011070515, 'centralized-exchange-token-cex': 0.0, 'decentralized-finance-defi': 0.11321558683817587, 'non-fungible-tokens-nft': 0.1001299261363752, 'meme-token': 0.0, 'gaming': 0.12882240441300258, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.10705857222229799}}
# Today is 2021-01-22 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1144.3162940669604, 0.0)
# {'smart-contract-platform': 0.2978516706486208, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0.18363362751583706, 'non-fungible-tokens-nft': 0.20373028399120321, 'meme-token': 0.008519494685425299, 'gaming': 0.23596849739861167, 'Other': 0, 'sports': 0, 'bitcoin': 0.07029638839510714}
# Warning: 9.640997292096436 of new pocket money cannot buy 9.748996585749042, buying MAX
# 2021-01-22 00:00:00+00:00,{'totalValue': 1144.1003180065038, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.1969871007252651, 'centralized-exchange-token-cex': 0.0, 'decentralized-finance-defi': 0.13498126556556653, 'non-fungible-tokens-nft': 0.09990567193168391, 'meme-token': 0.004226837425636718, 'gaming': 0.15066711310001812, 'Other': 0.0, 'sports': 0, 'bitcoin': 0.04581787942393681}}
# Today is 2021-01-23 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1265.2825915609062, 0.0)
# {'smart-contract-platform': 0.16152527545430173, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0.22460435251986377, 'non-fungible-tokens-nft': 0.0829636949968301, 'meme-token': 0.10268828691551263, 'gaming': 0.4282181411937215, 'Other': 0, 'sports': 0, 'bitcoin': 7.700178128341181e-08}
# Warning: 119.56545841289235 of new pocket money cannot buy 119.96746866292654, buying MAX
# 2021-01-23 00:00:00+00:00,{'totalValue': 1264.478538238935, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.1070194895163681, 'centralized-exchange-token-cex': 0.0, 'decentralized-finance-defi': 0.15794522754129367, 'non-fungible-tokens-nft': 0.04079644589793468, 'meme-token': 0.05490607411555969, 'gaming': 0.2711690191394685, 'Other': 0.0, 'sports': 0, 'bitcoin': 5.699393786738529e-08}}
# Today is 2021-01-24 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1342.5029044829084, 0.0)
# {'smart-contract-platform': 0.15310786761735098, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0.25444847190363984, 'non-fungible-tokens-nft': 0.08699121166053891, 'meme-token': 0.09278115599094673, 'gaming': 0.41267122774783227, 'Other': 0, 'sports': 0, 'bitcoin': 2.134681187896175e-08}
# Warning: 32.56226644879928 of new pocket money cannot buy 32.60324612373977, buying MAX
# 2021-01-24 00:00:00+00:00,{'totalValue': 1342.4208687483786, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.10655884879700893, 'centralized-exchange-token-cex': 0.0, 'decentralized-finance-defi': 0.17457306533142752, 'non-fungible-tokens-nft': 0.04396926048787339, 'meme-token': 0.05248013288635859, 'gaming': 0.25531933648312005, 'Other': 0.0, 'sports': 0, 'bitcoin': 1.6669895716381294e-08}}
# Today is 2021-01-25 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (1383.5069381726332, 0.0)
# {'smart-contract-platform': 0.025316844967848362, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0.3800391601318095, 'non-fungible-tokens-nft': 0.03160058147641062, 'meme-token': 0.10742666168557544, 'gaming': 0.4556166505267274, 'Other': 0, 'sports': 0, 'bitcoin': 2.983434688437258e-08}
# Warning: 20.31828258785505 of new pocket money cannot buy 20.580829961278095, buying MAX
# 2021-01-25 00:00:00+00:00,{'totalValue': 1382.9819085699817, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.016596396361769062, 'centralized-exchange-token-cex': 0.0, 'decentralized-finance-defi': 0.24696717202924207, 'non-fungible-tokens-nft': 0.016500088208639484, 'meme-token': 0.06079941395677102, 'gaming': 0.2966129374165225, 'Other': 0.0, 'sports': 0, 'bitcoin': 2.4006365259174467e-08}}
# Today is 2021-01-26 00:00:00+00:00
# START wallet (assetValue, pocketMoney):
 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 0.14044764205026, 'decentralized-finance-defi': 0.3754251132326299, 'non-fungible-tokens-nft': 0.16351640171481466, 'meme-token': 0.006977147810896046, 'gaming': 0.12013599559697548, 'Other': 0.7892561014094344, 'sports': 0, 'bitcoin': 5.047933013754511e-08}}
# Today is 2021-02-22 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (5286.088720677173, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.18390613927546937, 'decentralized-finance-defi': 0.5011556181113156, 'non-fungible-tokens-nft': 0.19931437670650728, 'meme-token': 0.0197998370848279, 'gaming': 0, 'Other': 0.09227953949929597, 'sports': 0, 'bitcoin': 0.003544478671969121}
# Warning: 1283.1141786074254 of new pocket money cannot buy 1284.6404521491702, buying MAX
# 2021-02-22 00:00:00+00:00,{'totalValue': 5283.037587323337, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 0.1055770710712142, 'decentralized-finance-defi': 0.7281016437887927, 'non-fungible-tokens-nft': 0.20736211736679894, 'meme-token': 0.006720329948803395, 'gaming': 0.0, 'Other': 0.30584278488492417, 'sports': 0, 'bitcoin': 0.0064938413880514505}}
# ...
# Warning: 1156.3201523497348 of new pocket money cannot buy 1157.475666061521, buying MAX
# 2022-08-10 00:00:00+00:00,{'totalValue': 12180.636950725326, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 1.0925555831371279, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.49737820851391695, 'meme-token': 0.0, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 3.5037072576769806e-07}}
# Today is 2022-08-11 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (12401.635094500125, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.9280988001679226, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.07190112026912371, 'meme-token': 0, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 1.0873346874492138e-08}
# Warning: 497.3812416245832 of new pocket money cannot buy 497.878268881891, buying MAX
# 2022-08-11 00:00:00+00:00,{'totalValue': 12400.639834137755, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 1.1418536272620425, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.3191691059326002, 'meme-token': 0.0, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 1.0572251137118908e-07}}
# Today is 2022-08-12 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (12187.467103121691, 0.0)
# {'smart-contract-platform': 0.03413699097941013, 'centralized-exchange-token-cex': 0.8115463263564404, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.15431666477663358, 'meme-token': 0, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 3.781505401499144e-09}
# Warning: 414.6176490308525 of new pocket money cannot buy 416.04345456112287, buying MAX
# 2022-08-12 00:00:00+00:00,{'totalValue': 12184.616574205524, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.16297196658029778, 'centralized-exchange-token-cex': 0.9979723266387823, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.6889658623652463, 'meme-token': 0.0, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 3.5438106010280204e-08}}
# Today is 2022-08-13 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (12373.827019549957, 0.0)
# {'smart-contract-platform': 0.14633684390288554, 'centralized-exchange-token-cex': 0.7452352401861014, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.10842771589783896, 'meme-token': 0, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 4.5538341359770025e-08}
# Warning: 1379.3468858965916 of new pocket money cannot buy 1380.7257025830843, buying MAX
# 2022-08-13 00:00:00+00:00,{'totalValue': 12371.066944015382, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.6852023517857063, 'centralized-exchange-token-cex': 0.9175689490205888, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.48285850040659684, 'meme-token': 0.0, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 4.322194102888327e-07}}
# Today is 2022-08-14 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (12278.221606263747, 0.0)
# {'smart-contract-platform': 0.15783315596959827, 'centralized-exchange-token-cex': 0.6885752551152372, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.15359143324787844, 'meme-token': 0, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 4.010601581770463e-08}
# Warning: 104.71878975804259 of new pocket money cannot buy 105.39159214798869, buying MAX
# 2022-08-14 00:00:00+00:00,{'totalValue': 12276.87383793136, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.7243188970434761, 'centralized-exchange-token-cex': 0.8497997821739606, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.691202168268978, 'meme-token': 0.0, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 3.801830211372783e-07}}
# Today is 2022-08-15 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (12027.348183472392, 0.0)
# {'smart-contract-platform': 0.20505577807752853, 'centralized-exchange-token-cex': 0.6538465674860516, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.14109750648929628, 'meme-token': 0, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 3.752852476715738e-08}
# Warning: 573.3563305266123 of new pocket money cannot buy 573.9289327444653, buying MAX
# 2022-08-15 00:00:00+00:00,{'totalValue': 12026.200896881077, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.9435584157571225, 'centralized-exchange-token-cex': 0.8066898625457397, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.6338085902075143, 'meme-token': 0.0, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 3.51524284712128e-07}}
# Today is 2022-08-16 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (11990.613121179125, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.4918468323460641, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.16199659813389555, 'meme-token': 0.3461563522068401, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 2.0653065848749626e-08}
# Warning: 4146.205824665528 of new pocket money cannot buy 4150.626898750839, buying MAX
# 2022-08-16 00:00:00+00:00,{'totalValue': 11981.770680289486, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 0.601706198372177, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.7372634494556776, 'meme-token': 0.12536291371786676, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 1.9480445112133344e-07}}
# Today is 2022-08-17 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (12273.151345370215, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.6882873681196027, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.08032441202172955, 'meme-token': 0.23138779544316154, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 5.5183920996882897e-08}
# Warning: 2607.1624480928112 of new pocket money cannot buy 2609.7676891133865, buying MAX
# 2022-08-17 00:00:00+00:00,{'totalValue': 12267.934409831465, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 0.8701647446600362, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.3759982857804279, 'meme-token': 0.07907133937550796, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 5.441103004179868e-07}}
# Today is 2022-08-18 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (11801.866944796859, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.638683046458875, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0.017875391641789508, 'meme-token': 0.34344126891252513, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 6.737275606313421e-08}
# Warning: 1413.9001803837618 of new pocket money cannot buy 1415.3128333353854, buying MAX
# 2022-08-18 00:00:00+00:00,{'totalValue': 11799.037728875133, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 0.7996015952676373, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.08253250776275517, 'meme-token': 0.12141020224911656, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 6.432687325971759e-07}}
# Today is 2022-08-19 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (11274.92602583926, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.700341854662701, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0, 'meme-token': 0.299657642689178, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 1.5398261049754716e-08}
# Warning: 561.1289100916641 of new pocket money cannot buy 561.6851069862298, buying MAX
# 2022-08-19 00:00:00+00:00,{'totalValue': 11273.803206328477, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 0.860713288176439, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0, 'meme-token': 0.10971351286293271, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 1.5636956669556975e-07}}
# Today is 2022-08-20 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (10526.961401747867, 0.0)
# {'smart-contract-platform': 0.18336091832676163, 'centralized-exchange-token-cex': 0.7288410188415151, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0, 'meme-token': 0.08779796329428687, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 6.828525625985878e-09}
# Warning: 310.20277913795917 of new pocket money cannot buy 312.44448196255365, buying MAX
# 2022-08-20 00:00:00+00:00,{'totalValue': 10522.478286891193, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.8959100683465661, 'centralized-exchange-token-cex': 0.8969534138632018, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0, 'meme-token': 0.03201915687123802, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 6.380742167991392e-08}}
# Today is 2022-08-21 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (10617.776573798703, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.7691747620741473, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0, 'meme-token': 0.2308252374599467, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 4.385081273463111e-11}
# Warning: 372.3591098730308 of new pocket money cannot buy 374.25729700354486, buying MAX
# 2022-08-21 00:00:00+00:00,{'totalValue': 10613.982088766708, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 0.9397699133933728, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0, 'meme-token': 0.08460889634611671, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 4.060740237775755e-10}}
# Today is 2022-08-22 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (11172.654624059265, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.7775264500561536, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0, 'meme-token': 0.22247354880514444, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 1.424441057875919e-10}
# Warning: 14.982501270449774 of new pocket money cannot buy 14.997487639502628, buying MAX
# 2022-08-22 00:00:00+00:00,{'totalValue': 11172.624644056968, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 0.941391911064459, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0, 'meme-token': 0.0841014529439896, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 1.3945373327437377e-09}}
# Today is 2022-08-23 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (11076.776646238937, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.9088322470262846, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0, 'meme-token': 0.09116773419978463, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 3.3038576644850975e-09}
# Warning: 1428.9462777147485 of new pocket money cannot buy 1430.3764830456046, buying MAX
# 2022-08-23 00:00:00+00:00,{'totalValue': 11073.917323236825, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 1.0969925200998705, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0, 'meme-token': 0.03480397450422359, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 3.186695638854251e-08}}
# Today is 2022-08-24 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (11063.204916451974, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.9156350196443358, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0, 'meme-token': 0.08436488467688054, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 1.6492256391156664e-08}
# Warning: 85.58886915994839 of new pocket money cannot buy 85.67366779318934, buying MAX
# 2022-08-24 00:00:00+00:00,{'totalValue': 11063.033652746624, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 1.1063309051007921, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0, 'meme-token': 0.03187781241937591, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 1.6010139507588948e-07}}
# Today is 2022-08-25 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (10950.416833693273, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.8299746893952632, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0, 'meme-token': 0.17002526523342204, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 5.685286770958491e-09}
# Warning: 942.718423377428 of new pocket money cannot buy 943.6616508843423, buying MAX
# 2022-08-25 00:00:00+00:00,{'totalValue': 10948.530453184432, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 1.0022660746550223, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0, 'meme-token': 0.06457462257384267, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 5.41877666129485e-08}}
# Today is 2022-08-26 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (11169.034793699542, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.8340667217008794, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0, 'meme-token': 0.16593294583409082, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 3.419589992428083e-08}
# Warning: 79.42141666951609 of new pocket money cannot buy 79.49758653262175, buying MAX
# 2022-08-26 00:00:00+00:00,{'totalValue': 11168.875870717991, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 1.010875848711416, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0, 'meme-token': 0.06191851198127795, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 3.5378246164121026e-07}}
# Today is 2022-08-27 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (10327.705763369135, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.7750027461147628, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0, 'meme-token': 0.22499708037271057, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 2.326957116899135e-08}
# Warning: 641.4597120611323 of new pocket money cannot buy 642.1002622099709, buying MAX
# 2022-08-27 00:00:00+00:00,{'totalValue': 10326.422201843197, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 0.9358032811193561, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0, 'meme-token': 0.08551415473063224, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 2.25057855558237e-07}}
# Today is 2022-08-28 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (10254.564359368314, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0.6352115308431255, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0, 'meme-token': 0.36478846915659036, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 4.333462253241421e-14}
# Warning: 1439.8179825939685 of new pocket money cannot buy 1441.2592418333356, buying MAX
# 2022-08-28 00:00:00+00:00,{'totalValue': 10251.683282143886, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': 0.766259354983496, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0, 'meme-token': 0.13900506867200163, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 4.264111071307907e-13}}
# Today is 2022-08-29 00:00:00+00:00
# START wallet (assetValue, pocketMoney): (10107.746096061346, 0.0)
# {'smart-contract-platform': 0, 'centralized-exchange-token-cex': 0, 'decentralized-finance-defi': 0, 'non-fungible-tokens-nft': 0, 'meme-token': 0.99999999999968, 'gaming': 0, 'Other': 0, 'sports': 0, 'bitcoin': 2.8884770765998074e-14}
# Warning: 6469.105601847165 of new pocket money cannot buy 6475.5811830272505, buying MAX
# 2022-08-29 00:00:00+00:00,{'totalValue': 10094.801409276468, 'pocketMoney': 0.0, 'portfolio': {'smart-contract-platform': 0.0, 'centralized-exchange-token-cex': -1.0762104648888618e-16, 'decentralized-finance-defi': 0.0, 'non-fungible-tokens-nft': 0.0, 'meme-token': 0.3863339349191966, 'gaming': 0.0, 'Other': 0.0, 'sports': 0, 'bitcoin': 2.700724296472373e-13}}

# %%
import csv
with open('Historical-ONN-PortfolioOptDaily-B-30dW-30dR_2020-12-01_2022-08-30.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['Date', 'Close'])
    for key in result['days']:
        vals = []
        vals.append(key)
        vals.append(result['days'][key]['totalValue']+result['days'][key]['pocketMoney'])
        writer.writerow(vals)
